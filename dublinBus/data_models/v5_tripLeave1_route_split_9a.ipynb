# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave1 route split 9a CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_9a.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (77446, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-02  5964210            1         4664            27000
# 1   2018-01-02  5964210            2         2160            27058
# 2   2018-01-02  5964210            3         4665            27099
# 3   2018-01-02  5964210            4         4666            27143
# 4   2018-01-02  5964210            5         4667            27179
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            27000           27000           27000    1932306  2018  ...
# 1            27058           27058           27058    1932306  2018  ...
# 2            27099           27099           27099    1932306  2018  ...
# 3            27143           27143           27143    1932306  2018  ...
# 4            27179           27179           27179    1932306  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 0  20180102596421001  201801025964210     51D          90         2
# 1  20180102596421002  201801025964210     51D          90         2
# 2  20180102596421003  201801025964210     51D          90         2
# 3  20180102596421004  201801025964210     51D          90         2
# 4  20180102596421005  201801025964210     51D          90         2
#
#    actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 0             3801          1        0         1               8
# 1             3801          1        0         1               8
# 2             3801          1        0         1               8
# 3             3801          1        0         1               8
# 4             3801          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-02  5964210            1         4664            27000
# 1   2018-01-02  5964210            2         2160            27058
# 2   2018-01-02  5964210            3         4665            27099
# 3   2018-01-02  5964210            4         4666            27143
# 4   2018-01-02  5964210            5         4667            27179
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            27000           27000           27000    1932306  2018  ...
# 1            27058           27058           27058    1932306  2018  ...
# 2            27099           27099           27099    1932306  2018  ...
# 3            27143           27143           27143    1932306  2018  ...
# 4            27179           27179           27179    1932306  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 0  20180102596421001  201801025964210     51D          90         2
# 1  20180102596421002  201801025964210     51D          90         2
# 2  20180102596421003  201801025964210     51D          90         2
# 3  20180102596421004  201801025964210     51D          90         2
# 4  20180102596421005  201801025964210     51D          90         2
#
#    actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 0             3801          1        0         1               8
# 1             3801          1        0         1               8
# 2             3801          1        0         1               8
# 3             3801          1        0         1               8
# 4             3801          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 51D

# %%
lwk = wk[(wk['LINEID'] == '51D')]

# %%
lwk.shape
# Out:
# (5969, 22)

# %%
# Drop Route 51D rows from wk
wk.drop(wk[wk['LINEID'] == '51D'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 49   2018-01-02  5964527            1         4795            23400
# 50   2018-01-02  5964527            3         4688            23647
# 51   2018-01-02  5964527            4         4689            23698
# 52   2018-01-02  5964527            5         4410            23742
# 53   2018-01-02  5964527            6         2678            23771
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 49            23400           23400           23400    1000257  2018  ...
# 50            23647           23647           23647    1000257  2018  ...
# 51            23698           23698           23698    1000257  2018  ...
# 52            23742           23742           23742    1000257  2018  ...
# 53            23771           23771           23771    1000257  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 49  20180102596452701  201801025964527     239          36         2
# 50  20180102596452703  201801025964527     239          36         2
# 51  20180102596452704  201801025964527     239          36         2
# 52  20180102596452705  201801025964527     239          36         2
# 53  20180102596452706  201801025964527     239          36         2
#
#     actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 49             2930          1        0         0               6
# 50             2930          1        0         0               7
# 51             2930          1        0         0               7
# 52             2930          1        0         0               7
# 53             2930          1        0         0               7
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (71477, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51D_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 239

# %%
lwk = wk[(wk['LINEID'] == '239')]

# %%
lwk.shape
# Out:
# (31534, 22)

# %%
# Drop Route 239 rows from wk
wk.drop(wk[wk['LINEID'] == '239'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 267   2018-01-02  5965085            1         3085            29100
# 268   2018-01-02  5965085            2         3034            29181
# 269   2018-01-02  5965085            3         3114            29280
# 270   2018-01-02  5965085            4         4353            29366
# 271   2018-01-02  5965085            5         4355            29400
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 267            29100           29100           29100    2172286  2018  ...
# 268            29181           29181           29181    2172286  2018  ...
# 269            29280           29280           29280    2172286  2018  ...
# 270            29366           29366           29366    2172286  2018  ...
# 271            29400           29400           29400    2172286  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 267  20180102596508501  201801025965085     46E          87         2
# 268  20180102596508502  201801025965085     46E          87         2
# 269  20180102596508503  201801025965085     46E          87         2
# 270  20180102596508504  201801025965085     46E          87         2
# 271  20180102596508505  201801025965085     46E          87         2
#
#      actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 267             2903          1        0         1               8
# 268             2903          1        0         1               8
# 269             2903          1        0         1               8
# 270             2903          1        0         1               8
# 271             2903          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (39943, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_239_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 46E

# %%
lwk = wk[(wk['LINEID'] == '46E')]

# %%
lwk.shape
# Out:
# (1833, 22)

# %%
# Drop Route 46E rows from wk
wk.drop(wk[wk['LINEID'] == '46E'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 663   2018-01-02  5966175            8         3486            28359
# 664   2018-01-02  5966175            9         3487            28453
# 665   2018-01-02  5966175           10         7415            28620
# 666   2018-01-02  5966175           11         7416            28760
# 667   2018-01-02  5966175           12         3317            29141
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 663            28359           28359           28359    1932300  2018  ...
# 664            28453           28453           28453    1932300  2018  ...
# 665            28620           28620           28620    1932300  2018  ...
# 666            28760           28760           28760    1932300  2018  ...
# 667            29141           29141           29141    1932300  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 663  20180102596617508  201801025966175     118           7         2
# 664  20180102596617509  201801025966175     118           7         2
# 665  20180102596617510  201801025966175     118           7         2
# 666  20180102596617511  201801025966175     118           7         2
# 667  20180102596617512  201801025966175     118           7         2
#
#      actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 663             3845          1        0         1               8
# 664             3845          1        0         1               8
# 665             3845          1        0         1               8
# 666             3845          1        0         1               8
# 667             3845          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (38110, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46E_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 118

# %%
lwk = wk[(wk['LINEID'] == '118')]

# %%
lwk.shape
# Out:
# (2621, 22)

# %%
# Drop Route 118 rows from wk
wk.drop(wk[wk['LINEID'] == '118'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 699   2018-01-02  5966233            1         3057            19200
# 700   2018-01-02  5966233           35          772            20700
# 701   2018-01-02  5966233           36          773            20732
# 702   2018-01-02  5966233           52          281            21240
# 703   2018-01-02  5966233           53            4            21253
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 699            19200           19200           19200    2693274  2018  ...
# 700            20700           20700           20700    2693274  2018  ...
# 701            20732           20732           20732    2693274  2018  ...
# 702            21240           21240           21240    2693274  2018  ...
# 703            21253           21253           21253    2693274  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 699  20180102596623301  201801025966233      7D         123         2
# 700  20180102596623335  201801025966233      7D         123         2
# 701  20180102596623336  201801025966233      7D         123         2
# 702  20180102596623352  201801025966233      7D         123         2
# 703  20180102596623353  201801025966233      7D         123         2
#
#      actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 699             4971          1        0         0               5
# 700             4971          1        0         0               6
# 701             4971          1        0         0               6
# 702             4971          1        0         0               6
# 703             4971          1        0         0               6
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (35489, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_118_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 7D

# %%
lwk = wk[(wk['LINEID'] == '7D')]

# %%
lwk.shape
# Out:
# (4409, 22)

# %%
# Drop Route 7D rows from wk
wk.drop(wk[wk['LINEID'] == '7D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 804   2018-01-02  5967286            1         4595            27300
# 805   2018-01-02  5967286            2         4596            27349
# 806   2018-01-02  5967286            3         4563            27402
# 807   2018-01-02  5967286            4         1218            27451
# 808   2018-01-02  5967286            5         1258            27557
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 804            27300           27300           27300    1932367  2018  ...
# 805            27349           27349           27349    1932367  2018  ...
# 806            27402           27402           27402    1932367  2018  ...
# 807            27451           27451           27451    1932367  2018  ...
# 808            27557           27557           27557    1932367  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 804  20180102596728601  201801025967286     27X          47         2
# 805  20180102596728602  201801025967286     27X          47         2
# 806  20180102596728603  201801025967286     27X          47         2
# 807  20180102596728604  201801025967286     27X          47         2
# 808  20180102596728605  201801025967286     27X          47         2
#
#      actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 804             3122          1        0         1               8
# 805             3122          1        0         1               8
# 806             3122          1        0         1               8
# 807             3122          1        0         1               8
# 808             3122          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (31080, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7D_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 27X

# %%
lwk = wk[(wk['LINEID'] == '27X')]

# %%
lwk.shape
# Out:
# (6566, 22)

# %%
# Drop Route 27X rows from wk
wk.drop(wk[wk['LINEID'] == '27X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 895   2018-01-02  5967738            1         4747            25200
# 896   2018-01-02  5967738            2         2960            25249
# 897   2018-01-02  5967738            3         1545            25307
# 898   2018-01-02  5967738            4         1816            25392
# 899   2018-01-02  5967738            5         6171            25455
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 895            25200           25200           25200    1001166  2018  ...
# 896            25249           25249           25249    1001166  2018  ...
# 897            25307           25307           25307    1001166  2018  ...
# 898            25392           25392           25392    1001166  2018  ...
# 899            25455           25455           25455    1001166  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 895  20180102596773801  201801025967738     236          34         1
# 896  20180102596773802  201801025967738     236          34         1
# 897  20180102596773803  201801025967738     236          34         1
# 898  20180102596773804  201801025967738     236          34         1
# 899  20180102596773805  201801025967738     236          34         1
#
#      actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 895             1885          1        0         0               7
# 896             1885          1        0         0               7
# 897             1885          1        0         0               7
# 898             1885          1        0         0               7
# 899             1885          1        0         0               7
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (24514, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27X_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 236

# %%
lwk = wk[(wk['LINEID'] == '236')]

# %%
lwk.shape
# Out:
# (5583, 22)

# %%
# Drop Route 236 rows from wk
wk.drop(wk[wk['LINEID'] == '236'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1016   2018-01-02  5968174            1         1375            29400
# 1017   2018-01-02  5968174            2         1376            29470
# 1018   2018-01-02  5968174            3         1377            29556
# 1019   2018-01-02  5968174            4         1378            29627
# 1020   2018-01-02  5968174            5         1379            29709
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1016            29400           29400           29400    1000748  2018  ...
# 1017            29470           29470           29470    1000748  2018  ...
# 1018            29556           29556           29556    1000748  2018  ...
# 1019            29627           29627           29627    1000748  2018  ...
# 1020            29709           29709           29709    1000748  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1016  20180102596817401  201801025968174     68A         107         2
# 1017  20180102596817402  201801025968174     68A         107         2
# 1018  20180102596817403  201801025968174     68A         107         2
# 1019  20180102596817404  201801025968174     68A         107         2
# 1020  20180102596817405  201801025968174     68A         107         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1016             1479          1        0         1               8
# 1017             1479          1        0         1               8
# 1018             1479          1        0         1               8
# 1019             1479          1        0         1               8
# 1020             1479          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (18931, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_236_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 68A

# %%
lwk = wk[(wk['LINEID'] == '68A')]

# %%
lwk.shape
# Out:
# (6530, 22)

# %%
# Drop Route 68A rows from wk
wk.drop(wk[wk['LINEID'] == '68A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1286   2018-01-02  5969871            1         7333            27600
# 1287   2018-01-02  5969871            2          783            27782
# 1288   2018-01-02  5969871            3          784            27815
# 1289   2018-01-02  5969871            4          785            27872
# 1290   2018-01-02  5969871            5          786            27992
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1286            27600           27600           27600    2406865  2018  ...
# 1287            27782           27782           27782    2406865  2018  ...
# 1288            27815           27815           27815    2406865  2018  ...
# 1289            27872           27872           27872    2406865  2018  ...
# 1290            27992           27992           27992    2406865  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1286  20180102596987101  201801025969871     38D          65         1
# 1287  20180102596987102  201801025969871     38D          65         1
# 1288  20180102596987103  201801025969871     38D          65         1
# 1289  20180102596987104  201801025969871     38D          65         1
# 1290  20180102596987105  201801025969871     38D          65         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1286             2772          1        0         1               8
# 1287             2772          1        0         1               8
# 1288             2772          1        0         1               8
# 1289             2772          1        0         1               8
# 1290             2772          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12401, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68A_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 38D

# %%
lwk = wk[(wk['LINEID'] == '38D')]

# %%
lwk.shape
# Out:
# (1534, 22)

# %%
# Drop Route 38D rows from wk
wk.drop(wk[wk['LINEID'] == '38D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1316   2018-01-02  5969901            1         3333            26100
# 1317   2018-01-02  5969901            2         3334            26160
# 1318   2018-01-02  5969901            3         3352            26216
# 1319   2018-01-02  5969901            4         3335            26267
# 1320   2018-01-02  5969901            5         3336            26306
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1316            26100           26100           26100    1001157  2018  ...
# 1317            26160           26160           26160    1001157  2018  ...
# 1318            26216           26216           26216    1001157  2018  ...
# 1319            26267           26267           26267    1001157  2018  ...
# 1320            26306           26306           26306    1001157  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1316  20180102596990101  201801025969901     70D         113         2
# 1317  20180102596990102  201801025969901     70D         113         2
# 1318  20180102596990103  201801025969901     70D         113         2
# 1319  20180102596990104  201801025969901     70D         113         2
# 1320  20180102596990105  201801025969901     70D         113         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1316             2728          1        0         0               7
# 1317             2728          1        0         0               7
# 1318             2728          1        0         0               7
# 1319             2728          1        0         0               7
# 1320             2728          1        0         0               7
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (10867, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38D_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 70D

# %%
lwk = wk[(wk['LINEID'] == '70D')]

# %%
lwk.shape
# Out:
# (2805, 22)

# %%
# Drop Route 70D rows from wk
wk.drop(wk[wk['LINEID'] == '70D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1357   2018-01-02  5971378            1         7433            26700
# 1358   2018-01-02  5971378            2         4677            26810
# 1359   2018-01-02  5971378            3         2136            26847
# 1360   2018-01-02  5971378            4         2137            26871
# 1361   2018-01-02  5971378            5         2138            26931
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1357            26700           26700           26700    1001187  2018  ...
# 1358            26810           26810           26810    1001187  2018  ...
# 1359            26847           26847           26847    1001187  2018  ...
# 1360            26871           26871           26871    1001187  2018  ...
# 1361            26931           26931           26931    1001187  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1357  20180102597137801  201801025971378     51X          91         2
# 1358  20180102597137802  201801025971378     51X          91         2
# 1359  20180102597137803  201801025971378     51X          91         2
# 1360  20180102597137804  201801025971378     51X          91         2
# 1361  20180102597137805  201801025971378     51X          91         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1357             3907          1        0         0               7
# 1358             3907          1        0         0               7
# 1359             3907          1        0         0               7
# 1360             3907          1        0         0               7
# 1361             3907          1        0         0               7
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (8062, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70D_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 51X

# %%
lwk = wk[(wk['LINEID'] == '51X')]

# %%
lwk.shape
# Out:
# (1707, 22)

# %%
# Drop Route 51X rows from wk
wk.drop(wk[wk['LINEID'] == '51X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1406   2018-01-02  5971907            1          943            27000
# 1407   2018-01-02  5971907            2         3599            27051
# 1408   2018-01-02  5971907            3         3600            27086
# 1409   2018-01-02  5971907            4         3601            27128
# 1410   2018-01-02  5971907            5         3602            27166
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1406            27000           27000           27000    1000758  2018  ...
# 1407            27051           27051           27051    1000758  2018  ...
# 1408            27086           27086           27086    1000758  2018  ...
# 1409            27128           27128           27128    1000758  2018  ...
# 1410            27166           27166           27166    1000758  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1406  20180102597190701  201801025971907     42D          81         2
# 1407  20180102597190702  201801025971907     42D          81         2
# 1408  20180102597190703  201801025971907     42D          81         2
# 1409  20180102597190704  201801025971907     42D          81         2
# 1410  20180102597190705  201801025971907     42D          81         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1406             2512          1        0         1               8
# 1407             2512          1        0         1               8
# 1408             2512          1        0         1               8
# 1409             2512          1        0         1               8
# 1410             2512          1        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (6355, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51X_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 42D

# %%
lwk = wk[(wk['LINEID'] == '42D')]

# %%
lwk.shape
# Out:
# (2498, 22)

# %%
# Drop Route 42D rows from wk
wk.drop(wk[wk['LINEID'] == '42D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1586   2018-01-03  5961034            1         2955            27600
# 1587   2018-01-03  5961034            2         7067            27610
# 1588   2018-01-03  5961034            3         2956            27644
# 1589   2018-01-03  5961034            4         2965            27715
# 1590   2018-01-03  5961034            5         2967            27843
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1586            27600           27600           27600    1000576  2018  ...
# 1587            27610           27610           27610    1000576  2018  ...
# 1588            27644           27644           27644    1000576  2018  ...
# 1589            27715           27715           27715    1000576  2018  ...
# 1590            27843           27843           27843    1000576  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1586  20180103596103401  201801035961034     116           6         2
# 1587  20180103596103402  201801035961034     116           6         2
# 1588  20180103596103403  201801035961034     116           6         2
# 1589  20180103596103404  201801035961034     116           6         2
# 1590  20180103596103405  201801035961034     116           6         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1586             4898          2        0         1               8
# 1587             4898          2        0         1               8
# 1588             4898          2        0         1               8
# 1589             4898          2        0         1               8
# 1590             4898          2        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (3857, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42D_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (2794, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 12809   2018-01-10  6103748            1         6185            27000
# 12810   2018-01-10  6103748            2         6186            27064
# 12811   2018-01-10  6103748            3         6216            27173
# 12812   2018-01-10  6103748            4         3400            27261
# 12813   2018-01-10  6103748            5         3401            27314
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 12809            27000           27000           27000    2693291  2018  ...
# 12810            27064           27064           27064    2693291  2018  ...
# 12811            27173           27173           27173    2693291  2018  ...
# 12812            27261           27261           27261    2693291  2018  ...
# 12813            27314           27314           27314    2693291  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 12809  20180110610374801  201801106103748     68X         108         2
# 12810  20180110610374802  201801106103748     68X         108         2
# 12811  20180110610374803  201801106103748     68X         108         2
# 12812  20180110610374804  201801106103748     68X         108         2
# 12813  20180110610374805  201801106103748     68X         108         2
#
#        actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 12809             4731          2        0         1               8
# 12810             4731          2        0         1               8
# 12811             4731          2        0         1               8
# 12812             4731          2        0         1               8
# 12813             4731          2        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (1063, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 68X

# %%
lwk = wk[(wk['LINEID'] == '68X')]

# %%
lwk.shape
# Out:
# (334, 22)

# %%
# Drop Route 68X rows from wk
wk.drop(wk[wk['LINEID'] == '68X'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 33754   2018-01-25  6218166            4         3735            26483
# 33755   2018-01-25  6218166            5         7039            26547
# 33756   2018-01-25  6218166            6         7204            26594
# 33757   2018-01-25  6218166            7         3736            26646
# 33758   2018-01-25  6218166            8         3738            26676
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 33754            26483           26483           26483    1001231  2018  ...
# 33755            26547           26547           26547    1001231  2018  ...
# 33756            26594           26594           26594    1001231  2018  ...
# 33757            26646           26646           26646    1001231  2018  ...
# 33758            26676           26676           26676    1001231  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 33754  20180125621816604  201801256218166     33D          58         2
# 33755  20180125621816605  201801256218166     33D          58         2
# 33756  20180125621816606  201801256218166     33D          58         2
# 33757  20180125621816607  201801256218166     33D          58         2
# 33758  20180125621816608  201801256218166     33D          58         2
#
#        actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 33754             3585          3        0         0               7
# 33755             3585          3        0         0               7
# 33756             3585          3        0         0               7
# 33757             3585          3        0         0               7
# 33758             3585          3        0         0               7
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (729, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68X_tripLeave1_sp9a.csv', index=False)

# %% [markdown]
# ## Route 33D

# %%
lwk = wk[(wk['LINEID'] == '33D')]

# %%
lwk.shape
# Out:
# (729, 22)

# %%
# Drop Route 33D rows from wk
wk.drop(wk[wk['LINEID'] == '33D'].index, inplace = True)

# %%
wk.head()
# Out:
# Empty DataFrame
# Columns: [DAYOFSERVICE, TRIPID, PROGRNUMBER, STOPPOINTID, PLANNEDTIME_ARR, PLANNEDTIME_DEP, ACTUALTIME_ARR, ACTUALTIME_DEP, VEHICLEID, year, month, day, id, trip_leave_id, LINEID, num_lineID, DIRECTION, actual_duration, dayOfWeek, weekend, rushHour, actualARR_hour]
# Index: []
#
# [0 rows x 22 columns]

# %%
wk.shape
# Out:
# (0, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33D_tripLeave1_sp9a.csv', index=False)
