# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 5 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_24687/1865078263.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (9903252, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6289221            1         6122            31500
# 1   2018-02-26  6289221            2           35            31564
# 2   2018-02-26  6289221            3           36            31617
# 3   2018-02-26  6289221            4           37            31686
# 4   2018-02-26  6289221            5           38            31777
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            31500           31500           31500    1000372  2018  ...
# 1            31564           31564           31564    1000372  2018  ...
# 2            31617           31617           31617    1000372  2018  ...
# 3            31686           31686           31686    1000372  2018  ...
# 4            31777           31777           31777    1000372  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 11

# %%
lwk = wk[(wk['LINEID'] == '11')]

# %%
lwk.shape
# Out:
# (248578, 22)

# %%
# Drop Route 11 rows from wk
wk.drop(wk[wk['LINEID'] == '11'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 545   2018-02-26  6289280            1         6041            23400
# 546   2018-02-26  6289280            2         2826            23454
# 547   2018-02-26  6289280            3         2842            23486
# 548   2018-02-26  6289280            4         2843            23526
# 549   2018-02-26  6289280            5         2844            23546
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 545            23400           23400           23400    2534854  2018  ...
# 546            23454           23454           23454    2534854  2018  ...
# 547            23486           23486           23486    2534854  2018  ...
# 548            23526           23526           23526    2534854  2018  ...
# 549            23546           23546           23546    2534854  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9654674, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_11_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Route 14

# %%
lwk = wk[(wk['LINEID'] == '14')]

# %%
lwk.shape
# Out:
# (401909, 22)

# %%
# Drop Route 14 rows from wk
wk.drop(wk[wk['LINEID'] == '14'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1046   2018-02-26  6289321            1         4843            49200
# 1047   2018-02-26  6289321            2         4905            49245
# 1048   2018-02-26  6289321            4         4906            49289
# 1049   2018-02-26  6289321            5         4907            49321
# 1050   2018-02-26  6289321            6         4908            49341
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1046            49200           49200           49200    3088367  2018  ...
# 1047            49245           49245           49245    3088367  2018  ...
# 1048            49289           49289           49289    3088367  2018  ...
# 1049            49321           49321           49321    3088367  2018  ...
# 1050            49341           49341           49341    3088367  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9252765, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_14_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Route 41

# %%
lwk = wk[(wk['LINEID'] == '41')]

# %%
lwk.shape
# Out:
# (270218, 22)

# %%
# Drop Route 41 rows from wk
wk.drop(wk[wk['LINEID'] == '41'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1152   2018-02-26  6289395            1          395            24000
# 1153   2018-02-26  6289395            2          396            24052
# 1154   2018-02-26  6289395            3          397            24081
# 1155   2018-02-26  6289395            4          398            24114
# 1156   2018-02-26  6289395            5          399            24141
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1152            24000           24000           24000    1932331  2018  ...
# 1153            24052           24052           24052    1932331  2018  ...
# 1154            24081           24081           24081    1932331  2018  ...
# 1155            24114           24114           24114    1932331  2018  ...
# 1156            24141           24141           24141    1932331  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8982547, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Route 77A

# %%
lwk = wk[(wk['LINEID'] == '77A')]

# %%
lwk.shape
# Out:
# (354960, 22)

# %%
# Drop Route 77A rows from wk
wk.drop(wk[wk['LINEID'] == '77A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1293   2018-02-26  6289412            1          956            22800
# 1294   2018-02-26  6289412            2          957            22851
# 1295   2018-02-26  6289412            3          958            22910
# 1296   2018-02-26  6289412            4          959            22941
# 1297   2018-02-26  6289412            5          960            22984
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1293            22800           22800           22800    1000146  2018  ...
# 1294            22851           22851           22851    1000146  2018  ...
# 1295            22910           22910           22910    1000146  2018  ...
# 1296            22941           22941           22941    1000146  2018  ...
# 1297            22984           22984           22984    1000146  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8627587, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77A_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Route 17A

# %%
lwk = wk[(wk['LINEID'] == '17A')]

# %%
lwk.shape
# Out:
# (303767, 22)

# %%
# Drop Route 17A rows from wk
wk.drop(wk[wk['LINEID'] == '17A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1863   2018-02-26  6289447            1         2492            25200
# 1864   2018-02-26  6289447            2         2493            25262
# 1865   2018-02-26  6289447            3         2465            25303
# 1866   2018-02-26  6289447            4         2466            25335
# 1867   2018-02-26  6289447            5         2467            25383
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1863            25200           25200           25200    2172307  2018  ...
# 1864            25262           25262           25262    2172307  2018  ...
# 1865            25303           25303           25303    2172307  2018  ...
# 1866            25335           25335           25335    2172307  2018  ...
# 1867            25383           25383           25383    2172307  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8323820, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17A_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Route 83

# %%
lwk = wk[(wk['LINEID'] == '83')]

# %%
lwk.shape
# Out:
# (335466, 22)

# %%
# Drop Route 83 rows from wk
wk.drop(wk[wk['LINEID'] == '83'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2135   2018-02-26  6289451            1         2492            48600
# 2136   2018-02-26  6289451            2         2493            48650
# 2137   2018-02-26  6289451            3         2465            48683
# 2138   2018-02-26  6289451            4         2466            48709
# 2139   2018-02-26  6289451            5         2467            48748
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2135            48600           48600           48600    1932315  2018  ...
# 2136            48650           48650           48650    1932315  2018  ...
# 2137            48683           48683           48683    1932315  2018  ...
# 2138            48709           48709           48709    1932315  2018  ...
# 2139            48748           48748           48748    1932315  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7988354, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83_tripLeave2_sp5.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_6

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_6.csv', index=False)
