# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave5 route split 5 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave5_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (4055893, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-08-26  7507211            4         7490            41940
# 1   2018-08-26  7507211            5          515            42008
# 2   2018-08-26  7507211            6          516            42048
# 3   2018-08-26  7507211            7         4384            42086
# 4   2018-08-26  7507211            8          519            42133
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            41940           41940           41940    1000730  2018  ...
# 1            42008           42008           42008    1000730  2018  ...
# 2            42048           42048           42048    1000730  2018  ...
# 3            42086           42086           42086    1000730  2018  ...
# 4            42133           42133           42133    1000730  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 32

# %%
lwk = wk[(wk['LINEID'] == '32')]

# %%
lwk.shape
# Out:
# (133059, 22)

# %%
# Drop Route 32 rows from wk
wk.drop(wk[wk['LINEID'] == '32'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 749   2018-08-26  7507339            1         1772            27000
# 750   2018-08-26  7507339            2         1773            27031
# 751   2018-08-26  7507339            3         1774            27077
# 752   2018-08-26  7507339            4         1775            27114
# 753   2018-08-26  7507339            5         1776            27146
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 749            27000           27000           27000    1932328  2018  ...
# 750            27031           27031           27031    1932328  2018  ...
# 751            27077           27077           27077    1932328  2018  ...
# 752            27114           27114           27114    1932328  2018  ...
# 753            27146           27146           27146    1932328  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3922834, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 130

# %%
lwk = wk[(wk['LINEID'] == '130')]

# %%
lwk.shape
# Out:
# (323298, 22)

# %%
# Drop Route 130 rows from wk
wk.drop(wk[wk['LINEID'] == '130'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1609   2018-08-26  7507529            1         6004            32100
# 1610   2018-08-26  7507529            2            7            32175
# 1611   2018-08-26  7507529            3           11            32312
# 1612   2018-08-26  7507529            4           14            32348
# 1613   2018-08-26  7507529            5           15            32389
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1609            32100           32100           32100    2406932  2018  ...
# 1610            32175           32175           32175    2406932  2018  ...
# 1611            32312           32312           32312    2406932  2018  ...
# 1612            32348           32348           32348    2406932  2018  ...
# 1613            32389           32389           32389    2406932  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3599536, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_130_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 40D

# %%
lwk = wk[(wk['LINEID'] == '40D')]

# %%
lwk.shape
# Out:
# (175752, 22)

# %%
# Drop Route 40D rows from wk
wk.drop(wk[wk['LINEID'] == '40D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1783   2018-08-26  7507533            1         6004            45000
# 1784   2018-08-26  7507533            2            7            45079
# 1785   2018-08-26  7507533            3           11            45222
# 1786   2018-08-26  7507533            4           14            45250
# 1787   2018-08-26  7507533            5           15            45283
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1783            45000           45000           45000    2406932  2018  ...
# 1784            45079           45079           45079    2406932  2018  ...
# 1785            45222           45222           45222    2406932  2018  ...
# 1786            45250           45250           45250    2406932  2018  ...
# 1787            45283           45283           45283    2406932  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3423784, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40D_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 40B

# %%
lwk = wk[(wk['LINEID'] == '40B')]

# %%
lwk.shape
# Out:
# (22050, 22)

# %%
# Drop Route 40B rows from wk
wk.drop(wk[wk['LINEID'] == '40B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2001   2018-08-26  7507598            1         5161            36000
# 2002   2018-08-26  7507598            2         5162            36069
# 2003   2018-08-26  7507598            3         2571            36182
# 2004   2018-08-26  7507598            4         2359            36245
# 2005   2018-08-26  7507598            5         2360            36309
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2001            36000           36000           36000    1001241  2018  ...
# 2002            36069           36069           36069    1001241  2018  ...
# 2003            36182           36182           36182    1001241  2018  ...
# 2004            36245           36245           36245    1001241  2018  ...
# 2005            36309           36309           36309    1001241  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3401734, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40B_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 54A

# %%
lwk = wk[(wk['LINEID'] == '54A')]

# %%
lwk.shape
# Out:
# (138635, 22)

# %%
# Drop Route 54A rows from wk
wk.drop(wk[wk['LINEID'] == '54A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2624   2018-08-26  7507721            1         4330            49200
# 2625   2018-08-26  7507721            2         3679            49368
# 2626   2018-08-26  7507721            3         3711            49419
# 2627   2018-08-26  7507721            4         3712            49450
# 2628   2018-08-26  7507721            5         3713            49521
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2624            49200           49200           49200    1932311  2018  ...
# 2625            49368           49368           49368    1932311  2018  ...
# 2626            49419           49419           49419    1932311  2018  ...
# 2627            49450           49450           49450    1932311  2018  ...
# 2628            49521           49521           49521    1932311  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3263099, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_54A_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 33B

# %%
lwk = wk[(wk['LINEID'] == '33B')]

# %%
lwk.shape
# Out:
# (54351, 22)

# %%
# Drop Route 33B rows from wk
wk.drop(wk[wk['LINEID'] == '33B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2762   2018-08-26  7507881            1         7564            28800
# 2763   2018-08-26  7507881            2         4521            28959
# 2764   2018-08-26  7507881            3         1283            29072
# 2765   2018-08-26  7507881            4         4456            29100
# 2766   2018-08-26  7507881            5         1284            29125
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2762            28800           28800           28800    2693264  2018  ...
# 2763            28959           28959           28959    2693264  2018  ...
# 2764            29072           29072           29072    2693264  2018  ...
# 2765            29100           29100           29100    2693264  2018  ...
# 2766            29125           29125           29125    2693264  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3208748, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33B_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 65

# %%
lwk = wk[(wk['LINEID'] == '65')]

# %%
lwk.shape
# Out:
# (123847, 22)

# %%
# Drop Route 65 rows from wk
wk.drop(wk[wk['LINEID'] == '65'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3315   2018-08-26  7507965            1         2270            37800
# 3316   2018-08-26  7507965            2         2274            37957
# 3317   2018-08-26  7507965            3         7601            38074
# 3318   2018-08-26  7507965            4         2508            38207
# 3319   2018-08-26  7507965            5         2278            38263
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3315            37800           37800           37800    2693261  2018  ...
# 3316            37957           37957           37957    2693261  2018  ...
# 3317            38074           38074           38074    2693261  2018  ...
# 3318            38207           38207           38207    2693261  2018  ...
# 3319            38263           38263           38263    2693261  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3084901, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 53

# %%
lwk = wk[(wk['LINEID'] == '53')]

# %%
lwk.shape
# Out:
# (30459, 22)

# %%
# Drop Route 53 rows from wk
wk.drop(wk[wk['LINEID'] == '53'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3592   2018-08-26  7508279            1         7564            46800
# 3593   2018-08-26  7508279            2         4521            47032
# 3594   2018-08-26  7508279            3         1283            47196
# 3595   2018-08-26  7508279            4         4456            47246
# 3596   2018-08-26  7508279            5         1284            47292
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3592            46800           46800           46800    1932333  2018  ...
# 3593            47032           47032           47032    1932333  2018  ...
# 3594            47196           47196           47196    1932333  2018  ...
# 3595            47246           47246           47246    1932333  2018  ...
# 3596            47292           47292           47292    1932333  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3054442, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_53_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (106834, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3827   2018-08-26  7508452            1         4096            36000
# 3828   2018-08-26  7508452            2         4114            36023
# 3829   2018-08-26  7508452            3         4115            36038
# 3830   2018-08-26  7508452            4         4116            36107
# 3831   2018-08-26  7508452            5         4117            36137
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3827            36000           36000           36000    2172240  2018  ...
# 3828            36023           36023           36023    2172240  2018  ...
# 3829            36038           36038           36038    2172240  2018  ...
# 3830            36107           36107           36107    2172240  2018  ...
# 3831            36137           36137           36137    2172240  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2947608, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (141254, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4475   2018-08-26  7508601            1          324            46500
# 4476   2018-08-26  7508601            7         1634            46788
# 4477   2018-08-26  7508601            8         1635            46798
# 4478   2018-08-26  7508601            9         1636            46841
# 4479   2018-08-26  7508601           10         1637            46916
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4475            46500           46500           46500    2868357  2018  ...
# 4476            46788           46788           46788    2868357  2018  ...
# 4477            46798           46798           46798    2868357  2018  ...
# 4478            46841           46841           46841    2868357  2018  ...
# 4479            46916           46916           46916    2868357  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2806354, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 27B

# %%
lwk = wk[(wk['LINEID'] == '27B')]

# %%
lwk.shape
# Out:
# (244106, 22)

# %%
# Drop Route 27B rows from wk
wk.drop(wk[wk['LINEID'] == '27B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4836   2018-08-26  7508796            1          288            83700
# 4837   2018-08-26  7508796            2         1171            83753
# 4838   2018-08-26  7508796            3         1172            83794
# 4839   2018-08-26  7508796            4         1173            83853
# 4840   2018-08-26  7508796            5         1174            83928
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4836            83700           83700           83700    2693202  2018  ...
# 4837            83753           83753           83753    2693202  2018  ...
# 4838            83794           83794           83794    2693202  2018  ...
# 4839            83853           83853           83853    2693202  2018  ...
# 4840            83928           83928           83928    2693202  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2562248, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27B_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 41B

# %%
lwk = wk[(wk['LINEID'] == '41B')]

# %%
lwk.shape
# Out:
# (22872, 22)

# %%
# Drop Route 41B rows from wk
wk.drop(wk[wk['LINEID'] == '41B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4982   2018-08-26  7509218            1         4495            48300
# 4983   2018-08-26  7509218           15         1950            49476
# 4984   2018-08-26  7509218           16         1951            49547
# 4985   2018-08-26  7509218           17         1952            49565
# 4986   2018-08-26  7509218           18         1953            49585
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4982            48300           48300           48300    1932307  2018  ...
# 4983            49476           49476           49476    1932307  2018  ...
# 4984            49547           49547           49547    1932307  2018  ...
# 4985            49565           49565           49565    1932307  2018  ...
# 4986            49585           49585           49585    1932307  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2539376, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41B_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 69

# %%
lwk = wk[(wk['LINEID'] == '69')]

# %%
lwk.shape
# Out:
# (111971, 22)

# %%
# Drop Route 69 rows from wk
wk.drop(wk[wk['LINEID'] == '69'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5076   2018-08-26  7509220            1         4495            55500
# 5077   2018-08-26  7509220            4         1278            55648
# 5078   2018-08-26  7509220            5         1282            55797
# 5079   2018-08-26  7509220            6         4456            55869
# 5080   2018-08-26  7509220            7         1284            55916
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5076            55500           55500           55500    1932307  2018  ...
# 5077            55648           55648           55648    1932307  2018  ...
# 5078            55797           55797           55797    1932307  2018  ...
# 5079            55869           55869           55869    1932307  2018  ...
# 5080            55916           55916           55916    1932307  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2427405, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 68

# %%
lwk = wk[(wk['LINEID'] == '68')]

# %%
lwk.shape
# Out:
# (129231, 22)

# %%
# Drop Route 68 rows from wk
wk.drop(wk[wk['LINEID'] == '68'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5214   2018-08-26  7509272            1          385            80400
# 5215   2018-08-26  7509272            2         2806            80477
# 5216   2018-08-26  7509272            3         2807            80507
# 5217   2018-08-26  7509272            4         2808            80549
# 5218   2018-08-26  7509272            5          486            80639
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5214            80400           80400           80400    1001243  2018  ...
# 5215            80477           80477           80477    1001243  2018  ...
# 5216            80507           80507           80507    1001243  2018  ...
# 5217            80549           80549           80549    1001243  2018  ...
# 5218            80639           80639           80639    1001243  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2298174, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 18

# %%
lwk = wk[(wk['LINEID'] == '18')]

# %%
lwk.shape
# Out:
# (225045, 22)

# %%
# Drop Route 18 rows from wk
wk.drop(wk[wk['LINEID'] == '18'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6169   2018-08-26  7510386            1          395            39600
# 6170   2018-08-26  7510386            2          396            39669
# 6171   2018-08-26  7510386            3          397            39707
# 6172   2018-08-26  7510386            4          398            39740
# 6173   2018-08-26  7510386            5          399            39767
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6169            39600           39600           39600    1001056  2018  ...
# 6170            39669           39669           39669    1001056  2018  ...
# 6171            39707           39707           39707    1001056  2018  ...
# 6172            39740           39740           39740    1001056  2018  ...
# 6173            39767           39767           39767    1001056  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2073129, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_18_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (86159, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6709   2018-08-26  7510617            1         4657            32400
# 6710   2018-08-26  7510617            2         7279            32454
# 6711   2018-08-26  7510617            3         4658            32498
# 6712   2018-08-26  7510617            4         4659            32528
# 6713   2018-08-26  7510617            5         4660            32581
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6709            32400           32400           32400    2693280  2018  ...
# 6710            32454           32454           32454    2693280  2018  ...
# 6711            32498           32498           32498    2693280  2018  ...
# 6712            32528           32528           32528    2693280  2018  ...
# 6713            32581           32581           32581    2693280  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1986970, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (109804, 22)

# %%
# Drop Route 184 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7377   2018-08-26  7510720            1         1730            33000
# 7378   2018-08-26  7510720            2         1731            33027
# 7379   2018-08-26  7510720            3         1732            33061
# 7380   2018-08-26  7510720            4         1733            33091
# 7381   2018-08-26  7510720            5         1650            33128
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7377            33000           33000           33000    2406899  2018  ...
# 7378            33027           33027           33027    2406899  2018  ...
# 7379            33061           33061           33061    2406899  2018  ...
# 7380            33091           33091           33091    2406899  2018  ...
# 7381            33128           33128           33128    2406899  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1877166, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave5_sp5.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave5_route_split_6

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave5_route_split_6.csv', index=False)
