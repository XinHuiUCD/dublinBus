# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_29197/1318410809.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (5155066, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6289802            1         7158            26520
# 1   2018-02-26  6289802            2         7048            26565
# 2   2018-02-26  6289802            3         7159            26640
# 3   2018-02-26  6289802            4         7388            26660
# 4   2018-02-26  6289802            5         7017            26767
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            26520           26520           26520    2406908  2018  ...
# 1            26565           26565           26565    2406908  2018  ...
# 2            26640           26640           26640    2406908  2018  ...
# 3            26660           26660           26660    2406908  2018  ...
# 4            26767           26767           26767    2406908  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 39

# %%
lwk = wk[(wk['LINEID'] == '39')]

# %%
lwk.shape
# Out:
# (266714, 22)

# %%
# Drop Route 39 rows from wk
wk.drop(wk[wk['LINEID'] == '39'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 78   2018-02-26  6289830            1         7564            19800
# 79   2018-02-26  6289830            2         4521            19927
# 80   2018-02-26  6289830            3         1283            20017
# 81   2018-02-26  6289830            4         4456            20044
# 82   2018-02-26  6289830            5         1284            20069
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 78            19800           19800           19800    2534842  2018  ...
# 79            19927           19927           19927    2534842  2018  ...
# 80            20017           20017           20017    2534842  2018  ...
# 81            20044           20044           20044    2534842  2018  ...
# 82            20069           20069           20069    2534842  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4888352, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 65

# %%
lwk = wk[(wk['LINEID'] == '65')]

# %%
lwk.shape
# Out:
# (107293, 22)

# %%
# Drop Route 65 rows from wk
wk.drop(wk[wk['LINEID'] == '65'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 725   2018-02-26  6289951            1         6041            82800
# 726   2018-02-26  6289951            2         2826            82898
# 727   2018-02-26  6289951            3         2842            82933
# 728   2018-02-26  6289951            4         2843            82976
# 729   2018-02-26  6289951            5         2844            82994
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 725            82800           82800           82800    2868343  2018  ...
# 726            82898           82898           82898    2868343  2018  ...
# 727            82933           82933           82933    2868343  2018  ...
# 728            82976           82976           82976    2868343  2018  ...
# 729            82994           82994           82994    2868343  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4781059, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 14C

# %%
lwk = wk[(wk['LINEID'] == '14C')]

# %%
lwk.shape
# Out:
# (4491, 22)

# %%
# Drop Route 14C rows from wk
wk.drop(wk[wk['LINEID'] == '14C'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 772   2018-02-26  6289964            1         3605            26700
# 773   2018-02-26  6289964            2         3606            26746
# 774   2018-02-26  6289964            3         3607            26799
# 775   2018-02-26  6289964            4         6051            26812
# 776   2018-02-26  6289964            5         6053            26854
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 772            26700           26700           26700    1001162  2018  ...
# 773            26746           26746           26746    1001162  2018  ...
# 774            26799           26799           26799    1001162  2018  ...
# 775            26812           26812           26812    1001162  2018  ...
# 776            26854           26854           26854    1001162  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4776568, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_14C_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (22503, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 874   2018-02-26  6290011            1         4962            28800
# 875   2018-02-26  6290011            2         4725            29117
# 876   2018-02-26  6290011            3          273            29307
# 877   2018-02-26  6290011            4          405            29577
# 878   2018-02-26  6290011            5          408            29716
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 874            28800           28800           28800    2693226  2018  ...
# 875            29117           29117           29117    2693226  2018  ...
# 876            29307           29307           29307    2693226  2018  ...
# 877            29577           29577           29577    2693226  2018  ...
# 878            29716           29716           29716    2693226  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4754065, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 7A

# %%
lwk = wk[(wk['LINEID'] == '7A')]

# %%
lwk.shape
# Out:
# (218783, 22)

# %%
# Drop Route 7A rows from wk
wk.drop(wk[wk['LINEID'] == '7A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1187   2018-02-26  6290016            1         4962            63000
# 1188   2018-02-26  6290016            2         6059            63260
# 1189   2018-02-26  6290016            3          334            63473
# 1190   2018-02-26  6290016            4          406            63804
# 1191   2018-02-26  6290016            5          747            63987
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1187            63000           63000           63000    2406888  2018  ...
# 1188            63260           63260           63260    2406888  2018  ...
# 1189            63473           63473           63473    2406888  2018  ...
# 1190            63804           63804           63804    2406888  2018  ...
# 1191            63987           63987           63987    2406888  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4535282, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7A_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 7B

# %%
lwk = wk[(wk['LINEID'] == '7B')]

# %%
lwk.shape
# Out:
# (18488, 22)

# %%
# Drop Route 7B rows from wk
wk.drop(wk[wk['LINEID'] == '7B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1240   2018-02-26  6290050            1          324            24000
# 1241   2018-02-26  6290050            7         1634            24260
# 1242   2018-02-26  6290050            8         1635            24267
# 1243   2018-02-26  6290050            9         1636            24324
# 1244   2018-02-26  6290050           10         1637            24398
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1240            24000           24000           24000    1000144  2018  ...
# 1241            24260           24260           24260    1000144  2018  ...
# 1242            24267           24267           24267    1000144  2018  ...
# 1243            24324           24324           24324    1000144  2018  ...
# 1244            24398           24398           24398    1000144  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4516794, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7B_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 27B

# %%
lwk = wk[(wk['LINEID'] == '27B')]

# %%
lwk.shape
# Out:
# (227174, 22)

# %%
# Drop Route 27B rows from wk
wk.drop(wk[wk['LINEID'] == '27B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2247   2018-02-26  6290126            1         7564            72000
# 2248   2018-02-26  6290126            2         4521            72291
# 2249   2018-02-26  6290126            3         1283            72497
# 2250   2018-02-26  6290126            4         4456            72564
# 2251   2018-02-26  6290126            5         1284            72626
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2247            72000           72000           72000    1000696  2018  ...
# 2248            72291           72291           72291    1000696  2018  ...
# 2249            72497           72497           72497    1000696  2018  ...
# 2250            72564           72564           72564    1000696  2018  ...
# 2251            72626           72626           72626    1000696  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4289620, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27B_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (108688, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2479   2018-02-26  6290186            1         7333            24000
# 2480   2018-02-26  6290186            2          783            24112
# 2481   2018-02-26  6290186            3          784            24136
# 2482   2018-02-26  6290186            4          785            24177
# 2483   2018-02-26  6290186            5          786            24247
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2479            24000           24000           24000    1001141  2018  ...
# 2480            24112           24112           24112    1001141  2018  ...
# 2481            24136           24136           24136    1001141  2018  ...
# 2482            24177           24177           24177    1001141  2018  ...
# 2483            24247           24247           24247    1001141  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4180932, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 38B

# %%
lwk = wk[(wk['LINEID'] == '38B')]

# %%
lwk.shape
# Out:
# (22284, 22)

# %%
# Drop Route 38B rows from wk
wk.drop(wk[wk['LINEID'] == '38B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2578   2018-02-26  6290198            1         4962            25800
# 2579   2018-02-26  6290198            2         4725            26040
# 2580   2018-02-26  6290198            3          273            26230
# 2581   2018-02-26  6290198            4          405            26500
# 2582   2018-02-26  6290198            5          408            26640
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2578            25800           25800           25800    2172283  2018  ...
# 2579            26040           26040           26040    2172283  2018  ...
# 2580            26230           26230           26230    2172283  2018  ...
# 2581            26500           26500           26500    2172283  2018  ...
# 2582            26640           26640           26640    2172283  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4158648, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38B_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 7

# %%
lwk = wk[(wk['LINEID'] == '7')]

# %%
lwk.shape
# Out:
# (188081, 22)

# %%
# Drop Route 7 rows from wk
wk.drop(wk[wk['LINEID'] == '7'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2931   2018-02-26  6290226            1         7639            27000
# 2932   2018-02-26  6290226            2         7640            27054
# 2933   2018-02-26  6290226            3         5047            27120
# 2934   2018-02-26  6290226            4         3134            27157
# 2935   2018-02-26  6290226            5         3143            27260
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2931            27000           27000           27000    1000722  2018  ...
# 2932            27054           27054           27054    1000722  2018  ...
# 2933            27120           27120           27120    1000722  2018  ...
# 2934            27157           27157           27157    1000722  2018  ...
# 2935            27260           27260           27260    1000722  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3970567, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (65205, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3721   2018-02-26  6290243            1          284            27600
# 3722   2018-02-26  6290243            2         4504            27769
# 3723   2018-02-26  6290243            3         7028            27867
# 3724   2018-02-26  6290243            4         5147            28014
# 3725   2018-02-26  6290243            5           68            28156
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3721            27600           27600           27600    2693288  2018  ...
# 3722            27769           27769           27769    2693288  2018  ...
# 3723            27867           27867           27867    2693288  2018  ...
# 3724            28014           28014           28014    2693288  2018  ...
# 3725            28156           28156           28156    2693288  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3905362, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (138211, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4397   2018-02-26  6290344            1         1380            27600
# 4398   2018-02-26  6290344            2         1381            27636
# 4399   2018-02-26  6290344            3         1406            27699
# 4400   2018-02-26  6290344            4         1407            27757
# 4401   2018-02-26  6290344            5         1409            27809
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4397            27600           27600           27600    1001093  2018  ...
# 4398            27636           27636           27636    1001093  2018  ...
# 4399            27699           27699           27699    1001093  2018  ...
# 4400            27757           27757           27757    1001093  2018  ...
# 4401            27809           27809           27809    1001093  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3767151, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (182063, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4786   2018-02-26  6290430            1         4096            23700
# 4787   2018-02-26  6290430            2         4114            23724
# 4788   2018-02-26  6290430            3         4115            23739
# 4789   2018-02-26  6290430            4         4116            23811
# 4790   2018-02-26  6290430            5         4117            23842
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4786            23700           23700           23700    2868382  2018  ...
# 4787            23724           23724           23724    2868382  2018  ...
# 4788            23739           23739           23739    2868382  2018  ...
# 4789            23811           23811           23811    2868382  2018  ...
# 4790            23842           23842           23842    2868382  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3585088, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (146250, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5514   2018-02-26  6290456            1         6185            23700
# 5515   2018-02-26  6290456            2         6186            23751
# 5516   2018-02-26  6290456            3         6216            23838
# 5517   2018-02-26  6290456            4         3400            23908
# 5518   2018-02-26  6290456            5         3401            23950
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5514            23700           23700           23700    2868346  2018  ...
# 5515            23751           23751           23751    2868346  2018  ...
# 5516            23838           23838           23838    2868346  2018  ...
# 5517            23908           23908           23908    2868346  2018  ...
# 5518            23950           23950           23950    2868346  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3438838, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Route 68

# %%
lwk = wk[(wk['LINEID'] == '68')]

# %%
lwk.shape
# Out:
# (108643, 22)

# %%
# Drop Route 68 rows from wk
wk.drop(wk[wk['LINEID'] == '68'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5730   2018-02-26  6290460            1         4564            45000
# 5731   2018-02-26  6290460            2         3443            45088
# 5732   2018-02-26  6290460            3         3444            45126
# 5733   2018-02-26  6290460            4         3445            45172
# 5734   2018-02-26  6290460            5         3446            45233
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5730            45000           45000           45000    2868348  2018  ...
# 5731            45088           45088           45088    2868348  2018  ...
# 5732            45126           45126           45126    2868348  2018  ...
# 5733            45172           45172           45172    2868348  2018  ...
# 5734            45233           45233           45233    2868348  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3330195, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68_tripLeave2_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_8.csv', index=False)
