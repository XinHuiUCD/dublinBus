# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave6_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (1090772, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-10  8089347            1         7333            22800
# 1   2018-09-10  8089347            2          783            22906
# 2   2018-09-10  8089347            3          784            22929
# 3   2018-09-10  8089347            4          785            22968
# 4   2018-09-10  8089347            5          786            23045
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            22800           22800           22800    1000615  2018  ...
# 1            22906           22906           22906    1000615  2018  ...
# 2            22929           22929           22929    1000615  2018  ...
# 3            22968           22968           22968    1000615  2018  ...
# 4            23045           23045           23045    1000615  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 38B

# %%
lwk = wk[(wk['LINEID'] == '38B')]

# %%
lwk.shape
# Out:
# (21026, 22)

# %%
# Drop Route 38B rows from wk
wk.drop(wk[wk['LINEID'] == '38B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 100   2018-09-10  8089373            1          943            27000
# 101   2018-09-10  8089373            2         3599            27240
# 102   2018-09-10  8089373            3         3600            27312
# 103   2018-09-10  8089373            4         3601            27401
# 104   2018-09-10  8089373            5         3602            27480
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 100            27000           27000           27000    1000337  2018  ...
# 101            27240           27240           27240    1000337  2018  ...
# 102            27312           27312           27312    1000337  2018  ...
# 103            27401           27401           27401    1000337  2018  ...
# 104            27480           27480           27480    1000337  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1069746, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38B_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 42D

# %%
lwk = wk[(wk['LINEID'] == '42D')]

# %%
lwk.shape
# Out:
# (2566, 22)

# %%
# Drop Route 42D rows from wk
wk.drop(wk[wk['LINEID'] == '42D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 131   2018-09-10  8089497            1         6290            58200
# 132   2018-09-10  8089497            2         7120            58353
# 133   2018-09-10  8089497            3         7119            58440
# 134   2018-09-10  8089497            4         7127            58511
# 135   2018-09-10  8089497            5         7143            58631
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 131            58200           58200           58200    1000110  2018  ...
# 132            58353           58353           58353    1000110  2018  ...
# 133            58440           58440           58440    1000110  2018  ...
# 134            58511           58511           58511    1000110  2018  ...
# 135            58631           58631           58631    1000110  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1067180, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42D_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 25D

# %%
lwk = wk[(wk['LINEID'] == '25D')]

# %%
lwk.shape
# Out:
# (9253, 22)

# %%
# Drop Route 25D rows from wk
wk.drop(wk[wk['LINEID'] == '25D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 191   2018-09-10  8089510            1         7158            26100
# 192   2018-09-10  8089510            2         7048            26143
# 193   2018-09-10  8089510            3         7159            26215
# 194   2018-09-10  8089510            4         7017            26338
# 195   2018-09-10  8089510            5         7018            26391
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 191            26100           26100           26100    1000199  2018  ...
# 192            26143           26143           26143    1000199  2018  ...
# 193            26215           26215           26215    1000199  2018  ...
# 194            26338           26338           26338    1000199  2018  ...
# 195            26391           26391           26391    1000199  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1057927, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25D_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 39X

# %%
lwk = wk[(wk['LINEID'] == '39X')]

# %%
lwk.shape
# Out:
# (6155, 22)

# %%
# Drop Route 39X rows from wk
wk.drop(wk[wk['LINEID'] == '39X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 297   2018-09-10  8089557            1         3980            25800
# 298   2018-09-10  8089557            2         6089            25883
# 299   2018-09-10  8089557            3         3981            26008
# 300   2018-09-10  8089557            4         3982            26069
# 301   2018-09-10  8089557            5         3983            26209
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 297            25800           25800           25800    2172311  2018  ...
# 298            25883           25883           25883    2172311  2018  ...
# 299            26008           26008           26008    2172311  2018  ...
# 300            26069           26069           26069    2172311  2018  ...
# 301            26209           26209           26209    2172311  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1051772, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39X_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (25813, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 345   2018-09-10  8089558            1         7391            32400
# 346   2018-09-10  8089558            2          493            32561
# 347   2018-09-10  8089558            3          494            32685
# 348   2018-09-10  8089558            4          495            32835
# 349   2018-09-10  8089558            5          400            32956
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 345            32400           32400           32400    2172311  2018  ...
# 346            32561           32561           32561    2172311  2018  ...
# 347            32685           32685           32685    2172311  2018  ...
# 348            32835           32835           32835    2172311  2018  ...
# 349            32956           32956           32956    2172311  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1025959, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 66B

# %%
lwk = wk[(wk['LINEID'] == '66B')]

# %%
lwk.shape
# Out:
# (78653, 22)

# %%
# Drop Route 66B rows from wk
wk.drop(wk[wk['LINEID'] == '66B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 456   2018-09-10  8089736            3         5047            23545
# 457   2018-09-10  8089736            4         3134            23579
# 458   2018-09-10  8089736            5         3143            23676
# 459   2018-09-10  8089736            6         3144            23721
# 460   2018-09-10  8089736            7         3221            23835
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 456            23545           23545           23545    1000716  2018  ...
# 457            23579           23579           23579    1000716  2018  ...
# 458            23676           23676           23676    1000716  2018  ...
# 459            23721           23721           23721    1000716  2018  ...
# 460            23835           23835           23835    1000716  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (947306, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66B_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (10323, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1212   2018-09-10  8090067            1          342            63000
# 1213   2018-09-10  8090067            2         4495            63001
# 1214   2018-09-10  8090067            3          746            63800
# 1215   2018-09-10  8090067            4          844            63904
# 1216   2018-09-10  8090067            5          846            64076
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1212            63000           63000           63000    3248746  2018  ...
# 1213            63001           63001           63001    3248746  2018  ...
# 1214            63800           63800           63800    3248746  2018  ...
# 1215            63904           63904           63904    3248746  2018  ...
# 1216            64076           64076           64076    3248746  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (936983, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 84X

# %%
lwk = wk[(wk['LINEID'] == '84X')]

# %%
lwk.shape
# Out:
# (26498, 22)

# %%
# Drop Route 84X rows from wk
wk.drop(wk[wk['LINEID'] == '84X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1248   2018-09-10  8090112            1         3921            28200
# 1249   2018-09-10  8090112            2         3922            28276
# 1250   2018-09-10  8090112            3         3923            28338
# 1251   2018-09-10  8090112            4         3112            28387
# 1252   2018-09-10  8090112            5         3924            28490
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1248            28200           28200           28200    2868317  2018  ...
# 1249            28276           28276           28276    2868317  2018  ...
# 1250            28338           28338           28338    2868317  2018  ...
# 1251            28387           28387           28387    2868317  2018  ...
# 1252            28490           28490           28490    2868317  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (910485, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84X_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 67X

# %%
lwk = wk[(wk['LINEID'] == '67X')]

# %%
lwk.shape
# Out:
# (33235, 22)

# %%
# Drop Route 67X rows from wk
wk.drop(wk[wk['LINEID'] == '67X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1352   2018-09-10  8090160            1         7333            46200
# 1353   2018-09-10  8090160            2          783            46321
# 1354   2018-09-10  8090160            3          784            46355
# 1355   2018-09-10  8090160            4          785            46412
# 1356   2018-09-10  8090160            5          786            46549
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1352            46200           46200           46200    1000900  2018  ...
# 1353            46321           46321           46321    1000900  2018  ...
# 1354            46355           46355           46355    1000900  2018  ...
# 1355            46412           46412           46412    1000900  2018  ...
# 1356            46549           46549           46549    1000900  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (877250, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67X_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (102484, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1629   2018-09-10  8090304            1         3283            26100
# 1630   2018-09-10  8090304            2         3284            26135
# 1631   2018-09-10  8090304            3         3285            26208
# 1632   2018-09-10  8090304            4         7324            26260
# 1633   2018-09-10  8090304            5         5106            26367
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1629            26100           26100           26100    1000792  2018  ...
# 1630            26135           26135           26135    1000792  2018  ...
# 1631            26208           26208           26208    1000792  2018  ...
# 1632            26260           26260           26260    1000792  2018  ...
# 1633            26367           26367           26367    1000792  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (774766, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 63

# %%
lwk = wk[(wk['LINEID'] == '63')]

# %%
lwk.shape
# Out:
# (21828, 22)

# %%
# Drop Route 63 rows from wk
wk.drop(wk[wk['LINEID'] == '63'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2245   2018-09-10  8090602            1         1184            25200
# 2246   2018-09-10  8090602            2         7490            25371
# 2247   2018-09-10  8090602            3          497            25393
# 2248   2018-09-10  8090602            4          515            25466
# 2249   2018-09-10  8090602            5          516            25522
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2245            25200           25200           25200    2406897  2018  ...
# 2246            25371           25371           25371    2406897  2018  ...
# 2247            25393           25393           25393    2406897  2018  ...
# 2248            25466           25466           25466    2406897  2018  ...
# 2249            25522           25522           25522    2406897  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (752938, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_63_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (128914, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2888   2018-09-10  8090645            1         4168            26400
# 2889   2018-09-10  8090645            2         4170            26481
# 2890   2018-09-10  8090645            3         4153            26539
# 2891   2018-09-10  8090645            4         4154            26593
# 2892   2018-09-10  8090645            5         4416            26637
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2888            26400           26400           26400    1932337  2018  ...
# 2889            26481           26481           26481    1932337  2018  ...
# 2890            26539           26539           26539    1932337  2018  ...
# 2891            26593           26593           26593    1932337  2018  ...
# 2892            26637           26637           26637    1932337  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (624024, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 84A

# %%
lwk = wk[(wk['LINEID'] == '84A')]

# %%
lwk.shape
# Out:
# (20168, 22)

# %%
# Drop Route 84A rows from wk
wk.drop(wk[wk['LINEID'] == '84A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3128   2018-09-10  8090756            1          621            57900
# 3129   2018-09-10  8090756            2          289            58083
# 3130   2018-09-10  8090756            3          496            58219
# 3131   2018-09-10  8090756            4         7490            58248
# 3132   2018-09-10  8090756            5          515            58339
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3128            57900           57900           57900    1000712  2018  ...
# 3129            58083           58083           58083    1000712  2018  ...
# 3130            58219           58219           58219    1000712  2018  ...
# 3131            58248           58248           58248    1000712  2018  ...
# 3132            58339           58339           58339    1000712  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (603856, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84A_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 31B

# %%
lwk = wk[(wk['LINEID'] == '31B')]

# %%
lwk.shape
# Out:
# (22197, 22)

# %%
# Drop Route 31B rows from wk
wk.drop(wk[wk['LINEID'] == '31B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3911   2018-09-10  8091093           19         2970            58982
# 3912   2018-09-10  8091093           20         4988            59023
# 3913   2018-09-10  8091093           31         2825            59585
# 3914   2018-09-10  8091095            8         2948            63023
# 3915   2018-09-10  8091095            9         2949            63048
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3911            58982           58982           58982    2534851  2018  ...
# 3912            59023           59023           59023    2534851  2018  ...
# 3913            59585           59585           59585    2534851  2018  ...
# 3914            63023           63023           63023    2534851  2018  ...
# 3915            63048           63048           63048    2534851  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (581659, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31B_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 161

# %%
lwk = wk[(wk['LINEID'] == '161')]

# %%
lwk.shape
# Out:
# (5922, 22)

# %%
# Drop Route 161 rows from wk
wk.drop(wk[wk['LINEID'] == '161'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3978   2018-09-10  8091308            1         4843            27600
# 3979   2018-09-10  8091308            2         4905            27653
# 3980   2018-09-10  8091308            4         4906            27705
# 3981   2018-09-10  8091308            5         4907            27742
# 3982   2018-09-10  8091308            6         4908            27765
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3978            27600           27600           27600    2868342  2018  ...
# 3979            27653           27653           27653    2868342  2018  ...
# 3980            27705           27705           27705    2868342  2018  ...
# 3981            27742           27742           27742    2868342  2018  ...
# 3982            27765           27765           27765    2868342  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (575737, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_161_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 41A

# %%
lwk = wk[(wk['LINEID'] == '41A')]

# %%
lwk.shape
# Out:
# (3154, 22)

# %%
# Drop Route 41A rows from wk
wk.drop(wk[wk['LINEID'] == '41A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4032   2018-09-10  8091350            1         7067            29100
# 4033   2018-09-10  8091350            2         2956            29127
# 4034   2018-09-10  8091350            3         2965            29183
# 4035   2018-09-10  8091350            4         2983            29254
# 4036   2018-09-10  8091350            5         2984            29335
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4032            29100           29100           29100    1000171  2018  ...
# 4033            29127           29127           29127    1000171  2018  ...
# 4034            29183           29183           29183    1000171  2018  ...
# 4035            29254           29254           29254    1000171  2018  ...
# 4036            29335           29335           29335    1000171  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (572583, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41A_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 15D

# %%
lwk = wk[(wk['LINEID'] == '15D')]

# %%
lwk.shape
# Out:
# (4812, 22)

# %%
# Drop Route 15D rows from wk
wk.drop(wk[wk['LINEID'] == '15D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4181   2018-09-10  8091544            1          215            28200
# 4182   2018-09-10  8091544            2          216            28288
# 4183   2018-09-10  8091544            3          236            28295
# 4184   2018-09-10  8091544            4          217            28355
# 4185   2018-09-10  8091544            5          218            28418
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4181            28200           28200           28200    1000115  2018  ...
# 4182            28288           28288           28288    1000115  2018  ...
# 4183            28295           28295           28295    1000115  2018  ...
# 4184            28355           28355           28355    1000115  2018  ...
# 4185            28418           28418           28418    1000115  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (567771, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15D_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 16C

# %%
lwk = wk[(wk['LINEID'] == '16C')]

# %%
lwk.shape
# Out:
# (10008, 22)

# %%
# Drop Route 16C rows from wk
wk.drop(wk[wk['LINEID'] == '16C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4327   2018-09-10  8091851            1         3544            26100
# 4328   2018-09-10  8091851            2         3552            26153
# 4329   2018-09-10  8091851            3         3553            26181
# 4330   2018-09-10  8091851            4         3554            26243
# 4331   2018-09-10  8091851            5         3555            26281
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4327            26100           26100           26100    1000784  2018  ...
# 4328            26153           26153           26153    1000784  2018  ...
# 4329            26181           26181           26181    1000784  2018  ...
# 4330            26243           26243           26243    1000784  2018  ...
# 4331            26281           26281           26281    1000784  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (557763, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_16C_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 7B

# %%
lwk = wk[(wk['LINEID'] == '7B')]

# %%
lwk.shape
# Out:
# (18295, 22)

# %%
# Drop Route 7B rows from wk
wk.drop(wk[wk['LINEID'] == '7B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4460   2018-09-10  8091936            1         4564            27000
# 4461   2018-09-10  8091936            2         3444            27080
# 4462   2018-09-10  8091936            3         3447            27182
# 4463   2018-09-10  8091936            4         3454            27415
# 4464   2018-09-10  8091936            5         3455            27477
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4460            27000           27000           27000    2534837  2018  ...
# 4461            27080           27080           27080    2534837  2018  ...
# 4462            27182           27182           27182    2534837  2018  ...
# 4463            27415           27415           27415    2534837  2018  ...
# 4464            27477           27477           27477    2534837  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (539468, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7B_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Route 69X

# %%
lwk = wk[(wk['LINEID'] == '69X')]

# %%
lwk.shape
# Out:
# (1503, 22)

# %%
# Drop Route 69X rows from wk
wk.drop(wk[wk['LINEID'] == '69X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4651   2018-09-10  8092065            1         3890            27300
# 4652   2018-09-10  8092065            2         3891            27324
# 4653   2018-09-10  8092065            3         3949            27413
# 4654   2018-09-10  8092065            4         3950            27468
# 4655   2018-09-10  8092065            5         3372            27557
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4651            27300           27300           27300    1000286  2018  ...
# 4652            27324           27324           27324    1000286  2018  ...
# 4653            27413           27413           27413    1000286  2018  ...
# 4654            27468           27468           27468    1000286  2018  ...
# 4655            27557           27557           27557    1000286  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (537965, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69X_tripLeave6_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_7.csv', index=False)
