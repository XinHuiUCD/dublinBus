# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 8 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_8.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (372982, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-25  7114063            1         7333            27600
# 1   2018-06-25  7114063            2          783            27729
# 2   2018-06-25  7114063            3          784            27763
# 3   2018-06-25  7114063            4          785            27821
# 4   2018-06-25  7114063            5          786            27927
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            27600           27600           27600    2406866  2018  ...
# 1            27729           27729           27729    2406866  2018  ...
# 2            27763           27763           27763    2406866  2018  ...
# 3            27821           27821           27821    2406866  2018  ...
# 4            27927           27927           27927    2406866  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 38D

# %%
lwk = wk[(wk['LINEID'] == '38D')]

# %%
lwk.shape
# Out:
# (1656, 22)

# %%
# Drop Route 38D rows from wk
wk.drop(wk[wk['LINEID'] == '38D'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 30   2018-06-25  7114779            1         4664            27900
# 31   2018-06-25  7114779            2         2160            27948
# 32   2018-06-25  7114779            3         4665            27982
# 33   2018-06-25  7114779            4         4666            28018
# 34   2018-06-25  7114779            5         4667            28047
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 30            27900           27900           27900    1000898  2018  ...
# 31            27948           27948           27948    1000898  2018  ...
# 32            27982           27982           27982    1000898  2018  ...
# 33            28018           28018           28018    1000898  2018  ...
# 34            28047           28047           28047    1000898  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (371326, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38D_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 51D

# %%
lwk = wk[(wk['LINEID'] == '51D')]

# %%
lwk.shape
# Out:
# (6049, 22)

# %%
# Drop Route 51D rows from wk
wk.drop(wk[wk['LINEID'] == '51D'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 79   2018-06-25  7114923            1         4843            27600
# 80   2018-06-25  7114923            2         4905            27651
# 81   2018-06-25  7114923            4         4906            27700
# 82   2018-06-25  7114923            5         4907            27736
# 83   2018-06-25  7114923            6         4908            27758
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 79            27600           27600           27600    2868391  2018  ...
# 80            27651           27651           27651    2868391  2018  ...
# 81            27700           27700           27700    2868391  2018  ...
# 82            27736           27736           27736    2868391  2018  ...
# 83            27758           27758           27758    2868391  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (365277, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51D_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 41A

# %%
lwk = wk[(wk['LINEID'] == '41A')]

# %%
lwk.shape
# Out:
# (4240, 22)

# %%
# Drop Route 41A rows from wk
wk.drop(wk[wk['LINEID'] == '41A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 133   2018-06-25  7115588            1         6290            28560
# 134   2018-06-25  7115588            2         7120            28699
# 135   2018-06-25  7115588            3         7119            28778
# 136   2018-06-25  7115588            4         7127            28843
# 137   2018-06-25  7115588            5         7143            28952
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 133            28560           28560           28560    1000495  2018  ...
# 134            28699           28699           28699    1000495  2018  ...
# 135            28778           28778           28778    1000495  2018  ...
# 136            28843           28843           28843    1000495  2018  ...
# 137            28952           28952           28952    1000495  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (361037, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41A_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 25D

# %%
lwk = wk[(wk['LINEID'] == '25D')]

# %%
lwk.shape
# Out:
# (8799, 22)

# %%
# Drop Route 25D rows from wk
wk.drop(wk[wk['LINEID'] == '25D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 162   2018-06-26  7110283            4         3950            29529
# 163   2018-06-26  7110283            5         3372            29630
# 164   2018-06-26  7110283            6         3373            29695
# 165   2018-06-26  7110283            7         3374            29733
# 166   2018-06-26  7110283            8         2233            29783
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 162            29529           29529           29529    1000292  2018  ...
# 163            29630           29630           29630    1000292  2018  ...
# 164            29695           29695           29695    1000292  2018  ...
# 165            29733           29733           29733    1000292  2018  ...
# 166            29783           29783           29783    1000292  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (352238, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25D_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 25X

# %%
lwk = wk[(wk['LINEID'] == '25X')]

# %%
lwk.shape
# Out:
# (6224, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '25X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 968   2018-06-30  7110214            5         4262            25289
# 969   2018-06-30  7110214            6         4263            25342
# 970   2018-06-30  7110214            7         4264            25381
# 971   2018-06-30  7110214            8         7296            25419
# 972   2018-06-30  7110214            9         4265            25448
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 968            25289           25289           25289    1932303  2018  ...
# 969            25342           25342           25342    1932303  2018  ...
# 970            25381           25381           25381    1932303  2018  ...
# 971            25419           25419           25419    1932303  2018  ...
# 972            25448           25448           25448    1932303  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (346014, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25X_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 84

# %%
lwk = wk[(wk['LINEID'] == '84')]

# %%
lwk.shape
# Out:
# (149585, 22)

# %%
# Drop Route 84 rows from wk
wk.drop(wk[wk['LINEID'] == '84'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1972   2018-06-30  7110676            1         7564            25200
# 1973   2018-06-30  7110676            2         4521            25368
# 1974   2018-06-30  7110676            3         1283            25488
# 1975   2018-06-30  7110676            4         4456            25515
# 1976   2018-06-30  7110676            5         1284            25539
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1972            25200           25200           25200    2868403  2018  ...
# 1973            25368           25368           25368    2868403  2018  ...
# 1974            25488           25488           25488    2868403  2018  ...
# 1975            25515           25515           25515    2868403  2018  ...
# 1976            25539           25539           25539    2868403  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (196429, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 65

# %%
lwk = wk[(wk['LINEID'] == '65')]

# %%
lwk.shape
# Out:
# (109700, 22)

# %%
# Drop Route 65 rows from wk
wk.drop(wk[wk['LINEID'] == '65'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2046   2018-06-30  7111844            1         7073            24600
# 2047   2018-06-30  7111844            2         7097            24656
# 2048   2018-06-30  7111844            3         7098            24686
# 2049   2018-06-30  7111844            4         7099            24713
# 2050   2018-06-30  7111844            5         7100            24753
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2046            24600           24600           24600    1000764  2018  ...
# 2047            24656           24656           24656    1000764  2018  ...
# 2048            24686           24686           24686    1000764  2018  ...
# 2049            24713           24713           24713    1000764  2018  ...
# 2050            24753           24753           24753    1000764  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (86729, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 238

# %%
lwk = wk[(wk['LINEID'] == '238')]

# %%
lwk.shape
# Out:
# (33953, 22)

# %%
# Drop Route 238 rows from wk
wk.drop(wk[wk['LINEID'] == '238'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6832   2018-07-02  7133405            5          758            56019
# 6833   2018-07-02  7133405            6          759            56091
# 6834   2018-07-02  7133405            7          760            56145
# 6835   2018-07-02  7133405            8          761            56191
# 6836   2018-07-02  7133405            9          762            56230
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6832            56019           56019           56019    2693218  2018  ...
# 6833            56091           56091           56091    2693218  2018  ...
# 6834            56145           56145           56145    2693218  2018  ...
# 6835            56191           56191           56191    2693218  2018  ...
# 6836            56230           56230           56230    2693218  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (52776, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_238_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (3193, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7351   2018-07-02  7133838            2         3444            27070
# 7352   2018-07-02  7133838            3         3447            27160
# 7353   2018-07-02  7133838            4         3454            27366
# 7354   2018-07-02  7133838            5         3455            27463
# 7355   2018-07-02  7133838            6         5022            27759
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7351            27070           27070           27070    2534788  2018  ...
# 7352            27160           27160           27160    2534788  2018  ...
# 7353            27366           27366           27366    2534788  2018  ...
# 7354            27463           27463           27463    2534788  2018  ...
# 7355            27759           27759           27759    2534788  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (49583, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 69X

# %%
lwk = wk[(wk['LINEID'] == '69X')]

# %%
lwk.shape
# Out:
# (1347, 22)

# %%
# Drop Route 69X rows from wk
wk.drop(wk[wk['LINEID'] == '69X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8437   2018-07-02  7135752            1         3057            26100
# 8438   2018-07-02  7135752            2         3059            26136
# 8439   2018-07-02  7135752            3         3060            26163
# 8440   2018-07-02  7135752            4         3061            26192
# 8441   2018-07-02  7135752            5         3062            26228
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8437            26100           26100           26100    1932342  2018  ...
# 8438            26136           26136           26136    1932342  2018  ...
# 8439            26163           26163           26163    1932342  2018  ...
# 8440            26192           26192           26192    1932342  2018  ...
# 8441            26228           26228           26228    1932342  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (48236, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69X_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 7D

# %%
lwk = wk[(wk['LINEID'] == '7D')]

# %%
lwk.shape
# Out:
# (6955, 22)

# %%
# Drop Route 7D rows from wk
wk.drop(wk[wk['LINEID'] == '7D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9695   2018-07-02  7136237            1         2825            24600
# 9696   2018-07-02  7136237            2         2826            24669
# 9697   2018-07-02  7136237            3         2827            24723
# 9698   2018-07-02  7136237            4         2828            24784
# 9699   2018-07-02  7136237            5         2829            24838
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9695            24600           24600           24600    2868332  2018  ...
# 9696            24669           24669           24669    2868332  2018  ...
# 9697            24723           24723           24723    2868332  2018  ...
# 9698            24784           24784           24784    2868332  2018  ...
# 9699            24838           24838           24838    2868332  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (41281, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7D_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 44B

# %%
lwk = wk[(wk['LINEID'] == '44B')]

# %%
lwk.shape
# Out:
# (10606, 22)

# %%
# Drop Route 44B rows from wk
wk.drop(wk[wk['LINEID'] == '44B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9860   2018-07-02  7136723            1         3085            29100
# 9861   2018-07-02  7136723            2         3034            29208
# 9862   2018-07-02  7136723            3         3114            29340
# 9863   2018-07-02  7136723            4         4353            29426
# 9864   2018-07-02  7136723            5         4355            29460
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9860            29100           29100           29100    1930280  2018  ...
# 9861            29208           29208           29208    1930280  2018  ...
# 9862            29340           29340           29340    1930280  2018  ...
# 9863            29426           29426           29426    1930280  2018  ...
# 9864            29460           29460           29460    1930280  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (30675, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44B_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 46E

# %%
lwk = wk[(wk['LINEID'] == '46E')]

# %%
lwk.shape
# Out:
# (2353, 22)

# %%
# Drop Route 46E rows from wk
wk.drop(wk[wk['LINEID'] == '46E'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9951   2018-07-02  7138349            1         4168            22800
# 9952   2018-07-02  7138349            2         4170            22873
# 9953   2018-07-02  7138349            3         4153            22925
# 9954   2018-07-02  7138349            4         4154            22972
# 9955   2018-07-02  7138349            5         4416            23011
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9951            22800           22800           22800    2406895  2018  ...
# 9952            22873           22873           22873    2406895  2018  ...
# 9953            22925           22925           22925    2406895  2018  ...
# 9954            22972           22972           22972    2406895  2018  ...
# 9955            23011           23011           23011    2406895  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (28322, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46E_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 84A

# %%
lwk = wk[(wk['LINEID'] == '84A')]

# %%
lwk.shape
# Out:
# (23381, 22)

# %%
# Drop Route 84A rows from wk
wk.drop(wk[wk['LINEID'] == '84A'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 10471   2018-07-02  7140546            1          407            63900
# 10472   2018-07-02  7140546            2         2498            64027
# 10473   2018-07-02  7140546            3         2499            64127
# 10474   2018-07-02  7140546            4         2500            64263
# 10475   2018-07-02  7140546            5         2501            64325
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 10471            63900           63900           63900    1001232  2018  ...
# 10472            64027           64027           64027    1001232  2018  ...
# 10473            64127           64127           64127    1001232  2018  ...
# 10474            64263           64263           64263    1001232  2018  ...
# 10475            64325           64325           64325    1001232  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4941, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84A_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 33D

# %%
lwk = wk[(wk['LINEID'] == '33D')]

# %%
lwk.shape
# Out:
# (1294, 22)

# %%
# Drop Route 33D rows from wk
wk.drop(wk[wk['LINEID'] == '33D'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 12649   2018-07-02  7147145            4         3481            27989
# 12650   2018-07-02  7147145            5         3482            28014
# 12651   2018-07-02  7147145            6         3483            28088
# 12652   2018-07-02  7147145            7         3484            28163
# 12653   2018-07-02  7147145            8         3485            28203
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 12649            27989           27989           27989    1932297  2018  ...
# 12650            28014           28014           28014    1932297  2018  ...
# 12651            28088           28088           28088    1932297  2018  ...
# 12652            28163           28163           28163    1932297  2018  ...
# 12653            28203           28203           28203    1932297  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3647, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33D_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 118

# %%
lwk = wk[(wk['LINEID'] == '118')]

# %%
lwk.shape
# Out:
# (1165, 22)

# %%
# Drop Route 118 rows from wk
wk.drop(wk[wk['LINEID'] == '118'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 17774   2018-07-03  7141289            1         7433            26700
# 17775   2018-07-03  7141289            2         4677            26821
# 17776   2018-07-03  7141289            3         2136            26863
# 17777   2018-07-03  7141289            4         2137            26889
# 17778   2018-07-03  7141289            5         2138            26933
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 17774            26700           26700           26700    1000323  2018  ...
# 17775            26821           26821           26821    1000323  2018  ...
# 17776            26863           26863           26863    1000323  2018  ...
# 17777            26889           26889           26889    1000323  2018  ...
# 17778            26933           26933           26933    1000323  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2482, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_118_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 51X

# %%
lwk = wk[(wk['LINEID'] == '51X')]

# %%
lwk.shape
# Out:
# (1815, 22)

# %%
# Drop Route 51X rows from wk
wk.drop(wk[wk['LINEID'] == '51X'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 33599   2018-07-05  7140231            1         6185            27000
# 33600   2018-07-05  7140231            2         6186            27046
# 33601   2018-07-05  7140231            3         6216            27125
# 33602   2018-07-05  7140231            4         3400            27188
# 33603   2018-07-05  7140231            5         3401            27226
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 33599            27000           27000           27000    2534788  2018  ...
# 33600            27046           27046           27046    2534788  2018  ...
# 33601            27125           27125           27125    2534788  2018  ...
# 33602            27188           27188           27188    2534788  2018  ...
# 33603            27226           27226           27226    2534788  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (667, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51X_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Route 68X

# %%
lwk = wk[(wk['LINEID'] == '68X')]

# %%
lwk.shape
# Out:
# (667, 22)

# %%
# Drop Route 68X rows from wk
wk.drop(wk[wk['LINEID'] == '68X'].index, inplace = True)

# %%
wk.head()
# Out:
# Empty DataFrame
# Columns: [DAYOFSERVICE, TRIPID, PROGRNUMBER, STOPPOINTID, PLANNEDTIME_ARR, PLANNEDTIME_DEP, ACTUALTIME_ARR, ACTUALTIME_DEP, VEHICLEID, year, month, day, id, trip_leave_id, LINEID, num_lineID, DIRECTION, actual_duration, dayOfWeek, weekend, rushHour, actualARR_hour]
# Index: []
#
# [0 rows x 22 columns]

# %%
wk.shape
# Out:
# (0, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68X_tripLeave4_sp8.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_9

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_9.csv', index=False)
