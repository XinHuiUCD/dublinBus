# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 4 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_4.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_23234/3822031000.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_4.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (12137036, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6288856            2         2183            39637
# 1   2018-02-26  6288856            3         2184            39726
# 2   2018-02-26  6288856            4         2185            39821
# 3   2018-02-26  6288856            5         1423            39932
# 4   2018-02-26  6288856            6         1424            39973
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            39637           39637           39637    2534801  2018  ...
# 1            39726           39726           39726    2534801  2018  ...
# 2            39821           39821           39821    2534801  2018  ...
# 3            39932           39932           39932    2534801  2018  ...
# 4            39973           39973           39973    2534801  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 123

# %%
lwk = wk[(wk['LINEID'] == '123')]

# %%
lwk.shape
# Out:
# (312484, 22)

# %%
# Drop Route 123 rows from wk
wk.drop(wk[wk['LINEID'] == '123'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 439   2018-02-26  6288896            2          396            22849
# 440   2018-02-26  6288896            3          397            22876
# 441   2018-02-26  6288896            4          398            22915
# 442   2018-02-26  6288896            5          399            22947
# 443   2018-02-26  6288896            6          400            23005
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 439            22849           22849           22849    1001130  2018  ...
# 440            22876           22876           22876    1001130  2018  ...
# 441            22915           22915           22915    1001130  2018  ...
# 442            22947           22947           22947    1001130  2018  ...
# 443            23005           23005           23005    1001130  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (11824552, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_123_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 15B

# %%
lwk = wk[(wk['LINEID'] == '15B')]

# %%
lwk.shape
# Out:
# (251029, 22)

# %%
# Drop Route 15B rows from wk
wk.drop(wk[wk['LINEID'] == '15B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1177   2018-02-26  6288973            1         2038            25200
# 1178   2018-02-26  6288973            2         2039            25210
# 1179   2018-02-26  6288973            3         2040            25265
# 1180   2018-02-26  6288973            4         2041            25334
# 1181   2018-02-26  6288973            5         2042            25418
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1177            25200           25200           25200    1001178  2018  ...
# 1178            25210           25210           25210    1001178  2018  ...
# 1179            25265           25265           25265    1001178  2018  ...
# 1180            25334           25334           25334    1001178  2018  ...
# 1181            25418           25418           25418    1001178  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (11573523, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15B_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 75

# %%
lwk = wk[(wk['LINEID'] == '75')]

# %%
lwk.shape
# Out:
# (302456, 22)

# %%
# Drop Route 75 rows from wk
wk.drop(wk[wk['LINEID'] == '75'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1911   2018-02-26  6288985            1         1772            59700
# 1912   2018-02-26  6288985            2         1773            59740
# 1913   2018-02-26  6288985            3         1774            59799
# 1914   2018-02-26  6288985            4         1775            59847
# 1915   2018-02-26  6288985            5         1776            59889
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1911            59700           59700           59700    2406921  2018  ...
# 1912            59740           59740           59740    2406921  2018  ...
# 1913            59799           59799           59799    2406921  2018  ...
# 1914            59847           59847           59847    2406921  2018  ...
# 1915            59889           59889           59889    2406921  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (11271067, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_75_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 130

# %%
lwk = wk[(wk['LINEID'] == '130')]

# %%
lwk.shape
# Out:
# (293243, 22)

# %%
# Drop Route 130 rows from wk
wk.drop(wk[wk['LINEID'] == '130'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2288   2018-02-26  6288996            1         7132            29100
# 2289   2018-02-26  6288996            2         6230            29268
# 2290   2018-02-26  6288996            3         6228            29372
# 2291   2018-02-26  6288996            4         4788            29507
# 2292   2018-02-26  6288996            5         6273            29574
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2288            29100           29100           29100    2172268  2018  ...
# 2289            29268           29268           29268    2172268  2018  ...
# 2290            29372           29372           29372    2172268  2018  ...
# 2291            29507           29507           29507    2172268  2018  ...
# 2292            29574           29574           29574    2172268  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10977824, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_130_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 9

# %%
lwk = wk[(wk['LINEID'] == '9')]

# %%
lwk.shape
# Out:
# (431979, 22)

# %%
# Drop Route 9 rows from wk
wk.drop(wk[wk['LINEID'] == '9'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2488   2018-02-26  6289043            1          342            24900
# 2489   2018-02-26  6289043            2         4521            24961
# 2490   2018-02-26  6289043            3         1934            25037
# 2491   2018-02-26  6289043            4         2385            25152
# 2492   2018-02-26  6289043            5         2386            25244
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2488            24900           24900           24900    1000168  2018  ...
# 2489            24961           24961           24961    1000168  2018  ...
# 2490            25037           25037           25037    1000168  2018  ...
# 2491            25152           25152           25152    1000168  2018  ...
# 2492            25244           25244           25244    1000168  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10545845, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_9_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (141582, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2532   2018-02-26  6289045            9         7083            27344
# 2533   2018-02-26  6289045           10         7084            27420
# 2534   2018-02-26  6289045           11         7108            27455
# 2535   2018-02-26  6289045           12         3935            27540
# 2536   2018-02-26  6289045           13         3936            27600
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2532            27344           27344           27344    1001207  2018  ...
# 2533            27420           27420           27420    1001207  2018  ...
# 2534            27455           27455           27455    1001207  2018  ...
# 2535            27540           27540           27540    1001207  2018  ...
# 2536            27600           27600           27600    1001207  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10404263, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 67X

# %%
lwk = wk[(wk['LINEID'] == '67X')]

# %%
lwk.shape
# Out:
# (35101, 22)

# %%
# Drop Route 67X rows from wk
wk.drop(wk[wk['LINEID'] == '67X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2578   2018-02-26  6289046            1         7333            59400
# 2579   2018-02-26  6289046            2          783            59555
# 2580   2018-02-26  6289046            3          784            59590
# 2581   2018-02-26  6289046            4          785            59650
# 2582   2018-02-26  6289046            5          786            59792
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2578            59400           59400           59400    1001207  2018  ...
# 2579            59555           59555           59555    1001207  2018  ...
# 2580            59590           59590           59590    1001207  2018  ...
# 2581            59650           59650           59650    1001207  2018  ...
# 2582            59792           59792           59792    1001207  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10369162, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67X_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (98377, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3109   2018-02-26  6289078            1          395            77400
# 3110   2018-02-26  6289078            2          396            77453
# 3111   2018-02-26  6289078            3          397            77482
# 3112   2018-02-26  6289078            4          398            77525
# 3113   2018-02-26  6289078            5          399            77560
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3109            77400           77400           77400    2693227  2018  ...
# 3110            77453           77453           77453    2693227  2018  ...
# 3111            77482           77482           77482    2693227  2018  ...
# 3112            77525           77525           77525    2693227  2018  ...
# 3113            77560           77560           77560    2693227  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10270785, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 15A

# %%
lwk = wk[(wk['LINEID'] == '15A')]

# %%
lwk.shape
# Out:
# (195117, 22)

# %%
# Drop Route 15A rows from wk
wk.drop(wk[wk['LINEID'] == '15A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3228   2018-02-26  6289091            1         4953            61200
# 3229   2018-02-26  6289091            2          768            61323
# 3230   2018-02-26  6289091            3          769            61380
# 3231   2018-02-26  6289091            4          770            61434
# 3232   2018-02-26  6289091            5          771            61456
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3228            61200           61200           61200    1000762  2018  ...
# 3229            61323           61323           61323    1000762  2018  ...
# 3230            61380           61380           61380    1000762  2018  ...
# 3231            61434           61434           61434    1000762  2018  ...
# 3232            61456           61456           61456    1000762  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10075668, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15A_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 41X

# %%
lwk = wk[(wk['LINEID'] == '41X')]

# %%
lwk.shape
# Out:
# (13911, 22)

# %%
# Drop Route 41X rows from wk
wk.drop(wk[wk['LINEID'] == '41X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3273   2018-02-26  6289092            1         1184            26700
# 3274   2018-02-26  6289092            2          496            26953
# 3275   2018-02-26  6289092            3         7490            27006
# 3276   2018-02-26  6289092            4          497            27027
# 3277   2018-02-26  6289092            5          515            27096
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3273            26700           26700           26700    2534859  2018  ...
# 3274            26953           26953           26953    2534859  2018  ...
# 3275            27006           27006           27006    2534859  2018  ...
# 3276            27027           27027           27027    2534859  2018  ...
# 3277            27096           27096           27096    2534859  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10061757, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41X_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 53

# %%
lwk = wk[(wk['LINEID'] == '53')]

# %%
lwk.shape
# Out:
# (27499, 22)

# %%
# Drop Route 53 rows from wk
wk.drop(wk[wk['LINEID'] == '53'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3511   2018-02-26  6289118            1         4168            28800
# 3512   2018-02-26  6289118            2         4170            28880
# 3513   2018-02-26  6289118            3         4132            28936
# 3514   2018-02-26  6289118            4         4134            29034
# 3515   2018-02-26  6289118            5         4135            29097
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3511            28800           28800           28800    2868381  2018  ...
# 3512            28880           28880           28880    2868381  2018  ...
# 3513            28936           28936           28936    2868381  2018  ...
# 3514            29034           29034           29034    2868381  2018  ...
# 3515            29097           29097           29097    2868381  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10034258, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_53_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (131006, 22)

# %%
# Drop Route 184 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3953   2018-02-26  6289221            1         6122            31500
# 3954   2018-02-26  6289221            2           35            31564
# 3955   2018-02-26  6289221            3           36            31617
# 3956   2018-02-26  6289221            4           37            31686
# 3957   2018-02-26  6289221            5           38            31777
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3953            31500           31500           31500    1000372  2018  ...
# 3954            31564           31564           31564    1000372  2018  ...
# 3955            31617           31617           31617    1000372  2018  ...
# 3956            31686           31686           31686    1000372  2018  ...
# 3957            31777           31777           31777    1000372  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9903252, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave2_sp4.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_5

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_5.csv', index=False)
