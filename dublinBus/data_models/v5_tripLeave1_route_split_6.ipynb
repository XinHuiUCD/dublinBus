# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave1 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (5415303, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5958121            1         7333            42000
# 1   2018-01-01  5958121            2          783            42094
# 2   2018-01-01  5958121            3          784            42119
# 3   2018-01-01  5958121            4          785            42161
# 4   2018-01-01  5958121            5          786            42240
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            42000           42000           42000    2534866  2018  ...
# 1            42094           42094           42094    2534866  2018  ...
# 2            42119           42119           42119    2534866  2018  ...
# 3            42161           42161           42161    2534866  2018  ...
# 4            42240           42240           42240    2534866  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5958121            1         7333            42000
# 1   2018-01-01  5958121            2          783            42094
# 2   2018-01-01  5958121            3          784            42119
# 3   2018-01-01  5958121            4          785            42161
# 4   2018-01-01  5958121            5          786            42240
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            42000           42000           42000    2534866  2018  ...
# 1            42094           42094           42094    2534866  2018  ...
# 2            42119           42119           42119    2534866  2018  ...
# 3            42161           42161           42161    2534866  2018  ...
# 4            42240           42240           42240    2534866  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 39

# %%
lwk = wk[(wk['LINEID'] == '39')]

# %%
lwk.shape
# Out:
# (265971, 22)

# %%
# Drop Route 39 rows from wk
wk.drop(wk[wk['LINEID'] == '39'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 357   2018-01-01  5958182           15           48            42149
# 358   2018-01-01  5958182           16           49            42234
# 359   2018-01-01  5958182           17           51            42328
# 360   2018-01-01  5958182           18           52            42379
# 361   2018-01-01  5958182           19          265            42513
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 357            42149           42149           42149    2172281  2018  ...
# 358            42234           42234           42234    2172281  2018  ...
# 359            42328           42328           42328    2172281  2018  ...
# 360            42379           42379           42379    2172281  2018  ...
# 361            42513           42513           42513    2172281  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5149332, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (137870, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 888   2018-01-01  5958189            1          324            33600
# 889   2018-01-01  5958189            7         1634            33782
# 890   2018-01-01  5958189            8         1635            33794
# 891   2018-01-01  5958189            9         1636            33841
# 892   2018-01-01  5958189           10         1637            33967
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 888            33600           33600           33600    1000205  2018  ...
# 889            33782           33782           33782    1000205  2018  ...
# 890            33794           33794           33794    1000205  2018  ...
# 891            33841           33841           33841    1000205  2018  ...
# 892            33967           33967           33967    1000205  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5011462, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 27B

# %%
lwk = wk[(wk['LINEID'] == '27B')]

# %%
lwk.shape
# Out:
# (230854, 22)

# %%
# Drop Route 27B rows from wk
wk.drop(wk[wk['LINEID'] == '27B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1343   2018-01-01  5958199            4         4659            32528
# 1344   2018-01-01  5958199            5         4660            32581
# 1345   2018-01-01  5958199            6         4661            32606
# 1346   2018-01-01  5958199            7         4238            32717
# 1347   2018-01-01  5958199            8         4239            32738
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1343            32528           32528           32528    2172244  2018  ...
# 1344            32581           32581           32581    2172244  2018  ...
# 1345            32606           32606           32606    2172244  2018  ...
# 1346            32717           32717           32717    2172244  2018  ...
# 1347            32738           32738           32738    2172244  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4780608, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27B_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (130112, 22)

# %%
# Drop Route 4 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2008   2018-01-01  5958369            4         1173            83860
# 2009   2018-01-01  5958369            5         1174            83939
# 2010   2018-01-01  5958369            6         1175            84034
# 2011   2018-01-01  5958369            7           15            84105
# 2012   2018-01-01  5958369            8           17            84167
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2008            83860           83860           83860    2534802  2018  ...
# 2009            83939           83939           83939    2534802  2018  ...
# 2010            84034           84034           84034    2534802  2018  ...
# 2011            84105           84105           84105    2534802  2018  ...
# 2012            84167           84167           84167    2534802  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4650496, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 41B

# %%
lwk = wk[(wk['LINEID'] == '41B')]

# %%
lwk.shape
# Out:
# (21305, 22)

# %%
# Drop Route 41B rows from wk
wk.drop(wk[wk['LINEID'] == '41B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2129   2018-01-01  5958904            1         3624            34200
# 2130   2018-01-01  5958904            2         3587            34281
# 2131   2018-01-01  5958904            3         3588            34337
# 2132   2018-01-01  5958904            4         3590            34362
# 2133   2018-01-01  5958904            5         3589            34409
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2129            34200           34200           34200    1932328  2018  ...
# 2130            34281           34281           34281    1932328  2018  ...
# 2131            34337           34337           34337    1932328  2018  ...
# 2132            34362           34362           34362    1932328  2018  ...
# 2133            34409           34409           34409    1932328  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4629191, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41B_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 32

# %%
lwk = wk[(wk['LINEID'] == '32')]

# %%
lwk.shape
# Out:
# (138623, 22)

# %%
# Drop Route 32 rows from wk
wk.drop(wk[wk['LINEID'] == '32'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2188   2018-01-01  5958905            1          621            36900
# 2189   2018-01-01  5958905            2          289            37137
# 2190   2018-01-01  5958905            3          496            37336
# 2191   2018-01-01  5958905            4         7490            37373
# 2192   2018-01-01  5958905            5          515            37469
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2188            36900           36900           36900    1932328  2018  ...
# 2189            37137           37137           37137    1932328  2018  ...
# 2190            37336           37336           37336    1932328  2018  ...
# 2191            37373           37373           37373    1932328  2018  ...
# 2192            37469           37469           37469    1932328  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4490568, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 31

# %%
lwk = wk[(wk['LINEID'] == '31')]

# %%
lwk.shape
# Out:
# (205301, 22)

# %%
# Drop Route 31 rows from wk
wk.drop(wk[wk['LINEID'] == '31'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2569   2018-01-01  5959026            1         2670            36900
# 2570   2018-01-01  5959026            2         2910            36939
# 2571   2018-01-01  5959026            3         2911            36983
# 2572   2018-01-01  5959026            4         7507            37014
# 2573   2018-01-01  5959026            5         2663            37044
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2569            36900           36900           36900    1932306  2018  ...
# 2570            36939           36939           36939    1932306  2018  ...
# 2571            36983           36983           36983    1932306  2018  ...
# 2572            37014           37014           37014    1932306  2018  ...
# 2573            37044           37044           37044    1932306  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4285267, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 79

# %%
lwk = wk[(wk['LINEID'] == '79')]

# %%
lwk.shape
# Out:
# (114723, 22)

# %%
# Drop Route 79 rows from wk
wk.drop(wk[wk['LINEID'] == '79'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3161   2018-01-01  5959380            1          767            32400
# 3162   2018-01-01  5959380            2          768            32503
# 3163   2018-01-01  5959380            3          769            32527
# 3164   2018-01-01  5959380            4          770            32565
# 3165   2018-01-01  5959380            5          771            32581
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3161            32400           32400           32400    2172316  2018  ...
# 3162            32503           32503           32503    2172316  2018  ...
# 3163            32527           32527           32527    2172316  2018  ...
# 3164            32565           32565           32565    2172316  2018  ...
# 3165            32581           32581           32581    2172316  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4170544, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 39A

# %%
lwk = wk[(wk['LINEID'] == '39A')]

# %%
lwk.shape
# Out:
# (560961, 22)

# %%
# Drop Route 39A rows from wk
wk.drop(wk[wk['LINEID'] == '39A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3305   2018-01-01  5959464            4         3735            32468
# 3306   2018-01-01  5959464            6         7204            32565
# 3307   2018-01-01  5959464            7         3739            32704
# 3308   2018-01-01  5959464            8         3738            32770
# 3309   2018-01-01  5959464            9         7170            32811
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3305            32468           32468           32468    1001153  2018  ...
# 3306            32565           32565           32565    1001153  2018  ...
# 3307            32704           32704           32704    1001153  2018  ...
# 3308            32770           32770           32770    1001153  2018  ...
# 3309            32811           32811           32811    1001153  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3609583, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39A_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 33B

# %%
lwk = wk[(wk['LINEID'] == '33B')]

# %%
lwk.shape
# Out:
# (48081, 22)

# %%
# Drop Route 33B rows from wk
wk.drop(wk[wk['LINEID'] == '33B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3715   2018-01-01  5959530            1         7149            39600
# 3716   2018-01-01  5959530            2         7277            39685
# 3717   2018-01-01  5959530            3         6363            39806
# 3718   2018-01-01  5959530            4         6361            39888
# 3719   2018-01-01  5959530            5         6367            39920
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3715            39600           39600           39600    2693190  2018  ...
# 3716            39685           39685           39685    2693190  2018  ...
# 3717            39806           39806           39806    2693190  2018  ...
# 3718            39888           39888           39888    2693190  2018  ...
# 3719            39920           39920           39920    2693190  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3561502, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33B_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 140

# %%
lwk = wk[(wk['LINEID'] == '140')]

# %%
lwk.shape
# Out:
# (280843, 22)

# %%
# Drop Route 140 rows from wk
wk.drop(wk[wk['LINEID'] == '140'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4257   2018-01-01  5959559            1         4342            34200
# 4258   2018-01-01  5959559            2         4348            34283
# 4259   2018-01-01  5959559            3         7122            34405
# 4260   2018-01-01  5959559            4         7121            34468
# 4261   2018-01-01  5959559            5         7183            34498
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4257            34200           34200           34200    1932331  2018  ...
# 4258            34283           34283           34283    1932331  2018  ...
# 4259            34405           34405           34405    1932331  2018  ...
# 4260            34468           34468           34468    1932331  2018  ...
# 4261            34498           34498           34498    1932331  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3280659, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_140_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (143181, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4893   2018-01-01  5959710            1         2243            54000
# 4894   2018-01-01  5959710            2         2200            54050
# 4895   2018-01-01  5959710            3         5006            54127
# 4896   2018-01-01  5959710            4         5007            54170
# 4897   2018-01-01  5959710            5         2655            54259
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4893            54000           54000           54000    2693292  2018  ...
# 4894            54050           54050           54050    2693292  2018  ...
# 4895            54127           54127           54127    2693292  2018  ...
# 4896            54170           54170           54170    2693292  2018  ...
# 4897            54259           54259           54259    2693292  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3137478, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Route 76

# %%
lwk = wk[(wk['LINEID'] == '76')]

# %%
lwk.shape
# Out:
# (125223, 22)

# %%
# Drop Route 76 rows from wk
wk.drop(wk[wk['LINEID'] == '76'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5309   2018-01-01  5959946            1         1730            33000
# 5310   2018-01-01  5959946            2         1731            33018
# 5311   2018-01-01  5959946            3         1732            33049
# 5312   2018-01-01  5959946            4         1733            33080
# 5313   2018-01-01  5959946            5         1650            33118
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5309            33000           33000           33000    2868354  2018  ...
# 5310            33018           33018           33018    2868354  2018  ...
# 5311            33049           33049           33049    2868354  2018  ...
# 5312            33080           33080           33080    2868354  2018  ...
# 5313            33118           33118           33118    2868354  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3012255, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76_tripLeave1_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave1_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave1_route_split_7.csv', index=False)
