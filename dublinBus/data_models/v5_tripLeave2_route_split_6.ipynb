# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_26677/3796933060.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (7988354, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6289451            1         2492            48600
# 1   2018-02-26  6289451            2         2493            48650
# 2   2018-02-26  6289451            3         2465            48683
# 3   2018-02-26  6289451            4         2466            48709
# 4   2018-02-26  6289451            5         2467            48748
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            48600           48600           48600    1932315  2018  ...
# 1            48650           48650           48650    1932315  2018  ...
# 2            48683           48683           48683    1932315  2018  ...
# 3            48709           48709           48709    1932315  2018  ...
# 4            48748           48748           48748    1932315  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 83A

# %%
lwk = wk[(wk['LINEID'] == '83A')]

# %%
lwk.shape
# Out:
# (93528, 22)

# %%
# Drop Route 83A rows from wk
wk.drop(wk[wk['LINEID'] == '83A'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 69   2018-02-26  6289463            1          381            26400
# 70   2018-02-26  6289463            2          382            26454
# 71   2018-02-26  6289463            3         4451            26474
# 72   2018-02-26  6289463            4          383            26521
# 73   2018-02-26  6289463            5          384            26575
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 69            26400           26400           26400    2534838  2018  ...
# 70            26454           26454           26454    2534838  2018  ...
# 71            26474           26474           26474    2534838  2018  ...
# 72            26521           26521           26521    2534838  2018  ...
# 73            26575           26575           26575    2534838  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7894826, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83A_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 1

# %%
lwk = wk[(wk['LINEID'] == '1')]

# %%
lwk.shape
# Out:
# (195296, 22)

# %%
# Drop Route 1 rows from wk
wk.drop(wk[wk['LINEID'] == '1'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 495   2018-02-26  6289474            1         5044            22800
# 496   2018-02-26  6289474            2         4433            22902
# 497   2018-02-26  6289474            3         3752            23123
# 498   2018-02-26  6289474            4         3751            23168
# 499   2018-02-26  6289474            5         3689            23233
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 495            22800           22800           22800    1001070  2018  ...
# 496            22902           22902           22902    1001070  2018  ...
# 497            23123           23123           23123    1001070  2018  ...
# 498            23168           23168           23168    1001070  2018  ...
# 499            23233           23233           23233    1001070  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7699530, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_1_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (130063, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 750   2018-02-26  6289523            1          807            60000
# 751   2018-02-26  6289523            2          808            60089
# 752   2018-02-26  6289523            3          809            60141
# 753   2018-02-26  6289523            4          810            60223
# 754   2018-02-26  6289523            5          811            60274
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 750            60000           60000           60000    2406918  2018  ...
# 751            60089           60089           60089    2406918  2018  ...
# 752            60141           60141           60141    2406918  2018  ...
# 753            60223           60223           60223    2406918  2018  ...
# 754            60274           60274           60274    2406918  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7569467, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 46A

# %%
lwk = wk[(wk['LINEID'] == '46A')]

# %%
lwk.shape
# Out:
# (711200, 22)

# %%
# Drop Route 46A rows from wk
wk.drop(wk[wk['LINEID'] == '46A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 809   2018-02-26  6289527            4         1173            59262
# 810   2018-02-26  6289527            5         1174            59340
# 811   2018-02-26  6289527            6         1175            59445
# 812   2018-02-26  6289527            7           15            59522
# 813   2018-02-26  6289527            8           17            59617
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 809            59262           59262           59262    2868390  2018  ...
# 810            59340           59340           59340    2868390  2018  ...
# 811            59445           59445           59445    2868390  2018  ...
# 812            59522           59522           59522    2868390  2018  ...
# 813            59617           59617           59617    2868390  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6858267, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46A_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 41B

# %%
lwk = wk[(wk['LINEID'] == '41B')]

# %%
lwk.shape
# Out:
# (22107, 22)

# %%
# Drop Route 41B rows from wk
wk.drop(wk[wk['LINEID'] == '41B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 903   2018-02-26  6289591            1         7229            28800
# 904   2018-02-26  6289591            2         4617            28941
# 905   2018-02-26  6289591            3         4555            28965
# 906   2018-02-26  6289591            4         4576            29060
# 907   2018-02-26  6289591            5         3418            29133
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 903            28800           28800           28800    2172299  2018  ...
# 904            28941           28941           28941    2172299  2018  ...
# 905            28965           28965           28965    2172299  2018  ...
# 906            29060           29060           29060    2172299  2018  ...
# 907            29133           29133           29133    2172299  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6836160, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41B_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 13

# %%
lwk = wk[(wk['LINEID'] == '13')]

# %%
lwk.shape
# Out:
# (413126, 22)

# %%
# Drop Route 13 rows from wk
wk.drop(wk[wk['LINEID'] == '13'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1263   2018-02-26  6289617            1         3085            49200
# 1264   2018-02-26  6289617            2         3082            49334
# 1265   2018-02-26  6289617            3         3165            49407
# 1266   2018-02-26  6289617            4         3166            49517
# 1267   2018-02-26  6289617            5         3167            49540
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1263            49200           49200           49200    1000724  2018  ...
# 1264            49334           49334           49334    1000724  2018  ...
# 1265            49407           49407           49407    1000724  2018  ...
# 1266            49517           49517           49517    1000724  2018  ...
# 1267            49540           49540           49540    1000724  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6423034, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_13_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 114

# %%
lwk = wk[(wk['LINEID'] == '114')]

# %%
lwk.shape
# Out:
# (35345, 22)

# %%
# Drop Route 114 rows from wk
wk.drop(wk[wk['LINEID'] == '114'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1520   2018-02-26  6289626            1         3677            57600
# 1521   2018-02-26  6289626            2         3678            57643
# 1522   2018-02-26  6289626            3         3679            57693
# 1523   2018-02-26  6289626            4         3711            57726
# 1524   2018-02-26  6289626            5         3712            57761
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1520            57600           57600           57600    2693253  2018  ...
# 1521            57643           57643           57643    2693253  2018  ...
# 1522            57693           57693           57693    2693253  2018  ...
# 1523            57726           57726           57726    2693253  2018  ...
# 1524            57761           57761           57761    2693253  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6387689, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_114_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 33A

# %%
lwk = wk[(wk['LINEID'] == '33A')]

# %%
lwk.shape
# Out:
# (33544, 22)

# %%
# Drop Route 33A rows from wk
wk.drop(wk[wk['LINEID'] == '33A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1584   2018-02-26  6289627            1         6048            61200
# 1585   2018-02-26  6289627            2         5064            61224
# 1586   2018-02-26  6289627            3         7173            61275
# 1587   2018-02-26  6289627            4         3811            61320
# 1588   2018-02-26  6289627            5         3812            61333
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1584            61200           61200           61200    2693253  2018  ...
# 1585            61224           61224           61224    2693253  2018  ...
# 1586            61275           61275           61275    2693253  2018  ...
# 1587            61320           61320           61320    2693253  2018  ...
# 1588            61333           61333           61333    2693253  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6354145, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33A_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 33

# %%
lwk = wk[(wk['LINEID'] == '33')]

# %%
lwk.shape
# Out:
# (220179, 22)

# %%
# Drop Route 33 rows from wk
wk.drop(wk[wk['LINEID'] == '33'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2389   2018-02-26  6289675            1          328            61200
# 2390   2018-02-26  6289675            2         1443            61307
# 2391   2018-02-26  6289675            3         1444            61387
# 2392   2018-02-26  6289675            4         1445            61475
# 2393   2018-02-26  6289675            5         1647            61623
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2389            61200           61200           61200    2868312  2018  ...
# 2390            61307           61307           61307    2868312  2018  ...
# 2391            61387           61387           61387    2868312  2018  ...
# 2392            61475           61475           61475    2868312  2018  ...
# 2393            61623           61623           61623    2868312  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6133966, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 39A

# %%
lwk = wk[(wk['LINEID'] == '39A')]

# %%
lwk.shape
# Out:
# (562943, 22)

# %%
# Drop Route 39A rows from wk
wk.drop(wk[wk['LINEID'] == '39A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2438   2018-02-26  6289686            1         4745            58560
# 2439   2018-02-26  6289686            2         4989            58590
# 2440   2018-02-26  6289686            3         4990            58729
# 2441   2018-02-26  6289686            4         4991            58755
# 2442   2018-02-26  6289686            5         4992            58793
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2438            58560           58560           58560    1000599  2018  ...
# 2439            58590           58590           58590    1000599  2018  ...
# 2440            58729           58729           58729    1000599  2018  ...
# 2441            58755           58755           58755    1000599  2018  ...
# 2442            58793           58793           58793    1000599  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5571023, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39A_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 38A

# %%
lwk = wk[(wk['LINEID'] == '38A')]

# %%
lwk.shape
# Out:
# (126617, 22)

# %%
# Drop Route 38A rows from wk
wk.drop(wk[wk['LINEID'] == '38A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2544   2018-02-26  6289688            1         4745            70200
# 2545   2018-02-26  6289688            2         4989            70221
# 2546   2018-02-26  6289688            3         4990            70318
# 2547   2018-02-26  6289688            4         4991            70336
# 2548   2018-02-26  6289688            5         4992            70363
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2544            70200           70200           70200    1000599  2018  ...
# 2545            70221           70221           70221    1000599  2018  ...
# 2546            70318           70318           70318    1000599  2018  ...
# 2547            70336           70336           70336    1000599  2018  ...
# 2548            70363           70363           70363    1000599  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5444406, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38A_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 38

# %%
lwk = wk[(wk['LINEID'] == '38')]

# %%
lwk.shape
# Out:
# (168302, 22)

# %%
# Drop Route 38 rows from wk
wk.drop(wk[wk['LINEID'] == '38'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2604   2018-02-26  6289689            1         4341            23400
# 2605   2018-02-26  6289689            2         4348            23459
# 2606   2018-02-26  6289689            3         4646            23518
# 2607   2018-02-26  6289689            4         4647            23546
# 2608   2018-02-26  6289689            5         2363            23601
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2604            23400           23400           23400    2534833  2018  ...
# 2605            23459           23459           23459    2534833  2018  ...
# 2606            23518           23518           23518    2534833  2018  ...
# 2607            23546           23546           23546    2534833  2018  ...
# 2608            23601           23601           23601    2534833  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5276104, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Route 76

# %%
lwk = wk[(wk['LINEID'] == '76')]

# %%
lwk.shape
# Out:
# (121038, 22)

# %%
# Drop Route 76 rows from wk
wk.drop(wk[wk['LINEID'] == '76'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3121   2018-02-26  6289802            1         7158            26520
# 3122   2018-02-26  6289802            2         7048            26565
# 3123   2018-02-26  6289802            3         7159            26640
# 3124   2018-02-26  6289802            4         7388            26660
# 3125   2018-02-26  6289802            5         7017            26767
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3121            26520           26520           26520    2406908  2018  ...
# 3122            26565           26565           26565    2406908  2018  ...
# 3123            26640           26640           26640    2406908  2018  ...
# 3124            26660           26660           26660    2406908  2018  ...
# 3125            26767           26767           26767    2406908  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5155066, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76_tripLeave2_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_7.csv', index=False)
