# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave3 route split 5 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave3_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (7510861, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6653625            1          621            54900
# 1   2018-04-29  6653625            2          289            55047
# 2   2018-04-29  6653625            3          496            55171
# 3   2018-04-29  6653625            4         7490            55194
# 4   2018-04-29  6653625            5          515            55285
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            54900           54900           54900    1000780  2018  ...
# 1            55047           55047           55047    1000780  2018  ...
# 2            55171           55171           55171    1000780  2018  ...
# 3            55194           55194           55194    1000780  2018  ...
# 4            55285           55285           55285    1000780  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 31A

# %%
lwk = wk[(wk['LINEID'] == '31A')]

# %%
lwk.shape
# Out:
# (71121, 22)

# %%
# Drop Route 31A rows from wk
wk.drop(wk[wk['LINEID'] == '31A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 143   2018-04-29  6654102            1         2037            38700
# 144   2018-04-29  6654102            2         2040            38718
# 145   2018-04-29  6654102            3         3047            38783
# 146   2018-04-29  6654102            4         3202            38810
# 147   2018-04-29  6654102            5         3203            38872
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 143            38700           38700           38700    1001184  2018  ...
# 144            38718           38718           38718    1001184  2018  ...
# 145            38783           38783           38783    1001184  2018  ...
# 146            38810           38810           38810    1001184  2018  ...
# 147            38872           38872           38872    1001184  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7439740, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31A_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 45A

# %%
lwk = wk[(wk['LINEID'] == '45A')]

# %%
lwk.shape
# Out:
# (184090, 22)

# %%
# Drop Route 45A rows from wk
wk.drop(wk[wk['LINEID'] == '45A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 672   2018-04-29  6654309            1         2037            36000
# 673   2018-04-29  6654309            2         3046            36051
# 674   2018-04-29  6654309            3         3047            36118
# 675   2018-04-29  6654309            4         3048            36184
# 676   2018-04-29  6654309            5         3049            36215
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 672            36000           36000           36000    1000243  2018  ...
# 673            36051           36051           36051    1000243  2018  ...
# 674            36118           36118           36118    1000243  2018  ...
# 675            36184           36184           36184    1000243  2018  ...
# 676            36215           36215           36215    1000243  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7255650, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_45A_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 59

# %%
lwk = wk[(wk['LINEID'] == '59')]

# %%
lwk.shape
# Out:
# (43699, 22)

# %%
# Drop Route 59 rows from wk
wk.drop(wk[wk['LINEID'] == '59'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1309   2018-04-29  6654401            1         4620            32520
# 1310   2018-04-29  6654401            2         7563            32572
# 1311   2018-04-29  6654401            3         3368            32628
# 1312   2018-04-29  6654401            4         4626            32699
# 1313   2018-04-29  6654401            5         4627            32740
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1309            32520           32520           32520    1000930  2018  ...
# 1310            32572           32572           32572    1000930  2018  ...
# 1311            32628           32628           32628    1000930  2018  ...
# 1312            32699           32699           32699    1000930  2018  ...
# 1313            32740           32740           32740    1000930  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7211951, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_59_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 25A

# %%
lwk = wk[(wk['LINEID'] == '25A')]

# %%
lwk.shape
# Out:
# (180976, 22)

# %%
# Drop Route 25A rows from wk
wk.drop(wk[wk['LINEID'] == '25A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1503   2018-04-29  6654406            1         7391            51420
# 1504   2018-04-29  6654406            2          493            51536
# 1505   2018-04-29  6654406            3          494            51626
# 1506   2018-04-29  6654406            4          495            51732
# 1507   2018-04-29  6654406            5          400            51817
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1503            51420           51420           51420    1000930  2018  ...
# 1504            51536           51536           51536    1000930  2018  ...
# 1505            51626           51626           51626    1000930  2018  ...
# 1506            51732           51732           51732    1000930  2018  ...
# 1507            51817           51817           51817    1000930  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7030975, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25A_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 25B

# %%
lwk = wk[(wk['LINEID'] == '25B')]

# %%
lwk.shape
# Out:
# (169519, 22)

# %%
# Drop Route 25B rows from wk
wk.drop(wk[wk['LINEID'] == '25B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1849   2018-04-29  6654431            1         3980            34200
# 1850   2018-04-29  6654431            2         6089            34270
# 1851   2018-04-29  6654431            3         3981            34374
# 1852   2018-04-29  6654431            4         3982            34425
# 1853   2018-04-29  6654431            5         3983            34563
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1849            34200           34200           34200    2868375  2018  ...
# 1850            34270           34270           34270    2868375  2018  ...
# 1851            34374           34374           34374    2868375  2018  ...
# 1852            34425           34425           34425    2868375  2018  ...
# 1853            34563           34563           34563    2868375  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6861456, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25B_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 66

# %%
lwk = wk[(wk['LINEID'] == '66')]

# %%
lwk.shape
# Out:
# (179355, 22)

# %%
# Drop Route 66 rows from wk
wk.drop(wk[wk['LINEID'] == '66'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2179   2018-04-29  6654467            1         6041            46800
# 2180   2018-04-29  6654467            2         2826            46899
# 2181   2018-04-29  6654467            3         2842            46953
# 2182   2018-04-29  6654467            4         2843            47021
# 2183   2018-04-29  6654467            5         2844            47046
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2179            46800           46800           46800    2693201  2018  ...
# 2180            46899           46899           46899    2693201  2018  ...
# 2181            46953           46953           46953    2693201  2018  ...
# 2182            47021           47021           47021    2693201  2018  ...
# 2183            47046           47046           47046    2693201  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6682101, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 14

# %%
lwk = wk[(wk['LINEID'] == '14')]

# %%
lwk.shape
# Out:
# (408741, 22)

# %%
# Drop Route 14 rows from wk
wk.drop(wk[wk['LINEID'] == '14'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2556   2018-04-29  6654560            1         6282            32400
# 2557   2018-04-29  6654560            2         6335            32465
# 2558   2018-04-29  6654560            3         6326            32507
# 2559   2018-04-29  6654560            4         4886            32543
# 2560   2018-04-29  6654560            5         4887            32641
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2556            32400           32400           32400    2868400  2018  ...
# 2557            32465           32465           32465    2868400  2018  ...
# 2558            32507           32507           32507    2868400  2018  ...
# 2559            32543           32543           32543    2868400  2018  ...
# 2560            32641           32641           32641    2868400  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6273360, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_14_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Route 15

# %%
lwk = wk[(wk['LINEID'] == '15')]

# %%
lwk.shape
# Out:
# (616654, 22)

# %%
# Drop Route 15 rows from wk
wk.drop(wk[wk['LINEID'] == '15'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3493   2018-04-29  6654629            1         4745            30600
# 3494   2018-04-29  6654629            2         4989            30618
# 3495   2018-04-29  6654629            3         4990            30703
# 3496   2018-04-29  6654629            4         4991            30719
# 3497   2018-04-29  6654629            5         4992            30742
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3493            30600           30600           30600    1000909  2018  ...
# 3494            30618           30618           30618    1000909  2018  ...
# 3495            30703           30703           30703    1000909  2018  ...
# 3496            30719           30719           30719    1000909  2018  ...
# 3497            30742           30742           30742    1000909  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5656706, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15_tripLeave3_sp5.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave3_route_split_6

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave3_route_split_6.csv', index=False)
