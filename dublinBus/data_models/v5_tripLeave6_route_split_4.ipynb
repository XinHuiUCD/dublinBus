# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 route split 4 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave6_route_split_4.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (6323987, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-09  8092685            1          300            46800
# 1   2018-09-09  8092685            2          496            46888
# 2   2018-09-09  8092685            3         7490            46905
# 3   2018-09-09  8092685            4          497            46929
# 4   2018-09-09  8092685            5          515            47009
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            46800           46800           46800    2406899  2018  ...
# 1            46888           46888           46888    2406899  2018  ...
# 2            46905           46905           46905    2406899  2018  ...
# 3            46929           46929           46929    2406899  2018  ...
# 4            47009           47009           47009    2406899  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 27A

# %%
lwk = wk[(wk['LINEID'] == '27A')]

# %%
lwk.shape
# Out:
# (117724, 22)

# %%
# Drop Route 27A rows from wk
wk.drop(wk[wk['LINEID'] == '27A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 553   2018-09-09  8092784            1         4606            43200
# 554   2018-09-09  8092784            2         7142            43312
# 555   2018-09-09  8092784            3         7015            43404
# 556   2018-09-09  8092784            4         4617            43488
# 557   2018-09-09  8092784            5         4555            43506
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 553            43200           43200           43200    1932308  2018  ...
# 554            43312           43312           43312    1932308  2018  ...
# 555            43404           43404           43404    1932308  2018  ...
# 556            43488           43488           43488    1932308  2018  ...
# 557            43506           43506           43506    1932308  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6206263, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27A_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 151

# %%
lwk = wk[(wk['LINEID'] == '151')]

# %%
lwk.shape
# Out:
# (236932, 22)

# %%
# Drop Route 151 rows from wk
wk.drop(wk[wk['LINEID'] == '151'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 806   2018-09-09  8092809            1          449            35400
# 807   2018-09-09  8092809            2          450            35431
# 808   2018-09-09  8092809            3         3181            35493
# 809   2018-09-09  8092809            4          451            35522
# 810   2018-09-09  8092809            5          447            35565
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 806            35400           35400           35400    2172286  2018  ...
# 807            35431           35431           35431    2172286  2018  ...
# 808            35493           35493           35493    2172286  2018  ...
# 809            35522           35522           35522    2172286  2018  ...
# 810            35565           35565           35565    2172286  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5969331, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_151_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 11

# %%
lwk = wk[(wk['LINEID'] == '11')]

# %%
lwk.shape
# Out:
# (265161, 22)

# %%
# Drop Route 11 rows from wk
wk.drop(wk[wk['LINEID'] == '11'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1418   2018-09-09  8092840            1         4745            36300
# 1419   2018-09-09  8092840            2         4989            36320
# 1420   2018-09-09  8092840            3         4990            36413
# 1421   2018-09-09  8092840            4         4991            36430
# 1422   2018-09-09  8092840            5         4992            36455
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1418            36300           36300           36300    1000924  2018  ...
# 1419            36320           36320           36320    1000924  2018  ...
# 1420            36413           36413           36413    1000924  2018  ...
# 1421            36430           36430           36430    1000924  2018  ...
# 1422            36455           36455           36455    1000924  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5704170, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_11_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 38A

# %%
lwk = wk[(wk['LINEID'] == '38A')]

# %%
lwk.shape
# Out:
# (125018, 22)

# %%
# Drop Route 38A rows from wk
wk.drop(wk[wk['LINEID'] == '38A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1518   2018-09-09  8092842            1         4745            44700
# 1519   2018-09-09  8092842            2         4989            44719
# 1520   2018-09-09  8092842            3         4990            44808
# 1521   2018-09-09  8092842            4         4991            44825
# 1522   2018-09-09  8092842            5         4992            44849
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1518            44700           44700           44700    1000924  2018  ...
# 1519            44719           44719           44719    1000924  2018  ...
# 1520            44808           44808           44808    1000924  2018  ...
# 1521            44825           44825           44825    1000924  2018  ...
# 1522            44849           44849           44849    1000924  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5579152, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38A_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 38

# %%
lwk = wk[(wk['LINEID'] == '38')]

# %%
lwk.shape
# Out:
# (166724, 22)

# %%
# Drop Route 38 rows from wk
wk.drop(wk[wk['LINEID'] == '38'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1887   2018-09-09  8092897            1         7149            54000
# 1888   2018-09-09  8092897            2         7277            54060
# 1889   2018-09-09  8092897            3         6363            54145
# 1890   2018-09-09  8092897            4         6361            54202
# 1891   2018-09-09  8092897            5         6367            54233
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1887            54000           54000           54000    2534869  2018  ...
# 1888            54060           54060           54060    2534869  2018  ...
# 1889            54145           54145           54145    2534869  2018  ...
# 1890            54202           54202           54202    2534869  2018  ...
# 1891            54233           54233           54233    2534869  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5412428, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 140

# %%
lwk = wk[(wk['LINEID'] == '140')]

# %%
lwk.shape
# Out:
# (309414, 22)

# %%
# Drop Route 140 rows from wk
wk.drop(wk[wk['LINEID'] == '140'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2112   2018-09-09  8092938            1         3917            36900
# 2113   2018-09-09  8092938            2         3918            36952
# 2114   2018-09-09  8092938            3         3926            37004
# 2115   2018-09-09  8092938            4         7074            37053
# 2116   2018-09-09  8092938            5         3919            37127
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2112            36900           36900           36900    2693213  2018  ...
# 2113            36952           36952           36952    2693213  2018  ...
# 2114            37004           37004           37004    2693213  2018  ...
# 2115            37053           37053           37053    2693213  2018  ...
# 2116            37127           37127           37127    2693213  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5103014, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_140_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 67

# %%
lwk = wk[(wk['LINEID'] == '67')]

# %%
lwk.shape
# Out:
# (240579, 22)

# %%
# Drop Route 67 rows from wk
wk.drop(wk[wk['LINEID'] == '67'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2533   2018-09-09  8092993            1         7158            48000
# 2534   2018-09-09  8092993            2         7048            48042
# 2535   2018-09-09  8092993            3         7159            48111
# 2536   2018-09-09  8092993            4         7388            48130
# 2537   2018-09-09  8092993            5         7017            48229
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2533            48000           48000           48000    2693231  2018  ...
# 2534            48042           48042           48042    2693231  2018  ...
# 2535            48111           48111           48111    2693231  2018  ...
# 2536            48130           48130           48130    2693231  2018  ...
# 2537            48229           48229           48229    2693231  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4862435, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 39A

# %%
lwk = wk[(wk['LINEID'] == '39A')]

# %%
lwk.shape
# Out:
# (573268, 22)

# %%
# Drop Route 39A rows from wk
wk.drop(wk[wk['LINEID'] == '39A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2821   2018-09-09  8093144            1          324            56100
# 2822   2018-09-09  8093144            7         1634            56333
# 2823   2018-09-09  8093144            8         1635            56345
# 2824   2018-09-09  8093144            9         1636            56396
# 2825   2018-09-09  8093144           10         1637            56483
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2821            56100           56100           56100    1000204  2018  ...
# 2822            56333           56333           56333    1000204  2018  ...
# 2823            56345           56345           56345    1000204  2018  ...
# 2824            56396           56396           56396    1000204  2018  ...
# 2825            56483           56483           56483    1000204  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4289167, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39A_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 27B

# %%
lwk = wk[(wk['LINEID'] == '27B')]

# %%
lwk.shape
# Out:
# (250227, 22)

# %%
# Drop Route 27B rows from wk
wk.drop(wk[wk['LINEID'] == '27B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3740   2018-09-09  8093192           20          319            37076
# 3741   2018-09-09  8093192           21          278            37304
# 3742   2018-09-09  8093192           22         7615            37433
# 3743   2018-09-09  8093192           23           10            37450
# 3744   2018-09-09  8093192           24           12            37566
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3740            37076           37076           37076    2693209  2018  ...
# 3741            37304           37304           37304    2693209  2018  ...
# 3742            37433           37433           37433    2693209  2018  ...
# 3743            37450           37450           37450    2693209  2018  ...
# 3744            37566           37566           37566    2693209  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4038940, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27B_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 1

# %%
lwk = wk[(wk['LINEID'] == '1')]

# %%
lwk.shape
# Out:
# (281893, 22)

# %%
# Drop Route 1 rows from wk
wk.drop(wk[wk['LINEID'] == '1'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4146   2018-09-09  8093225            1         3605            42600
# 4147   2018-09-09  8093225            2         3606            42647
# 4148   2018-09-09  8093225            3         3607            42702
# 4149   2018-09-09  8093225            4         6051            42716
# 4150   2018-09-09  8093225            5         6053            42759
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4146            42600           42600           42600    2693207  2018  ...
# 4147            42647           42647           42647    2693207  2018  ...
# 4148            42702           42702           42702    2693207  2018  ...
# 4149            42716           42716           42716    2693207  2018  ...
# 4150            42759           42759           42759    2693207  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3757047, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_1_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 42

# %%
lwk = wk[(wk['LINEID'] == '42')]

# %%
lwk.shape
# Out:
# (244461, 22)

# %%
# Drop Route 42 rows from wk
wk.drop(wk[wk['LINEID'] == '42'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6236   2018-09-09  8093973            1         4167            37800
# 6237   2018-09-09  8093973            2         4170            37887
# 6238   2018-09-09  8093973            3         4153            37946
# 6239   2018-09-09  8093973            4         4154            38000
# 6240   2018-09-09  8093973            5         4416            38045
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6236            37800           37800           37800    2868378  2018  ...
# 6237            37887           37887           37887    2868378  2018  ...
# 6238            37946           37946           37946    2868378  2018  ...
# 6239            38000           38000           38000    2868378  2018  ...
# 6240            38045           38045           38045    2868378  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3512586, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 185

# %%
lwk = wk[(wk['LINEID'] == '185')]

# %%
lwk.shape
# Out:
# (6776, 22)

# %%
# Drop Route 185 rows from wk
wk.drop(wk[wk['LINEID'] == '185'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6686   2018-09-09  8094266            4         3335            38537
# 6687   2018-09-09  8094266            5         3336            38573
# 6688   2018-09-09  8094266            6         3337            38598
# 6689   2018-09-09  8094266            7         3338            38665
# 6690   2018-09-09  8094266            8         3339            38718
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6686            38537           38537           38537    1001164  2018  ...
# 6687            38573           38573           38573    1001164  2018  ...
# 6688            38598           38598           38598    1001164  2018  ...
# 6689            38665           38665           38665    1001164  2018  ...
# 6690            38718           38718           38718    1001164  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3505810, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_185_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 270

# %%
lwk = wk[(wk['LINEID'] == '270')]

# %%
lwk.shape
# Out:
# (36584, 22)

# %%
# Drop Route 270 rows from wk
wk.drop(wk[wk['LINEID'] == '270'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7032   2018-09-09  8094427            1         4260            31800
# 7033   2018-09-09  8094427            2         4261            31808
# 7034   2018-09-09  8094427            3         7271            31845
# 7035   2018-09-09  8094427            4         5136            31854
# 7036   2018-09-09  8094427            5         4262            31898
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7032            31800           31800           31800    1932301  2018  ...
# 7033            31808           31808           31808    1932301  2018  ...
# 7034            31845           31845           31845    1932301  2018  ...
# 7035            31854           31854           31854    1932301  2018  ...
# 7036            31898           31898           31898    1932301  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3469226, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_270_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 84

# %%
lwk = wk[(wk['LINEID'] == '84')]

# %%
lwk.shape
# Out:
# (177941, 22)

# %%
# Drop Route 84 rows from wk
wk.drop(wk[wk['LINEID'] == '84'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8115   2018-09-09  8094497            1         4962            33000
# 8116   2018-09-09  8094497            2         4725            33164
# 8117   2018-09-09  8094497            3          273            33298
# 8118   2018-09-09  8094497            4          405            33489
# 8119   2018-09-09  8094497            5          408            33588
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8115            33000           33000           33000    2693223  2018  ...
# 8116            33164           33164           33164    2693223  2018  ...
# 8117            33298           33298           33298    2693223  2018  ...
# 8118            33489           33489           33489    2693223  2018  ...
# 8119            33588           33588           33588    2693223  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3291285, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 7

# %%
lwk = wk[(wk['LINEID'] == '7')]

# %%
lwk.shape
# Out:
# (191377, 22)

# %%
# Drop Route 7 rows from wk
wk.drop(wk[wk['LINEID'] == '7'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8773   2018-09-09  8094713            1         3980            30600
# 8774   2018-09-09  8094713            2         6089            30664
# 8775   2018-09-09  8094713            3         3981            30760
# 8776   2018-09-09  8094713            4         3982            30807
# 8777   2018-09-09  8094713            5         3983            30933
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8773            30600           30600           30600    3265683  2018  ...
# 8774            30664           30664           30664    3265683  2018  ...
# 8775            30760           30760           30760    3265683  2018  ...
# 8776            30807           30807           30807    3265683  2018  ...
# 8777            30933           30933           30933    3265683  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3099908, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 66

# %%
lwk = wk[(wk['LINEID'] == '66')]

# %%
lwk.shape
# Out:
# (194956, 22)

# %%
# Drop Route 66 rows from wk
wk.drop(wk[wk['LINEID'] == '66'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9075   2018-09-09  8094731            1         6048            62100
# 9076   2018-09-09  8094731           15         3819            62839
# 9077   2018-09-09  8094731           16         3820            62866
# 9078   2018-09-09  8094731           17         3822            62898
# 9079   2018-09-09  8094731           18         3823            62936
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9075            62100           62100           62100    2868389  2018  ...
# 9076            62839           62839           62839    2868389  2018  ...
# 9077            62866           62866           62866    2868389  2018  ...
# 9078            62898           62898           62898    2868389  2018  ...
# 9079            62936           62936           62936    2868389  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2904952, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Route 33A

# %%
lwk = wk[(wk['LINEID'] == '33A')]

# %%
lwk.shape
# Out:
# (21948, 22)

# %%
# Drop Route 33A rows from wk
wk.drop(wk[wk['LINEID'] == '33A'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 10222   2018-09-09  8094791            1         4713            30600
# 10223   2018-09-09  8094791            2         4714            30633
# 10224   2018-09-09  8094791            3         4960            30672
# 10225   2018-09-09  8094791            4         4932            30733
# 10226   2018-09-09  8094791            5         4933            30747
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 10222            30600           30600           30600    2534796  2018  ...
# 10223            30633           30633           30633    2534796  2018  ...
# 10224            30672           30672           30672    2534796  2018  ...
# 10225            30733           30733           30733    2534796  2018  ...
# 10226            30747           30747           30747    2534796  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2883004, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33A_tripLeave6_sp4.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_5

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_5.csv', index=False)
