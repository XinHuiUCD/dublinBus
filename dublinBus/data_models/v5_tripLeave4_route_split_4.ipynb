# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 4 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_4.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (8868890, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-24  7111752            1         4495            66000
# 1   2018-06-24  7111752            2         4720            66155
# 2   2018-06-24  7111752            3         1443            66363
# 3   2018-06-24  7111752            4         1444            66414
# 4   2018-06-24  7111752            5         1445            66471
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            66000           66000           66000    2693290  2018  ...
# 1            66155           66155           66155    2693290  2018  ...
# 2            66363           66363           66363    2693290  2018  ...
# 3            66414           66414           66414    2693290  2018  ...
# 4            66471           66471           66471    2693290  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 69

# %%
lwk = wk[(wk['LINEID'] == '69')]

# %%
lwk.shape
# Out:
# (107576, 22)

# %%
# Drop Route 69 rows from wk
wk.drop(wk[wk['LINEID'] == '69'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 119   2018-06-24  7111776            1         3624            41400
# 120   2018-06-24  7111776            2         3587            41431
# 121   2018-06-24  7111776            3         3588            41452
# 122   2018-06-24  7111776            4         3590            41471
# 123   2018-06-24  7111776            5         3589            41507
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 119            41400           41400           41400    1932325  2018  ...
# 120            41431           41431           41431    1932325  2018  ...
# 121            41452           41452           41452    1932325  2018  ...
# 122            41471           41471           41471    1932325  2018  ...
# 123            41507           41507           41507    1932325  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8761314, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 32

# %%
lwk = wk[(wk['LINEID'] == '32')]

# %%
lwk.shape
# Out:
# (153155, 22)

# %%
# Drop Route 32 rows from wk
wk.drop(wk[wk['LINEID'] == '32'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 294   2018-06-24  7111780            1          621            61200
# 295   2018-06-24  7111780            2          289            61320
# 296   2018-06-24  7111780            3          496            61420
# 297   2018-06-24  7111780            4         7490            61439
# 298   2018-06-24  7111780            5          515            61511
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 294            61200           61200           61200    2693262  2018  ...
# 295            61320           61320           61320    2693262  2018  ...
# 296            61420           61420           61420    2693262  2018  ...
# 297            61439           61439           61439    2693262  2018  ...
# 298            61511           61511           61511    2693262  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8608159, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 31A

# %%
lwk = wk[(wk['LINEID'] == '31A')]

# %%
lwk.shape
# Out:
# (71457, 22)

# %%
# Drop Route 31A rows from wk
wk.drop(wk[wk['LINEID'] == '31A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 588   2018-06-24  7111784            1          621            76500
# 589   2018-06-24  7111784            2          289            76621
# 590   2018-06-24  7111784            3          496            76722
# 591   2018-06-24  7111784            4         7490            76741
# 592   2018-06-24  7111784            5          515            76814
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 588            76500           76500           76500    2693262  2018  ...
# 589            76621           76621           76621    2693262  2018  ...
# 590            76722           76722           76722    2693262  2018  ...
# 591            76741           76741           76741    2693262  2018  ...
# 592            76814           76814           76814    2693262  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8536702, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31A_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 31

# %%
lwk = wk[(wk['LINEID'] == '31')]

# %%
lwk.shape
# Out:
# (204621, 22)

# %%
# Drop Route 31 rows from wk
wk.drop(wk[wk['LINEID'] == '31'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 806   2018-06-24  7111953            1         6282            36000
# 807   2018-06-24  7111953            2         6335            36072
# 808   2018-06-24  7111953            3         6326            36119
# 809   2018-06-24  7111953            4         4886            36160
# 810   2018-06-24  7111953            5         4887            36260
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 806            36000           36000           36000    2868353  2018  ...
# 807            36072           36072           36072    2868353  2018  ...
# 808            36119           36119           36119    2868353  2018  ...
# 809            36160           36160           36160    2868353  2018  ...
# 810            36260           36260           36260    2868353  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8332081, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 15

# %%
lwk = wk[(wk['LINEID'] == '15')]

# %%
lwk.shape
# Out:
# (577726, 22)

# %%
# Drop Route 15 rows from wk
wk.drop(wk[wk['LINEID'] == '15'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1231   2018-06-24  7112177            2         3891            38421
# 1232   2018-06-24  7112177            3         3949            38498
# 1233   2018-06-24  7112177            4         3950            38546
# 1234   2018-06-24  7112177            5         2229            38646
# 1235   2018-06-24  7112177            6         2230            38699
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1231            38421           38421           38421    2868398  2018  ...
# 1232            38498           38498           38498    2868398  2018  ...
# 1233            38546           38546           38546    2868398  2018  ...
# 1234            38646           38646           38646    2868398  2018  ...
# 1235            38699           38699           38699    2868398  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7754355, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 25

# %%
lwk = wk[(wk['LINEID'] == '25')]

# %%
lwk.shape
# Out:
# (72065, 22)

# %%
# Drop Route 25 rows from wk
wk.drop(wk[wk['LINEID'] == '25'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1558   2018-06-24  7112240            1         1105            41400
# 1559   2018-06-24  7112240            2         1107            41466
# 1560   2018-06-24  7112240            3         1108            41499
# 1561   2018-06-24  7112240            4         1109            41527
# 1562   2018-06-24  7112240            5         1110            41550
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1558            41400           41400           41400    2693211  2018  ...
# 1559            41466           41466           41466    2693211  2018  ...
# 1560            41499           41499           41499    2693211  2018  ...
# 1561            41527           41527           41527    2693211  2018  ...
# 1562            41550           41550           41550    2693211  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7682290, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 15A

# %%
lwk = wk[(wk['LINEID'] == '15A')]

# %%
lwk.shape
# Out:
# (207089, 22)

# %%
# Drop Route 15A rows from wk
wk.drop(wk[wk['LINEID'] == '15A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2118   2018-06-24  7112325            1         7132            44100
# 2119   2018-06-24  7112325            2         1558            44202
# 2120   2018-06-24  7112325            3         2957            44256
# 2121   2018-06-24  7112325            4         2958            44284
# 2122   2018-06-24  7112325            5         4938            44337
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2118            44100           44100           44100    2693195  2018  ...
# 2119            44202           44202           44202    2693195  2018  ...
# 2120            44256           44256           44256    2693195  2018  ...
# 2121            44284           44284           44284    2693195  2018  ...
# 2122            44337           44337           44337    2693195  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7475201, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15A_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 40

# %%
lwk = wk[(wk['LINEID'] == '40')]

# %%
lwk.shape
# Out:
# (679237, 22)

# %%
# Drop Route 40 rows from wk
wk.drop(wk[wk['LINEID'] == '40'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2840   2018-06-24  7112406            1         6290            34980
# 2841   2018-06-24  7112406            2         7120            35097
# 2842   2018-06-24  7112406            3         7119            35163
# 2843   2018-06-24  7112406            4         7127            35218
# 2844   2018-06-24  7112406            5         7143            35310
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2840            34980           34980           34980    1000323  2018  ...
# 2841            35097           35097           35097    1000323  2018  ...
# 2842            35163           35163           35163    1000323  2018  ...
# 2843            35218           35218           35218    1000323  2018  ...
# 2844            35310           35310           35310    1000323  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6795964, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 25B

# %%
lwk = wk[(wk['LINEID'] == '25B')]

# %%
lwk.shape
# Out:
# (166628, 22)

# %%
# Drop Route 25B rows from wk
wk.drop(wk[wk['LINEID'] == '25B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2956   2018-06-24  7112409            1         7391            46920
# 2957   2018-06-24  7112409            2          493            47007
# 2958   2018-06-24  7112409            3          494            47075
# 2959   2018-06-24  7112409            4          495            47185
# 2960   2018-06-24  7112409            5          400            47274
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2956            46920           46920           46920    1000323  2018  ...
# 2957            47007           47007           47007    1000323  2018  ...
# 2958            47075           47075           47075    1000323  2018  ...
# 2959            47185           47185           47185    1000323  2018  ...
# 2960            47274           47274           47274    1000323  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6629336, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25B_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 25A

# %%
lwk = wk[(wk['LINEID'] == '25A')]

# %%
lwk.shape
# Out:
# (172108, 22)

# %%
# Drop Route 25A rows from wk
wk.drop(wk[wk['LINEID'] == '25A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4217   2018-06-24  7112557            2         1492            33655
# 4218   2018-06-24  7112557            3         1493            33679
# 4219   2018-06-24  7112557            4         1482            33694
# 4220   2018-06-24  7112557            5         1494            33746
# 4221   2018-06-24  7112557            6         1495            33779
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4217            33655           33655           33655    2534848  2018  ...
# 4218            33679           33679           33679    2534848  2018  ...
# 4219            33694           33694           33694    2534848  2018  ...
# 4220            33746           33746           33746    2534848  2018  ...
# 4221            33779           33779           33779    2534848  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6457228, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25A_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 123

# %%
lwk = wk[(wk['LINEID'] == '123')]

# %%
lwk.shape
# Out:
# (308897, 22)

# %%
# Drop Route 123 rows from wk
wk.drop(wk[wk['LINEID'] == '123'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5105   2018-06-24  7112670            1          395            25800
# 5106   2018-06-24  7112670            2          396            25846
# 5107   2018-06-24  7112670            3          397            25871
# 5108   2018-06-24  7112670            4          398            25900
# 5109   2018-06-24  7112670            5          399            25924
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5105            25800           25800           25800    2693282  2018  ...
# 5106            25846           25846           25846    2693282  2018  ...
# 5107            25871           25871           25871    2693282  2018  ...
# 5108            25900           25900           25900    2693282  2018  ...
# 5109            25924           25924           25924    2693282  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (6148331, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_123_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 77A

# %%
lwk = wk[(wk['LINEID'] == '77A')]

# %%
lwk.shape
# Out:
# (362389, 22)

# %%
# Drop Route 77A rows from wk
wk.drop(wk[wk['LINEID'] == '77A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5957   2018-06-24  7112701            1          284            53100
# 5958   2018-06-24  7112701            2         4504            53228
# 5959   2018-06-24  7112701            3         7028            53319
# 5960   2018-06-24  7112701            4         5147            53402
# 5961   2018-06-24  7112701            5           68            53481
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5957            53100           53100           53100    2868373  2018  ...
# 5958            53228           53228           53228    2868373  2018  ...
# 5959            53319           53319           53319    2868373  2018  ...
# 5960            53402           53402           53402    2868373  2018  ...
# 5961            53481           53481           53481    2868373  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5785942, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77A_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (134485, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6356   2018-06-24  7112933            2         3223            31290
# 6357   2018-06-24  7112933            3         3224            31338
# 6358   2018-06-24  7112933            4         3225            31385
# 6359   2018-06-24  7112933            5         3226            31431
# 6360   2018-06-24  7112933            6         3227            31466
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6356            31290           31290           31290    2693221  2018  ...
# 6357            31338           31338           31338    2693221  2018  ...
# 6358            31385           31385           31385    2693221  2018  ...
# 6359            31431           31431           31431    2693221  2018  ...
# 6360            31466           31466           31466    2693221  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5651457, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 7A

# %%
lwk = wk[(wk['LINEID'] == '7A')]

# %%
lwk.shape
# Out:
# (228579, 22)

# %%
# Drop Route 7A rows from wk
wk.drop(wk[wk['LINEID'] == '7A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6420   2018-06-24  7112934            1         4962            35400
# 6421   2018-06-24  7112934            2         4725            35592
# 6422   2018-06-24  7112934            3          273            35738
# 6423   2018-06-24  7112934            4          405            35945
# 6424   2018-06-24  7112934            5          408            36052
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6420            35400           35400           35400    2693221  2018  ...
# 6421            35592           35592           35592    2693221  2018  ...
# 6422            35738           35738           35738    2693221  2018  ...
# 6423            35945           35945           35945    2693221  2018  ...
# 6424            36052           36052           36052    2693221  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5422878, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7A_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Route 7

# %%
lwk = wk[(wk['LINEID'] == '7')]

# %%
lwk.shape
# Out:
# (195083, 22)

# %%
# Drop Route 7 rows from wk
wk.drop(wk[wk['LINEID'] == '7'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6889   2018-06-24  7113092            4         3997            48523
# 6890   2018-06-24  7113092            5         3998            48600
# 6891   2018-06-24  7113092            6         3999            48660
# 6892   2018-06-24  7113092            7         4000            48690
# 6893   2018-06-24  7113092            8         4001            48720
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6889            48523           48523           48523    1001139  2018  ...
# 6890            48600           48600           48600    1001139  2018  ...
# 6891            48660           48660           48660    1001139  2018  ...
# 6892            48690           48690           48690    1001139  2018  ...
# 6893            48720           48720           48720    1001139  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5227795, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7_tripLeave4_sp4.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_5

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_5.csv', index=False)
