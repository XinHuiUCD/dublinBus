# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 CSV file into Data Frame:
wk = pd.read_csv('v4_tripLeave6_LT_2018.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (18295510, 21)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Add Actual Arrival Time Hour

# %%
wk['actualARR_hour'] = (wk['ACTUALTIME_ARR'] / 3600).round()

# %%
wk.head()

# %%
# Replace any 24 hour values to zero
wk['actualARR_hour'] = np.where(wk['actualARR_hour'] == 24, 0, wk['actualARR_hour'])

# %%
# Update actualARR_hour to int to rid of decimals
wk['actualARR_hour'] = wk['actualARR_hour'].astype('int32')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-09  8089358            1         4795            45900
# 1   2018-09-09  8089358            2         4688            46058
# 2   2018-09-09  8089358            3         4689            46096
# 3   2018-09-09  8089358            4         4410            46129
# 4   2018-09-09  8089358            5         2678            46153
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            45900           45900           45900    3088378  2018  ...
# 1            46058           46058           46058    3088378  2018  ...
# 2            46096           46096           46096    3088378  2018  ...
# 3            46129           46129           46129    3088378  2018  ...
# 4            46153           46153           46153    3088378  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-09  8089358            1         4795            45900
# 1   2018-09-09  8089358            2         4688            46058
# 2   2018-09-09  8089358            3         4689            46096
# 3   2018-09-09  8089358            4         4410            46129
# 4   2018-09-09  8089358            5         2678            46153
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            45900           45900           45900    3088378  2018  ...
# 1            46058           46058           46058    3088378  2018  ...
# 2            46096           46096           46096    3088378  2018  ...
# 3            46129           46129           46129    3088378  2018  ...
# 4            46153           46153           46153    3088378  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int32
# dtype: object

# %% [markdown]
# ## Route 40

# %%
lwk = wk[(wk['LINEID'] == '40')]

# %%
lwk.shape
# Out:
# (691970, 22)

# %%
# Drop Route 40 rows from wk
wk.drop(wk[wk['LINEID'] == '40'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 249   2018-09-09  8089442            1          395            35100
# 250   2018-09-09  8089442            2          396            35156
# 251   2018-09-09  8089442            3          397            35187
# 252   2018-09-09  8089442            4          398            35220
# 253   2018-09-09  8089442            5          399            35247
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 249            35100           35100           35100    1932334  2018  ...
# 250            35156           35156           35156    1932334  2018  ...
# 251            35187           35187           35187    1932334  2018  ...
# 252            35220           35220           35220    1932334  2018  ...
# 253            35247           35247           35247    1932334  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17603540, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (92527, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 896   2018-09-09  8089454            1         2670            43740
# 897   2018-09-09  8089454            2         2910            43781
# 898   2018-09-09  8089454            3         2911            43827
# 899   2018-09-09  8089454            4         7507            43859
# 900   2018-09-09  8089454            5         2663            43890
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 896            43740           43740           43740    1000110  2018  ...
# 897            43781           43781           43781    1000110  2018  ...
# 898            43827           43827           43827    1000110  2018  ...
# 899            43859           43859           43859    1000110  2018  ...
# 900            43890           43890           43890    1000110  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17511013, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 79

# %%
lwk = wk[(wk['LINEID'] == '79')]

# %%
lwk.shape
# Out:
# (118425, 22)

# %%
# Drop Route 79 rows from wk
wk.drop(wk[wk['LINEID'] == '79'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1552   2018-09-09  8089597            1          288            47400
# 1553   2018-09-09  8089597            2         1171            47475
# 1554   2018-09-09  8089597            3         1172            47533
# 1555   2018-09-09  8089597            4         1173            47616
# 1556   2018-09-09  8089597            5         1174            47722
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1552            47400           47400           47400    2693198  2018  ...
# 1553            47475           47475           47475    2693198  2018  ...
# 1554            47533           47533           47533    2693198  2018  ...
# 1555            47616           47616           47616    2693198  2018  ...
# 1556            47722           47722           47722    2693198  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17392588, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 41

# %%
lwk = wk[(wk['LINEID'] == '41')]

# %%
lwk.shape
# Out:
# (268475, 22)

# %%
# Drop Route 41 rows from wk
wk.drop(wk[wk['LINEID'] == '41'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1603   2018-09-09  8089598            1         4843            51000
# 1604   2018-09-09  8089598            2         4905            51051
# 1605   2018-09-09  8089598            4         4906            51100
# 1606   2018-09-09  8089598            5         4907            51136
# 1607   2018-09-09  8089598            6         4908            51158
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1603            51000           51000           51000    2693198  2018  ...
# 1604            51051           51051           51051    2693198  2018  ...
# 1605            51100           51100           51100    2693198  2018  ...
# 1606            51136           51136           51136    2693198  2018  ...
# 1607            51158           51158           51158    2693198  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17124113, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 41C

# %%
lwk = wk[(wk['LINEID'] == '41C')]

# %%
lwk.shape
# Out:
# (265734, 22)

# %%
# Drop Route 41C rows from wk
wk.drop(wk[wk['LINEID'] == '41C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2039   2018-09-09  8089674            1         2039            31800
# 2040   2018-09-09  8089674            2         2040            31847
# 2041   2018-09-09  8089674            3         2041            31907
# 2042   2018-09-09  8089674            4         2042            31980
# 2043   2018-09-09  8089674            5         2043            31993
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2039            31800           31800           31800    3265669  2018  ...
# 2040            31847           31847           31847    3265669  2018  ...
# 2041            31907           31907           31907    3265669  2018  ...
# 2042            31980           31980           31980    3265669  2018  ...
# 2043            31993           31993           31993    3265669  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16858379, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41C_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 46A

# %%
lwk = wk[(wk['LINEID'] == '46A')]

# %%
lwk.shape
# Out:
# (696361, 22)

# %%
# Drop Route 46A rows from wk
wk.drop(wk[wk['LINEID'] == '46A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2673   2018-09-09  8089767            1          324            34200
# 2674   2018-09-09  8089767            2          327            34309
# 2675   2018-09-09  8089767            3         7113            34436
# 2676   2018-09-09  8089767            4          127            34550
# 2677   2018-09-09  8089767            5          112            34649
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2673            34200           34200           34200    2868361  2018  ...
# 2674            34309           34309           34309    2868361  2018  ...
# 2675            34436           34436           34436    2868361  2018  ...
# 2676            34550           34550           34550    2868361  2018  ...
# 2677            34649           34649           34649    2868361  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16162018, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46A_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Route 4

# %%
lwk = wk[(wk['LINEID'] == '4')]

# %%
lwk.shape
# Out:
# (377747, 22)

# %%
# Drop Route 4 rows from wk
wk.drop(wk[wk['LINEID'] == '4'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3624   2018-09-09  8089827            2         4725            49420
# 3625   2018-09-09  8089827            3          273            49606
# 3626   2018-09-09  8089827            4          405            49870
# 3627   2018-09-09  8089827            5          408            50006
# 3628   2018-09-09  8089827            6          409            50031
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3624            49420           49420           49420    2693216  2018  ...
# 3625            49606           49606           49606    2693216  2018  ...
# 3626            49870           49870           49870    2693216  2018  ...
# 3627            50006           50006           50006    2693216  2018  ...
# 3628            50031           50031           50031    2693216  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15784271, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_4_tripLeave6_sp0.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_1

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_1.csv', index=False)
