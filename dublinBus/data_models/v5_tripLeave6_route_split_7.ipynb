# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave6_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (537965, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-10  8092065            1         3890            27300
# 1   2018-09-10  8092065            2         3891            27324
# 2   2018-09-10  8092065            3         3949            27413
# 3   2018-09-10  8092065            4         3950            27468
# 4   2018-09-10  8092065            5         3372            27557
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            27300           27300           27300    1000286  2018  ...
# 1            27324           27324           27324    1000286  2018  ...
# 2            27413           27413           27413    1000286  2018  ...
# 3            27468           27468           27468    1000286  2018  ...
# 4            27557           27557           27557    1000286  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 25X

# %%
lwk = wk[(wk['LINEID'] == '25X')]

# %%
lwk.shape
# Out:
# (6863, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '25X'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 41   2018-09-10  8092712            4         3335            26340
# 42   2018-09-10  8092712            5         3336            26460
# 43   2018-09-10  8092712            6         3337            26492
# 44   2018-09-10  8092712            7         3338            26580
# 45   2018-09-10  8092712            8         3339            26700
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 41            26340           26340           26340    1000335  2018  ...
# 42            26460           26460           26460    1000335  2018  ...
# 43            26492           26492           26492    1000335  2018  ...
# 44            26580           26580           26580    1000335  2018  ...
# 45            26700           26700           26700    1000335  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (531102, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 70D

# %%
lwk = wk[(wk['LINEID'] == '70D')]

# %%
lwk.shape
# Out:
# (3262, 22)

# %%
# Drop Route 70D rows from wk
wk.drop(wk[wk['LINEID'] == '70D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 114   2018-09-10  8092714            1          877            43200
# 115   2018-09-10  8092714            2          876            43326
# 116   2018-09-10  8092714            3         3011            43403
# 117   2018-09-10  8092714            4         2896            43430
# 118   2018-09-10  8092714            5         2897            43452
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 114            43200           43200           43200    2693273  2018  ...
# 115            43326           43326           43326    2693273  2018  ...
# 116            43403           43403           43403    2693273  2018  ...
# 117            43430           43430           43430    2693273  2018  ...
# 118            43452           43452           43452    2693273  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (527840, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70D_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (20830, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 278   2018-09-10  8092820            1         7654            27900
# 279   2018-09-10  8092820            2         4843            28131
# 280   2018-09-10  8092820            3         4905            28176
# 281   2018-09-10  8092820            5         4906            28220
# 282   2018-09-10  8092820            6         4907            28252
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 278            27900           27900           27900    1001105  2018  ...
# 279            28131           28131           28131    1001105  2018  ...
# 280            28176           28176           28176    1001105  2018  ...
# 281            28220           28220           28220    1001105  2018  ...
# 282            28252           28252           28252    1001105  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (507010, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 41X

# %%
lwk = wk[(wk['LINEID'] == '41X')]

# %%
lwk.shape
# Out:
# (14119, 22)

# %%
# Drop Route 41X rows from wk
wk.drop(wk[wk['LINEID'] == '41X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 316   2018-09-10  8092970            1         3815            26100
# 317   2018-09-10  8092970            2         3816            26123
# 318   2018-09-10  8092970            3         3566            26169
# 319   2018-09-10  8092970            4         3567            26210
# 320   2018-09-10  8092970            5         7292            26275
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 316            26100           26100           26100    1000758  2018  ...
# 317            26123           26123           26123    1000758  2018  ...
# 318            26169           26169           26169    1000758  2018  ...
# 319            26210           26210           26210    1000758  2018  ...
# 320            26275           26275           26275    1000758  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (492891, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 33X

# %%
lwk = wk[(wk['LINEID'] == '33X')]

# %%
lwk.shape
# Out:
# (23059, 22)

# %%
# Drop Route 33X rows from wk
wk.drop(wk[wk['LINEID'] == '33X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 435   2018-09-10  8093163            1         7333            27600
# 436   2018-09-10  8093163            2          783            27745
# 437   2018-09-10  8093163            3          784            27777
# 438   2018-09-10  8093163            4          785            27831
# 439   2018-09-10  8093163            5          786            27956
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 435            27600           27600           27600    1001139  2018  ...
# 436            27745           27745           27745    1001139  2018  ...
# 437            27777           27777           27777    1001139  2018  ...
# 438            27831           27831           27831    1001139  2018  ...
# 439            27956           27956           27956    1001139  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (469832, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 38D

# %%
lwk = wk[(wk['LINEID'] == '38D')]

# %%
lwk.shape
# Out:
# (1675, 22)

# %%
# Drop Route 38D rows from wk
wk.drop(wk[wk['LINEID'] == '38D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 502   2018-09-10  8093757            1          928            27900
# 503   2018-09-10  8093757            2          929            27961
# 504   2018-09-10  8093757            3          930            28080
# 505   2018-09-10  8093757            4          931            28162
# 506   2018-09-10  8093757            5          587            28260
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 502            27900           27900           27900    1000860  2018  ...
# 503            27961           27961           27961    1000860  2018  ...
# 504            28080           28080           28080    1000860  2018  ...
# 505            28162           28162           28162    1000860  2018  ...
# 506            28260           28260           28260    1000860  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (468157, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38D_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 31D

# %%
lwk = wk[(wk['LINEID'] == '31D')]

# %%
lwk.shape
# Out:
# (2953, 22)

# %%
# Drop Route 31D rows from wk
wk.drop(wk[wk['LINEID'] == '31D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 569   2018-09-10  8093841            1         3085            29100
# 570   2018-09-10  8093841            2         3034            29212
# 571   2018-09-10  8093841            3         3114            29347
# 572   2018-09-10  8093841            4         4353            29425
# 573   2018-09-10  8093841            5         4355            29456
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 569            29100           29100           29100    2172239  2018  ...
# 570            29212           29212           29212    2172239  2018  ...
# 571            29347           29347           29347    2172239  2018  ...
# 572            29425           29425           29425    2172239  2018  ...
# 573            29456           29456           29456    2172239  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (465204, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31D_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 46E

# %%
lwk = wk[(wk['LINEID'] == '46E')]

# %%
lwk.shape
# Out:
# (2407, 22)

# %%
# Drop Route 46E rows from wk
wk.drop(wk[wk['LINEID'] == '46E'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 606   2018-09-10  8093889            1         3890            29100
# 607   2018-09-10  8093889            2         3891            29123
# 608   2018-09-10  8093889            3         3949            29210
# 609   2018-09-10  8093889            4         3950            29264
# 610   2018-09-10  8093889            5         2229            29352
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 606            29100           29100           29100    2534836  2018  ...
# 607            29123           29123           29123    2534836  2018  ...
# 608            29210           29210           29210    2534836  2018  ...
# 609            29264           29264           29264    2534836  2018  ...
# 610            29352           29352           29352    2534836  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (462797, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46E_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 25

# %%
lwk = wk[(wk['LINEID'] == '25')]

# %%
lwk.shape
# Out:
# (66835, 22)

# %%
# Drop Route 25 rows from wk
wk.drop(wk[wk['LINEID'] == '25'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1259   2018-09-10  8094109            1         2825            24600
# 1260   2018-09-10  8094109            2         2826            24671
# 1261   2018-09-10  8094109            3         2827            24715
# 1262   2018-09-10  8094109            4         2828            24764
# 1263   2018-09-10  8094109            5         2829            24808
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1259            24600           24600           24600    2868332  2018  ...
# 1260            24671           24671           24671    2868332  2018  ...
# 1261            24715           24715           24715    2868332  2018  ...
# 1262            24764           24764           24764    2868332  2018  ...
# 1263            24808           24808           24808    2868332  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (395962, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 44B

# %%
lwk = wk[(wk['LINEID'] == '44B')]

# %%
lwk.shape
# Out:
# (10316, 22)

# %%
# Drop Route 44B rows from wk
wk.drop(wk[wk['LINEID'] == '44B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1424   2018-09-10  8094340            1         7026            24000
# 1425   2018-09-10  8094340            2         4747            24146
# 1426   2018-09-10  8094340            3         2960            24199
# 1427   2018-09-10  8094340            4         1840            24385
# 1428   2018-09-10  8094340            5         1841            24417
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1424            24000           24000           24000    2534832  2018  ...
# 1425            24146           24146           24146    2534832  2018  ...
# 1426            24199           24199           24199    2534832  2018  ...
# 1427            24385           24385           24385    2534832  2018  ...
# 1428            24417           24417           24417    2534832  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (385646, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44B_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 76A

# %%
lwk = wk[(wk['LINEID'] == '76A')]

# %%
lwk.shape
# Out:
# (7538, 22)

# %%
# Drop Route 76A rows from wk
wk.drop(wk[wk['LINEID'] == '76A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1467   2018-09-10  8094801            1         2955            27600
# 1468   2018-09-10  8094801            2         7067            27607
# 1469   2018-09-10  8094801            3         2956            27632
# 1470   2018-09-10  8094801            4         2965            27684
# 1471   2018-09-10  8094801            5         2967            27777
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1467            27600           27600           27600    1000904  2018  ...
# 1468            27607           27607           27607    1000904  2018  ...
# 1469            27632           27632           27632    1000904  2018  ...
# 1470            27684           27684           27684    1000904  2018  ...
# 1471            27777           27777           27777    1000904  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (378108, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76A_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (2793, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1529   2018-09-10  8094860            1         1184            57600
# 1530   2018-09-10  8094860            2          496            57723
# 1531   2018-09-10  8094860            3         7490            57749
# 1532   2018-09-10  8094860            4          497            57768
# 1533   2018-09-10  8094860            5          515            57830
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1529            57600           57600           57600    1932366  2018  ...
# 1530            57723           57723           57723    1932366  2018  ...
# 1531            57749           57749           57749    1932366  2018  ...
# 1532            57768           57768           57768    1932366  2018  ...
# 1533            57830           57830           57830    1932366  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (375315, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 53

# %%
lwk = wk[(wk['LINEID'] == '53')]

# %%
lwk.shape
# Out:
# (29515, 22)

# %%
# Drop Route 53 rows from wk
wk.drop(wk[wk['LINEID'] == '53'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1661   2018-09-10  8095372            1         7433            26700
# 1662   2018-09-10  8095372            2         4677            26863
# 1663   2018-09-10  8095372            3         2136            26919
# 1664   2018-09-10  8095372            4         2137            26956
# 1665   2018-09-10  8095372            5         2138            26994
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1661            26700           26700           26700    1001125  2018  ...
# 1662            26863           26863           26863    1001125  2018  ...
# 1663            26919           26919           26919    1001125  2018  ...
# 1664            26956           26956           26956    1001125  2018  ...
# 1665            26994           26994           26994    1001125  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (345800, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_53_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 51X

# %%
lwk = wk[(wk['LINEID'] == '51X')]

# %%
lwk.shape
# Out:
# (2103, 22)

# %%
# Drop Route 51X rows from wk
wk.drop(wk[wk['LINEID'] == '51X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1821   2018-09-10  8095450            1         4664            27900
# 1822   2018-09-10  8095450            2         2160            27954
# 1823   2018-09-10  8095450            3         4665            27992
# 1824   2018-09-10  8095450            4         4666            28032
# 1825   2018-09-10  8095450            5         4667            28065
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1821            27900           27900           27900    3265685  2018  ...
# 1822            27954           27954           27954    3265685  2018  ...
# 1823            27992           27992           27992    3265685  2018  ...
# 1824            28032           28032           28032    3265685  2018  ...
# 1825            28065           28065           28065    3265685  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (343697, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 51D

# %%
lwk = wk[(wk['LINEID'] == '51D')]

# %%
lwk.shape
# Out:
# (6110, 22)

# %%
# Drop Route 51D rows from wk
wk.drop(wk[wk['LINEID'] == '51D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1871   2018-09-10  8095457            1         4495            57600
# 1872   2018-09-10  8095457            2         1278            57788
# 1873   2018-09-10  8095457            3         1282            57978
# 1874   2018-09-10  8095457            4         4456            58079
# 1875   2018-09-10  8095457            5         1284            58146
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1871            57600           57600           57600    2693239  2018  ...
# 1872            57788           57788           57788    2693239  2018  ...
# 1873            57978           57978           57978    2693239  2018  ...
# 1874            58079           58079           58079    2693239  2018  ...
# 1875            58146           58146           58146    2693239  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (337587, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51D_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 68A

# %%
lwk = wk[(wk['LINEID'] == '68A')]

# %%
lwk.shape
# Out:
# (3039, 22)

# %%
# Drop Route 68A rows from wk
wk.drop(wk[wk['LINEID'] == '68A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1944   2018-09-10  8095832            1         4168            25200
# 1945   2018-09-10  8095832            2         4170            25271
# 1946   2018-09-10  8095832            3         4132            25320
# 1947   2018-09-10  8095832            4         4134            25406
# 1948   2018-09-10  8095832            5         4135            25462
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1944            25200           25200           25200    3265665  2018  ...
# 1945            25271           25271           25271    3265665  2018  ...
# 1946            25320           25320           25320    3265665  2018  ...
# 1947            25406           25406           25406    3265665  2018  ...
# 1948            25462           25462           25462    3265665  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (334548, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68A_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (17256, 22)

# %%
# Drop Route 184 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2610   2018-09-10  8096090            1         4713            26400
# 2611   2018-09-10  8096090            2         4714            26498
# 2612   2018-09-10  8096090            3         4960            26541
# 2613   2018-09-10  8096090            4         4932            26608
# 2614   2018-09-10  8096090            5         4933            26623
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2610            26400           26400           26400    2172252  2018  ...
# 2611            26498           26498           26498    2172252  2018  ...
# 2612            26541           26541           26541    2172252  2018  ...
# 2613            26608           26608           26608    2172252  2018  ...
# 2614            26623           26623           26623    2172252  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (317292, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 77X

# %%
lwk = wk[(wk['LINEID'] == '77X')]

# %%
lwk.shape
# Out:
# (2724, 22)

# %%
# Drop Route 77X rows from wk
wk.drop(wk[wk['LINEID'] == '77X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2701   2018-09-10  8096612            1         3085            28800
# 2702   2018-09-10  8096612            2         3082            28911
# 2703   2018-09-10  8096612            3         3083            28995
# 2704   2018-09-10  8096612            4          430            29049
# 2705   2018-09-10  8096612            5          431            29080
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2701            28800           28800           28800    1000724  2018  ...
# 2702            28911           28911           28911    1000724  2018  ...
# 2703            28995           28995           28995    1000724  2018  ...
# 2704            29049           29049           29049    1000724  2018  ...
# 2705            29080           29080           29080    1000724  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (314568, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (173488, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4674   2018-09-10  8097397            1         3640            27600
# 4675   2018-09-10  8097397            2         3574            27664
# 4676   2018-09-10  8097397            3         3641            27738
# 4677   2018-09-10  8097397            4         3642            27774
# 4678   2018-09-10  8097397            5         3643            27897
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4674            27600           27600           27600    2534857  2018  ...
# 4675            27664           27664           27664    2534857  2018  ...
# 4676            27738           27738           27738    2534857  2018  ...
# 4677            27774           27774           27774    2534857  2018  ...
# 4678            27897           27897           27897    2534857  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (141080, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Route 32X

# %%
lwk = wk[(wk['LINEID'] == '32X')]

# %%
lwk.shape
# Out:
# (5944, 22)

# %%
# Drop Route 32X rows from wk
wk.drop(wk[wk['LINEID'] == '32X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4771   2018-09-10  8097644            1         3085            25800
# 4772   2018-09-10  8097644            2         3082            25878
# 4773   2018-09-10  8097644            3         3165            25920
# 4774   2018-09-10  8097644            4         3166            25983
# 4775   2018-09-10  8097644            5         3167            26006
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4771            25800           25800           25800    1001242  2018  ...
# 4772            25878           25878           25878    1001242  2018  ...
# 4773            25920           25920           25920    1001242  2018  ...
# 4774            25983           25983           25983    1001242  2018  ...
# 4775            26006           26006           26006    1001242  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (135136, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32X_tripLeave6_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_8.csv', index=False)
