# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave5 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave5_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (1877166, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-08-26  7510720            1         1730            33000
# 1   2018-08-26  7510720            2         1731            33027
# 2   2018-08-26  7510720            3         1732            33061
# 3   2018-08-26  7510720            4         1733            33091
# 4   2018-08-26  7510720            5         1650            33128
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            33000           33000           33000    2406899  2018  ...
# 1            33027           33027           33027    2406899  2018  ...
# 2            33061           33061           33061    2406899  2018  ...
# 3            33091           33091           33091    2406899  2018  ...
# 4            33128           33128           33128    2406899  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (46833, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 176   2018-08-26  7510910            1         1791            36000
# 177   2018-08-26  7510910            2         1792            36080
# 178   2018-08-26  7510910            3         1793            36113
# 179   2018-08-26  7510910            4          962            36167
# 180   2018-08-26  7510910            5          635            36206
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 176            36000           36000           36000    2172253  2018  ...
# 177            36080           36080           36080    2172253  2018  ...
# 178            36113           36113           36113    2172253  2018  ...
# 179            36167           36167           36167    2172253  2018  ...
# 180            36206           36206           36206    2172253  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1830333, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 27A

# %%
lwk = wk[(wk['LINEID'] == '27A')]

# %%
lwk.shape
# Out:
# (127924, 22)

# %%
# Drop Route 27A rows from wk
wk.drop(wk[wk['LINEID'] == '27A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 885   2018-08-26  7511902            1         7067            37800
# 886   2018-08-26  7511902            2         2956            37837
# 887   2018-08-26  7511902            3         2965            37883
# 888   2018-08-26  7511902            4         2983            37936
# 889   2018-08-26  7511902            5         2984            37997
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 885            37800           37800           37800    2868335  2018  ...
# 886            37837           37837           37837    2868335  2018  ...
# 887            37883           37883           37883    2868335  2018  ...
# 888            37936           37936           37936    2868335  2018  ...
# 889            37997           37997           37997    2868335  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1702409, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27A_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 61

# %%
lwk = wk[(wk['LINEID'] == '61')]

# %%
lwk.shape
# Out:
# (86528, 22)

# %%
# Drop Route 61 rows from wk
wk.drop(wk[wk['LINEID'] == '61'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1460   2018-08-26  7512177            1         1380            50700
# 1461   2018-08-26  7512177            2         1381            50727
# 1462   2018-08-26  7512177            3         1406            50774
# 1463   2018-08-26  7512177            4         1407            50818
# 1464   2018-08-26  7512177            5         1409            50857
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1460            50700           50700           50700    1001242  2018  ...
# 1461            50727           50727           50727    1001242  2018  ...
# 1462            50774           50774           50774    1001242  2018  ...
# 1463            50818           50818           50818    1001242  2018  ...
# 1464            50857           50857           50857    1001242  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1615881, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_61_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (185428, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1788   2018-08-26  7512303            1         7348            34500
# 1789   2018-08-26  7512303            2         3669            34582
# 1790   2018-08-26  7512303            3         3671            34629
# 1791   2018-08-26  7512303            4         3672            34647
# 1792   2018-08-26  7512303            6         3087            34874
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1788            34500           34500           34500    1001159  2018  ...
# 1789            34582           34582           34582    1001159  2018  ...
# 1790            34629           34629           34629    1001159  2018  ...
# 1791            34647           34647           34647    1001159  2018  ...
# 1792            34874           34874           34874    1001159  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1430453, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 102

# %%
lwk = wk[(wk['LINEID'] == '102')]

# %%
lwk.shape
# Out:
# (179020, 22)

# %%
# Drop Route 102 rows from wk
wk.drop(wk[wk['LINEID'] == '102'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2693   2018-08-26  7512786            3          497            34954
# 2694   2018-08-26  7512786            4          515            35030
# 2695   2018-08-26  7512786            5          516            35088
# 2696   2018-08-26  7512786            6         4384            35129
# 2697   2018-08-26  7512786            7          519            35179
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2693            34954           34954           34954    1000345  2018  ...
# 2694            35030           35030           35030    1000345  2018  ...
# 2695            35088           35088           35088    1000345  2018  ...
# 2696            35129           35129           35129    1000345  2018  ...
# 2697            35179           35179           35179    1000345  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1251433, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_102_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (127833, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2842   2018-08-26  7512800            1         5171            84600
# 2843   2018-08-26  7512800            4         2976            84637
# 2844   2018-08-26  7512800            5         2977            84671
# 2845   2018-08-26  7512800            6         2978            84720
# 2846   2018-08-26  7512800            7         2979            84744
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2842            84600           84600           84600    2534849  2018  ...
# 2843            84637           84637           84637    2534849  2018  ...
# 2844            84671           84671           84671    2534849  2018  ...
# 2845            84720           84720           84720    2534849  2018  ...
# 2846            84744           84744           84744    2534849  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1123600, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 16C

# %%
lwk = wk[(wk['LINEID'] == '16C')]

# %%
lwk.shape
# Out:
# (9686, 22)

# %%
# Drop Route 16C rows from wk
wk.drop(wk[wk['LINEID'] == '16C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4244   2018-08-26  7514822            1         7333            61200
# 4245   2018-08-26  7514822            2          783            61298
# 4246   2018-08-26  7514822            3          784            61321
# 4247   2018-08-26  7514822            4          785            61359
# 4248   2018-08-26  7514822            5          786            61451
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4244            61200           61200           61200    1000912  2018  ...
# 4245            61298           61298           61298    1000912  2018  ...
# 4246            61321           61321           61321    1000912  2018  ...
# 4247            61359           61359           61359    1000912  2018  ...
# 4248            61451           61451           61451    1000912  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1113914, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_16C_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (100049, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4436   2018-08-27  7502615            4         4268            28439
# 4437   2018-08-27  7502615            5         4273            28560
# 4438   2018-08-27  7502615            6         4277            28711
# 4439   2018-08-27  7502615            7         7462            28913
# 4440   2018-08-27  7502615            8         7461            28945
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4436            28439           28439           28439    2534853  2018  ...
# 4437            28560           28560           28560    2534853  2018  ...
# 4438            28711           28711           28711    2534853  2018  ...
# 4439            28913           28913           28913    2534853  2018  ...
# 4440            28945           28945           28945    2534853  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1013865, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 84X

# %%
lwk = wk[(wk['LINEID'] == '84X')]

# %%
lwk.shape
# Out:
# (26748, 22)

# %%
# Drop Route 84X rows from wk
wk.drop(wk[wk['LINEID'] == '84X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4508   2018-08-27  7502714            1         3921            25200
# 4509   2018-08-27  7502714            2         3922            25276
# 4510   2018-08-27  7502714            3         3923            25333
# 4511   2018-08-27  7502714            4         3112            25378
# 4512   2018-08-27  7502714            5         3924            25472
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4508            25200           25200           25200    2172270  2018  ...
# 4509            25276           25276           25276    2172270  2018  ...
# 4510            25333           25333           25333    2172270  2018  ...
# 4511            25378           25378           25378    2172270  2018  ...
# 4512            25472           25472           25472    2172270  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (987117, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84X_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 67X

# %%
lwk = wk[(wk['LINEID'] == '67X')]

# %%
lwk.shape
# Out:
# (34324, 22)

# %%
# Drop Route 67X rows from wk
wk.drop(wk[wk['LINEID'] == '67X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4598   2018-08-27  7502754            1         3057            19200
# 4599   2018-08-27  7502754            2         4830            19252
# 4600   2018-08-27  7502754            3         7667            19284
# 4601   2018-08-27  7502754            4         3091            19333
# 4602   2018-08-27  7502754            5         3092            19358
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4598            19200           19200           19200    2868382  2018  ...
# 4599            19252           19252           19252    2868382  2018  ...
# 4600            19284           19284           19284    2868382  2018  ...
# 4601            19333           19333           19333    2868382  2018  ...
# 4602            19358           19358           19358    2868382  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (952793, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67X_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 7D

# %%
lwk = wk[(wk['LINEID'] == '7D')]

# %%
lwk.shape
# Out:
# (7449, 22)

# %%
# Drop Route 7D rows from wk
wk.drop(wk[wk['LINEID'] == '7D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4725   2018-08-27  7502769            3          784            25332
# 4726   2018-08-27  7502769            4          785            25373
# 4727   2018-08-27  7502769            5          786            25449
# 4728   2018-08-27  7502769            6          793            25562
# 4729   2018-08-27  7502769            7         7576            25571
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4725            25332           25332           25332    2868322  2018  ...
# 4726            25373           25373           25373    2868322  2018  ...
# 4727            25449           25449           25449    2868322  2018  ...
# 4728            25562           25562           25562    2868322  2018  ...
# 4729            25571           25571           25571    2868322  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (945344, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7D_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 38B

# %%
lwk = wk[(wk['LINEID'] == '38B')]

# %%
lwk.shape
# Out:
# (24643, 22)

# %%
# Drop Route 38B rows from wk
wk.drop(wk[wk['LINEID'] == '38B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4772   2018-08-27  7502806            1         4686            24600
# 4773   2018-08-27  7502806            2         4687            24621
# 4774   2018-08-27  7502806            3          102            24723
# 4775   2018-08-27  7502806            4         6239            24763
# 4776   2018-08-27  7502806            5          104            24833
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4772            24600           24600           24600    1001216  2018  ...
# 4773            24621           24621           24621    1001216  2018  ...
# 4774            24723           24723           24723    1001216  2018  ...
# 4775            24763           24763           24763    1001216  2018  ...
# 4776            24833           24833           24833    1001216  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (920701, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38B_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 220

# %%
lwk = wk[(wk['LINEID'] == '220')]

# %%
lwk.shape
# Out:
# (64760, 22)

# %%
# Drop Route 220 rows from wk
wk.drop(wk[wk['LINEID'] == '220'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5180   2018-08-27  7502870            1         3640            27600
# 5181   2018-08-27  7502870            2         3574            27665
# 5182   2018-08-27  7502870            3         3641            27741
# 5183   2018-08-27  7502870            4         3642            27776
# 5184   2018-08-27  7502870            5         3643            27896
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5180            27600           27600           27600    1932328  2018  ...
# 5181            27665           27665           27665    1932328  2018  ...
# 5182            27741           27741           27741    1932328  2018  ...
# 5183            27776           27776           27776    1932328  2018  ...
# 5184            27896           27896           27896    1932328  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (855941, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_220_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 32X

# %%
lwk = wk[(wk['LINEID'] == '32X')]

# %%
lwk.shape
# Out:
# (6653, 22)

# %%
# Drop Route 32X rows from wk
wk.drop(wk[wk['LINEID'] == '32X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5411   2018-08-27  7503228            1          342            22200
# 5412   2018-08-27  7503228            2         4521            22258
# 5413   2018-08-27  7503228            3         1934            22329
# 5414   2018-08-27  7503228            4         2385            22436
# 5415   2018-08-27  7503228            5         2386            22503
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5411            22200           22200           22200    1932369  2018  ...
# 5412            22258           22258           22258    1932369  2018  ...
# 5413            22329           22329           22329    1932369  2018  ...
# 5414            22436           22436           22436    1932369  2018  ...
# 5415            22503           22503           22503    1932369  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (849288, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32X_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (146247, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6561   2018-08-27  7503605            1          621            62400
# 6562   2018-08-27  7503605            2          289            62605
# 6563   2018-08-27  7503605            3          496            62757
# 6564   2018-08-27  7503605            4         7490            62789
# 6565   2018-08-27  7503605            5          515            62896
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6561            62400           62400           62400    1000790  2018  ...
# 6562            62605           62605           62605    1000790  2018  ...
# 6563            62757           62757           62757    1000790  2018  ...
# 6564            62789           62789           62789    1000790  2018  ...
# 6565            62896           62896           62896    1000790  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (703041, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 31B

# %%
lwk = wk[(wk['LINEID'] == '31B')]

# %%
lwk.shape
# Out:
# (18159, 22)

# %%
# Drop Route 31B rows from wk
wk.drop(wk[wk['LINEID'] == '31B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7142   2018-08-27  7504123            1         3605            27300
# 7143   2018-08-27  7504123            2         3606            27345
# 7144   2018-08-27  7504123            3         3607            27398
# 7145   2018-08-27  7504123            4         6051            27411
# 7146   2018-08-27  7504123            5         6053            27453
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7142            27300           27300           27300    1000884  2018  ...
# 7143            27345           27345           27345    1000884  2018  ...
# 7144            27398           27398           27398    1000884  2018  ...
# 7145            27411           27411           27411    1000884  2018  ...
# 7146            27453           27453           27453    1000884  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (684882, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31B_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (25284, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7245   2018-08-27  7504129            1         6004            36000
# 7246   2018-08-27  7504129            2            3            36089
# 7247   2018-08-27  7504129            3          192            36314
# 7248   2018-08-27  7504129            4          795            36356
# 7249   2018-08-27  7504129            5          796            36399
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7245            36000           36000           36000    1001221  2018  ...
# 7246            36089           36089           36089    1001221  2018  ...
# 7247            36314           36314           36314    1001221  2018  ...
# 7248            36356           36356           36356    1001221  2018  ...
# 7249            36399           36399           36399    1001221  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (659598, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (130948, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7934   2018-08-27  7504340            1         3088            27600
# 7935   2018-08-27  7504340            2         3704            27629
# 7936   2018-08-27  7504340            3         3705            27698
# 7937   2018-08-27  7504340            4          733            27798
# 7938   2018-08-27  7504340            5         6015            27827
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7934            27600           27600           27600    2406926  2018  ...
# 7935            27629           27629           27629    2406926  2018  ...
# 7936            27698           27698           27698    2406926  2018  ...
# 7937            27798           27798           27798    2406926  2018  ...
# 7938            27827           27827           27827    2406926  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (528650, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Route 41X

# %%
lwk = wk[(wk['LINEID'] == '41X')]

# %%
lwk.shape
# Out:
# (13948, 22)

# %%
# Drop Route 41X rows from wk
wk.drop(wk[wk['LINEID'] == '41X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8002   2018-08-27  7504348            1         7026            24000
# 8003   2018-08-27  7504348            2         4747            24127
# 8004   2018-08-27  7504348            3         2960            24178
# 8005   2018-08-27  7504348            4         1840            24357
# 8006   2018-08-27  7504348            5         1841            24387
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8002            24000           24000           24000    2534791  2018  ...
# 8003            24127           24127           24127    2534791  2018  ...
# 8004            24178           24178           24178    2534791  2018  ...
# 8005            24357           24357           24357    2534791  2018  ...
# 8006            24387           24387           24387    2534791  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (514702, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41X_tripLeave5_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave5_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave5_route_split_7.csv', index=False)
