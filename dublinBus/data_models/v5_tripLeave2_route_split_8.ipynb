# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 8 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_8.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_31263/3884054729.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_8.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (3330195, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6290460            1         4564            45000
# 1   2018-02-26  6290460            2         3443            45088
# 2   2018-02-26  6290460            3         3444            45126
# 3   2018-02-26  6290460            4         3445            45172
# 4   2018-02-26  6290460            5         3446            45233
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            45000           45000           45000    2868348  2018  ...
# 1            45088           45088           45088    2868348  2018  ...
# 2            45126           45126           45126    2868348  2018  ...
# 3            45172           45172           45172    2868348  2018  ...
# 4            45233           45233           45233    2868348  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 69

# %%
lwk = wk[(wk['LINEID'] == '69')]

# %%
lwk.shape
# Out:
# (98100, 22)

# %%
# Drop Route 69 rows from wk
wk.drop(wk[wk['LINEID'] == '69'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 357   2018-02-26  6290493            2         3891            29124
# 358   2018-02-26  6290493            3         3949            29214
# 359   2018-02-26  6290493            4         3950            29270
# 360   2018-02-26  6290493            5         2229            29370
# 361   2018-02-26  6290493            6         2230            29416
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 357            29124           29124           29124    1001100  2018  ...
# 358            29214           29214           29214    1001100  2018  ...
# 359            29270           29270           29270    1001100  2018  ...
# 360            29370           29370           29370    1001100  2018  ...
# 361            29416           29416           29416    1001100  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3232095, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 25

# %%
lwk = wk[(wk['LINEID'] == '25')]

# %%
lwk.shape
# Out:
# (64392, 22)

# %%
# Drop Route 25 rows from wk
wk.drop(wk[wk['LINEID'] == '25'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 955   2018-02-26  6290509            1         4533            24900
# 956   2018-02-26  6290509            2         4844            24949
# 957   2018-02-26  6290509            3         4177            25130
# 958   2018-02-26  6290509            4         4178            25166
# 959   2018-02-26  6290509            5         4142            25240
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 955            24900           24900           24900    1000786  2018  ...
# 956            24949           24949           24949    1000786  2018  ...
# 957            25130           25130           25130    1000786  2018  ...
# 958            25166           25166           25166    1000786  2018  ...
# 959            25240           25240           25240    1000786  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3167703, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 45A

# %%
lwk = wk[(wk['LINEID'] == '45A')]

# %%
lwk.shape
# Out:
# (183779, 22)

# %%
# Drop Route 45A rows from wk
wk.drop(wk[wk['LINEID'] == '45A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1787   2018-02-26  6290539            1         4620            22500
# 1788   2018-02-26  6290539            2         7563            22549
# 1789   2018-02-26  6290539            3         3368            22601
# 1790   2018-02-26  6290539            4         4626            22688
# 1791   2018-02-26  6290539            5         4627            22734
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1787            22500           22500           22500    1001225  2018  ...
# 1788            22549           22549           22549    1001225  2018  ...
# 1789            22601           22601           22601    1001225  2018  ...
# 1790            22688           22688           22688    1001225  2018  ...
# 1791            22734           22734           22734    1001225  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2983924, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_45A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 25A

# %%
lwk = wk[(wk['LINEID'] == '25A')]

# %%
lwk.shape
# Out:
# (182649, 22)

# %%
# Drop Route 25A rows from wk
wk.drop(wk[wk['LINEID'] == '25A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2059   2018-02-26  6290586            1         3088            29520
# 2060   2018-02-26  6290586            2         3704            29558
# 2061   2018-02-26  6290586            3         3705            29647
# 2062   2018-02-26  6290586            4          733            29776
# 2063   2018-02-26  6290586            5         6015            29814
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2059            29520           29520           29520    2868339  2018  ...
# 2060            29558           29558           29558    2868339  2018  ...
# 2061            29647           29647           29647    2868339  2018  ...
# 2062            29776           29776           29776    2868339  2018  ...
# 2063            29814           29814           29814    2868339  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2801275, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 41C

# %%
lwk = wk[(wk['LINEID'] == '41C')]

# %%
lwk.shape
# Out:
# (257265, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '41C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2541   2018-02-26  6290605            1         1423            26400
# 2542   2018-02-26  6290605            2         1424            26441
# 2543   2018-02-26  6290605            3         1425            26492
# 2544   2018-02-26  6290605            4         1426            26569
# 2545   2018-02-26  6290605            5         1427            26618
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2541            26400           26400           26400    1000274  2018  ...
# 2542            26441           26441           26441    1000274  2018  ...
# 2543            26492           26492           26492    1000274  2018  ...
# 2544            26569           26569           26569    1000274  2018  ...
# 2545            26618           26618           26618    1000274  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2544010, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41C_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 122

# %%
lwk = wk[(wk['LINEID'] == '122')]

# %%
lwk.shape
# Out:
# (303335, 22)

# %%
# Drop Route 122 rows from wk
wk.drop(wk[wk['LINEID'] == '122'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3592   2018-02-26  6290649            1         6030            26400
# 3593   2018-02-26  6290649            2         6028            26455
# 3594   2018-02-26  6290649            3         6025            26489
# 3595   2018-02-26  6290649            4         6024            26520
# 3596   2018-02-26  6290649            5         6021            26558
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3592            26400           26400           26400    1000744  2018  ...
# 3593            26455           26455           26455    1000744  2018  ...
# 3594            26489           26489           26489    1000744  2018  ...
# 3595            26520           26520           26520    1000744  2018  ...
# 3596            26558           26558           26558    1000744  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2240675, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_122_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 79A

# %%
lwk = wk[(wk['LINEID'] == '79A')]

# %%
lwk.shape
# Out:
# (86337, 22)

# %%
# Drop Route 79A rows from wk
wk.drop(wk[wk['LINEID'] == '79A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3624   2018-02-26  6290650            1          326            28800
# 3625   2018-02-26  6290650            2         1443            28902
# 3626   2018-02-26  6290650            3         1444            28960
# 3627   2018-02-26  6290650            4         1445            29023
# 3628   2018-02-26  6290650            5         4407            29120
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3624            28800           28800           28800    1000744  2018  ...
# 3625            28902           28902           28902    1000744  2018  ...
# 3626            28960           28960           28960    1000744  2018  ...
# 3627            29023           29023           29023    1000744  2018  ...
# 3628            29120           29120           29120    1000744  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2154338, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 79

# %%
lwk = wk[(wk['LINEID'] == '79')]

# %%
lwk.shape
# Out:
# (107235, 22)

# %%
# Drop Route 79 rows from wk
wk.drop(wk[wk['LINEID'] == '79'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4255   2018-02-26  6290804            1         3605            25200
# 4256   2018-02-26  6290804            2         3606            25241
# 4257   2018-02-26  6290804            3         3607            25288
# 4258   2018-02-26  6290804            4         6051            25300
# 4259   2018-02-26  6290804            5         6053            25337
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4255            25200           25200           25200    2172255  2018  ...
# 4256            25241           25241           25241    2172255  2018  ...
# 4257            25288           25288           25288    2172255  2018  ...
# 4258            25300           25300           25300    2172255  2018  ...
# 4259            25337           25337           25337    2172255  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2047103, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 42

# %%
lwk = wk[(wk['LINEID'] == '42')]

# %%
lwk.shape
# Out:
# (220033, 22)

# %%
# Drop Route 42 rows from wk
wk.drop(wk[wk['LINEID'] == '42'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4657   2018-02-26  6290947            1         4843            27600
# 4658   2018-02-26  6290947            2         4905            27663
# 4659   2018-02-26  6290947            4         4906            27724
# 4660   2018-02-26  6290947            5         4907            27768
# 4661   2018-02-26  6290947            6         4908            27796
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4657            27600           27600           27600    2534800  2018  ...
# 4658            27663           27663           27663    2534800  2018  ...
# 4659            27724           27724           27724    2534800  2018  ...
# 4660            27768           27768           27768    2534800  2018  ...
# 4661            27796           27796           27796    2534800  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1827070, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 41A

# %%
lwk = wk[(wk['LINEID'] == '41A')]

# %%
lwk.shape
# Out:
# (4274, 22)

# %%
# Drop Route 41A rows from wk
wk.drop(wk[wk['LINEID'] == '41A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4890   2018-02-26  6290956            1          395            22200
# 4891   2018-02-26  6290956            2          396            22268
# 4892   2018-02-26  6290956            3          397            22305
# 4893   2018-02-26  6290956            4          398            22347
# 4894   2018-02-26  6290956            5          399            22381
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4890            22200           22200           22200    1932368  2018  ...
# 4891            22268           22268           22268    1932368  2018  ...
# 4892            22305           22305           22305    1932368  2018  ...
# 4893            22347           22347           22347    1932368  2018  ...
# 4894            22381           22381           22381    1932368  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1822796, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (85193, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5640   2018-02-26  6290992            1          407            63000
# 5641   2018-02-26  6290992            2         2498            63072
# 5642   2018-02-26  6290992            3         2499            63128
# 5643   2018-02-26  6290992            4         2500            63220
# 5644   2018-02-26  6290992            5         2501            63335
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5640            63000           63000           63000    1000235  2018  ...
# 5641            63072           63072           63072    1000235  2018  ...
# 5642            63128           63128           63128    1000235  2018  ...
# 5643            63220           63220           63220    1000235  2018  ...
# 5644            63335           63335           63335    1000235  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1737603, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 33X

# %%
lwk = wk[(wk['LINEID'] == '33X')]

# %%
lwk.shape
# Out:
# (22476, 22)

# %%
# Drop Route 33X rows from wk
wk.drop(wk[wk['LINEID'] == '33X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5699   2018-02-26  6291036            2          915            26738
# 5700   2018-02-26  6291036            3          916            26766
# 5701   2018-02-26  6291036            4          917            26795
# 5702   2018-02-26  6291036            5          918            26835
# 5703   2018-02-26  6291036            6          919            26876
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5699            26738           26738           26738    2406922  2018  ...
# 5700            26766           26766           26766    2406922  2018  ...
# 5701            26795           26795           26795    2406922  2018  ...
# 5702            26835           26835           26835    2406922  2018  ...
# 5703            26876           26876           26876    2406922  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1715127, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33X_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 29A

# %%
lwk = wk[(wk['LINEID'] == '29A')]

# %%
lwk.shape
# Out:
# (212240, 22)

# %%
# Drop Route 29A rows from wk
wk.drop(wk[wk['LINEID'] == '29A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5923   2018-02-26  6291269            4         3102            24690
# 5924   2018-02-26  6291269            5         3103            24714
# 5925   2018-02-26  6291269            6         5105            24765
# 5926   2018-02-26  6291269            7         3105            24803
# 5927   2018-02-26  6291269            8         3106            24818
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5923            24690           24690           24690    2868388  2018  ...
# 5924            24714           24714           24714    2868388  2018  ...
# 5925            24765           24765           24765    2868388  2018  ...
# 5926            24803           24803           24803    2868388  2018  ...
# 5927            24818           24818           24818    2868388  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1502887, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_29A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 59

# %%
lwk = wk[(wk['LINEID'] == '59')]

# %%
lwk.shape
# Out:
# (44588, 22)

# %%
# Drop Route 59 rows from wk
wk.drop(wk[wk['LINEID'] == '59'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8225   2018-02-26  6291512            1         2955            27600
# 8226   2018-02-26  6291512            2         7067            27609
# 8227   2018-02-26  6291512            3         2956            27641
# 8228   2018-02-26  6291512            4         2965            27708
# 8229   2018-02-26  6291512            5         2967            27829
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8225            27600           27600           27600    1000586  2018  ...
# 8226            27609           27609           27609    1000586  2018  ...
# 8227            27641           27641           27641    1000586  2018  ...
# 8228            27708           27708           27708    1000586  2018  ...
# 8229            27829           27829           27829    1000586  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1458299, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_59_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (2662, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8287   2018-02-26  6291556            1         4495            61200
# 8288   2018-02-26  6291556            2         1278            61352
# 8289   2018-02-26  6291556            3         1282            61506
# 8290   2018-02-26  6291556            4         4456            61615
# 8291   2018-02-26  6291556            5         1284            61675
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8287            61200           61200           61200    1001102  2018  ...
# 8288            61352           61352           61352    1001102  2018  ...
# 8289            61506           61506           61506    1001102  2018  ...
# 8290            61615           61615           61615    1001102  2018  ...
# 8291            61675           61675           61675    1001102  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1455637, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Route 68A

# %%
lwk = wk[(wk['LINEID'] == '68A')]

# %%
lwk.shape
# Out:
# (4488, 22)

# %%
# Drop Route 68A rows from wk
wk.drop(wk[wk['LINEID'] == '68A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8371   2018-02-26  6291674            1         4795            23400
# 8372   2018-02-26  6291674            3         4688            23915
# 8373   2018-02-26  6291674            4         4689            24021
# 8374   2018-02-26  6291674            5         4410            24112
# 8375   2018-02-26  6291674            6         2678            24137
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8371            23400           23400           23400    1000257  2018  ...
# 8372            23915           23915           23915    1000257  2018  ...
# 8373            24021           24021           24021    1000257  2018  ...
# 8374            24112           24112           24112    1000257  2018  ...
# 8375            24137           24137           24137    1000257  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1451149, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68A_tripLeave2_sp8.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_9

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_9.csv', index=False)
