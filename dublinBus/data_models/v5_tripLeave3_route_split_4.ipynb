# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave3 route split 4 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave3_route_split_4.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (10449648, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6652820            1          395            36000
# 1   2018-04-29  6652820            2          396            36054
# 2   2018-04-29  6652820            3          397            36084
# 3   2018-04-29  6652820            4          398            36128
# 4   2018-04-29  6652820            5          399            36164
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            36000           36000           36000    2534797  2018  ...
# 1            36054           36054           36054    2534797  2018  ...
# 2            36084           36084           36084    2534797  2018  ...
# 3            36128           36128           36128    2534797  2018  ...
# 4            36164           36164           36164    2534797  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 15A

# %%
lwk = wk[(wk['LINEID'] == '15A')]

# %%
lwk.shape
# Out:
# (206049, 22)

# %%
# Drop Route 15A rows from wk
wk.drop(wk[wk['LINEID'] == '15A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 400   2018-04-29  6652830            1         4096            52200
# 401   2018-04-29  6652830            2         4114            52228
# 402   2018-04-29  6652830            3         4115            52246
# 403   2018-04-29  6652830            4         4116            52330
# 404   2018-04-29  6652830            5         4117            52366
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 400            52200           52200           52200    2534809  2018  ...
# 401            52228           52228           52228    2534809  2018  ...
# 402            52246           52246           52246    2534809  2018  ...
# 403            52330           52330           52330    2534809  2018  ...
# 404            52366           52366           52366    2534809  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10243599, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15A_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (149372, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 642   2018-04-29  6652867            1         7132            34200
# 643   2018-04-29  6652867            2         6230            34275
# 644   2018-04-29  6652867            3         6228            34321
# 645   2018-04-29  6652867            4         4788            34381
# 646   2018-04-29  6652867            5         6273            34432
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 642            34200           34200           34200    2172311  2018  ...
# 643            34275           34275           34275    2172311  2018  ...
# 644            34321           34321           34321    2172311  2018  ...
# 645            34381           34381           34381    2172311  2018  ...
# 646            34432           34432           34432    2172311  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10094227, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 9

# %%
lwk = wk[(wk['LINEID'] == '9')]

# %%
lwk.shape
# Out:
# (449099, 22)

# %%
# Drop Route 9 rows from wk
wk.drop(wk[wk['LINEID'] == '9'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1287   2018-04-29  6652927            1         7132            36600
# 1288   2018-04-29  6652927            2         6230            36659
# 1289   2018-04-29  6652927            3         6228            36696
# 1290   2018-04-29  6652927            4         4788            36743
# 1291   2018-04-29  6652927            5         6273            36790
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1287            36600           36600           36600    2172265  2018  ...
# 1288            36659           36659           36659    2172265  2018  ...
# 1289            36696           36696           36696    2172265  2018  ...
# 1290            36743           36743           36743    2172265  2018  ...
# 1291            36790           36790           36790    2172265  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9645128, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_9_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 83

# %%
lwk = wk[(wk['LINEID'] == '83')]

# %%
lwk.shape
# Out:
# (340648, 22)

# %%
# Drop Route 83 rows from wk
wk.drop(wk[wk['LINEID'] == '83'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1474   2018-04-29  6652930            1         2492            49200
# 1475   2018-04-29  6652930            2         2493            49250
# 1476   2018-04-29  6652930            3         2465            49283
# 1477   2018-04-29  6652930            4         2466            49309
# 1478   2018-04-29  6652930            5         2467            49349
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1474            49200           49200           49200    2172265  2018  ...
# 1475            49250           49250           49250    2172265  2018  ...
# 1476            49283           49283           49283    2172265  2018  ...
# 1477            49309           49309           49309    2172265  2018  ...
# 1478            49349           49349           49349    2172265  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9304480, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 83A

# %%
lwk = wk[(wk['LINEID'] == '83A')]

# %%
lwk.shape
# Out:
# (98010, 22)

# %%
# Drop Route 83A rows from wk
wk.drop(wk[wk['LINEID'] == '83A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2180   2018-04-29  6653022            1         4747            34200
# 2181   2018-04-29  6653022            2         1882            34302
# 2182   2018-04-29  6653022            3         7379            34340
# 2183   2018-04-29  6653022            4         4903            34378
# 2184   2018-04-29  6653022            5         7219            34418
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2180            34200           34200           34200    2693289  2018  ...
# 2181            34302           34302           34302    2693289  2018  ...
# 2182            34340           34340           34340    2693289  2018  ...
# 2183            34378           34378           34378    2693289  2018  ...
# 2184            34418           34418           34418    2693289  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9206470, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83A_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 37

# %%
lwk = wk[(wk['LINEID'] == '37')]

# %%
lwk.shape
# Out:
# (290285, 22)

# %%
# Drop Route 37 rows from wk
wk.drop(wk[wk['LINEID'] == '37'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2461   2018-04-29  6653209            1         2243            37800
# 2462   2018-04-29  6653209            2         2200            37847
# 2463   2018-04-29  6653209            3         5006            37920
# 2464   2018-04-29  6653209            4         5007            37961
# 2465   2018-04-29  6653209            5         2655            38045
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2461            37800           37800           37800    1001102  2018  ...
# 2462            37847           37847           37847    1001102  2018  ...
# 2463            37920           37920           37920    1001102  2018  ...
# 2464            37961           37961           37961    1001102  2018  ...
# 2465            38045           38045           38045    1001102  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8916185, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_37_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 76

# %%
lwk = wk[(wk['LINEID'] == '76')]

# %%
lwk.shape
# Out:
# (124512, 22)

# %%
# Drop Route 76 rows from wk
wk.drop(wk[wk['LINEID'] == '76'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2701   2018-04-29  6653217            1          298            30000
# 2702   2018-04-29  6653217            2          496            30051
# 2703   2018-04-29  6653217            3         7490            30059
# 2704   2018-04-29  6653217            4          497            30079
# 2705   2018-04-29  6653217            5          515            30146
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2701            30000           30000           30000    2172254  2018  ...
# 2702            30051           30051           30051    2172254  2018  ...
# 2703            30059           30059           30059    2172254  2018  ...
# 2704            30079           30079           30079    2172254  2018  ...
# 2705            30146           30146           30146    2172254  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8791673, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 27

# %%
lwk = wk[(wk['LINEID'] == '27')]

# %%
lwk.shape
# Out:
# (639661, 22)

# %%
# Drop Route 27 rows from wk
wk.drop(wk[wk['LINEID'] == '27'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3460   2018-04-29  6653290            3         2965            34269
# 3461   2018-04-29  6653290            4         2983            34303
# 3462   2018-04-29  6653290            5         2984            34342
# 3463   2018-04-29  6653290            6         7449            34371
# 3464   2018-04-29  6653290            7         2941            34414
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3460            34269           34269           34269    2172245  2018  ...
# 3461            34303           34303           34303    2172245  2018  ...
# 3462            34342           34342           34342    2172245  2018  ...
# 3463            34371           34371           34371    2172245  2018  ...
# 3464            34414           34414           34414    2172245  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8152012, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 61

# %%
lwk = wk[(wk['LINEID'] == '61')]

# %%
lwk.shape
# Out:
# (87468, 22)

# %%
# Drop Route 61 rows from wk
wk.drop(wk[wk['LINEID'] == '61'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4788   2018-04-29  6653358            1         7158            32400
# 4789   2018-04-29  6653358            2         7048            32437
# 4790   2018-04-29  6653358            3         7159            32499
# 4791   2018-04-29  6653358            4         7388            32516
# 4792   2018-04-29  6653358            5         7017            32605
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4788            32400           32400           32400    2406867  2018  ...
# 4789            32437           32437           32437    2406867  2018  ...
# 4790            32499           32499           32499    2406867  2018  ...
# 4791            32516           32516           32516    2406867  2018  ...
# 4792            32605           32605           32605    2406867  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8064544, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_61_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 39

# %%
lwk = wk[(wk['LINEID'] == '39')]

# %%
lwk.shape
# Out:
# (275597, 22)

# %%
# Drop Route 39 rows from wk
wk.drop(wk[wk['LINEID'] == '39'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5384   2018-04-29  6653406            3         3752            34935
# 5385   2018-04-29  6653406            4         3751            34953
# 5386   2018-04-29  6653406            5         3689            35024
# 5387   2018-04-29  6653406            6         7594            35038
# 5388   2018-04-29  6653406            7         3690            35056
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5384            34935           34935           34935    1000780  2018  ...
# 5385            34953           34953           34953    1000780  2018  ...
# 5386            35024           35024           35024    1000780  2018  ...
# 5387            35038           35038           35038    1000780  2018  ...
# 5388            35056           35056           35056    1000780  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7788947, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (125672, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5943   2018-04-29  6653519            1          288            83700
# 5944   2018-04-29  6653519            2         1171            83741
# 5945   2018-04-29  6653519            3         1172            83773
# 5946   2018-04-29  6653519            4         1173            83818
# 5947   2018-04-29  6653519            5         1174            83876
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5943            83700           83700           83700    1932322  2018  ...
# 5944            83741           83741           83741    1932322  2018  ...
# 5945            83773           83773           83773    1932322  2018  ...
# 5946            83818           83818           83818    1932322  2018  ...
# 5947            83876           83876           83876    1932322  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7663275, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 41B

# %%
lwk = wk[(wk['LINEID'] == '41B')]

# %%
lwk.shape
# Out:
# (22699, 22)

# %%
# Drop Route 41B rows from wk
wk.drop(wk[wk['LINEID'] == '41B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6526   2018-04-29  6653528            1         5161            36000
# 6527   2018-04-29  6653528            2         5162            36076
# 6528   2018-04-29  6653528            3         2571            36199
# 6529   2018-04-29  6653528            4         2359            36264
# 6530   2018-04-29  6653528            5         2360            36325
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6526            36000           36000           36000    1001240  2018  ...
# 6527            36076           36076           36076    1001240  2018  ...
# 6528            36199           36199           36199    1001240  2018  ...
# 6529            36264           36264           36264    1001240  2018  ...
# 6530            36325           36325           36325    1001240  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7640576, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41B_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Route 54A

# %%
lwk = wk[(wk['LINEID'] == '54A')]

# %%
lwk.shape
# Out:
# (129715, 22)

# %%
# Drop Route 54A rows from wk
wk.drop(wk[wk['LINEID'] == '54A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7094   2018-04-29  6653625            1          621            54900
# 7095   2018-04-29  6653625            2          289            55047
# 7096   2018-04-29  6653625            3          496            55171
# 7097   2018-04-29  6653625            4         7490            55194
# 7098   2018-04-29  6653625            5          515            55285
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7094            54900           54900           54900    1000780  2018  ...
# 7095            55047           55047           55047    1000780  2018  ...
# 7096            55171           55171           55171    1000780  2018  ...
# 7097            55194           55194           55194    1000780  2018  ...
# 7098            55285           55285           55285    1000780  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (7510861, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_54A_tripLeave3_sp4.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave3_route_split_5

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave3_route_split_5.csv', index=False)
