# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 2 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_2.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_19777/271468329.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_2.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (16376433, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6288537            1          385            62400
# 1   2018-02-26  6288537            2         2806            62507
# 2   2018-02-26  6288537            3         2807            62549
# 3   2018-02-26  6288537            4         2808            62608
# 4   2018-02-26  6288537            5          486            62786
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            62400           62400           62400    1000372  2018  ...
# 1            62507           62507           62507    1000372  2018  ...
# 2            62549           62549           62549    1000372  2018  ...
# 3            62608           62608           62608    1000372  2018  ...
# 4            62786           62786           62786    1000372  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 18

# %%
lwk = wk[(wk['LINEID'] == '18')]

# %%
lwk.shape
# Out:
# (210626, 22)

# %%
# Drop Route 18 rows from wk
wk.drop(wk[wk['LINEID'] == '18'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 125   2018-02-26  6288539            1         4260            23400
# 126   2018-02-26  6288539            2         7296            23597
# 127   2018-02-26  6288539            3         4266            23681
# 128   2018-02-26  6288539            4         4253            23711
# 129   2018-02-26  6288539            5         4268            23745
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 125            23400           23400           23400    1000580  2018  ...
# 126            23597           23597           23597    1000580  2018  ...
# 127            23681           23681           23681    1000580  2018  ...
# 128            23711           23711           23711    1000580  2018  ...
# 129            23745           23745           23745    1000580  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16165807, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_18_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 84X

# %%
lwk = wk[(wk['LINEID'] == '84X')]

# %%
lwk.shape
# Out:
# (22320, 22)

# %%
# Drop Route 84X rows from wk
wk.drop(wk[wk['LINEID'] == '84X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 166   2018-02-26  6288540            1         4320            30600
# 167   2018-02-26  6288540            2         1476            30753
# 168   2018-02-26  6288540            3         7453            30863
# 169   2018-02-26  6288540            4         1478            31013
# 170   2018-02-26  6288540            5         1479            31116
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 166            30600           30600           30600    1000580  2018  ...
# 167            30753           30753           30753    1000580  2018  ...
# 168            30863           30863           30863    1000580  2018  ...
# 169            31013           31013           31013    1000580  2018  ...
# 170            31116           31116           31116    1000580  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16143487, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84X_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 145

# %%
lwk = wk[(wk['LINEID'] == '145')]

# %%
lwk.shape
# Out:
# (666508, 22)

# %%
# Drop Route 145 rows from wk
wk.drop(wk[wk['LINEID'] == '145'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 442   2018-02-26  6288548            2         3995            23641
# 443   2018-02-26  6288548            3         3996            23700
# 444   2018-02-26  6288548            4         3997            23776
# 445   2018-02-26  6288548            5         3998            23834
# 446   2018-02-26  6288548            6         3999            23921
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 442            23641           23641           23641    2693233  2018  ...
# 443            23700           23700           23700    2693233  2018  ...
# 444            23776           23776           23776    2693233  2018  ...
# 445            23834           23834           23834    2693233  2018  ...
# 446            23921           23921           23921    2693233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15476979, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_145_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 66A

# %%
lwk = wk[(wk['LINEID'] == '66A')]

# %%
lwk.shape
# Out:
# (68189, 22)

# %%
# Drop Route 66A rows from wk
wk.drop(wk[wk['LINEID'] == '66A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 486   2018-02-26  6288549            1         7391            27600
# 487   2018-02-26  6288549            2          493            27680
# 488   2018-02-26  6288549            3          494            27742
# 489   2018-02-26  6288549            4          495            27816
# 490   2018-02-26  6288549            5          400            27876
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 486            27600           27600           27600    2693233  2018  ...
# 487            27680           27680           27680    2693233  2018  ...
# 488            27742           27742           27742    2693233  2018  ...
# 489            27816           27816           27816    2693233  2018  ...
# 490            27876           27876           27876    2693233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15408790, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66A_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 66

# %%
lwk = wk[(wk['LINEID'] == '66')]

# %%
lwk.shape
# Out:
# (187945, 22)

# %%
# Drop Route 66 rows from wk
wk.drop(wk[wk['LINEID'] == '66'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 638   2018-02-26  6288553            1         7391            46800
# 639   2018-02-26  6288553            2          493            46907
# 640   2018-02-26  6288553            3          494            46990
# 641   2018-02-26  6288553            4          495            47089
# 642   2018-02-26  6288553            5          400            47169
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 638            46800           46800           46800    2693233  2018  ...
# 639            46907           46907           46907    2693233  2018  ...
# 640            46990           46990           46990    2693233  2018  ...
# 641            47089           47089           47089    2693233  2018  ...
# 642            47169           47169           47169    2693233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15220845, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 66B

# %%
lwk = wk[(wk['LINEID'] == '66B')]

# %%
lwk.shape
# Out:
# (72156, 22)

# %%
# Drop Route 66B rows from wk
wk.drop(wk[wk['LINEID'] == '66B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 735   2018-02-26  6288555            1         7391            56220
# 736   2018-02-26  6288555            2          493            56358
# 737   2018-02-26  6288555            3          494            56465
# 738   2018-02-26  6288555            4          495            56593
# 739   2018-02-26  6288555            5          400            56697
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 735            56220           56220           56220    2693233  2018  ...
# 736            56358           56358           56358    2693233  2018  ...
# 737            56465           56465           56465    2693233  2018  ...
# 738            56593           56593           56593    2693233  2018  ...
# 739            56697           56697           56697    2693233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15148689, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66B_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 26

# %%
lwk = wk[(wk['LINEID'] == '26')]

# %%
lwk.shape
# Out:
# (61345, 22)

# %%
# Drop Route 26 rows from wk
wk.drop(wk[wk['LINEID'] == '26'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 764   2018-02-26  6288556            1          318            62400
# 765   2018-02-26  6288556            2          312            62700
# 766   2018-02-26  6288556            3         1444            62886
# 767   2018-02-26  6288556            4         1445            63000
# 768   2018-02-26  6288556            5         1447            63148
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 764            62400           62400           62400    2693233  2018  ...
# 765            62700           62700           62700    2693233  2018  ...
# 766            62886           62886           62886    2693233  2018  ...
# 767            63000           63000           63000    2693233  2018  ...
# 768            63148           63148           63148    2693233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15087344, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_26_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (26380, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 997    2018-02-26  6288636            1         7348            25500
# 998    2018-02-26  6288636            2         3669            25564
# 999    2018-02-26  6288636            3         3671            25601
# 1000   2018-02-26  6288636            4         3672            25620
# 1001   2018-02-26  6288636            5         3078            25775
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 997             25500           25500           25500    1001155  2018  ...
# 998             25564           25564           25564    1001155  2018  ...
# 999             25601           25601           25601    1001155  2018  ...
# 1000            25620           25620           25620    1001155  2018  ...
# 1001            25775           25775           25775    1001155  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15060964, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Route 102

# %%
lwk = wk[(wk['LINEID'] == '102')]

# %%
lwk.shape
# Out:
# (157612, 22)

# %%
# Drop Route 102 rows from wk
wk.drop(wk[wk['LINEID'] == '102'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1466   2018-02-26  6288712            1         7158            25200
# 1467   2018-02-26  6288712            2         7048            25245
# 1468   2018-02-26  6288712            3         7159            25320
# 1469   2018-02-26  6288712            4         7017            25447
# 1470   2018-02-26  6288712            5         7018            25500
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1466            25200           25200           25200    1000268  2018  ...
# 1467            25245           25245           25245    1000268  2018  ...
# 1468            25320           25320           25320    1000268  2018  ...
# 1469            25447           25447           25447    1000268  2018  ...
# 1470            25500           25500           25500    1000268  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14903352, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_102_tripLeave2_sp2.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_3

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_3.csv', index=False)
