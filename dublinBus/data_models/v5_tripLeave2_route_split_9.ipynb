# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 9 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_9.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (1451149, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6291674            1         4795            23400
# 1   2018-02-26  6291674            3         4688            23915
# 2   2018-02-26  6291674            4         4689            24021
# 3   2018-02-26  6291674            5         4410            24112
# 4   2018-02-26  6291674            6         2678            24137
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            23400           23400           23400    1000257  2018  ...
# 1            23915           23915           23915    1000257  2018  ...
# 2            24021           24021           24021    1000257  2018  ...
# 3            24112           24112           24112    1000257  2018  ...
# 4            24137           24137           24137    1000257  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 239

# %%
lwk = wk[(wk['LINEID'] == '239')]

# %%
lwk.shape
# Out:
# (33602, 22)

# %%
# Drop Route 239 rows from wk
wk.drop(wk[wk['LINEID'] == '239'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 308   2018-02-26  6291854           14         2965            59040
# 309   2018-02-26  6291854           15         7448            59072
# 310   2018-02-26  6291854           16         2967            59098
# 311   2018-02-26  6291854           17         2968            59119
# 312   2018-02-26  6291854           18         2969            59139
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 308            59040           59040           59040    2868331  2018  ...
# 309            59072           59072           59072    2868331  2018  ...
# 310            59098           59098           59098    2868331  2018  ...
# 311            59119           59119           59119    2868331  2018  ...
# 312            59139           59139           59139    2868331  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1417547, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_239_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 161

# %%
lwk = wk[(wk['LINEID'] == '161')]

# %%
lwk.shape
# Out:
# (3011, 22)

# %%
# Drop Route 161 rows from wk
wk.drop(wk[wk['LINEID'] == '161'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 347   2018-02-26  6291962            1         1828            24600
# 348   2018-02-26  6291962            2         1829            24630
# 349   2018-02-26  6291962            3         1830            24715
# 350   2018-02-26  6291962            4         1831            24753
# 351   2018-02-26  6291962            5         4464            24932
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 347            24600           24600           24600    1000304  2018  ...
# 348            24630           24630           24630    1000304  2018  ...
# 349            24715           24715           24715    1000304  2018  ...
# 350            24753           24753           24753    1000304  2018  ...
# 351            24932           24932           24932    1000304  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1414536, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_161_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 220

# %%
lwk = wk[(wk['LINEID'] == '220')]

# %%
lwk.shape
# Out:
# (63052, 22)

# %%
# Drop Route 220 rows from wk
wk.drop(wk[wk['LINEID'] == '220'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 593   2018-02-26  6292046            4         3735            26483
# 594   2018-02-26  6292046            5         7039            26547
# 595   2018-02-26  6292046            6         7204            26595
# 596   2018-02-26  6292046            7         3736            26647
# 597   2018-02-26  6292046            8         3738            26677
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 593            26483           26483           26483    1001164  2018  ...
# 594            26547           26547           26547    1001164  2018  ...
# 595            26595           26595           26595    1001164  2018  ...
# 596            26647           26647           26647    1001164  2018  ...
# 597            26677           26677           26677    1001164  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1351484, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_220_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 33D

# %%
lwk = wk[(wk['LINEID'] == '33D')]

# %%
lwk.shape
# Out:
# (1434, 22)

# %%
# Drop Route 33D rows from wk
wk.drop(wk[wk['LINEID'] == '33D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 612   2018-02-26  6292238            1         4341            24600
# 613   2018-02-26  6292238            2         4348            24667
# 614   2018-02-26  6292238            3         4646            24735
# 615   2018-02-26  6292238            4         4647            24767
# 616   2018-02-26  6292238            5         2363            24830
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 612            24600           24600           24600    1000896  2018  ...
# 613            24667           24667           24667    1000896  2018  ...
# 614            24735           24735           24735    1000896  2018  ...
# 615            24767           24767           24767    1000896  2018  ...
# 616            24830           24830           24830    1000896  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1350050, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33D_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 76A

# %%
lwk = wk[(wk['LINEID'] == '76A')]

# %%
lwk.shape
# Out:
# (9055, 22)

# %%
# Drop Route 76A rows from wk
wk.drop(wk[wk['LINEID'] == '76A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 770   2018-02-26  6292645            2         3891            28215
# 771   2018-02-26  6292645            3         7187            28300
# 772   2018-02-26  6292645            4         4001            28375
# 773   2018-02-26  6292645            5         3949            28466
# 774   2018-02-26  6292645            6         3950            28500
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 770            28215           28215           28215    2172298  2018  ...
# 771            28300           28300           28300    2172298  2018  ...
# 772            28375           28375           28375    2172298  2018  ...
# 773            28466           28466           28466    2172298  2018  ...
# 774            28500           28500           28500    2172298  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1340995, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76A_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 25X

# %%
lwk = wk[(wk['LINEID'] == '25X')]

# %%
lwk.shape
# Out:
# (7858, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '25X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1171   2018-02-26  6293150            2          396            60259
# 1172   2018-02-26  6293150            3          397            60303
# 1173   2018-02-26  6293150            4          398            60367
# 1174   2018-02-26  6293150            5          399            60419
# 1175   2018-02-26  6293150            6          400            60513
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1171            60259           60259           60259    2534796  2018  ...
# 1172            60303           60303           60303    2534796  2018  ...
# 1173            60367           60367           60367    2534796  2018  ...
# 1174            60419           60419           60419    2534796  2018  ...
# 1175            60513           60513           60513    2534796  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1333137, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25X_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 15D

# %%
lwk = wk[(wk['LINEID'] == '15D')]

# %%
lwk.shape
# Out:
# (4139, 22)

# %%
# Drop Route 15D rows from wk
wk.drop(wk[wk['LINEID'] == '15D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1212   2018-02-26  6293284            1         1730            28200
# 1213   2018-02-26  6293284            2         1731            28243
# 1214   2018-02-26  6293284            3         1732            28279
# 1215   2018-02-26  6293284            4         1733            28324
# 1216   2018-02-26  6293284            5         1650            28379
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1212            28200           28200           28200    2693208  2018  ...
# 1213            28243           28243           28243    2693208  2018  ...
# 1214            28279           28279           28279    2693208  2018  ...
# 1215            28324           28324           28324    2693208  2018  ...
# 1216            28379           28379           28379    2693208  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1328998, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15D_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (43541, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1627   2018-02-26  6293471            3         3352            26204
# 1628   2018-02-26  6293471            4         3335            26249
# 1629   2018-02-26  6293471            5         3336            26287
# 1630   2018-02-26  6293471            6         3337            26316
# 1631   2018-02-26  6293471            7         3338            26393
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1627            26204           26204           26204    1000766  2018  ...
# 1628            26249           26249           26249    1000766  2018  ...
# 1629            26287           26287           26287    1000766  2018  ...
# 1630            26316           26316           26316    1000766  2018  ...
# 1631            26393           26393           26393    1000766  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1285457, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 70D

# %%
lwk = wk[(wk['LINEID'] == '70D')]

# %%
lwk.shape
# Out:
# (2874, 22)

# %%
# Drop Route 70D rows from wk
wk.drop(wk[wk['LINEID'] == '70D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1666   2018-02-26  6293496            1         4564            27000
# 1667   2018-02-26  6293496            2         3444            27080
# 1668   2018-02-26  6293496            3         3447            27182
# 1669   2018-02-26  6293496            4         3454            27416
# 1670   2018-02-26  6293496            5         3455            27485
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1666            27000           27000           27000    2868348  2018  ...
# 1667            27080           27080           27080    2868348  2018  ...
# 1668            27182           27182           27182    2868348  2018  ...
# 1669            27416           27416           27416    2868348  2018  ...
# 1670            27485           27485           27485    2868348  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1282583, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70D_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 69X

# %%
lwk = wk[(wk['LINEID'] == '69X')]

# %%
lwk.shape
# Out:
# (1285, 22)

# %%
# Drop Route 69X rows from wk
wk.drop(wk[wk['LINEID'] == '69X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1681   2018-02-26  6293561            8         1111            24276
# 1682   2018-02-26  6293561            9         2323            24342
# 1683   2018-02-26  6293561           10         2324            24371
# 1684   2018-02-26  6293561           11         2325            24403
# 1685   2018-02-26  6293561           12         2326            24440
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1681            24276           24276           24276    1001152  2018  ...
# 1682            24342           24342           24342    1001152  2018  ...
# 1683            24371           24371           24371    1001152  2018  ...
# 1684            24403           24403           24403    1001152  2018  ...
# 1685            24440           24440           24440    1001152  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1281298, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69X_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 150

# %%
lwk = wk[(wk['LINEID'] == '150')]

# %%
lwk.shape
# Out:
# (171765, 22)

# %%
# Drop Route 150 rows from wk
wk.drop(wk[wk['LINEID'] == '150'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2257   2018-02-26  6293712            2         7097            23476
# 2258   2018-02-26  6293712            3         7098            23517
# 2259   2018-02-26  6293712            4         7099            23553
# 2260   2018-02-26  6293712            5         7100            23607
# 2261   2018-02-26  6293712            6         7101            23664
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2257            23476           23476           23476    3088374  2018  ...
# 2258            23517           23517           23517    3088374  2018  ...
# 2259            23553           23553           23553    3088374  2018  ...
# 2260            23607           23607           23607    3088374  2018  ...
# 2261            23664           23664           23664    3088374  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1109533, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_150_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 40D

# %%
lwk = wk[(wk['LINEID'] == '40D')]

# %%
lwk.shape
# Out:
# (179974, 22)

# %%
# Drop Route 40D rows from wk
wk.drop(wk[wk['LINEID'] == '40D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2781   2018-02-26  6293778            8         2948            25500
# 2782   2018-02-26  6293778            9         2949            25527
# 2783   2018-02-26  6293778           10         2950            25570
# 2784   2018-02-26  6293778           11         2954            25685
# 2785   2018-02-26  6293778           12         7067            25740
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2781            25500           25500           25500    2534805  2018  ...
# 2782            25527           25527           25527    2534805  2018  ...
# 2783            25570           25570           25570    2534805  2018  ...
# 2784            25685           25685           25685    2534805  2018  ...
# 2785            25740           25740           25740    2534805  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (929559, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40D_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 61

# %%
lwk = wk[(wk['LINEID'] == '61')]

# %%
lwk.shape
# Out:
# (85325, 22)

# %%
# Drop Route 61 rows from wk
wk.drop(wk[wk['LINEID'] == '61'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3756   2018-02-26  6294084           12         1558            51468
# 3757   2018-02-26  6294084           13         1549            51577
# 3758   2018-02-26  6294084           14         1523            51628
# 3759   2018-02-26  6294084           15         1524            51687
# 3760   2018-02-26  6294084           16         1525            51717
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3756            51468           51468           51468    1000111  2018  ...
# 3757            51577           51577           51577    1000111  2018  ...
# 3758            51628           51628           51628    1000111  2018  ...
# 3759            51687           51687           51687    1000111  2018  ...
# 3760            51717           51717           51717    1000111  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (844234, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_61_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 40B

# %%
lwk = wk[(wk['LINEID'] == '40B')]

# %%
lwk.shape
# Out:
# (22273, 22)

# %%
# Drop Route 40B rows from wk
wk.drop(wk[wk['LINEID'] == '40B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3785   2018-02-26  6294411            1         3283            28500
# 3786   2018-02-26  6294411            2         3284            28563
# 3787   2018-02-26  6294411            3         3481            28625
# 3788   2018-02-26  6294411            4         3482            28658
# 3789   2018-02-26  6294411            5         3483            28730
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3785            28500           28500           28500    1930281  2018  ...
# 3786            28563           28563           28563    1930281  2018  ...
# 3787            28625           28625           28625    1930281  2018  ...
# 3788            28658           28658           28658    1930281  2018  ...
# 3789            28730           28730           28730    1930281  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (821961, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40B_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 118

# %%
lwk = wk[(wk['LINEID'] == '118')]

# %%
lwk.shape
# Out:
# (1180, 22)

# %%
# Drop Route 118 rows from wk
wk.drop(wk[wk['LINEID'] == '118'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3828   2018-02-26  6294536            1         4745            62160
# 3829   2018-02-26  6294536            2         4989            62178
# 3830   2018-02-26  6294536            3         1845            62729
# 3831   2018-02-26  6294536            4         7166            62769
# 3832   2018-02-26  6294536            5         1847            62828
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3828            62160           62160           62160    1001155  2018  ...
# 3829            62178           62178           62178    1001155  2018  ...
# 3830            62729           62729           62729    1001155  2018  ...
# 3831            62769           62769           62769    1001155  2018  ...
# 3832            62828           62828           62828    1001155  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (820781, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_118_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Route 38D

# %%
lwk = wk[(wk['LINEID'] == '38D')]

# %%
lwk.shape
# Out:
# (1641, 22)

# %%
# Drop Route 38D rows from wk
wk.drop(wk[wk['LINEID'] == '38D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3996   2018-02-26  6294774            1         7433            26700
# 3997   2018-02-26  6294774            2         4677            26776
# 3998   2018-02-26  6294774            3         2136            26802
# 3999   2018-02-26  6294774            4         2137            26820
# 4000   2018-02-26  6294774            5         2138            26871
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3996            26700           26700           26700    1001099  2018  ...
# 3997            26776           26776           26776    1001099  2018  ...
# 3998            26802           26802           26802    1001099  2018  ...
# 3999            26820           26820           26820    1001099  2018  ...
# 4000            26871           26871           26871    1001099  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (819140, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38D_tripLeave2_sp9.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_9a

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_9a.csv', index=False)
