# %%
# Library Imports.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

# Allows plots to appear directly in the notebook.
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score 

import pickle

# %%
# Read tripleave1 route split 2 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_2.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (12947289, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5955784            3         7271            31848
# 1   2018-01-01  5955784            4         5136            31858
# 2   2018-01-01  5955784            5         4262            31905
# 3   2018-01-01  5955784            6         4263            31957
# 4   2018-01-01  5955784            7         4264            31995
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            31848           31848           31848    2534807  2018  ...
# 1            31858           31858           31858    2534807  2018  ...
# 2            31905           31905           31905    2534807  2018  ...
# 3            31957           31957           31957    2534807  2018  ...
# 4            31995           31995           31995    2534807  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 0  20180101595578403  201801015955784      84         126         2
# 1  20180101595578404  201801015955784      84         126         2
# 2  20180101595578405  201801015955784      84         126         2
# 3  20180101595578406  201801015955784      84         126         2
# 4  20180101595578407  201801015955784      84         126         2
#
#    actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 0             4255          0        0         0               9
# 1             4255          0        0         0               9
# 2             4255          0        0         0               9
# 3             4255          0        0         0               9
# 4             4255          0        0         0               9
#
# [5 rows x 22 columns]

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5955784            3         7271            31848
# 1   2018-01-01  5955784            4         5136            31858
# 2   2018-01-01  5955784            5         4262            31905
# 3   2018-01-01  5955784            6         4263            31957
# 4   2018-01-01  5955784            7         4264            31995
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            31848           31848           31848    2534807  2018  ...
# 1            31858           31858           31858    2534807  2018  ...
# 2            31905           31905           31905    2534807  2018  ...
# 3            31957           31957           31957    2534807  2018  ...
# 4            31995           31995           31995    2534807  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 0  20180101595578403  201801015955784      84         126         2
# 1  20180101595578404  201801015955784      84         126         2
# 2  20180101595578405  201801015955784      84         126         2
# 3  20180101595578406  201801015955784      84         126         2
# 4  20180101595578407  201801015955784      84         126         2
#
#    actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 0             4255          0        0         0               9
# 1             4255          0        0         0               9
# 2             4255          0        0         0               9
# 3             4255          0        0         0               9
# 4             4255          0        0         0               9
#
# [5 rows x 22 columns]

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 84

# %%
lwk = wk[(wk['LINEID'] == '84')]

# %%
lwk.shape
# Out:
# (153825, 22)

# %%
# Drop Route 84 rows from wk
wk.drop(wk[wk['LINEID'] == '84'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1026   2018-01-01  5955815            1         6004            36000
# 1027   2018-01-01  5955815            2            3            36073
# 1028   2018-01-01  5955815            3          192            36251
# 1029   2018-01-01  5955815            4          795            36278
# 1030   2018-01-01  5955815            5          796            36305
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1026            36000           36000           36000    1001212  2018  ...
# 1027            36073           36073           36073    1001212  2018  ...
# 1028            36251           36251           36251    1001212  2018  ...
# 1029            36278           36278           36278    1001212  2018  ...
# 1030            36305           36305           36305    1001212  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1026  20180101595581501  201801015955815     120           8         1
# 1027  20180101595581502  201801015955815     120           8         1
# 1028  20180101595581503  201801015955815     120           8         1
# 1029  20180101595581504  201801015955815     120           8         1
# 1030  20180101595581505  201801015955815     120           8         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1026             1016          0        0         0              10
# 1027             1016          0        0         0              10
# 1028             1016          0        0         0              10
# 1029             1016          0        0         0              10
# 1030             1016          0        0         0              10
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12793464, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (136499, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1223   2018-01-01  5955843            1          449            39000
# 1224   2018-01-01  5955843            2          450            39033
# 1225   2018-01-01  5955843            3         3181            39100
# 1226   2018-01-01  5955843            4          451            39131
# 1227   2018-01-01  5955843            5          447            39178
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1223            39000           39000           39000    2534811  2018  ...
# 1224            39033           39033           39033    2534811  2018  ...
# 1225            39100           39100           39100    2534811  2018  ...
# 1226            39131           39131           39131    2534811  2018  ...
# 1227            39178           39178           39178    2534811  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1223  20180101595584301  201801015955843      11           3         2
# 1224  20180101595584302  201801015955843      11           3         2
# 1225  20180101595584303  201801015955843      11           3         2
# 1226  20180101595584304  201801015955843      11           3         2
# 1227  20180101595584305  201801015955843      11           3         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1223             2884          0        0         0              11
# 1224             2884          0        0         0              11
# 1225             2884          0        0         0              11
# 1226             2884          0        0         0              11
# 1227             2884          0        0         0              11
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12656965, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 11

# %%
lwk = wk[(wk['LINEID'] == '11')]

# %%
lwk.shape
# Out:
# (258160, 22)

# %%
# Drop Route 11 rows from wk
wk.drop(wk[wk['LINEID'] == '11'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1475   2018-01-01  5955967            1          395            35100
# 1476   2018-01-01  5955967            2          396            35155
# 1477   2018-01-01  5955967            3          397            35185
# 1478   2018-01-01  5955967            4          398            35214
# 1479   2018-01-01  5955967            5          399            35238
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1475            35100           35100           35100    1932330  2018  ...
# 1476            35155           35155           35155    1932330  2018  ...
# 1477            35185           35185           35185    1932330  2018  ...
# 1478            35214           35214           35214    1932330  2018  ...
# 1479            35238           35238           35238    1932330  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 1475  20180101595596701  201801015955967     56A          94         1
# 1476  20180101595596702  201801015955967     56A          94         1
# 1477  20180101595596703  201801015955967     56A          94         1
# 1478  20180101595596704  201801015955967     56A          94         1
# 1479  20180101595596705  201801015955967     56A          94         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 1475             1935          0        0         0              10
# 1476             1935          0        0         0              10
# 1477             1935          0        0         0              10
# 1478             1935          0        0         0              10
# 1479             1935          0        0         0              10
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12398805, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_11_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (86426, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2014   2018-01-01  5956060            3         2807            46625
# 2015   2018-01-01  5956060            4         2808            46675
# 2016   2018-01-01  5956060            5          486            46810
# 2017   2018-01-01  5956060            6          487            46883
# 2018   2018-01-01  5956060            7         2798            46917
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2014            46625           46625           46625    1000156  2018  ...
# 2015            46675           46675           46675    1000156  2018  ...
# 2016            46810           46810           46810    1000156  2018  ...
# 2017            46883           46883           46883    1000156  2018  ...
# 2018            46917           46917           46917    1000156  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 2014  20180101595606003  201801015956060      18          30         2
# 2015  20180101595606004  201801015956060      18          30         2
# 2016  20180101595606005  201801015956060      18          30         2
# 2017  20180101595606006  201801015956060      18          30         2
# 2018  20180101595606007  201801015956060      18          30         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 2014             3274          0        0         0              13
# 2015             3274          0        0         0              13
# 2016             3274          0        0         0              13
# 2017             3274          0        0         0              13
# 2018             3274          0        0         0              13
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12312379, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 18

# %%
lwk = wk[(wk['LINEID'] == '18')]

# %%
lwk.shape
# Out:
# (211465, 22)

# %%
# Drop Route 41C rows from wk
wk.drop(wk[wk['LINEID'] == '18'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2319   2018-01-01  5956222            4          962            28920
# 2320   2018-01-01  5956222            5          635            28956
# 2321   2018-01-01  5956222            6          636            28979
# 2322   2018-01-01  5956222            7          637            29017
# 2323   2018-01-01  5956222            8          638            29036
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2319            28920           28920           28920    2406900  2018  ...
# 2320            28956           28956           28956    2406900  2018  ...
# 2321            28979           28979           28979    2406900  2018  ...
# 2322            29017           29017           29017    2406900  2018  ...
# 2323            29036           29036           29036    2406900  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 2319  20180101595622204  201801015956222     27A          45         2
# 2320  20180101595622205  201801015956222     27A          45         2
# 2321  20180101595622206  201801015956222     27A          45         2
# 2322  20180101595622207  201801015956222     27A          45         2
# 2323  20180101595622208  201801015956222     27A          45         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 2319             1557          0        0         1               8
# 2320             1557          0        0         1               8
# 2321             1557          0        0         1               8
# 2322             1557          0        0         1               8
# 2323             1557          0        0         1               8
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (12100914, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_18_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 27A

# %%
lwk = wk[(wk['LINEID'] == '27A')]

# %%
lwk.shape
# Out:
# (124391, 22)

# %%
# Drop Route 27A rows from wk
wk.drop(wk[wk['LINEID'] == '27A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2592   2018-01-01  5956256            1         4747            48600
# 2593   2018-01-01  5956256            2         7298            48890
# 2594   2018-01-01  5956256            3         2294            48960
# 2595   2018-01-01  5956256            4         6039            49046
# 2596   2018-01-01  5956256            6         6171            49144
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2592            48600           48600           48600    1000186  2018  ...
# 2593            48890           48890           48890    1000186  2018  ...
# 2594            48960           48960           48960    1000186  2018  ...
# 2595            49046           49046           49046    1000186  2018  ...
# 2596            49144           49144           49144    1000186  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 2592  20180101595625601  201801015956256     17A          29         1
# 2593  20180101595625602  201801015956256     17A          29         1
# 2594  20180101595625603  201801015956256     17A          29         1
# 2595  20180101595625604  201801015956256     17A          29         1
# 2596  20180101595625606  201801015956256     17A          29         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 2592             3166          0        0         0              14
# 2593             3166          0        0         0              14
# 2594             3166          0        0         0              14
# 2595             3166          0        0         0              14
# 2596             3166          0        0         0              14
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (11976523, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27A_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 17A

# %%
lwk = wk[(wk['LINEID'] == '17A')]

# %%
lwk.shape
# Out:
# (304922, 22)

# %%
# Drop Route 17A rows from wk
wk.drop(wk[wk['LINEID'] == '17A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2887   2018-01-01  5956265            1          226            36000
# 2888   2018-01-01  5956265            2          228            36052
# 2889   2018-01-01  5956265            3          229            36095
# 2890   2018-01-01  5956265            4          227            36166
# 2891   2018-01-01  5956265            5          230            36209
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2887            36000           36000           36000    2693264  2018  ...
# 2888            36052           36052           36052    2693264  2018  ...
# 2889            36095           36095           36095    2693264  2018  ...
# 2890            36166           36166           36166    2693264  2018  ...
# 2891            36209           36209           36209    2693264  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 2887  20180101595626501  201801015956265       1           0         1
# 2888  20180101595626502  201801015956265       1           0         1
# 2889  20180101595626503  201801015956265       1           0         1
# 2890  20180101595626504  201801015956265       1           0         1
# 2891  20180101595626505  201801015956265       1           0         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 2887             1876          0        0         0              10
# 2888             1876          0        0         0              10
# 2889             1876          0        0         0              10
# 2890             1876          0        0         0              10
# 2891             1876          0        0         0              10
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (11671601, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17A_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 1

# %%
lwk = wk[(wk['LINEID'] == '1')]

# %%
lwk.shape
# Out:
# (202277, 22)

# %%
# Drop Route 1 rows from wk
wk.drop(wk[wk['LINEID'] == '1'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3094   2018-01-01  5956287            1         7564            34200
# 3095   2018-01-01  5956287            2         4521            34346
# 3096   2018-01-01  5956287            3         1283            34449
# 3097   2018-01-01  5956287            4         4456            34486
# 3098   2018-01-01  5956287            5         1284            34520
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3094            34200           34200           34200    2534840  2018  ...
# 3095            34346           34346           34346    2534840  2018  ...
# 3096            34449           34449           34449    2534840  2018  ...
# 3097            34486           34486           34486    2534840  2018  ...
# 3098            34520           34520           34520    2534840  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 3094  20180101595628701  201801015956287      65          98         1
# 3095  20180101595628702  201801015956287      65          98         1
# 3096  20180101595628703  201801015956287      65          98         1
# 3097  20180101595628704  201801015956287      65          98         1
# 3098  20180101595628705  201801015956287      65          98         1
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 3094             3682          0        0         0              10
# 3095             3682          0        0         0              10
# 3096             3682          0        0         0              10
# 3097             3682          0        0         0              10
# 3098             3682          0        0         0              10
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (11469324, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_1_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Route 65

# %%
lwk = wk[(wk['LINEID'] == '65')]

# %%
lwk.shape
# Out:
# (112289, 22)

# %%
# Drop Route 65 rows from wk
wk.drop(wk[wk['LINEID'] == '65'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3749   2018-01-01  5956325            3         3926            40597
# 3750   2018-01-01  5956325            4         7074            40649
# 3751   2018-01-01  5956325            5         3919            40728
# 3752   2018-01-01  5956325            6         3920            40802
# 3753   2018-01-01  5956325            7         3921            40840
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3749            40597           40597           40597    2534817  2018  ...
# 3750            40649           40649           40649    2534817  2018  ...
# 3751            40728           40728           40728    2534817  2018  ...
# 3752            40802           40802           40802    2534817  2018  ...
# 3753            40840           40840           40840    2534817  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# 3749  20180101595632503  201801015956325      67         104         2
# 3750  20180101595632504  201801015956325      67         104         2
# 3751  20180101595632505  201801015956325      67         104         2
# 3752  20180101595632506  201801015956325      67         104         2
# 3753  20180101595632507  201801015956325      67         104         2
#
#       actual_duration  dayOfWeek  weekend  rushHour  actualARR_hour
# 3749             3352          0        0         0              11
# 3750             3352          0        0         0              11
# 3751             3352          0        0         0              11
# 3752             3352          0        0         0              11
# 3753             3352          0        0         0              11
#
# [5 rows x 22 columns]

# %%
wk.shape
# Out:
# (11357035, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65_tripLeave1_sp2.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave1_route_split_3

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave1_route_split_3.csv', index=False)
