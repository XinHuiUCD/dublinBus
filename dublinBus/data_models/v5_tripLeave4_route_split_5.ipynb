# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 5 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (5227795, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-24  7113092            4         3997            48523
# 1   2018-06-24  7113092            5         3998            48600
# 2   2018-06-24  7113092            6         3999            48660
# 3   2018-06-24  7113092            7         4000            48690
# 4   2018-06-24  7113092            8         4001            48720
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            48523           48523           48523    1001139  2018  ...
# 1            48600           48600           48600    1001139  2018  ...
# 2            48660           48660           48660    1001139  2018  ...
# 3            48690           48690           48690    1001139  2018  ...
# 4            48720           48720           48720    1001139  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 66A

# %%
lwk = wk[(wk['LINEID'] == '66A')]

# %%
lwk.shape
# Out:
# (72129, 22)

# %%
# Drop Route 66A rows from wk
wk.drop(wk[wk['LINEID'] == '66A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 267   2018-06-24  7113118            1         4342            32400
# 268   2018-06-24  7113118            2         4348            32475
# 269   2018-06-24  7113118            3         4646            32540
# 270   2018-06-24  7113118            4         4647            32571
# 271   2018-06-24  7113118            5         4435            32685
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 267            32400           32400           32400    1000233  2018  ...
# 268            32475           32475           32475    1000233  2018  ...
# 269            32540           32540           32540    1000233  2018  ...
# 270            32571           32571           32571    1000233  2018  ...
# 271            32685           32685           32685    1000233  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5155666, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66A_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 75

# %%
lwk = wk[(wk['LINEID'] == '75')]

# %%
lwk.shape
# Out:
# (318103, 22)

# %%
# Drop Route 75 rows from wk
wk.drop(wk[wk['LINEID'] == '75'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 510   2018-06-24  7113165            1         4713            30600
# 511   2018-06-24  7113165            2         4714            30639
# 512   2018-06-24  7113165            3         4960            30684
# 513   2018-06-24  7113165            4         4932            30754
# 514   2018-06-24  7113165            5         4933            30770
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 510            30600           30600           30600    2868403  2018  ...
# 511            30639           30639           30639    2868403  2018  ...
# 512            30684           30684           30684    2868403  2018  ...
# 513            30754           30754           30754    2868403  2018  ...
# 514            30770           30770           30770    2868403  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4837563, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_75_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (108412, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1034   2018-06-24  7113204            1         1184            33000
# 1035   2018-06-24  7113204            2         7490            33137
# 1036   2018-06-24  7113204            3          497            33160
# 1037   2018-06-24  7113204            4          515            33237
# 1038   2018-06-24  7113204            5          516            33296
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1034            33000           33000           33000    2406919  2018  ...
# 1035            33137           33137           33137    2406919  2018  ...
# 1036            33160           33160           33160    2406919  2018  ...
# 1037            33237           33237           33237    2406919  2018  ...
# 1038            33296           33296           33296    2406919  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4729151, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 42

# %%
lwk = wk[(wk['LINEID'] == '42')]

# %%
lwk.shape
# Out:
# (217413, 22)

# %%
# Drop Route 42 rows from wk
wk.drop(wk[wk['LINEID'] == '42'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1264   2018-06-24  7113498            3         3926            40604
# 1265   2018-06-24  7113498            4         7074            40656
# 1266   2018-06-24  7113498            5         3919            40734
# 1267   2018-06-24  7113498            6         3920            40807
# 1268   2018-06-24  7113498            7         3921            40845
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1264            40604           40604           40604    2868318  2018  ...
# 1265            40656           40656           40656    2868318  2018  ...
# 1266            40734           40734           40734    2868318  2018  ...
# 1267            40807           40807           40807    2868318  2018  ...
# 1268            40845           40845           40845    2868318  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4511738, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 67

# %%
lwk = wk[(wk['LINEID'] == '67')]

# %%
lwk.shape
# Out:
# (233636, 22)

# %%
# Drop Route 67 rows from wk
wk.drop(wk[wk['LINEID'] == '67'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1922   2018-06-24  7113662            1          395            39600
# 1923   2018-06-24  7113662            2          396            39679
# 1924   2018-06-24  7113662            3          397            39723
# 1925   2018-06-24  7113662            4          398            39759
# 1926   2018-06-24  7113662            5          399            39788
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1922            39600           39600           39600    1932330  2018  ...
# 1923            39679           39679           39679    1932330  2018  ...
# 1924            39723           39723           39723    1932330  2018  ...
# 1925            39759           39759           39759    1932330  2018  ...
# 1926            39788           39788           39788    1932330  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4278102, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (90408, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2798   2018-06-24  7114460            2         5162            32460
# 2799   2018-06-24  7114460            3         2571            32559
# 2800   2018-06-24  7114460            4         2359            32610
# 2801   2018-06-24  7114460            5         2360            32663
# 2802   2018-06-24  7114460            6         4348            32724
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2798            32460           32460           32460    1932336  2018  ...
# 2799            32559           32559           32559    1932336  2018  ...
# 2800            32610           32610           32610    1932336  2018  ...
# 2801            32663           32663           32663    1932336  2018  ...
# 2802            32724           32724           32724    1932336  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4187694, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 54A

# %%
lwk = wk[(wk['LINEID'] == '54A')]

# %%
lwk.shape
# Out:
# (130087, 22)

# %%
# Drop Route 54A rows from wk
wk.drop(wk[wk['LINEID'] == '54A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3420   2018-06-24  7114884            1         2670            43740
# 3421   2018-06-24  7114884            2         2910            43779
# 3422   2018-06-24  7114884            3         2911            43823
# 3423   2018-06-24  7114884            4         7507            43854
# 3424   2018-06-24  7114884            5         2663            43884
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3420            43740           43740           43740    1000927  2018  ...
# 3421            43779           43779           43779    1000927  2018  ...
# 3422            43823           43823           43823    1000927  2018  ...
# 3423            43854           43854           43854    1000927  2018  ...
# 3424            43884           43884           43884    1000927  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4057607, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_54A_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 79

# %%
lwk = wk[(wk['LINEID'] == '79')]

# %%
lwk.shape
# Out:
# (112550, 22)

# %%
# Drop Route 79 rows from wk
wk.drop(wk[wk['LINEID'] == '79'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4070   2018-06-24  7114972            1         1828            39600
# 4071   2018-06-24  7114972            2         1829            39647
# 4072   2018-06-24  7114972            3         1830            39781
# 4073   2018-06-24  7114972            4         1831            39840
# 4074   2018-06-24  7114972            5         4464            39888
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4070            39600           39600           39600    1000915  2018  ...
# 4071            39647           39647           39647    1000915  2018  ...
# 4072            39781           39781           39781    1000915  2018  ...
# 4073            39840           39840           39840    1000915  2018  ...
# 4074            39888           39888           39888    1000915  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3945057, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 220

# %%
lwk = wk[(wk['LINEID'] == '220')]

# %%
lwk.shape
# Out:
# (69831, 22)

# %%
# Drop Route 220 rows from wk
wk.drop(wk[wk['LINEID'] == '220'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4556   2018-06-24  7115013            3         6287            35178
# 4557   2018-06-24  7115013            4         6288            35209
# 4558   2018-06-24  7115013            5         6342            35244
# 4559   2018-06-24  7115013            6         6298            35273
# 4560   2018-06-24  7115013            7         6336            35307
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4556            35178           35178           35178    2868349  2018  ...
# 4557            35209           35209           35209    2868349  2018  ...
# 4558            35244           35244           35244    2868349  2018  ...
# 4559            35273           35273           35273    2868349  2018  ...
# 4560            35307           35307           35307    2868349  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3875226, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_220_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 15B

# %%
lwk = wk[(wk['LINEID'] == '15B')]

# %%
lwk.shape
# Out:
# (262761, 22)

# %%
# Drop Route 15B rows from wk
wk.drop(wk[wk['LINEID'] == '15B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5186   2018-06-24  7115170            1         4747            48600
# 5187   2018-06-24  7115170            2         7298            48868
# 5188   2018-06-24  7115170            3         2294            48932
# 5189   2018-06-24  7115170            4         6039            49017
# 5190   2018-06-24  7115170            6         6171            49116
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5186            48600           48600           48600    1001232  2018  ...
# 5187            48868           48868           48868    1001232  2018  ...
# 5188            48932           48932           48932    1001232  2018  ...
# 5189            49017           49017           49017    1001232  2018  ...
# 5190            49116           49116           49116    1001232  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3612465, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15B_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 17A

# %%
lwk = wk[(wk['LINEID'] == '17A')]

# %%
lwk.shape
# Out:
# (308478, 22)

# %%
# Drop Route 17A rows from wk
wk.drop(wk[wk['LINEID'] == '17A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5422   2018-06-24  7115202            1         5044            34800
# 5423   2018-06-24  7115202            2         4433            34874
# 5424   2018-06-24  7115202            3         3752            35034
# 5425   2018-06-24  7115202            4         3751            35066
# 5426   2018-06-24  7115202            5         3689            35134
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5422            34800           34800           34800    1932328  2018  ...
# 5423            34874           34874           34874    1932328  2018  ...
# 5424            35034           35034           35034    1932328  2018  ...
# 5425            35066           35066           35066    1932328  2018  ...
# 5426            35134           35134           35134    1932328  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3303987, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17A_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (141671, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6082   2018-06-24  7115235            1         7347            84600
# 6083   2018-06-24  7115235            2         3669            84677
# 6084   2018-06-24  7115235            3         7349            84733
# 6085   2018-06-24  7115235            4         1631            84799
# 6086   2018-06-24  7115235            5         1632            84814
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6082            84600           84600           84600    1000307  2018  ...
# 6083            84677           84677           84677    1000307  2018  ...
# 6084            84733           84733           84733    1000307  2018  ...
# 6085            84799           84799           84799    1000307  2018  ...
# 6086            84814           84814           84814    1000307  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3162316, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 16C

# %%
lwk = wk[(wk['LINEID'] == '16C')]

# %%
lwk.shape
# Out:
# (8443, 22)

# %%
# Drop Route 16C rows from wk
wk.drop(wk[wk['LINEID'] == '16C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6118   2018-06-24  7115577            1         6041            84600
# 6119   2018-06-24  7115577            6         2845            84807
# 6120   2018-06-24  7115577            7         2846            84838
# 6121   2018-06-24  7115577            8         2847            84857
# 6122   2018-06-24  7115577            9         4397            84872
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6118            84600           84600           84600    2406888  2018  ...
# 6119            84807           84807           84807    2406888  2018  ...
# 6120            84838           84838           84838    2406888  2018  ...
# 6121            84857           84857           84857    2406888  2018  ...
# 6122            84872           84872           84872    2406888  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3153873, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_16C_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Route 14C

# %%
lwk = wk[(wk['LINEID'] == '14C')]

# %%
lwk.shape
# Out:
# (4312, 22)

# %%
# Drop Route 14C rows from wk
wk.drop(wk[wk['LINEID'] == '14C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6161   2018-06-24  7115697            1         2037            36000
# 6162   2018-06-24  7115697            2         3046            36056
# 6163   2018-06-24  7115697            3         3047            36130
# 6164   2018-06-24  7115697            4         3048            36202
# 6165   2018-06-24  7115697            5         3049            36242
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6161            36000           36000           36000    2172282  2018  ...
# 6162            36056           36056           36056    2172282  2018  ...
# 6163            36130           36130           36130    2172282  2018  ...
# 6164            36202           36202           36202    2172282  2018  ...
# 6165            36242           36242           36242    2172282  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3149561, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_14C_tripLeave4_sp5.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_6

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_6.csv', index=False)
