# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 route split 5 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave6_route_split_5.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (2883004, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-09  8094791            1         4713            30600
# 1   2018-09-09  8094791            2         4714            30633
# 2   2018-09-09  8094791            3         4960            30672
# 3   2018-09-09  8094791            4         4932            30733
# 4   2018-09-09  8094791            5         4933            30747
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            30600           30600           30600    2534796  2018  ...
# 1            30633           30633           30633    2534796  2018  ...
# 2            30672           30672           30672    2534796  2018  ...
# 3            30733           30733           30733    2534796  2018  ...
# 4            30747           30747           30747    2534796  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (121450, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 526   2018-09-09  8094891            1          284            53100
# 527   2018-09-09  8094891            2         4504            53233
# 528   2018-09-09  8094891            3         7028            53328
# 529   2018-09-09  8094891            4         5147            53422
# 530   2018-09-09  8094891            5           68            53499
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 526            53100           53100           53100    2868374  2018  ...
# 527            53233           53233           53233    2868374  2018  ...
# 528            53328           53328           53328    2868374  2018  ...
# 529            53422           53422           53422    2868374  2018  ...
# 530            53499           53499           53499    2868374  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2761554, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (117425, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 750   2018-09-09  8095042            2          915            45936
# 751   2018-09-09  8095042            3          916            45962
# 752   2018-09-09  8095042            4          917            45992
# 753   2018-09-09  8095042            5          918            46034
# 754   2018-09-09  8095042            6          919            46077
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 750            45936           45936           45936    1932328  2018  ...
# 751            45962           45962           45962    1932328  2018  ...
# 752            45992           45992           45992    1932328  2018  ...
# 753            46034           46034           46034    1932328  2018  ...
# 754            46077           46077           46077    1932328  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2644129, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 29A

# %%
lwk = wk[(wk['LINEID'] == '29A')]

# %%
lwk.shape
# Out:
# (213241, 22)

# %%
# Drop Route 29A rows from wk
wk.drop(wk[wk['LINEID'] == '29A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1065   2018-09-09  8095050            3         3996            34002
# 1066   2018-09-09  8095050            4         3997            34064
# 1067   2018-09-09  8095050            5         3998            34110
# 1068   2018-09-09  8095050            6         3999            34162
# 1069   2018-09-09  8095050            7         4000            34189
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1065            34002           34002           34002    2534863  2018  ...
# 1066            34064           34064           34064    2534863  2018  ...
# 1067            34110           34110           34110    2534863  2018  ...
# 1068            34162           34162           34162    2534863  2018  ...
# 1069            34189           34189           34189    2534863  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2430888, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_29A_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 66A

# %%
lwk = wk[(wk['LINEID'] == '66A')]

# %%
lwk.shape
# Out:
# (74275, 22)

# %%
# Drop Route 66A rows from wk
wk.drop(wk[wk['LINEID'] == '66A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1221   2018-09-09  8095111            1         2243            36000
# 1222   2018-09-09  8095111            2         2200            36043
# 1223   2018-09-09  8095111            3         5006            36110
# 1224   2018-09-09  8095111            4         5007            36147
# 1225   2018-09-09  8095111            5         2655            36224
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1221            36000           36000           36000    1001223  2018  ...
# 1222            36043           36043           36043    1001223  2018  ...
# 1223            36110           36110           36110    1001223  2018  ...
# 1224            36147           36147           36147    1001223  2018  ...
# 1225            36224           36224           36224    1001223  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2356613, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66A_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 76

# %%
lwk = wk[(wk['LINEID'] == '76')]

# %%
lwk.shape
# Out:
# (120451, 22)

# %%
# Drop Route 76 rows from wk
wk.drop(wk[wk['LINEID'] == '76'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1634   2018-09-09  8095159            1          686            31500
# 1635   2018-09-09  8095159            2          688            31534
# 1636   2018-09-09  8095159            3          689            31561
# 1637   2018-09-09  8095159            4          690            31588
# 1638   2018-09-09  8095159            5         5062            31618
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1634            31500           31500           31500    3265691  2018  ...
# 1635            31534           31534           31534    3265691  2018  ...
# 1636            31561           31561           31561    3265691  2018  ...
# 1637            31588           31588           31588    3265691  2018  ...
# 1638            31618           31618           31618    3265691  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2236162, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 31A

# %%
lwk = wk[(wk['LINEID'] == '31A')]

# %%
lwk.shape
# Out:
# (74496, 22)

# %%
# Drop Route 31A rows from wk
wk.drop(wk[wk['LINEID'] == '31A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1883   2018-09-09  8095164            1          621            50400
# 1884   2018-09-09  8095164            2          289            50578
# 1885   2018-09-09  8095164            3          496            50710
# 1886   2018-09-09  8095164            4         7490            50737
# 1887   2018-09-09  8095164            5          515            50821
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1883            50400           50400           50400    3265691  2018  ...
# 1884            50578           50578           50578    3265691  2018  ...
# 1885            50710           50710           50710    3265691  2018  ...
# 1886            50737           50737           50737    3265691  2018  ...
# 1887            50821           50821           50821    3265691  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2161666, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31A_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 31

# %%
lwk = wk[(wk['LINEID'] == '31')]

# %%
lwk.shape
# Out:
# (212465, 22)

# %%
# Drop Route 31 rows from wk
wk.drop(wk[wk['LINEID'] == '31'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2497   2018-09-09  8095186            1         1730            33000
# 2498   2018-09-09  8095186            2         1731            33027
# 2499   2018-09-09  8095186            3         1732            33061
# 2500   2018-09-09  8095186            4         1733            33091
# 2501   2018-09-09  8095186            5         1650            33128
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2497            33000           33000           33000    2868406  2018  ...
# 2498            33027           33027           33027    2868406  2018  ...
# 2499            33061           33061           33061    2868406  2018  ...
# 2500            33091           33091           33091    2868406  2018  ...
# 2501            33128           33128           33128    2868406  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1949201, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (37293, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2638   2018-09-09  8095639            1         4863            45900
# 2639   2018-09-09  8095639            2         4864            45935
# 2640   2018-09-09  8095639            3         4865            45960
# 2641   2018-09-09  8095639            4         4577            45986
# 2642   2018-09-09  8095639            5         4578            46031
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2638            45900           45900           45900    2693284  2018  ...
# 2639            45935           45935           45935    2693284  2018  ...
# 2640            45960           45960           45960    2693284  2018  ...
# 2641            45986           45986           45986    2693284  2018  ...
# 2642            46031           46031           46031    2693284  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1911908, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 150

# %%
lwk = wk[(wk['LINEID'] == '150')]

# %%
lwk.shape
# Out:
# (170116, 22)

# %%
# Drop Route 150 rows from wk
wk.drop(wk[wk['LINEID'] == '150'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3950   2018-09-09  8095894            1         4495            39000
# 3951   2018-09-09  8095894            2         4720            39130
# 3952   2018-09-09  8095894            3         1443            39305
# 3953   2018-09-09  8095894            4         1444            39346
# 3954   2018-09-09  8095894            5         1445            39391
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3950            39000           39000           39000    2693238  2018  ...
# 3951            39130           39130           39130    2693238  2018  ...
# 3952            39305           39305           39305    2693238  2018  ...
# 3953            39346           39346           39346    2693238  2018  ...
# 3954            39391           39391           39391    2693238  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1741792, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_150_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 69

# %%
lwk = wk[(wk['LINEID'] == '69')]

# %%
lwk.shape
# Out:
# (115563, 22)

# %%
# Drop Route 69 rows from wk
wk.drop(wk[wk['LINEID'] == '69'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4069   2018-09-09  8095896            1         4495            46200
# 4070   2018-09-09  8095896            4         1278            46325
# 4071   2018-09-09  8095896            5         1282            46452
# 4072   2018-09-09  8095896            6         4456            46524
# 4073   2018-09-09  8095896            7         1284            46565
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4069            46200           46200           46200    2693238  2018  ...
# 4070            46325           46325           46325    2693238  2018  ...
# 4071            46452           46452           46452    2693238  2018  ...
# 4072            46524           46524           46524    2693238  2018  ...
# 4073            46565           46565           46565    2693238  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1626229, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 68

# %%
lwk = wk[(wk['LINEID'] == '68')]

# %%
lwk.shape
# Out:
# (119725, 22)

# %%
# Drop Route 68 rows from wk
wk.drop(wk[wk['LINEID'] == '68'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4787   2018-09-09  8096291            1         2037            36000
# 4788   2018-09-09  8096291            2         3046            36053
# 4789   2018-09-09  8096291            3         3047            36122
# 4790   2018-09-09  8096291            4         3048            36190
# 4791   2018-09-09  8096291            5         3049            36226
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4787            36000           36000           36000    1000379  2018  ...
# 4788            36053           36053           36053    1000379  2018  ...
# 4789            36122           36122           36122    1000379  2018  ...
# 4790            36190           36190           36190    1000379  2018  ...
# 4791            36226           36226           36226    1000379  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1506504, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 59

# %%
lwk = wk[(wk['LINEID'] == '59')]

# %%
lwk.shape
# Out:
# (10263, 22)

# %%
# Drop Route 59 rows from wk
wk.drop(wk[wk['LINEID'] == '59'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5418   2018-09-09  8096337            6         7204            31963
# 5419   2018-09-09  8096337            7         3739            32103
# 5420   2018-09-09  8096337            8         3738            32184
# 5421   2018-09-09  8096337            9         7170            32225
# 5422   2018-09-09  8096337           10         3740            32256
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5418            31963           31963           31963    1001159  2018  ...
# 5419            32103           32103           32103    1001159  2018  ...
# 5420            32184           32184           32184    1001159  2018  ...
# 5421            32225           32225           32225    1001159  2018  ...
# 5422            32256           32256           32256    1001159  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1496241, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_59_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 33B

# %%
lwk = wk[(wk['LINEID'] == '33B')]

# %%
lwk.shape
# Out:
# (24499, 22)

# %%
# Drop Route 33B rows from wk
wk.drop(wk[wk['LINEID'] == '33B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5807   2018-09-09  8096489            1         7073            39300
# 5808   2018-09-09  8096489            2         7097            39367
# 5809   2018-09-09  8096489            3         7098            39403
# 5810   2018-09-09  8096489            4         7099            39436
# 5811   2018-09-09  8096489            5         7100            39484
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5807            39300           39300           39300    1000208  2018  ...
# 5808            39367           39367           39367    1000208  2018  ...
# 5809            39403           39403           39403    1000208  2018  ...
# 5810            39436           39436           39436    1000208  2018  ...
# 5811            39484           39484           39484    1000208  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1471742, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33B_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 238

# %%
lwk = wk[(wk['LINEID'] == '238')]

# %%
lwk.shape
# Out:
# (37865, 22)

# %%
# Drop Route 238 rows from wk
wk.drop(wk[wk['LINEID'] == '238'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6498   2018-09-09  8097169            1         7348            34500
# 6499   2018-09-09  8097169            2         3669            34582
# 6500   2018-09-09  8097169            3         3671            34629
# 6501   2018-09-09  8097169            4         3672            34647
# 6502   2018-09-09  8097169            5         3078            34790
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6498            34500           34500           34500    1000204  2018  ...
# 6499            34582           34582           34582    1000204  2018  ...
# 6500            34629           34629           34629    1000204  2018  ...
# 6501            34647           34647           34647    1000204  2018  ...
# 6502            34790           34790           34790    1000204  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1433877, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_238_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 102

# %%
lwk = wk[(wk['LINEID'] == '102')]

# %%
lwk.shape
# Out:
# (101804, 22)

# %%
# Drop Route 102 rows from wk
wk.drop(wk[wk['LINEID'] == '102'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7085   2018-09-09  8097276            1         6030            39000
# 7086   2018-09-09  8097276            2         6028            39048
# 7087   2018-09-09  8097276            3         6025            39078
# 7088   2018-09-09  8097276            4         6024            39105
# 7089   2018-09-09  8097276            5         6021            39139
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7085            39000           39000           39000    1001224  2018  ...
# 7086            39048           39048           39048    1001224  2018  ...
# 7087            39078           39078           39078    1001224  2018  ...
# 7088            39105           39105           39105    1001224  2018  ...
# 7089            39139           39139           39139    1001224  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1332073, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_102_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 79A

# %%
lwk = wk[(wk['LINEID'] == '79A')]

# %%
lwk.shape
# Out:
# (92157, 22)

# %%
# Drop Route 79A rows from wk
wk.drop(wk[wk['LINEID'] == '79A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7415   2018-09-09  8097730            2         2956            34237
# 7416   2018-09-09  8097730            3         2965            34283
# 7417   2018-09-09  8097730            4         2983            34336
# 7418   2018-09-09  8097730            5         2984            34397
# 7419   2018-09-09  8097730            6         7449            34424
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 7415            34237           34237           34237    2868379  2018  ...
# 7416            34283           34283           34283    2868379  2018  ...
# 7417            34336           34336           34336    2868379  2018  ...
# 7418            34397           34397           34397    2868379  2018  ...
# 7419            34424           34424           34424    2868379  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1239916, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79A_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 61

# %%
lwk = wk[(wk['LINEID'] == '61')]

# %%
lwk.shape
# Out:
# (88448, 22)

# %%
# Drop Route 61 rows from wk
wk.drop(wk[wk['LINEID'] == '61'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9210   2018-09-09  8098515            1         2210            61800
# 9211   2018-09-09  8098515            2         2211            61884
# 9212   2018-09-09  8098515            3         2241            61961
# 9213   2018-09-09  8098515            4         2242            61992
# 9214   2018-09-09  8098515            5         2243            62070
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9210            61800           61800           61800    2693269  2018  ...
# 9211            61884           61884           61884    2693269  2018  ...
# 9212            61961           61961           61961    2693269  2018  ...
# 9213            61992           61992           61992    2693269  2018  ...
# 9214            62070           62070           62070    2693269  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1151468, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_61_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Route 26

# %%
lwk = wk[(wk['LINEID'] == '26')]

# %%
lwk.shape
# Out:
# (60696, 22)

# %%
# Drop Route 26 rows from wk
wk.drop(wk[wk['LINEID'] == '26'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9264   2018-09-10  8089347            1         7333            22800
# 9265   2018-09-10  8089347            2          783            22906
# 9266   2018-09-10  8089347            3          784            22929
# 9267   2018-09-10  8089347            4          785            22968
# 9268   2018-09-10  8089347            5          786            23045
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9264            22800           22800           22800    1000615  2018  ...
# 9265            22906           22906           22906    1000615  2018  ...
# 9266            22929           22929           22929    1000615  2018  ...
# 9267            22968           22968           22968    1000615  2018  ...
# 9268            23045           23045           23045    1000615  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1090772, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_26_tripLeave6_sp5.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_6

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_6.csv', index=False)
