# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 9b CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_9b.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_4609/3241950466.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_9b.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (141585, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-03-05  6367786            1          943            27000
# 1   2018-03-05  6367786            2         3599            27058
# 2   2018-03-05  6367786            3         3600            27090
# 3   2018-03-05  6367786            4         3601            27129
# 4   2018-03-05  6367786            5         3602            27165
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            27000           27000           27000    1000758  2018  ...
# 1            27058           27058           27058    1000758  2018  ...
# 2            27090           27090           27090    1000758  2018  ...
# 3            27129           27129           27129    1000758  2018  ...
# 4            27165           27165           27165    1000758  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 42D

# %%
lwk = wk[(wk['LINEID'] == '42D')]

# %%
lwk.shape
# Out:
# (2091, 22)

# %%
# Drop Route 42D rows from wk
wk.drop(wk[wk['LINEID'] == '42D'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 63   2018-03-05  6373829            4         1816            25369
# 64   2018-03-05  6373829            5         6171            25425
# 65   2018-03-05  6373829            6         4974            25501
# 66   2018-03-05  6373829            7         4976            25564
# 67   2018-03-05  6373829            8         7126            25676
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 63            25369           25369           25369    1000333  2018  ...
# 64            25425           25425           25425    1000333  2018  ...
# 65            25501           25501           25501    1000333  2018  ...
# 66            25564           25564           25564    1000333  2018  ...
# 67            25676           25676           25676    1000333  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (139494, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_42D_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 236

# %%
lwk = wk[(wk['LINEID'] == '236')]

# %%
lwk.shape
# Out:
# (4470, 22)

# %%
# Drop Route 236 rows from wk
wk.drop(wk[wk['LINEID'] == '236'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 205   2018-03-05  6376823            2         4714            26486
# 206   2018-03-05  6376823            3         4960            26530
# 207   2018-03-05  6376823            4         4932            26598
# 208   2018-03-05  6376823            5         4933            26614
# 209   2018-03-05  6376823            6         2590            26665
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 205            26486           26486           26486    2172293  2018  ...
# 206            26530           26530           26530    2172293  2018  ...
# 207            26598           26598           26598    2172293  2018  ...
# 208            26614           26614           26614    2172293  2018  ...
# 209            26665           26665           26665    2172293  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (135024, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_236_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 77X

# %%
lwk = wk[(wk['LINEID'] == '77X')]

# %%
lwk.shape
# Out:
# (2196, 22)

# %%
# Drop Route 77X rows from wk
wk.drop(wk[wk['LINEID'] == '77X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 254   2018-03-05  6384850            1          928            27900
# 255   2018-03-05  6384850            2          929            27935
# 256   2018-03-05  6384850            3          930            28002
# 257   2018-03-05  6384850            4          931            28084
# 258   2018-03-05  6384850            5          587            28183
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 254            27900           27900           27900    1000199  2018  ...
# 255            27935           27935           27935    1000199  2018  ...
# 256            28002           28002           28002    1000199  2018  ...
# 257            28084           28084           28084    1000199  2018  ...
# 258            28183           28183           28183    1000199  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (132828, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77X_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 31D

# %%
lwk = wk[(wk['LINEID'] == '31D')]

# %%
lwk.shape
# Out:
# (2818, 22)

# %%
# Drop Route 31D rows from wk
wk.drop(wk[wk['LINEID'] == '31D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1647   2018-03-09  6403039            1         6185            27000
# 1648   2018-03-09  6403039            2         6186            27045
# 1649   2018-03-09  6403039            3         6216            27123
# 1650   2018-03-09  6403039            4         3400            27186
# 1651   2018-03-09  6403039            5         3401            27224
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1647            27000           27000           27000    1000498  2018  ...
# 1648            27045           27045           27045    1000498  2018  ...
# 1649            27123           27123           27123    1000498  2018  ...
# 1650            27186           27186           27186    1000498  2018  ...
# 1651            27224           27224           27224    1000498  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (130010, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31D_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 68X

# %%
lwk = wk[(wk['LINEID'] == '68X')]

# %%
lwk.shape
# Out:
# (417, 22)

# %%
# Drop Route 68X rows from wk
wk.drop(wk[wk['LINEID'] == '68X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5165   2018-03-27  6593706            1         1772            83700
# 5166   2018-03-27  6593706            2         1773            83731
# 5167   2018-03-27  6593706            3         1774            83777
# 5168   2018-03-27  6593706            4         1775            83814
# 5169   2018-03-27  6593706            5         1776            83846
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5165            83700           83700           83700    2693260  2018  ...
# 5166            83731           83731           83731    2693260  2018  ...
# 5167            83777           83777           83777    2693260  2018  ...
# 5168            83814           83814           83814    2693260  2018  ...
# 5169            83846           83846           83846    2693260  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (129593, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68X_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 130

# %%
lwk = wk[(wk['LINEID'] == '130')]

# %%
lwk.shape
# Out:
# (6794, 22)

# %%
# Drop Route 130 rows from wk
wk.drop(wk[wk['LINEID'] == '130'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 11063   2018-03-27  6594107            1         7229            82800
# 11064   2018-03-27  6594107            2         4617            82879
# 11065   2018-03-27  6594107            6         2374            83088
# 11066   2018-03-27  6594107            7         2146            83115
# 11067   2018-03-27  6594107            8         2147            83135
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 11063            82800           82800           82800    2534872  2018  ...
# 11064            82879           82879           82879    2534872  2018  ...
# 11065            83088           83088           83088    2534872  2018  ...
# 11066            83115           83115           83115    2534872  2018  ...
# 11067            83135           83135           83135    2534872  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (122799, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_130_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 13

# %%
lwk = wk[(wk['LINEID'] == '13')]

# %%
lwk.shape
# Out:
# (11077, 22)

# %%
# Drop Route 13 rows from wk
wk.drop(wk[wk['LINEID'] == '13'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 20559   2018-03-27  6594428            1         1491            67680
# 20560   2018-03-27  6594428            2         1492            67749
# 20561   2018-03-27  6594428            3         1493            67780
# 20562   2018-03-27  6594428            4         1482            67799
# 20563   2018-03-27  6594428            5         1494            67863
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 20559            67680           67680           67680    2693252  2018  ...
# 20560            67749           67749           67749    2693252  2018  ...
# 20561            67780           67780           67780    2693252  2018  ...
# 20562            67799           67799           67799    2693252  2018  ...
# 20563            67863           67863           67863    2693252  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (111722, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_13_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 123

# %%
lwk = wk[(wk['LINEID'] == '123')]

# %%
lwk.shape
# Out:
# (15793, 22)

# %%
# Drop Route 123 rows from wk
wk.drop(wk[wk['LINEID'] == '123'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 27520   2018-03-27  6595094            1          284            84600
# 27521   2018-03-27  6595094            2         4504            84701
# 27522   2018-03-27  6595094            3         7028            84773
# 27523   2018-03-27  6595094            4         5147            84845
# 27524   2018-03-27  6595094            5           68            84915
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 27520            84600           84600           84600    2172316  2018  ...
# 27521            84701           84701           84701    2172316  2018  ...
# 27522            84773           84773           84773    2172316  2018  ...
# 27523            84845           84845           84845    2172316  2018  ...
# 27524            84915           84915           84915    2172316  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (95929, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_123_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (2785, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 30305   2018-03-27  6595361            1         3085            75600
# 30306   2018-03-27  6595361            2         3082            75698
# 30307   2018-03-27  6595361            3         3165            75751
# 30308   2018-03-27  6595361            4         3166            75831
# 30309   2018-03-27  6595361            5         3167            75852
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 30305            75600           75600           75600    1932297  2018  ...
# 30306            75698           75698           75698    1932297  2018  ...
# 30307            75751           75751           75751    1932297  2018  ...
# 30308            75831           75831           75831    1932297  2018  ...
# 30309            75852           75852           75852    1932297  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (93144, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 114

# %%
lwk = wk[(wk['LINEID'] == '114')]

# %%
lwk.shape
# Out:
# (1676, 22)

# %%
# Drop Route 114 rows from wk
wk.drop(wk[wk['LINEID'] == '114'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 31158   2018-03-27  6595427            1         3057            63000
# 31159   2018-03-27  6595427            2         3058            63020
# 31160   2018-03-27  6595427            3         3059            63046
# 31161   2018-03-27  6595427            4         3060            63075
# 31162   2018-03-27  6595427            5         3061            63105
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 31158            63000           63000           63000    1000786  2018  ...
# 31159            63020           63020           63020    1000786  2018  ...
# 31160            63046           63046           63046    1000786  2018  ...
# 31161            63075           63075           63075    1000786  2018  ...
# 31162            63105           63105           63105    1000786  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (91468, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_114_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (1221, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 32379   2018-03-27  6595494            1          449            84600
# 32380   2018-03-27  6595494            2          450            84629
# 32381   2018-03-27  6595494            3         3181            84687
# 32382   2018-03-27  6595494            4          451            84714
# 32383   2018-03-27  6595494            5          447            84754
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 32379            84600           84600           84600    2693217  2018  ...
# 32380            84629           84629           84629    2693217  2018  ...
# 32381            84687           84687           84687    2693217  2018  ...
# 32382            84714           84714           84714    2693217  2018  ...
# 32383            84754           84754           84754    2693217  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (90247, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 11

# %%
lwk = wk[(wk['LINEID'] == '11')]

# %%
lwk.shape
# Out:
# (9877, 22)

# %%
# Drop Route 11 rows from wk
wk.drop(wk[wk['LINEID'] == '11'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 38030   2018-03-29  6592934           17          757            37013
# 38031   2018-03-29  6592934           18          758            37051
# 38032   2018-03-29  6592934           19          759            37139
# 38033   2018-03-29  6592934           20          760            37205
# 38034   2018-03-29  6592934           21          761            37234
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 38030            37013           37013           37013    1000296  2018  ...
# 38031            37051           37051           37051    1000296  2018  ...
# 38032            37139           37139           37139    1000296  2018  ...
# 38033            37205           37205           37205    1000296  2018  ...
# 38034            37234           37234           37234    1000296  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (80370, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_11_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 145

# %%
lwk = wk[(wk['LINEID'] == '145')]

# %%
lwk.shape
# Out:
# (5878, 22)

# %%
# Drop Route 145 rows from wk
wk.drop(wk[wk['LINEID'] == '145'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 50926   2018-03-29  6594792            1         1423            84600
# 50927   2018-03-29  6594792            2         1424            84633
# 50928   2018-03-29  6594792            3         1425            84673
# 50929   2018-03-29  6594792            4         1426            84734
# 50930   2018-03-29  6594792            5         1427            84774
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 50926            84600           84600           84600    2693269  2018  ...
# 50927            84633           84633           84633    2693269  2018  ...
# 50928            84673           84673           84673    2693269  2018  ...
# 50929            84734           84734           84734    2693269  2018  ...
# 50930            84774           84774           84774    2693269  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (74492, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_145_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 122

# %%
lwk = wk[(wk['LINEID'] == '122')]

# %%
lwk.shape
# Out:
# (5853, 22)

# %%
# Drop Route 122 rows from wk
wk.drop(wk[wk['LINEID'] == '122'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 56779   2018-03-29  6595355            1         2955            27600
# 56780   2018-03-29  6595355            2         7067            27606
# 56781   2018-03-29  6595355            3         2956            27628
# 56782   2018-03-29  6595355            4         2965            27674
# 56783   2018-03-29  6595355            5         2967            27757
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 56779            27600           27600           27600    1000590  2018  ...
# 56780            27606           27606           27606    1000590  2018  ...
# 56781            27628           27628           27628    1000590  2018  ...
# 56782            27674           27674           27674    1000590  2018  ...
# 56783            27757           27757           27757    1000590  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (68639, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_122_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (107, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 62540   2018-03-29  6595760            1         7348            80100
# 62541   2018-03-29  6595760            2         3669            80180
# 62542   2018-03-29  6595760            3         3671            80226
# 62543   2018-03-29  6595760            4         3672            80250
# 62544   2018-03-29  6595760            7         6033            80510
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 62540            80100           80100           80100    2868360  2018  ...
# 62541            80180           80180           80180    2868360  2018  ...
# 62542            80226           80226           80226    2868360  2018  ...
# 62543            80250           80250           80250    2868360  2018  ...
# 62544            80510           80510           80510    2868360  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (68532, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave2_sp9b.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_9c

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_9c.csv', index=False)
