# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave5 CSV file into Data Frame:
wk = pd.read_csv('v4_tripLeave5_LT_2018.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (18326560, 21)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Add Actual Arrival Time Hour

# %%
wk['actualARR_hour'] = (wk['ACTUALTIME_ARR'] / 3600).round()

# %%
wk.head()

# %%
# Replace any 24 hour values to zero
wk['actualARR_hour'] = np.where(wk['actualARR_hour'] == 24, 0, wk['actualARR_hour'])

# %%
# Update actualARR_hour to int to rid of decimals
wk['actualARR_hour'] = wk['actualARR_hour'].astype('int32')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-08-26  7502507            1         7347            33600
# 1   2018-08-26  7502507            2         3669            33682
# 2   2018-08-26  7502507            3         7349            33742
# 3   2018-08-26  7502507            4         1631            33814
# 4   2018-08-26  7502507            5         1632            33830
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            33600           33600           33600    1000953  2018  ...
# 1            33682           33682           33682    1000953  2018  ...
# 2            33742           33742           33742    1000953  2018  ...
# 3            33814           33814           33814    1000953  2018  ...
# 4            33830           33830           33830    1000953  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-08-26  7502507            1         7347            33600
# 1   2018-08-26  7502507            2         3669            33682
# 2   2018-08-26  7502507            3         7349            33742
# 3   2018-08-26  7502507            4         1631            33814
# 4   2018-08-26  7502507            5         1632            33830
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            33600           33600           33600    1000953  2018  ...
# 1            33682           33682           33682    1000953  2018  ...
# 2            33742           33742           33742    1000953  2018  ...
# 3            33814           33814           33814    1000953  2018  ...
# 4            33830           33830           33830    1000953  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int32
# dtype: object

# %% [markdown]
# ## Route 16

# %%
lwk = wk[(wk['LINEID'] == '16')]

# %%
lwk.shape
# Out:
# (545390, 22)

# %%
# Drop Route 16 rows from wk
wk.drop(wk[wk['LINEID'] == '16'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 661   2018-08-26  7502517           18           84            46280
# 662   2018-08-26  7502517           19           51            46452
# 663   2018-08-26  7502517           20           52            46514
# 664   2018-08-26  7502517           21          263            46648
# 665   2018-08-26  7502517           22          271            46853
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 661            46280           46280           46280    1001139  2018  ...
# 662            46452           46452           46452    1001139  2018  ...
# 663            46514           46514           46514    1001139  2018  ...
# 664            46648           46648           46648    1001139  2018  ...
# 665            46853           46853           46853    1001139  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17781170, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_16_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Route 122

# %%
lwk = wk[(wk['LINEID'] == '122')]

# %%
lwk.shape
# Out:
# (297255, 22)

# %%
# Drop Route 122 rows from wk
wk.drop(wk[wk['LINEID'] == '122'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 931   2018-08-26  7502558            4         4886            36137
# 932   2018-08-26  7502558            5         4887            36241
# 933   2018-08-26  7502558            6         1150            36313
# 934   2018-08-26  7502558            7         1151            36370
# 935   2018-08-26  7502558            8         1152            36396
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 931            36137           36137           36137    2534838  2018  ...
# 932            36241           36241           36241    2534838  2018  ...
# 933            36313           36313           36313    2534838  2018  ...
# 934            36370           36370           36370    2534838  2018  ...
# 935            36396           36396           36396    2534838  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17483915, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_122_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Route 15

# %%
lwk = wk[(wk['LINEID'] == '15')]

# %%
lwk.shape
# Out:
# (617802, 22)

# %%
# Drop Route 15 rows from wk
wk.drop(wk[wk['LINEID'] == '15'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1347   2018-08-26  7502573            2         1829            55523
# 1348   2018-08-26  7502573            3         1830            55586
# 1349   2018-08-26  7502573            4         1831            55615
# 1350   2018-08-26  7502573            5         4747            55878
# 1351   2018-08-26  7502573            6         2960            55941
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1347            55523           55523           55523    1000333  2018  ...
# 1348            55586           55586           55586    1000333  2018  ...
# 1349            55615           55615           55615    1000333  2018  ...
# 1350            55878           55878           55878    1000333  2018  ...
# 1351            55941           55941           55941    1000333  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16866113, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Route 238

# %%
lwk = wk[(wk['LINEID'] == '238')]

# %%
lwk.shape
# Out:
# (32339, 22)

# %%
# Drop Route 238 rows from wk
wk.drop(wk[wk['LINEID'] == '238'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1465   2018-08-26  7502581            1         7229            50400
# 1466   2018-08-26  7502581            2         4617            50509
# 1467   2018-08-26  7502581            3         4555            50528
# 1468   2018-08-26  7502581            4         4576            50602
# 1469   2018-08-26  7502581            5         3418            50659
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1465            50400           50400           50400    2868361  2018  ...
# 1466            50509           50509           50509    2868361  2018  ...
# 1467            50528           50528           50528    2868361  2018  ...
# 1468            50602           50602           50602    2868361  2018  ...
# 1469            50659           50659           50659    2868361  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16833774, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_238_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Route 13

# %%
lwk = wk[(wk['LINEID'] == '13')]

# %%
lwk.shape
# Out:
# (463447, 22)

# %%
# Drop Route 13 rows from wk
wk.drop(wk[wk['LINEID'] == '13'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1688   2018-08-26  7502661            1         3917            45900
# 1689   2018-08-26  7502661            2         3918            45967
# 1690   2018-08-26  7502661            3         3926            46030
# 1691   2018-08-26  7502661            4         7074            46083
# 1692   2018-08-26  7502661            5         3919            46163
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1688            45900           45900           45900    2534865  2018  ...
# 1689            45967           45967           45967    2534865  2018  ...
# 1690            46030           46030           46030    2534865  2018  ...
# 1691            46083           46083           46083    2534865  2018  ...
# 1692            46163           46163           46163    2534865  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16370327, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_13_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Route 67

# %%
lwk = wk[(wk['LINEID'] == '67')]

# %%
lwk.shape
# Out:
# (239661, 22)

# %%
# Drop Route 67 rows from wk
wk.drop(wk[wk['LINEID'] == '67'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2012   2018-08-26  7502684            1         4606            28800
# 2013   2018-08-26  7502684            2         7142            28859
# 2014   2018-08-26  7502684            3         7015            28938
# 2015   2018-08-26  7502684            4         4617            29011
# 2016   2018-08-26  7502684            5         4555            29027
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2012            28800           28800           28800    1000501  2018  ...
# 2013            28859           28859           28859    1000501  2018  ...
# 2014            28938           28938           28938    1000501  2018  ...
# 2015            29011           29011           29011    1000501  2018  ...
# 2016            29027           29027           29027    1000501  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (16130666, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67_tripLeave5_sp0.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave5_route_split_1

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave5_route_split_1.csv', index=False)
