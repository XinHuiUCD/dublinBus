# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave3 CSV file into Data Frame:
wk = pd.read_csv('v4_tripLeave3_LT_2018.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (18424000, 21)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Add Actual Arrival Time Hour

# %%
wk['actualARR_hour'] = (wk['ACTUALTIME_ARR'] / 3600).round()

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6651125            1         6004            44100
# 1   2018-04-29  6651125            2            7            44208
# 2   2018-04-29  6651125            3           11            44402
# 3   2018-04-29  6651125            4           14            44479
# 4   2018-04-29  6651125            5           15            44567
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            44100           44100           44100    2406908  2018  ...
# 1            44208           44208           44208    2406908  2018  ...
# 2            44402           44402           44402    2406908  2018  ...
# 3            44479           44479           44479    2406908  2018  ...
# 4            44567           44567           44567    2406908  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
# Replace any 24 hour values to zero
wk['actualARR_hour'] = np.where(wk['actualARR_hour'] == 24, 0, wk['actualARR_hour'])

# %%
# Update actualARR_hour to int to rid of decimals
wk['actualARR_hour'] = wk['actualARR_hour'].astype('int32')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6651125            1         6004            44100
# 1   2018-04-29  6651125            2            7            44208
# 2   2018-04-29  6651125            3           11            44402
# 3   2018-04-29  6651125            4           14            44479
# 4   2018-04-29  6651125            5           15            44567
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            44100           44100           44100    2406908  2018  ...
# 1            44208           44208           44208    2406908  2018  ...
# 2            44402           44402           44402    2406908  2018  ...
# 3            44479           44479           44479    2406908  2018  ...
# 4            44567           44567           44567    2406908  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6651125            1         6004            44100
# 1   2018-04-29  6651125            2            7            44208
# 2   2018-04-29  6651125            3           11            44402
# 3   2018-04-29  6651125            4           14            44479
# 4   2018-04-29  6651125            5           15            44567
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            44100           44100           44100    2406908  2018  ...
# 1            44208           44208           44208    2406908  2018  ...
# 2            44402           44402           44402    2406908  2018  ...
# 3            44479           44479           44479    2406908  2018  ...
# 4            44567           44567           44567    2406908  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int32
# dtype: object

# %% [markdown]
# ## Route 40D

# %%
lwk = wk[(wk['LINEID'] == '40D')]

# %%
lwk.shape
# Out:
# (195344, 22)

# %%
# Drop Route 40D rows from wk
wk.drop(wk[wk['LINEID'] == '40D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 136   2018-04-29  6651128            2         4317            73828
# 137   2018-04-29  6651128            3         7013            74018
# 138   2018-04-29  6651128            4         6162            74132
# 139   2018-04-29  6651128            5         7022            74160
# 140   2018-04-29  6651128            6         1554            74280
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 136            73828           73828           73828    2693185  2018  ...
# 137            74018           74018           74018    2693185  2018  ...
# 138            74132           74132           74132    2693185  2018  ...
# 139            74160           74160           74160    2693185  2018  ...
# 140            74280           74280           74280    2693185  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (18228656, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40D_tripLeave3_sp0.csv', index=False)

# %% [markdown]
# ## Route 40B

# %%
lwk = wk[(wk['LINEID'] == '40B')]

# %%
lwk.shape
# Out:
# (24089, 22)

# %%
# Drop Route 40B rows from wk
wk.drop(wk[wk['LINEID'] == '40B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 311   2018-04-29  6651147            1          896            46200
# 312   2018-04-29  6651147            2          897            46244
# 313   2018-04-29  6651147            3          893            46280
# 314   2018-04-29  6651147            4          894            46331
# 315   2018-04-29  6651147            5         1067            46368
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 311            46200           46200           46200    2406901  2018  ...
# 312            46244           46244           46244    2406901  2018  ...
# 313            46280           46280           46280    2406901  2018  ...
# 314            46331           46331           46331    2406901  2018  ...
# 315            46368           46368           46368    2406901  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (18204567, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40B_tripLeave3_sp0.csv', index=False)

# %% [markdown]
# ## Route 140

# %%
lwk = wk[(wk['LINEID'] == '140')]

# %%
lwk.shape
# Out:
# (307791, 22)

# %%
# Drop Route 140 rows from wk
wk.drop(wk[wk['LINEID'] == '140'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 584   2018-04-29  6651165            1         3732            31800
# 585   2018-04-29  6651165            2         3733            31816
# 586   2018-04-29  6651165            3         3734            31849
# 587   2018-04-29  6651165            4         3735            31866
# 588   2018-04-29  6651165            5         3736            31911
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 584            31800           31800           31800    1000198  2018  ...
# 585            31816           31816           31816    1000198  2018  ...
# 586            31849           31849           31849    1000198  2018  ...
# 587            31866           31866           31866    1000198  2018  ...
# 588            31911           31911           31911    1000198  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17896776, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_140_tripLeave3_sp0.csv', index=False)

# %% [markdown]
# ## Route 33B

# %%
lwk = wk[(wk['LINEID'] == '33B')]

# %%
lwk.shape
# Out:
# (49478, 22)

# %%
# Drop Route 33B rows from wk
wk.drop(wk[wk['LINEID'] == '33B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1006   2018-04-29  6651184            1         7574            32400
# 1007   2018-04-29  6651184            2         4177            32502
# 1008   2018-04-29  6651184            3         4178            32526
# 1009   2018-04-29  6651184            4         4179            32575
# 1010   2018-04-29  6651184            5         2993            32624
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1006            32400           32400           32400    2693271  2018  ...
# 1007            32502           32502           32502    2693271  2018  ...
# 1008            32526           32526           32526    2693271  2018  ...
# 1009            32575           32575           32575    2693271  2018  ...
# 1010            32624           32624           32624    2693271  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17847298, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33B_tripLeave3_sp0.csv', index=False)

# %% [markdown]
# ## Route 145

# %%
lwk = wk[(wk['LINEID'] == '145')]

# %%
lwk.shape
# Out:
# (643674, 22)

# %%
# Drop Route 145 rows from wk
wk.drop(wk[wk['LINEID'] == '145'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1618   2018-04-29  6651213            1         1828            55500
# 1619   2018-04-29  6651213            2         1829            55522
# 1620   2018-04-29  6651213            3         1830            55584
# 1621   2018-04-29  6651213            4         1831            55612
# 1622   2018-04-29  6651213            5         4747            55940
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1618            55500           55500           55500    1000760  2018  ...
# 1619            55522           55522           55522    1000760  2018  ...
# 1620            55584           55584           55584    1000760  2018  ...
# 1621            55612           55612           55612    1000760  2018  ...
# 1622            55940           55940           55940    1000760  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (17203624, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_145_tripLeave3_sp0.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave3_route_split_1

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave3_route_split_1.csv', index=False)
