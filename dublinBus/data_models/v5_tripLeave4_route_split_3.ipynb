# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 3 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_3.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (12555467, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-24  7111310            4         3811            46915
# 1   2018-06-24  7111310            5         3812            46942
# 2   2018-06-24  7111310            6         3664            46964
# 3   2018-06-24  7111310            7         3813            47097
# 4   2018-06-24  7111310            8         3814            47168
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            46915           46915           46915    2868338  2018  ...
# 1            46942           46942           46942    2868338  2018  ...
# 2            46964           46964           46964    2868338  2018  ...
# 3            47097           47097           47097    2868338  2018  ...
# 4            47168           47168           47168    2868338  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 33

# %%
lwk = wk[(wk['LINEID'] == '33')]

# %%
lwk.shape
# Out:
# (230895, 22)

# %%
# Drop Route 33 rows from wk
wk.drop(wk[wk['LINEID'] == '33'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 193   2018-06-24  7111314            1         3677            73800
# 194   2018-06-24  7111314            2         3678            73838
# 195   2018-06-24  7111314            3         3679            73882
# 196   2018-06-24  7111314            4         3711            73911
# 197   2018-06-24  7111314            5         3712            73942
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 193            73800           73800           73800    2868338  2018  ...
# 194            73838           73838           73838    2868338  2018  ...
# 195            73882           73882           73882    2868338  2018  ...
# 196            73911           73911           73911    2868338  2018  ...
# 197            73942           73942           73942    2868338  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (12324572, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 33A

# %%
lwk = wk[(wk['LINEID'] == '33A')]

# %%
lwk.shape
# Out:
# (32111, 22)

# %%
# Drop Route 33A rows from wk
wk.drop(wk[wk['LINEID'] == '33A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 358   2018-06-24  7111335            1         2039            31800
# 359   2018-06-24  7111335            2         2040            31848
# 360   2018-06-24  7111335            3         2041            31909
# 361   2018-06-24  7111335            4         2042            31984
# 362   2018-06-24  7111335            5         2043            31998
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 358            31800           31800           31800    2693277  2018  ...
# 359            31848           31848           31848    2693277  2018  ...
# 360            31909           31909           31909    2693277  2018  ...
# 361            31984           31984           31984    2693277  2018  ...
# 362            31998           31998           31998    2693277  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (12292461, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33A_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 46A

# %%
lwk = wk[(wk['LINEID'] == '46A')]

# %%
lwk.shape
# Out:
# (658593, 22)

# %%
# Drop Route 46A rows from wk
wk.drop(wk[wk['LINEID'] == '46A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 846   2018-06-24  7111390            1         4320            50400
# 847   2018-06-24  7111390            2         1476            50519
# 848   2018-06-24  7111390            3         7453            50604
# 849   2018-06-24  7111390            4         1478            50687
# 850   2018-06-24  7111390            5         1479            50744
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 846            50400           50400           50400    2693276  2018  ...
# 847            50519           50519           50519    2693276  2018  ...
# 848            50604           50604           50604    2693276  2018  ...
# 849            50687           50687           50687    2693276  2018  ...
# 850            50744           50744           50744    2693276  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (11633868, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46A_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 145

# %%
lwk = wk[(wk['LINEID'] == '145')]

# %%
lwk.shape
# Out:
# (647685, 22)

# %%
# Drop Route 145 rows from wk
wk.drop(wk[wk['LINEID'] == '145'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1130   2018-06-24  7111474            1         2243            39600
# 1131   2018-06-24  7111474            2         2200            39648
# 1132   2018-06-24  7111474            3         5006            39722
# 1133   2018-06-24  7111474            4         5007            39764
# 1134   2018-06-24  7111474            5         2655            39849
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1130            39600           39600           39600    2534785  2018  ...
# 1131            39648           39648           39648    2534785  2018  ...
# 1132            39722           39722           39722    2534785  2018  ...
# 1133            39764           39764           39764    2534785  2018  ...
# 1134            39849           39849           39849    2534785  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10986183, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_145_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 76

# %%
lwk = wk[(wk['LINEID'] == '76')]

# %%
lwk.shape
# Out:
# (128289, 22)

# %%
# Drop Route 76 rows from wk
wk.drop(wk[wk['LINEID'] == '76'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1337   2018-06-24  7111489            1          449            39000
# 1338   2018-06-24  7111489            2          450            39030
# 1339   2018-06-24  7111489            3         3181            39092
# 1340   2018-06-24  7111489            4          451            39121
# 1341   2018-06-24  7111489            5          447            39164
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1337            39000           39000           39000    2172240  2018  ...
# 1338            39030           39030           39030    2172240  2018  ...
# 1339            39092           39092           39092    2172240  2018  ...
# 1340            39121           39121           39121    2172240  2018  ...
# 1341            39164           39164           39164    2172240  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10857894, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 11

# %%
lwk = wk[(wk['LINEID'] == '11')]

# %%
lwk.shape
# Out:
# (248785, 22)

# %%
# Drop Route 11 rows from wk
wk.drop(wk[wk['LINEID'] == '11'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1589   2018-06-24  7111517            1         7132            41400
# 1590   2018-06-24  7111517            2         6230            41462
# 1591   2018-06-24  7111517            3         6228            41500
# 1592   2018-06-24  7111517            4         4788            41549
# 1593   2018-06-24  7111517            5         6273            41593
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1589            41400           41400           41400    2172265  2018  ...
# 1590            41462           41462           41462    2172265  2018  ...
# 1591            41500           41500           41500    2172265  2018  ...
# 1592            41549           41549           41549    2172265  2018  ...
# 1593            41593           41593           41593    2172265  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10609109, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_11_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 83

# %%
lwk = wk[(wk['LINEID'] == '83')]

# %%
lwk.shape
# Out:
# (350158, 22)

# %%
# Drop Route 83 rows from wk
wk.drop(wk[wk['LINEID'] == '83'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1651   2018-06-24  7111518            1         2492            45600
# 1652   2018-06-24  7111518            2         2493            45652
# 1653   2018-06-24  7111518            3         2465            45686
# 1654   2018-06-24  7111518            4         2466            45713
# 1655   2018-06-24  7111518            5         2467            45753
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1651            45600           45600           45600    2172265  2018  ...
# 1652            45652           45652           45652    2172265  2018  ...
# 1653            45686           45686           45686    2172265  2018  ...
# 1654            45713           45713           45713    2172265  2018  ...
# 1655            45753           45753           45753    2172265  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10258951, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 83A

# %%
lwk = wk[(wk['LINEID'] == '83A')]

# %%
lwk.shape
# Out:
# (99213, 22)

# %%
# Drop Route 83A rows from wk
wk.drop(wk[wk['LINEID'] == '83A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2025   2018-06-24  7111565            1         7347            34800
# 2026   2018-06-24  7111565            2         3669            34888
# 2027   2018-06-24  7111565            3         7349            34952
# 2028   2018-06-24  7111565            4         1631            35027
# 2029   2018-06-24  7111565            5         1632            35044
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2025            34800           34800           34800    1932321  2018  ...
# 2026            34888           34888           34888    1932321  2018  ...
# 2027            34952           34952           34952    1932321  2018  ...
# 2028            35027           35027           35027    1932321  2018  ...
# 2029            35044           35044           35044    1932321  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (10159738, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_83A_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 16

# %%
lwk = wk[(wk['LINEID'] == '16')]

# %%
lwk.shape
# Out:
# (496394, 22)

# %%
# Drop Route 16 rows from wk
wk.drop(wk[wk['LINEID'] == '16'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2752   2018-06-24  7111652            1         2037            36000
# 2753   2018-06-24  7111652            2         2040            36024
# 2754   2018-06-24  7111652            3         3047            36110
# 2755   2018-06-24  7111652            4         3202            36146
# 2756   2018-06-24  7111652            5         3203            36228
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2752            36000           36000           36000    1000964  2018  ...
# 2753            36024           36024           36024    1000964  2018  ...
# 2754            36110           36110           36110    1000964  2018  ...
# 2755            36146           36146           36146    1000964  2018  ...
# 2756            36228           36228           36228    1000964  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9663344, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_16_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 45A

# %%
lwk = wk[(wk['LINEID'] == '45A')]

# %%
lwk.shape
# Out:
# (205053, 22)

# %%
# Drop Route 45A rows from wk
wk.drop(wk[wk['LINEID'] == '45A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3084   2018-06-24  7111688            1         1772            39600
# 3085   2018-06-24  7111688            2         1773            39640
# 3086   2018-06-24  7111688            3         1774            39698
# 3087   2018-06-24  7111688            4         1775            39745
# 3088   2018-06-24  7111688            5         1776            39786
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3084            39600           39600           39600    1001068  2018  ...
# 3085            39640           39640           39640    1001068  2018  ...
# 3086            39698           39698           39698    1001068  2018  ...
# 3087            39745           39745           39745    1001068  2018  ...
# 3088            39786           39786           39786    1001068  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9458291, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_45A_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 130

# %%
lwk = wk[(wk['LINEID'] == '130')]

# %%
lwk.shape
# Out:
# (303112, 22)

# %%
# Drop Route 130 rows from wk
wk.drop(wk[wk['LINEID'] == '130'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3578   2018-06-24  7111729            1         4096            52200
# 3579   2018-06-24  7111729            2         4114            52223
# 3580   2018-06-24  7111729            3         4115            52237
# 3581   2018-06-24  7111729            4         4116            52305
# 3582   2018-06-24  7111729            5         4117            52334
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3578            52200           52200           52200    2693274  2018  ...
# 3579            52223           52223           52223    2693274  2018  ...
# 3580            52237           52237           52237    2693274  2018  ...
# 3581            52305           52305           52305    2693274  2018  ...
# 3582            52334           52334           52334    2693274  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (9155179, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_130_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (159509, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3807   2018-06-24  7111745            1         4495            33300
# 3808   2018-06-24  7111745            4         1278            33429
# 3809   2018-06-24  7111745            5         1282            33559
# 3810   2018-06-24  7111745            6         4456            33600
# 3811   2018-06-24  7111745            7         1284            33637
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3807            33300           33300           33300    1000331  2018  ...
# 3808            33429           33429           33429    1000331  2018  ...
# 3809            33559           33559           33559    1000331  2018  ...
# 3810            33600           33600           33600    1000331  2018  ...
# 3811            33637           33637           33637    1000331  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8995670, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Route 68

# %%
lwk = wk[(wk['LINEID'] == '68')]

# %%
lwk.shape
# Out:
# (126780, 22)

# %%
# Drop Route 68 rows from wk
wk.drop(wk[wk['LINEID'] == '68'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4288   2018-06-24  7111752            1         4495            66000
# 4289   2018-06-24  7111752            2         4720            66155
# 4290   2018-06-24  7111752            3         1443            66363
# 4291   2018-06-24  7111752            4         1444            66414
# 4292   2018-06-24  7111752            5         1445            66471
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4288            66000           66000           66000    2693290  2018  ...
# 4289            66155           66155           66155    2693290  2018  ...
# 4290            66363           66363           66363    2693290  2018  ...
# 4291            66414           66414           66414    2693290  2018  ...
# 4292            66471           66471           66471    2693290  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (8868890, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68_tripLeave4_sp3.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_4

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_4.csv', index=False)
