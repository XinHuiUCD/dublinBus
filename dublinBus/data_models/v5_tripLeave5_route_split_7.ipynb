# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave5 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave5_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (514702, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-08-27  7504348            1         7026            24000
# 1   2018-08-27  7504348            2         4747            24127
# 2   2018-08-27  7504348            3         2960            24178
# 3   2018-08-27  7504348            4         1840            24357
# 4   2018-08-27  7504348            5         1841            24387
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            24000           24000           24000    2534791  2018  ...
# 1            24127           24127           24127    2534791  2018  ...
# 2            24178           24178           24178    2534791  2018  ...
# 3            24357           24357           24357    2534791  2018  ...
# 4            24387           24387           24387    2534791  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 76A

# %%
lwk = wk[(wk['LINEID'] == '76A')]

# %%
lwk.shape
# Out:
# (10236, 22)

# %%
# Drop Route 76A rows from wk
wk.drop(wk[wk['LINEID'] == '76A'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 43   2018-08-27  7504401            1         4962            63000
# 44   2018-08-27  7504401            3          334            63510
# 45   2018-08-27  7504401            4          406            63852
# 46   2018-08-27  7504401            5          747            64041
# 47   2018-08-27  7504401            6          842            64164
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 43            63000           63000           63000    1001082  2018  ...
# 44            63510           63510           63510    1001082  2018  ...
# 45            63852           63852           63852    1001082  2018  ...
# 46            64041           64041           64041    1001082  2018  ...
# 47            64164           64164           64164    1001082  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (504466, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76A_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 7B

# %%
lwk = wk[(wk['LINEID'] == '7B')]

# %%
lwk.shape
# Out:
# (20099, 22)

# %%
# Drop Route 7B rows from wk
wk.drop(wk[wk['LINEID'] == '7B'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 95   2018-08-27  7504702            1         7391            21300
# 96   2018-08-27  7504702            2          493            21365
# 97   2018-08-27  7504702            3          494            21415
# 98   2018-08-27  7504702            4          495            21475
# 99   2018-08-27  7504702            5          400            21524
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 95            21300           21300           21300    2172271  2018  ...
# 96            21365           21365           21365    2172271  2018  ...
# 97            21415           21415           21415    2172271  2018  ...
# 98            21475           21475           21475    2172271  2018  ...
# 99            21524           21524           21524    2172271  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (484367, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7B_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 66B

# %%
lwk = wk[(wk['LINEID'] == '66B')]

# %%
lwk.shape
# Out:
# (77002, 22)

# %%
# Drop Route 66B rows from wk
wk.drop(wk[wk['LINEID'] == '66B'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 192   2018-08-27  7505230            1         3994            23580
# 193   2018-08-27  7505230            2         3995            23640
# 194   2018-08-27  7505230            3         3996            23698
# 195   2018-08-27  7505230            4         3997            23758
# 196   2018-08-27  7505230            5         3998            23803
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 192            23580           23580           23580    2868316  2018  ...
# 193            23640           23640           23640    2868316  2018  ...
# 194            23698           23698           23698    2868316  2018  ...
# 195            23758           23758           23758    2868316  2018  ...
# 196            23803           23803           23803    2868316  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (407365, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66B_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 66A

# %%
lwk = wk[(wk['LINEID'] == '66A')]

# %%
lwk.shape
# Out:
# (73506, 22)

# %%
# Drop Route 66A rows from wk
wk.drop(wk[wk['LINEID'] == '66A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 427   2018-08-27  7505238           33         3966            65525
# 428   2018-08-27  7505238           34         5113            65599
# 429   2018-08-27  7505238           35         3918            65784
# 430   2018-08-27  7505238           36         5114            65920
# 629   2018-08-27  7505474            1         4664            27900
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 427            65525           65525           65525    2868316  2018  ...
# 428            65599           65599           65599    2868316  2018  ...
# 429            65784           65784           65784    2868316  2018  ...
# 430            65920           65920           65920    2868316  2018  ...
# 629            27900           27900           27900    1000501  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (333859, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66A_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (28099, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 629   2018-08-27  7505474            1         4664            27900
# 630   2018-08-27  7505474            2         2160            27953
# 631   2018-08-27  7505474            3         4665            27990
# 632   2018-08-27  7505474            4         4666            28030
# 633   2018-08-27  7505474            5         4667            28063
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 629            27900           27900           27900    1000501  2018  ...
# 630            27953           27953           27953    1000501  2018  ...
# 631            27990           27990           27990    1000501  2018  ...
# 632            28030           28030           28030    1000501  2018  ...
# 633            28063           28063           28063    1000501  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (305760, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 51D

# %%
lwk = wk[(wk['LINEID'] == '51D')]

# %%
lwk.shape
# Out:
# (8113, 22)

# %%
# Drop Route 51D rows from wk
wk.drop(wk[wk['LINEID'] == '51D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 899   2018-08-27  7505869            1         4953            63000
# 900   2018-08-27  7505869            2          768            63128
# 901   2018-08-27  7505869            3          769            63150
# 902   2018-08-27  7505869            4          770            63205
# 903   2018-08-27  7505869            5          771            63227
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 899            63000           63000           63000    1000124  2018  ...
# 900            63128           63128           63128    1000124  2018  ...
# 901            63150           63150           63150    1000124  2018  ...
# 902            63205           63205           63205    1000124  2018  ...
# 903            63227           63227           63227    1000124  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (297647, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_51D_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 25X

# %%
lwk = wk[(wk['LINEID'] == '25X')]

# %%
lwk.shape
# Out:
# (8589, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '25X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 947   2018-08-27  7506085            1         4564            27000
# 948   2018-08-27  7506085            2         3444            27079
# 949   2018-08-27  7506085            3         3447            27180
# 950   2018-08-27  7506085            4         3454            27412
# 951   2018-08-27  7506085            5         3455            27500
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 947            27000           27000           27000    3265685  2018  ...
# 948            27079           27079           27079    3265685  2018  ...
# 949            27180           27180           27180    3265685  2018  ...
# 950            27412           27412           27412    3265685  2018  ...
# 951            27500           27500           27500    3265685  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (289058, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 69X

# %%
lwk = wk[(wk['LINEID'] == '69X')]

# %%
lwk.shape
# Out:
# (1383, 22)

# %%
# Drop Route 69X rows from wk
wk.drop(wk[wk['LINEID'] == '69X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1189   2018-08-27  7507160            2         4989            62184
# 1190   2018-08-27  7507160            3         1845            62889
# 1191   2018-08-27  7507160            4         7166            62940
# 1192   2018-08-27  7507160            5         1847            63000
# 1193   2018-08-27  7507160            6         1696            63120
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1189            62184           62184           62184    3265705  2018  ...
# 1190            62889           62889           62889    3265705  2018  ...
# 1191            62940           62940           62940    3265705  2018  ...
# 1192            63000           63000           63000    3265705  2018  ...
# 1193            63120           63120           63120    3265705  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (287675, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 38D

# %%
lwk = wk[(wk['LINEID'] == '38D')]

# %%
lwk.shape
# Out:
# (1640, 22)

# %%
# Drop Route 38D rows from wk
wk.drop(wk[wk['LINEID'] == '38D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1282   2018-08-27  7507208            6         7204            26595
# 1283   2018-08-27  7507208            7         3736            26647
# 1284   2018-08-27  7507208            8         3738            26677
# 1285   2018-08-27  7507208            9         7170            26760
# 1286   2018-08-27  7507208           10         3740            26810
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1282            26595           26595           26595    1001164  2018  ...
# 1283            26647           26647           26647    1001164  2018  ...
# 1284            26677           26677           26677    1001164  2018  ...
# 1285            26760           26760           26760    1001164  2018  ...
# 1286            26810           26810           26810    1001164  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (286035, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38D_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 33D

# %%
lwk = wk[(wk['LINEID'] == '33D')]

# %%
lwk.shape
# Out:
# (1748, 22)

# %%
# Drop Route 33D rows from wk
wk.drop(wk[wk['LINEID'] == '33D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1357   2018-08-27  7507719           11         2236            27713
# 1358   2018-08-27  7507719           12         2237            27728
# 1359   2018-08-27  7507719           13         2238            27746
# 1360   2018-08-27  7507719           14         5056            27774
# 1361   2018-08-27  7507719           15         2239            27915
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1357            27713           27713           27713    1000949  2018  ...
# 1358            27728           27728           27728    1000949  2018  ...
# 1359            27746           27746           27746    1000949  2018  ...
# 1360            27774           27774           27774    1000949  2018  ...
# 1361            27915           27915           27915    1000949  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (284287, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33D_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 25D

# %%
lwk = wk[(wk['LINEID'] == '25D')]

# %%
lwk.shape
# Out:
# (8287, 22)

# %%
# Drop Route 25D rows from wk
wk.drop(wk[wk['LINEID'] == '25D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1408   2018-08-27  7507851            4         2965            27678
# 1409   2018-08-27  7507851            5         2967            27764
# 1410   2018-08-27  7507851            6         2968            27796
# 1411   2018-08-27  7507851            7         2969            27826
# 1412   2018-08-27  7507851            8         2970            27858
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1408            27678           27678           27678    1000586  2018  ...
# 1409            27764           27764           27764    1000586  2018  ...
# 1410            27796           27796           27796    1000586  2018  ...
# 1411            27826           27826           27826    1000586  2018  ...
# 1412            27858           27858           27858    1000586  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (276000, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25D_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 116

# %%
lwk = wk[(wk['LINEID'] == '116')]

# %%
lwk.shape
# Out:
# (2802, 22)

# %%
# Drop Route 116 rows from wk
wk.drop(wk[wk['LINEID'] == '116'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1467   2018-08-27  7507854            1         4843            24900
# 1468   2018-08-27  7507854            2         4905            24943
# 1469   2018-08-27  7507854            4         4906            24985
# 1470   2018-08-27  7507854            5         4907            25015
# 1471   2018-08-27  7507854            6         4908            25034
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1467            24900           24900           24900    2534847  2018  ...
# 1468            24943           24943           24943    2534847  2018  ...
# 1469            24985           24985           24985    2534847  2018  ...
# 1470            25015           25015           25015    2534847  2018  ...
# 1471            25034           25034           25034    2534847  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (273198, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_116_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 41A

# %%
lwk = wk[(wk['LINEID'] == '41A')]

# %%
lwk.shape
# Out:
# (4100, 22)

# %%
# Drop Route 41A rows from wk
wk.drop(wk[wk['LINEID'] == '41A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1560   2018-08-27  7508258            1         6200            63000
# 1561   2018-08-27  7508258            2         6201            63012
# 1562   2018-08-27  7508258            3         6196            63083
# 1563   2018-08-27  7508258            4         3532            63119
# 1564   2018-08-27  7508258            5         3533            63161
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1560            63000           63000           63000    1000959  2018  ...
# 1561            63012           63012           63012    1000959  2018  ...
# 1562            63083           63083           63083    1000959  2018  ...
# 1563            63119           63119           63119    1000959  2018  ...
# 1564            63161           63161           63161    1000959  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (269098, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41A_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 114

# %%
lwk = wk[(wk['LINEID'] == '114')]

# %%
lwk.shape
# Out:
# (44763, 22)

# %%
# Drop Route 114 rows from wk
wk.drop(wk[wk['LINEID'] == '114'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1639   2018-08-27  7508341            1         4595            27300
# 1640   2018-08-27  7508341            2         4596            27348
# 1641   2018-08-27  7508341            3         4563            27401
# 1642   2018-08-27  7508341            4         1218            27450
# 1643   2018-08-27  7508341            5         1258            27542
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1639            27300           27300           27300    3265721  2018  ...
# 1640            27348           27348           27348    3265721  2018  ...
# 1641            27401           27401           27401    3265721  2018  ...
# 1642            27450           27450           27450    3265721  2018  ...
# 1643            27542           27542           27542    3265721  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (224335, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_114_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 27X

# %%
lwk = wk[(wk['LINEID'] == '27X')]

# %%
lwk.shape
# Out:
# (8295, 22)

# %%
# Drop Route 27X rows from wk
wk.drop(wk[wk['LINEID'] == '27X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1730   2018-08-27  7508352            1         4795            23400
# 1731   2018-08-27  7508352            3         4688            23729
# 1732   2018-08-27  7508352            4         4689            23796
# 1733   2018-08-27  7508352            5         4410            23854
# 1734   2018-08-27  7508352            6         2678            23878
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1730            23400           23400           23400    1001162  2018  ...
# 1731            23729           23729           23729    1001162  2018  ...
# 1732            23796           23796           23796    1001162  2018  ...
# 1733            23854           23854           23854    1001162  2018  ...
# 1734            23878           23878           23878    1001162  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (216040, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 239

# %%
lwk = wk[(wk['LINEID'] == '239')]

# %%
lwk.shape
# Out:
# (37302, 22)

# %%
# Drop Route 239 rows from wk
wk.drop(wk[wk['LINEID'] == '239'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2501   2018-08-27  7509585            1          407            61200
# 2502   2018-08-27  7509585            2         2498            61264
# 2503   2018-08-27  7509585            3         2499            61314
# 2504   2018-08-27  7509585            4         2500            61395
# 2505   2018-08-27  7509585            5         2501            61497
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2501            61200           61200           61200    1000458  2018  ...
# 2502            61264           61264           61264    1000458  2018  ...
# 2503            61314           61314           61314    1000458  2018  ...
# 2504            61395           61395           61395    1000458  2018  ...
# 2505            61497           61497           61497    1000458  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (178738, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_239_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 33X

# %%
lwk = wk[(wk['LINEID'] == '33X')]

# %%
lwk.shape
# Out:
# (22448, 22)

# %%
# Drop Route 33X rows from wk
wk.drop(wk[wk['LINEID'] == '33X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2618   2018-08-27  7509772            1         7639            27000
# 2619   2018-08-27  7509772            2         7640            27051
# 2620   2018-08-27  7509772            3         5047            27112
# 2621   2018-08-27  7509772            4         3134            27152
# 2622   2018-08-27  7509772            5         3143            27266
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2618            27000           27000           27000    1000728  2018  ...
# 2619            27051           27051           27051    1000728  2018  ...
# 2620            27112           27112           27112    1000728  2018  ...
# 2621            27152           27152           27152    1000728  2018  ...
# 2622            27266           27266           27266    1000728  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (156290, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (50797, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3992   2018-08-27  7510589            1         3085            29100
# 3993   2018-08-27  7510589            2         3034            29209
# 3994   2018-08-27  7510589            3         3114            29340
# 3995   2018-08-27  7510589            4         4353            29426
# 3996   2018-08-27  7510589            5         4355            29460
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3992            29100           29100           29100    2172282  2018  ...
# 3993            29209           29209           29209    2172282  2018  ...
# 3994            29340           29340           29340    2172282  2018  ...
# 3995            29426           29426           29426    2172282  2018  ...
# 3996            29460           29460           29460    2172282  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (105493, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 46E

# %%
lwk = wk[(wk['LINEID'] == '46E')]

# %%
lwk.shape
# Out:
# (2923, 22)

# %%
# Drop Route 46E rows from wk
wk.drop(wk[wk['LINEID'] == '46E'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4299   2018-08-27  7511328            2         6186            27055
# 4300   2018-08-27  7511328            3         6216            27150
# 4301   2018-08-27  7511328            4         3400            27227
# 4302   2018-08-27  7511328            5         3401            27273
# 4303   2018-08-27  7511328            6         3402            27313
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4299            27055           27055           27055    1001099  2018  ...
# 4300            27150           27150           27150    1001099  2018  ...
# 4301            27227           27227           27227    1001099  2018  ...
# 4302            27273           27273           27273    1001099  2018  ...
# 4303            27313           27313           27313    1001099  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (102570, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_46E_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Route 68X

# %%
lwk = wk[(wk['LINEID'] == '68X')]

# %%
lwk.shape
# Out:
# (411, 22)

# %%
# Drop Route 68X rows from wk
wk.drop(wk[wk['LINEID'] == '68X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4399   2018-08-27  7511422            1         4168            26400
# 4400   2018-08-27  7511422            2         4170            26482
# 4401   2018-08-27  7511422            3         4153            26541
# 4402   2018-08-27  7511422            4         4154            26595
# 4403   2018-08-27  7511422            5         4416            26640
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4399            26400           26400           26400    2534806  2018  ...
# 4400            26482           26482           26482    2534806  2018  ...
# 4401            26541           26541           26541    2534806  2018  ...
# 4402            26595           26595           26595    2534806  2018  ...
# 4403            26640           26640           26640    2534806  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (102159, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68X_tripLeave5_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave5_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave5_route_split_8.csv', index=False)
