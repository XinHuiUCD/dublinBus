# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave1 route split 9 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_9.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (297685, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-02  5956888            2         7120            28154
# 1   2018-01-02  5956888            3         7119            28264
# 2   2018-01-02  5956888            4         7127            28354
# 3   2018-01-02  5956888            5         7143            28506
# 4   2018-01-02  5956888            6         7168            28789
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            28154           28154           28154    1000937  2018  ...
# 1            28264           28264           28264    1000937  2018  ...
# 2            28354           28354           28354    1000937  2018  ...
# 3            28506           28506           28506    1000937  2018  ...
# 4            28789           28789           28789    1000937  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-02  5956888            2         7120            28154
# 1   2018-01-02  5956888            3         7119            28264
# 2   2018-01-02  5956888            4         7127            28354
# 3   2018-01-02  5956888            5         7143            28506
# 4   2018-01-02  5956888            6         7168            28789
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            28154           28154           28154    1000937  2018  ...
# 1            28264           28264           28264    1000937  2018  ...
# 2            28354           28354           28354    1000937  2018  ...
# 3            28506           28506           28506    1000937  2018  ...
# 4            28789           28789           28789    1000937  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 25D

# %%
lwk = wk[(wk['LINEID'] == '25D')]

# %%
lwk.shape
# Out:
# (8624, 22)

# %%
# Drop Route 25D rows from wk
wk.drop(wk[wk['LINEID'] == '25D'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 28   2018-01-02  5957409            1         3815            26100
# 29   2018-01-02  5957409            2         3816            26127
# 30   2018-01-02  5957409            3         3566            26181
# 31   2018-01-02  5957409            4         3567            26229
# 32   2018-01-02  5957409            5         7292            26305
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 28            26100           26100           26100    1000337  2018  ...
# 29            26127           26127           26127    1000337  2018  ...
# 30            26181           26181           26181    1000337  2018  ...
# 31            26229           26229           26229    1000337  2018  ...
# 32            26305           26305           26305    1000337  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (289061, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25D_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 33X

# %%
lwk = wk[(wk['LINEID'] == '33X')]

# %%
lwk.shape
# Out:
# (21564, 22)

# %%
# Drop Route 33X rows from wk
wk.drop(wk[wk['LINEID'] == '33X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 148   2018-01-02  5957587            1         4713            26400
# 149   2018-01-02  5957587            2         4714            26495
# 150   2018-01-02  5957587            3         4960            26537
# 151   2018-01-02  5957587            4         4932            26603
# 152   2018-01-02  5957587            5         4933            26618
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 148            26400           26400           26400    2534792  2018  ...
# 149            26495           26495           26495    2534792  2018  ...
# 150            26537           26537           26537    2534792  2018  ...
# 151            26603           26603           26603    2534792  2018  ...
# 152            26618           26618           26618    2534792  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (267497, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33X_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 77X

# %%
lwk = wk[(wk['LINEID'] == '77X')]

# %%
lwk.shape
# Out:
# (2487, 22)

# %%
# Drop Route 77X rows from wk
wk.drop(wk[wk['LINEID'] == '77X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 212   2018-01-02  5957818           17         2968            38719
# 213   2018-01-02  5957818           18         2969            38739
# 214   2018-01-02  5957818           19         2970            38760
# 215   2018-01-02  5957818           20         4988            38807
# 216   2018-01-02  5957818           21         4707            38876
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 212            38719           38719           38719    2868383  2018  ...
# 213            38739           38739           38739    2868383  2018  ...
# 214            38760           38760           38760    2868383  2018  ...
# 215            38807           38807           38807    2868383  2018  ...
# 216            38876           38876           38876    2868383  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (265010, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77X_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 161

# %%
lwk = wk[(wk['LINEID'] == '161')]

# %%
lwk.shape
# Out:
# (3235, 22)

# %%
# Drop Route 161 rows from wk
wk.drop(wk[wk['LINEID'] == '161'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 227   2018-01-02  5957959            1         7639            23400
# 228   2018-01-02  5957959            2         7640            23458
# 229   2018-01-02  5957959            3         5047            23528
# 230   2018-01-02  5957959            4         3134            23564
# 231   2018-01-02  5957959            5         3143            23666
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 227            23400           23400           23400    1001078  2018  ...
# 228            23458           23458           23458    1001078  2018  ...
# 229            23528           23528           23528    1001078  2018  ...
# 230            23564           23564           23564    1001078  2018  ...
# 231            23666           23666           23666    1001078  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (261775, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_161_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (69819, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1024   2018-01-02  5958313            1          877            43200
# 1025   2018-01-02  5958313            2          876            43348
# 1026   2018-01-02  5958313            3         3011            43441
# 1027   2018-01-02  5958313            4         2896            43475
# 1028   2018-01-02  5958313            5         2897            43505
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1024            43200           43200           43200    2534805  2018  ...
# 1025            43348           43348           43348    2534805  2018  ...
# 1026            43441           43441           43441    2534805  2018  ...
# 1027            43475           43475           43475    2534805  2018  ...
# 1028            43505           43505           43505    2534805  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (191956, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (22503, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1228   2018-01-02  5959019            1         3544            27900
# 1229   2018-01-02  5959019            2         3552            27965
# 1230   2018-01-02  5959019            3         3553            27999
# 1231   2018-01-02  5959019            4         3554            28074
# 1232   2018-01-02  5959019            5         3555            28129
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1228            27900           27900           27900    2693219  2018  ...
# 1229            27965           27965           27965    2693219  2018  ...
# 1230            27999           27999           27999    2693219  2018  ...
# 1231            28074           28074           28074    2693219  2018  ...
# 1232            28129           28129           28129    2693219  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (169453, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 7B

# %%
lwk = wk[(wk['LINEID'] == '7B')]

# %%
lwk.shape
# Out:
# (18621, 22)

# %%
# Drop Route 7B rows from wk
wk.drop(wk[wk['LINEID'] == '7B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1286   2018-01-02  5959078            1         7158            26100
# 1287   2018-01-02  5959078            2         7048            26147
# 1288   2018-01-02  5959078            3         7159            26225
# 1289   2018-01-02  5959078            4         7017            26358
# 1290   2018-01-02  5959078            5         7018            26415
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1286            26100           26100           26100    1001200  2018  ...
# 1287            26147           26147           26147    1001200  2018  ...
# 1288            26225           26225           26225    1001200  2018  ...
# 1289            26358           26358           26358    1001200  2018  ...
# 1290            26415           26415           26415    1001200  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (150832, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7B_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 39X

# %%
lwk = wk[(wk['LINEID'] == '39X')]

# %%
lwk.shape
# Out:
# (6482, 22)

# %%
# Drop Route 39X rows from wk
wk.drop(wk[wk['LINEID'] == '39X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1312   2018-01-02  5959207            1          928            27900
# 1313   2018-01-02  5959207            2          929            27933
# 1314   2018-01-02  5959207            3          930            27997
# 1315   2018-01-02  5959207            4          931            28080
# 1316   2018-01-02  5959207            5          587            28179
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1312            27900           27900           27900    1000199  2018  ...
# 1313            27933           27933           27933    1000199  2018  ...
# 1314            27997           27997           27997    1000199  2018  ...
# 1315            28080           28080           28080    1000199  2018  ...
# 1316            28179           28179           28179    1000199  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (144350, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39X_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 31D

# %%
lwk = wk[(wk['LINEID'] == '31D')]

# %%
lwk.shape
# Out:
# (2788, 22)

# %%
# Drop Route 31D rows from wk
wk.drop(wk[wk['LINEID'] == '31D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1433   2018-01-02  5959704            1         4168            26400
# 1434   2018-01-02  5959704            2         4170            26483
# 1435   2018-01-02  5959704            3         4153            26542
# 1436   2018-01-02  5959704            4         4154            26596
# 1437   2018-01-02  5959704            5         4416            26640
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1433            26400           26400           26400    2406872  2018  ...
# 1434            26483           26483           26483    2406872  2018  ...
# 1435            26542           26542           26542    2406872  2018  ...
# 1436            26596           26596           26596    2406872  2018  ...
# 1437            26640           26640           26640    2406872  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (141562, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31D_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 84A

# %%
lwk = wk[(wk['LINEID'] == '84A')]

# %%
lwk.shape
# Out:
# (22908, 22)

# %%
# Drop Route 84A rows from wk
wk.drop(wk[wk['LINEID'] == '84A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1958   2018-01-02  5960544            1         3640            27600
# 1959   2018-01-02  5960544            2         3574            27683
# 1960   2018-01-02  5960544            3         3641            27780
# 1961   2018-01-02  5960544            4         3642            27825
# 1962   2018-01-02  5960544            5         3643            27977
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1958            27600           27600           27600    2172295  2018  ...
# 1959            27683           27683           27683    2172295  2018  ...
# 1960            27780           27780           27780    2172295  2018  ...
# 1961            27825           27825           27825    2172295  2018  ...
# 1962            27977           27977           27977    2172295  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (118654, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84A_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 32X

# %%
lwk = wk[(wk['LINEID'] == '32X')]

# %%
lwk.shape
# Out:
# (5589, 22)

# %%
# Drop Route 32X rows from wk
wk.drop(wk[wk['LINEID'] == '32X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2002   2018-01-02  5960640            1         4564            27000
# 2003   2018-01-02  5960640            2         3444            27080
# 2004   2018-01-02  5960640            3         3447            27182
# 2005   2018-01-02  5960640            4         3454            27416
# 2006   2018-01-02  5960640            5         3455            27506
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2002            27000           27000           27000    2693290  2018  ...
# 2003            27080           27080           27080    2693290  2018  ...
# 2004            27182           27182           27182    2693290  2018  ...
# 2005            27416           27416           27416    2693290  2018  ...
# 2006            27506           27506           27506    2693290  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (113065, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32X_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 69X

# %%
lwk = wk[(wk['LINEID'] == '69X')]

# %%
lwk.shape
# Out:
# (1416, 22)

# %%
# Drop Route 69X rows from wk
wk.drop(wk[wk['LINEID'] == '69X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3073   2018-01-02  5963181            1         3514            29700
# 3074   2018-01-02  5963181            2         3515            29780
# 3075   2018-01-02  5963181            3         3516            29812
# 3076   2018-01-02  5963181            4         3517            29869
# 3077   2018-01-02  5963181            5         3518            29903
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3073            29700           29700           29700    2868388  2018  ...
# 3074            29780           29780           29780    2868388  2018  ...
# 3075            29812           29812           29812    2868388  2018  ...
# 3076            29869           29869           29869    2868388  2018  ...
# 3077            29903           29903           29903    2868388  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (111649, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_69X_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 44B

# %%
lwk = wk[(wk['LINEID'] == '44B')]

# %%
lwk.shape
# Out:
# (10310, 22)

# %%
# Drop Route 44B rows from wk
wk.drop(wk[wk['LINEID'] == '44B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3314   2018-01-02  5963804            1          557            28800
# 3315   2018-01-02  5963804            2          558            28826
# 3316   2018-01-02  5963804            3          559            28880
# 3317   2018-01-02  5963804            4          560            28919
# 3318   2018-01-02  5963804            5          562            29007
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3314            28800           28800           28800    1001070  2018  ...
# 3315            28826           28826           28826    1001070  2018  ...
# 3316            28880           28880           28880    1001070  2018  ...
# 3317            28919           28919           28919    1001070  2018  ...
# 3318            29007           29007           29007    1001070  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (101339, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44B_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 31B

# %%
lwk = wk[(wk['LINEID'] == '31B')]

# %%
lwk.shape
# Out:
# (19567, 22)

# %%
# Drop Route 31B rows from wk
wk.drop(wk[wk['LINEID'] == '31B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3511   2018-01-02  5963829            1         4843            27600
# 3512   2018-01-02  5963829            2         4905            27665
# 3513   2018-01-02  5963829            4         4906            27727
# 3514   2018-01-02  5963829            5         4907            27772
# 3515   2018-01-02  5963829            6         4908            27801
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3511            27600           27600           27600    1001238  2018  ...
# 3512            27665           27665           27665    1001238  2018  ...
# 3513            27727           27727           27727    1001238  2018  ...
# 3514            27772           27772           27772    1001238  2018  ...
# 3515            27801           27801           27801    1001238  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (81772, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31B_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Route 41A

# %%
lwk = wk[(wk['LINEID'] == '41A')]

# %%
lwk.shape
# Out:
# (4326, 22)

# %%
# Drop Route 41A rows from wk
wk.drop(wk[wk['LINEID'] == '41A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3619   2018-01-02  5964210            1         4664            27000
# 3620   2018-01-02  5964210            2         2160            27058
# 3621   2018-01-02  5964210            3         4665            27099
# 3622   2018-01-02  5964210            4         4666            27143
# 3623   2018-01-02  5964210            5         4667            27179
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3619            27000           27000           27000    1932306  2018  ...
# 3620            27058           27058           27058    1932306  2018  ...
# 3621            27099           27099           27099    1932306  2018  ...
# 3622            27143           27143           27143    1932306  2018  ...
# 3623            27179           27179           27179    1932306  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (77446, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41A_tripLeave1_sp9.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave1_route_split_9a

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave1_route_split_9a.csv', index=False)
