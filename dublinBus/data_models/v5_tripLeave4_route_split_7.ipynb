# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (1815999, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-25  7110895            1         4745            29760
# 1   2018-06-25  7110895            2         4989            29783
# 2   2018-06-25  7110895            3         4990            29891
# 3   2018-06-25  7110895            4         4991            29911
# 4   2018-06-25  7110895            5         4992            29941
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            29760           29760           29760    1001213  2018  ...
# 1            29783           29783           29783    1001213  2018  ...
# 2            29891           29891           29891    1001213  2018  ...
# 3            29911           29911           29911    1001213  2018  ...
# 4            29941           29941           29941    1001213  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 38B

# %%
lwk = wk[(wk['LINEID'] == '38B')]

# %%
lwk.shape
# Out:
# (22943, 22)

# %%
# Drop Route 38B rows from wk
wk.drop(wk[wk['LINEID'] == '38B'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 51   2018-06-25  7111014           15         4983            34928
# 52   2018-06-25  7111014           16         7648            34952
# 53   2018-06-25  7111014           18         2043            35122
# 54   2018-06-25  7111014           19         2044            35151
# 55   2018-06-25  7111014           20         2045            35185
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 51            34928           34928           34928    1930281  2018  ...
# 52            34952           34952           34952    1930281  2018  ...
# 53            35122           35122           35122    1930281  2018  ...
# 54            35151           35151           35151    1930281  2018  ...
# 55            35185           35185           35185    1930281  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1793056, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38B_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 111

# %%
lwk = wk[(wk['LINEID'] == '111')]

# %%
lwk.shape
# Out:
# (74110, 22)

# %%
# Drop Route 111 rows from wk
wk.drop(wk[wk['LINEID'] == '111'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 693   2018-06-25  7111067            1         7158            26100
# 694   2018-06-25  7111067            2         7048            26140
# 695   2018-06-25  7111067            3         7159            26206
# 696   2018-06-25  7111067            4         7017            26319
# 697   2018-06-25  7111067            5         7018            26367
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 693            26100           26100           26100    1000111  2018  ...
# 694            26140           26140           26140    1000111  2018  ...
# 695            26206           26206           26206    1000111  2018  ...
# 696            26319           26319           26319    1000111  2018  ...
# 697            26367           26367           26367    1000111  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1718946, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_111_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 39X

# %%
lwk = wk[(wk['LINEID'] == '39X')]

# %%
lwk.shape
# Out:
# (5349, 22)

# %%
# Drop Route 39X rows from wk
wk.drop(wk[wk['LINEID'] == '39X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 743   2018-06-25  7111127            1         4713            26400
# 744   2018-06-25  7111127            2         4714            26436
# 745   2018-06-25  7111127            3         4960            26470
# 746   2018-06-25  7111127            4         4932            26523
# 747   2018-06-25  7111127            5         4933            26535
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 743            26400           26400           26400    1932331  2018  ...
# 744            26436           26436           26436    1932331  2018  ...
# 745            26470           26470           26470    1932331  2018  ...
# 746            26523           26523           26523    1932331  2018  ...
# 747            26535           26535           26535    1932331  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1713597, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39X_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 77X

# %%
lwk = wk[(wk['LINEID'] == '77X')]

# %%
lwk.shape
# Out:
# (2781, 22)

# %%
# Drop Route 77X rows from wk
wk.drop(wk[wk['LINEID'] == '77X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 808   2018-06-25  7111128            1         4595            27300
# 809   2018-06-25  7111128            2         4596            27344
# 810   2018-06-25  7111128            3         4563            27393
# 811   2018-06-25  7111128            4         1218            27438
# 812   2018-06-25  7111128            5         1258            27525
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 808            27300           27300           27300    2868355  2018  ...
# 809            27344           27344           27344    2868355  2018  ...
# 810            27393           27393           27393    2868355  2018  ...
# 811            27438           27438           27438    2868355  2018  ...
# 812            27525           27525           27525    2868355  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1710816, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77X_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 27X

# %%
lwk = wk[(wk['LINEID'] == '27X')]

# %%
lwk.shape
# Out:
# (7509, 22)

# %%
# Drop Route 27X rows from wk
wk.drop(wk[wk['LINEID'] == '27X'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 899   2018-06-25  7111150            1         4168            25200
# 900   2018-06-25  7111150            2         4170            25266
# 901   2018-06-25  7111150            3         4132            25312
# 902   2018-06-25  7111150            4         4134            25392
# 903   2018-06-25  7111150            5         4135            25444
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 899            25200           25200           25200    2868330  2018  ...
# 900            25266           25266           25266    2868330  2018  ...
# 901            25312           25312           25312    2868330  2018  ...
# 902            25392           25392           25392    2868330  2018  ...
# 903            25444           25444           25444    2868330  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1703307, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27X_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (139055, 22)

# %%
# Drop Route 184 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1565   2018-06-25  7111328            1          621            62400
# 1566   2018-06-25  7111328            2          289            62643
# 1567   2018-06-25  7111328            3          496            62846
# 1568   2018-06-25  7111328            4         7490            62884
# 1569   2018-06-25  7111328            5          515            63031
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1565            62400           62400           62400    2172296  2018  ...
# 1566            62643           62643           62643    2172296  2018  ...
# 1567            62846           62846           62846    2172296  2018  ...
# 1568            62884           62884           62884    2172296  2018  ...
# 1569            63031           63031           63031    2172296  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1564252, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 31B

# %%
lwk = wk[(wk['LINEID'] == '31B')]

# %%
lwk.shape
# Out:
# (21217, 22)

# %%
# Drop Route 31B rows from wk
wk.drop(wk[wk['LINEID'] == '31B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1633   2018-06-25  7111457            1         4863            24000
# 1634   2018-06-25  7111457            2         4864            24032
# 1635   2018-06-25  7111457            3         4865            24055
# 1636   2018-06-25  7111457            4         4577            24079
# 1637   2018-06-25  7111457            5         4578            24121
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1633            24000           24000           24000    1001174  2018  ...
# 1634            24032           24032           24032    1001174  2018  ...
# 1635            24055           24055           24055    1001174  2018  ...
# 1636            24079           24079           24079    1001174  2018  ...
# 1637            24121           24121           24121    1001174  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1543035, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31B_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 150

# %%
lwk = wk[(wk['LINEID'] == '150')]

# %%
lwk.shape
# Out:
# (172999, 22)

# %%
# Drop Route 150 rows from wk
wk.drop(wk[wk['LINEID'] == '150'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2253   2018-06-25  7111574            1         7026            24000
# 2254   2018-06-25  7111574            3         2960            24181
# 2255   2018-06-25  7111574            4         1840            24401
# 2256   2018-06-25  7111574            5         1841            24439
# 2257   2018-06-25  7111574            6         1842            24490
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2253            24000           24000           24000    2172257  2018  ...
# 2254            24181           24181           24181    2172257  2018  ...
# 2255            24401           24401           24401    2172257  2018  ...
# 2256            24439           24439           24439    2172257  2018  ...
# 2257            24490           24490           24490    2172257  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1370036, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_150_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 76A

# %%
lwk = wk[(wk['LINEID'] == '76A')]

# %%
lwk.shape
# Out:
# (8756, 22)

# %%
# Drop Route 76A rows from wk
wk.drop(wk[wk['LINEID'] == '76A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2294   2018-06-25  7111717            1         7158            29520
# 2295   2018-06-25  7111717            2         7048            29563
# 2296   2018-06-25  7111717            3         7159            29635
# 2297   2018-06-25  7111717            4         7388            29655
# 2298   2018-06-25  7111717            5         7017            29759
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2294            29520           29520           29520    1000888  2018  ...
# 2295            29563           29563           29563    1000888  2018  ...
# 2296            29635           29635           29635    1000888  2018  ...
# 2297            29655           29655           29655    1000888  2018  ...
# 2298            29759           29759           29759    1000888  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1361280, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76A_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 39

# %%
lwk = wk[(wk['LINEID'] == '39')]

# %%
lwk.shape
# Out:
# (273993, 22)

# %%
# Drop Route 39 rows from wk
wk.drop(wk[wk['LINEID'] == '39'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2372   2018-06-25  7111759            1         1375            29700
# 2373   2018-06-25  7111759            2         1376            29779
# 2374   2018-06-25  7111759            3         1377            29876
# 2375   2018-06-25  7111759            4         1378            29957
# 2376   2018-06-25  7111759            5         1379            30051
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2372            29700           29700           29700    2868345  2018  ...
# 2373            29779           29779           29779    2868345  2018  ...
# 2374            29876           29876           29876    2868345  2018  ...
# 2375            29957           29957           29957    2868345  2018  ...
# 2376            30051           30051           30051    2868345  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1087287, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 68A

# %%
lwk = wk[(wk['LINEID'] == '68A')]

# %%
lwk.shape
# Out:
# (3626, 22)

# %%
# Drop Route 68A rows from wk
wk.drop(wk[wk['LINEID'] == '68A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3117   2018-06-25  7111909            1          877            63300
# 3118   2018-06-25  7111909            2          876            63446
# 3119   2018-06-25  7111909            3         3011            63537
# 3120   2018-06-25  7111909            4         2896            63570
# 3121   2018-06-25  7111909            5         2897            63615
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3117            63300           63300           63300    1000259  2018  ...
# 3118            63446           63446           63446    1000259  2018  ...
# 3119            63537           63537           63537    1000259  2018  ...
# 3120            63570           63570           63570    1000259  2018  ...
# 3121            63615           63615           63615    1000259  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1083661, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_68A_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (21917, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3166   2018-06-25  7111945            1         3815            27000
# 3167   2018-06-25  7111945            2         3816            27021
# 3168   2018-06-25  7111945            3         3566            27063
# 3169   2018-06-25  7111945            4         3567            27101
# 3170   2018-06-25  7111945            5         7292            27161
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3166            27000           27000           27000    1000764  2018  ...
# 3167            27021           27021           27021    1000764  2018  ...
# 3168            27063           27063           27063    1000764  2018  ...
# 3169            27101           27101           27101    1000764  2018  ...
# 3170            27161           27161           27161    1000764  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1061744, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 33X

# %%
lwk = wk[(wk['LINEID'] == '33X')]

# %%
lwk.shape
# Out:
# (22605, 22)

# %%
# Drop Route 33X rows from wk
wk.drop(wk[wk['LINEID'] == '33X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3285   2018-06-25  7112015            1         4003            44100
# 3286   2018-06-25  7112015            2         4404            44200
# 3287   2018-06-25  7112015            3         4405            44241
# 3288   2018-06-25  7112015            4         3991            44331
# 3289   2018-06-25  7112015            5         3998            44481
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3285            44100           44100           44100    1001139  2018  ...
# 3286            44200           44200           44200    1001139  2018  ...
# 3287            44241           44241           44241    1001139  2018  ...
# 3288            44331           44331           44331    1001139  2018  ...
# 3289            44481           44481           44481    1001139  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1039139, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_33X_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 66B

# %%
lwk = wk[(wk['LINEID'] == '66B')]

# %%
lwk.shape
# Out:
# (76279, 22)

# %%
# Drop Route 66B rows from wk
wk.drop(wk[wk['LINEID'] == '66B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3330   2018-06-25  7112404            1         4843            27000
# 3331   2018-06-25  7112404            2         4905            27043
# 3332   2018-06-25  7112404            4         4906            27085
# 3333   2018-06-25  7112404            5         4907            27115
# 3334   2018-06-25  7112404            6         4908            27134
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3330            27000           27000           27000    1000261  2018  ...
# 3331            27043           27043           27043    1000261  2018  ...
# 3332            27085           27085           27085    1000261  2018  ...
# 3333            27115           27115           27115    1000261  2018  ...
# 3334            27134           27134           27134    1000261  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (962860, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66B_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 41X

# %%
lwk = wk[(wk['LINEID'] == '41X')]

# %%
lwk.shape
# Out:
# (14451, 22)

# %%
# Drop Route 41X rows from wk
wk.drop(wk[wk['LINEID'] == '41X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3953   2018-06-25  7112775           14         2965            27900
# 3954   2018-06-25  7112775           15         2983            28011
# 3955   2018-06-25  7112775           16         2984            28140
# 3956   2018-06-25  7112775           17         7449            28188
# 3957   2018-06-25  7112775           18         2941            28260
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3953            27900           27900           27900    2406880  2018  ...
# 3954            28011           28011           28011    2406880  2018  ...
# 3955            28140           28140           28140    2406880  2018  ...
# 3956            28188           28188           28188    2406880  2018  ...
# 3957            28260           28260           28260    2406880  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (948409, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41X_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 61

# %%
lwk = wk[(wk['LINEID'] == '61')]

# %%
lwk.shape
# Out:
# (88820, 22)

# %%
# Drop Route 61 rows from wk
wk.drop(wk[wk['LINEID'] == '61'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4048   2018-06-25  7112792            1         4795            23400
# 4049   2018-06-25  7112792            3         4688            23570
# 4050   2018-06-25  7112792            4         4689            23604
# 4051   2018-06-25  7112792            5         4410            23634
# 4052   2018-06-25  7112792            6         2678            23657
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4048            23400           23400           23400    2693195  2018  ...
# 4049            23570           23570           23570    2693195  2018  ...
# 4050            23604           23604           23604    2693195  2018  ...
# 4051            23634           23634           23634    2693195  2018  ...
# 4052            23657           23657           23657    2693195  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (859589, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_61_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 239

# %%
lwk = wk[(wk['LINEID'] == '239')]

# %%
lwk.shape
# Out:
# (33495, 22)

# %%
# Drop Route 239 rows from wk
wk.drop(wk[wk['LINEID'] == '239'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4446   2018-06-25  7112967            1         3283            22500
# 4447   2018-06-25  7112967            2         3284            22538
# 4448   2018-06-25  7112967            3         3285            22618
# 4449   2018-06-25  7112967            4         7324            22673
# 4450   2018-06-25  7112967            5         5106            22786
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4446            22500           22500           22500    1000792  2018  ...
# 4447            22538           22538           22538    1000792  2018  ...
# 4448            22618           22618           22618    1000792  2018  ...
# 4449            22673           22673           22673    1000792  2018  ...
# 4450            22786           22786           22786    1000792  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (826094, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_239_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 63

# %%
lwk = wk[(wk['LINEID'] == '63')]

# %%
lwk.shape
# Out:
# (119789, 22)

# %%
# Drop Route 63 rows from wk
wk.drop(wk[wk['LINEID'] == '63'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6309   2018-06-25  7113382            1          326            53100
# 6310   2018-06-25  7113382            2         1443            53204
# 6311   2018-06-25  7113382            3         1444            53261
# 6312   2018-06-25  7113382            4         1445            53324
# 6313   2018-06-25  7113382            5         4407            53407
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6309            53100           53100           53100    2172300  2018  ...
# 6310            53204           53204           53204    2172300  2018  ...
# 6311            53261           53261           53261    2172300  2018  ...
# 6312            53324           53324           53324    2172300  2018  ...
# 6313            53407           53407           53407    2172300  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (706305, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_63_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 79A

# %%
lwk = wk[(wk['LINEID'] == '79A')]

# %%
lwk.shape
# Out:
# (89359, 22)

# %%
# Drop Route 79A rows from wk
wk.drop(wk[wk['LINEID'] == '79A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6623   2018-06-25  7113970            2         7142            24370
# 6624   2018-06-25  7113970            3         7015            24448
# 6625   2018-06-25  7113970            4         4617            24520
# 6626   2018-06-25  7113970            5         4555            24538
# 6627   2018-06-25  7113970            6         4576            24611
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6623            24370           24370           24370    2534837  2018  ...
# 6624            24448           24448           24448    2534837  2018  ...
# 6625            24520           24520           24520    2534837  2018  ...
# 6626            24538           24538           24538    2534837  2018  ...
# 6627            24611           24611           24611    2534837  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (616946, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79A_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Route 151

# %%
lwk = wk[(wk['LINEID'] == '151')]

# %%
lwk.shape
# Out:
# (243964, 22)

# %%
# Drop Route 151 rows from wk
wk.drop(wk[wk['LINEID'] == '151'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6925   2018-06-25  7114063            1         7333            27600
# 6926   2018-06-25  7114063            2          783            27729
# 6927   2018-06-25  7114063            3          784            27763
# 6928   2018-06-25  7114063            4          785            27821
# 6929   2018-06-25  7114063            5          786            27927
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6925            27600           27600           27600    2406866  2018  ...
# 6926            27729           27729           27729    2406866  2018  ...
# 6927            27763           27763           27763    2406866  2018  ...
# 6928            27821           27821           27821    2406866  2018  ...
# 6929            27927           27927           27927    2406866  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (372982, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_151_tripLeave4_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_8.csv', index=False)
