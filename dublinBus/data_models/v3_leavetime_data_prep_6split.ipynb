# %%
# Library Imports.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

# Allows plots to appear directly in the notebook.
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

# %%
chunk = pd.read_csv('v2_dtypes_LT_2018.csv', delimiter = ',',chunksize=1000000)

leave = pd.concat(chunk)

# %%
leave.head()
# Out:
#          DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0  01-JAN-18 00:00:00  5972116           12          119            48030
# 1  01-JAN-18 00:00:00  5966674           12          119            54001
# 2  01-JAN-18 00:00:00  5959105           12          119            60001
# 3  01-JAN-18 00:00:00  5966888           12          119            58801
# 4  01-JAN-18 00:00:00  5965960           12          119            56401
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID
# 0            48030           48030           48030    2693211
# 1            54001           54001           54001    2693267
# 2            60001           60001           60001    2693263
# 3            58801           58801           58801    2693284
# 4            56401           56401           56401    2693209

# %%
leave.shape
# Out:
# (116360526, 9)

# %%
leave.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# dtype: object

# %% [markdown]
# <h3>Changing Data Types to make size of leave dataframe smaller</h3>

# %%
leave['TRIPID'] = leave['TRIPID'].astype('int32')

# %%
leave['PROGRNUMBER'] = leave['PROGRNUMBER'].astype('int16')

# %%
leave['STOPPOINTID'] = leave['STOPPOINTID'].astype('int16')

# %%
leave['PLANNEDTIME_ARR'] = leave['PLANNEDTIME_ARR'].astype('int32')

# %%
leave['PLANNEDTIME_DEP'] = leave['PLANNEDTIME_DEP'].astype('int32')

# %%
leave['ACTUALTIME_ARR'] = leave['PLANNEDTIME_DEP'].astype('int32')

# %%
leave['ACTUALTIME_DEP'] = leave['PLANNEDTIME_DEP'].astype('int32')

# %%
leave['VEHICLEID'] = leave['VEHICLEID'].astype('int32')

# %%
leave.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int32
# PROGRNUMBER         int16
# STOPPOINTID         int16
# PLANNEDTIME_ARR     int32
# PLANNEDTIME_DEP     int32
# ACTUALTIME_ARR      int32
# ACTUALTIME_DEP      int32
# VEHICLEID           int32
# dtype: object

# %%
leave.head()
# Out:
#          DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0  01-JAN-18 00:00:00  5972116           12          119            48030
# 1  01-JAN-18 00:00:00  5966674           12          119            54001
# 2  01-JAN-18 00:00:00  5959105           12          119            60001
# 3  01-JAN-18 00:00:00  5966888           12          119            58801
# 4  01-JAN-18 00:00:00  5965960           12          119            56401
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID
# 0            48030           48030           48030    2693211
# 1            54001           54001           54001    2693267
# 2            60001           60001           60001    2693263
# 3            58801           58801           58801    2693284
# 4            56401           56401           56401    2693209

# %% [markdown]
# ## Sort the dataframe by Trip ID

# %%
leave_sort = leave.sort_values('TRIPID')

# %%
leave_sort.shape
# Out:
# (116360526, 9)

# %%
leave_sort.head()
# Out:
#                DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 1580830  06-JAN-18 00:00:00  5955221           69         2861
# 1578400  06-JAN-18 00:00:00  5955221           65         2857
# 9777438  06-JAN-18 00:00:00  5955221           74         2865
# 1572261  06-JAN-18 00:00:00  5955221           52         1045
# 1578368  06-JAN-18 00:00:00  5955221           64         2856
#
#          PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 1580830            42184            42184           42184           42184
# 1578400            42001            42001           42001           42001
# 9777438            42457            42457           42457           42457
# 1572261            41336            41336           41336           41336
# 1578368            41956            41956           41956           41956
#
#          VEHICLEID
# 1580830    2693254
# 1578400    2693254
# 9777438    2693254
# 1572261    2693254
# 1578368    2693254

# %% [markdown]
# ## Splitting the Sorted Dataframe into Five Dataframes

# %%
leave1, leave2, leave3, leave4, leave5, leave6 = np.array_split(leave_sort, 6)

# %%
leave1.shape
# Out:
# (19393421, 9)

# %%
leave1.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 18749270  26-FEB-18 00:00:00  6288438           10         4692
# 18081673  28-FEB-18 00:00:00  6288438           82         2622
# 18253354  28-FEB-18 00:00:00  6288438           38          619
# 17818731  27-FEB-18 00:00:00  6288438            5         1258
# 18232791  28-FEB-18 00:00:00  6288438           29          665
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 18749270            26244            26244           26244           26244
# 18081673            31943            31943           31943           31943
# 18253354            27948            27948           27948           27948
# 17818731            26035            26035           26035           26035
# 18232791            27305            27305           27305           27305
#
#           VEHICLEID
# 18749270    2868356
# 18081673    1932364
# 18253354    1932364
# 17818731    2868356
# 18232791    1932364

# %%
leave2.shape
# Out:
# (19393421, 9)

# %%
leave2.head()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 19870167  28-FEB-18 00:00:00  6288438           62         2332
# 18343791  27-FEB-18 00:00:00  6288438           52         1406
# 18731627  26-FEB-18 00:00:00  6288438            5         1258
# 18306170  27-FEB-18 00:00:00  6288438           87         2669
# 18262240  28-FEB-18 00:00:00  6288438           42         4495
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 19870167            30444            30444           30444           30444
# 18343791            29759            29759           29759           29759
# 18731627            26035            26035           26035           26035
# 18306170            32127            32127           32127           32127
# 18262240            28659            28659           28659           28659
#
#           VEHICLEID
# 19870167    1932364
# 18343791    2868356
# 18731627    2868356
# 18306170    2868356
# 18262240    1932364

# %%
leave2.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 37491553  30-APR-18 00:00:00  6651088            8         2676
# 44644531  04-MAY-18 00:00:00  6651088           30         1989
# 44001571  02-MAY-18 00:00:00  6651088           32         1992
# 38832489  30-APR-18 00:00:00  6651088           79          987
# 43598285  01-MAY-18 00:00:00  6651088           62         1595
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 37491553            27350            27350           27350           27350
# 44644531            28628            28628           28628           28628
# 44001571            28787            28787           28787           28787
# 38832489            32378            32378           32378           32378
# 43598285            31483            31483           31483           31483
#
#           VEHICLEID
# 37491553    2172259
# 44644531    2693290
# 44001571    2868347
# 38832489    2172259
# 43598285    2172300

# %%
leave3.shape
# Out:
# (19393421, 9)

# %%
leave3.head()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 37497811  30-APR-18 00:00:00  6651088           12         2121
# 44015990  02-MAY-18 00:00:00  6651088           27         2716
# 43602310  01-MAY-18 00:00:00  6651088           67         1599
# 44271498  03-MAY-18 00:00:00  6651088            1         4795
# 37516259  30-APR-18 00:00:00  6651088           34         1994
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 37497811            27558            27558           27558           27558
# 44015990            28392            28392           28392           28392
# 43602310            31698            31698           31698           31698
# 44271498            27000            27000           27000           27000
# 37516259            28980            28980           28980           28980
#
#           VEHICLEID
# 37497811    2172259
# 44015990    2868347
# 43602310    2172300
# 44271498    1932309
# 37516259    2172259

# %%
leave3.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 56599825  27-JUN-18 00:00:00  7110198           30          762
# 56623323  27-JUN-18 00:00:00  7110198            5          811
# 57404784  29-JUN-18 00:00:00  7110198           36          435
# 58879315  28-JUN-18 00:00:00  7110198           53         2031
# 57629768  29-JUN-18 00:00:00  7110198           24          756
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 56599825            42211            42211           42211           42211
# 56623323            40004            40004           40004           40004
# 57404784            42551            42551           42551           42551
# 58879315            43473            43473           43473           43473
# 57629768            41820            41820           41820           41820
#
#           VEHICLEID
# 56599825    1000582
# 56623323    1000582
# 57404784    1000296
# 58879315    1000578
# 57629768    1000296

# %%
leave4.shape
# Out:
# (19393421, 9)

# %%
leave4.head()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 56345236  26-JUN-18 00:00:00  7110198           48         2021
# 58916136  27-JUN-18 00:00:00  7110198           14         6059
# 56345138  26-JUN-18 00:00:00  7110198           33         2008
# 58890403  29-JUN-18 00:00:00  7110198            4          810
# 56807793  27-JUN-18 00:00:00  7110198           20          846
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 56345236            43116            43116           43116           43116
# 58916136            40745            40745           40745           40745
# 56345138            42380            42380           42380           42380
# 58890403            39962            39962           39962           39962
# 56807793            41588            41588           41588           41588
#
#           VEHICLEID
# 56345236    1000302
# 58916136    1000582
# 56345138    1000302
# 58890403    1000296
# 56807793    1000582

# %%
leave4.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 76131694  27-AUG-18 00:00:00  7502493            3          229
# 77843761  31-AUG-18 00:00:00  7502493           11         4432
# 76906162  29-AUG-18 00:00:00  7502493           38         2804
# 77848485  31-AUG-18 00:00:00  7502493           16           46
# 76476803  28-AUG-18 00:00:00  7502493            8         1642
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 76131694            54117            54117           54117           54117
# 77843761            54591            54591           54591           54591
# 76906162            57009            57009           57009           57009
# 77848485            54812            54812           54812           54812
# 76476803            54456            54456           54456           54456
#
#           VEHICLEID
# 76131694    1932370
# 77843761    1932370
# 76906162    1932370
# 77848485    1932370
# 76476803    1932370

# %%
leave5.shape
# Out:
# (19393421, 9)

# %%
leave5.head()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 76491067  28-AUG-18 00:00:00  7502493           14         7603
# 76322295  27-AUG-18 00:00:00  7502493           17           47
# 76510200  28-AUG-18 00:00:00  7502493           25          350
# 76329266  28-AUG-18 00:00:00  7502493            5          230
# 76117608  27-AUG-18 00:00:00  7502493           33          390
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 76491067            54710            54710           54710           54710
# 76322295            54891            54891           54891           54891
# 76510200            56029            56029           56029           56029
# 76329266            54257            54257           54257           54257
# 76117608            56703            56703           56703           56703
#
#           VEHICLEID
# 76491067    1932370
# 76322295    1932370
# 76510200    1932370
# 76329266    1932370
# 76117608    1932370

# %%
leave5.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 85334676  11-SEP-18 00:00:00  8089321           16         2154
# 85334677  11-SEP-18 00:00:00  8089321           17         6245
# 85334678  11-SEP-18 00:00:00  8089321           18         4671
# 85334679  11-SEP-18 00:00:00  8089321           19         4672
# 85339184  11-SEP-18 00:00:00  8089321           82          105
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 85334676            31045            31045           31045           31045
# 85334677            31078            31078           31078           31078
# 85334678            31158            31158           31158           31158
# 85334679            31231            31231           31231           31231
# 85339184            36003            36003           36003           36003
#
#           VEHICLEID
# 85334676    2693187
# 85334677    2693187
# 85334678    2693187
# 85334679    2693187
# 85339184    2693187

# %%
leave6.shape
# Out:
# (19393421, 9)

# %%
leave6.head()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 85498785  10-SEP-18 00:00:00  8089321           52         2002
# 85498783  10-SEP-18 00:00:00  8089321           50         1999
# 85334680  11-SEP-18 00:00:00  8089321           20         3465
# 85498782  10-SEP-18 00:00:00  8089321           49         1998
# 85334681  11-SEP-18 00:00:00  8089321           23         2159
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 85498785            33600            33600           33600           33600
# 85498783            33376            33376           33376           33376
# 85334680            31298            31298           31298           31298
# 85498782            33285            33285           33285           33285
# 85334681            31432            31432           31432           31432
#
#           VEHICLEID
# 85498785    2693187
# 85498783    2693187
# 85334680    2693187
# 85498782    2693187
# 85334681    2693187

# %%
leave6.tail()
# Out:
#                  DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 113795534  23-DEC-18 00:00:00  8592207           64         3913
# 114168242  26-DEC-18 00:00:00  8592207           43         3947
# 113781124  23-DEC-18 00:00:00  8592207           13         1450
# 115865288  30-DEC-18 00:00:00  8592207           27         2213
# 113764483  23-DEC-18 00:00:00  8592207            3          494
#
#            PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 113795534            67391            67391           67391           67391
# 114168242            66487            66487           66487           66487
# 113781124            65040            65040           65040           65040
# 115865288            65798            65798           65798           65798
# 113764483            64063            64063           64063           64063
#
#            VEHICLEID
# 113795534    3265681
# 114168242    3265682
# 113781124    3265681
# 115865288    2868369
# 113764483    3265681

# %% [markdown]
# ## Moving the Split Trip ID into the other Dataframes

# %% [markdown]
# <h3>1 to 2:</h3>

# %%
leave1.TRIPID.value_counts()[6288438]
# Out:
# 93

# %%
leave2.TRIPID.value_counts()[6288438]
# Out:
# 151

# %%
# Grabbing trip 6288438 from leave1
tripMove = leave1 [leave1['TRIPID'] == 6288438]

tripMove.shape
# Out:
# (93, 9)

# %%
leave2
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 19870167  28-FEB-18 00:00:00  6288438           62         2332
# 18343791  27-FEB-18 00:00:00  6288438           52         1406
# 18731627  26-FEB-18 00:00:00  6288438            5         1258
# 18306170  27-FEB-18 00:00:00  6288438           87         2669
# 18262240  28-FEB-18 00:00:00  6288438           42         4495
# ...                      ...      ...          ...          ...
# 37491553  30-APR-18 00:00:00  6651088            8         2676
# 44644531  04-MAY-18 00:00:00  6651088           30         1989
# 44001571  02-MAY-18 00:00:00  6651088           32         1992
# 38832489  30-APR-18 00:00:00  6651088           79          987
# 43598285  01-MAY-18 00:00:00  6651088           62         1595
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 19870167            30444            30444           30444           30444
# 18343791            29759            29759           29759           29759
# 18731627            26035            26035           26035           26035
# 18306170            32127            32127           32127           32127
# 18262240            28659            28659           28659           28659
# ...                   ...              ...             ...             ...
# 37491553            27350            27350           27350           27350
# 44644531            28628            28628           28628           28628
# 44001571            28787            28787           28787           28787
# 38832489            32378            32378           32378           32378
# 43598285            31483            31483           31483           31483
#
#           VEHICLEID
# 19870167    1932364
# 18343791    2868356
# 18731627    2868356
# 18306170    2868356
# 18262240    1932364
# ...             ...
# 37491553    2172259
# 44644531    2693290
# 44001571    2868347
# 38832489    2172259
# 43598285    2172300
#
# [19393421 rows x 9 columns]

# %%
# Append trip dataframe to leave2
leave2 = leave2.append(tripMove)
# Out:
# /tmp/ipykernel_1960/3771521975.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leave2 = leave2.append(tripMove)

# %%
leave2.shape
# Out:
# (19393514, 9)

# %%
# Drop rows with tripMove from leave1
leave1.drop(leave1[leave1['TRIPID'] == 6288438].index, inplace = True)

# %%
leave1.shape
# Out:
# (19393328, 9)

# %%
leave1.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 19969441  03-MAR-18 00:00:00  6288425           19         2062
# 27931010  03-MAR-18 00:00:00  6288425           52          795
# 19969764  03-MAR-18 00:00:00  6288425           10         4569
# 19969779  03-MAR-18 00:00:00  6288425           11         7658
# 27931170  03-MAR-18 00:00:00  6288425            4         2042
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 19969441            82805            82805           82805           82805
# 27931010            84924            84924           84924           84924
# 19969764            82352            82352           82352           82352
# 19969779            82364            82364           82364           82364
# 27931170            82124            82124           82124           82124
#
#           VEHICLEID
# 19969441    2406873
# 27931010    2406873
# 19969764    2406873
# 19969779    2406873
# 27931170    2406873

# %% [markdown]
# <h3>2 to 3:</h3>

# %%
leave2.TRIPID.value_counts()[6651088]
# Out:
# 135

# %%
leave3.TRIPID.value_counts()[6651088]
# Out:
# 283

# %%
# Grabbing trip 6651088 from leave3
tripMove = leave2 [leave2['TRIPID'] == 6651088]

tripMove.shape
# Out:
# (135, 9)

# %%
leave3
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 37497811  30-APR-18 00:00:00  6651088           12         2121
# 44015990  02-MAY-18 00:00:00  6651088           27         2716
# 43602310  01-MAY-18 00:00:00  6651088           67         1599
# 44271498  03-MAY-18 00:00:00  6651088            1         4795
# 37516259  30-APR-18 00:00:00  6651088           34         1994
# ...                      ...      ...          ...          ...
# 56599825  27-JUN-18 00:00:00  7110198           30          762
# 56623323  27-JUN-18 00:00:00  7110198            5          811
# 57404784  29-JUN-18 00:00:00  7110198           36          435
# 58879315  28-JUN-18 00:00:00  7110198           53         2031
# 57629768  29-JUN-18 00:00:00  7110198           24          756
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 37497811            27558            27558           27558           27558
# 44015990            28392            28392           28392           28392
# 43602310            31698            31698           31698           31698
# 44271498            27000            27000           27000           27000
# 37516259            28980            28980           28980           28980
# ...                   ...              ...             ...             ...
# 56599825            42211            42211           42211           42211
# 56623323            40004            40004           40004           40004
# 57404784            42551            42551           42551           42551
# 58879315            43473            43473           43473           43473
# 57629768            41820            41820           41820           41820
#
#           VEHICLEID
# 37497811    2172259
# 44015990    2868347
# 43602310    2172300
# 44271498    1932309
# 37516259    2172259
# ...             ...
# 56599825    1000582
# 56623323    1000582
# 57404784    1000296
# 58879315    1000578
# 57629768    1000296
#
# [19393421 rows x 9 columns]

# %%
# Append trip dataframe to leave3
leave3 = leave3.append(tripMove)
# Out:
# /tmp/ipykernel_1960/124224763.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leave3 = leave3.append(tripMove)

# %%
leave3.shape
# Out:
# (19393556, 9)

# %%
# Drop rows with tripMove from leave2
leave2.drop(leave2[leave2['TRIPID'] == 6651088].index, inplace = True)

# %%
leave2.shape
# Out:
# (19393379, 9)

# %%
leave2.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 18749270  26-FEB-18 00:00:00  6288438           10         4692
# 18081673  28-FEB-18 00:00:00  6288438           82         2622
# 18253354  28-FEB-18 00:00:00  6288438           38          619
# 17818731  27-FEB-18 00:00:00  6288438            5         1258
# 18232791  28-FEB-18 00:00:00  6288438           29          665
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 18749270            26244            26244           26244           26244
# 18081673            31943            31943           31943           31943
# 18253354            27948            27948           27948           27948
# 17818731            26035            26035           26035           26035
# 18232791            27305            27305           27305           27305
#
#           VEHICLEID
# 18749270    2868356
# 18081673    1932364
# 18253354    1932364
# 17818731    2868356
# 18232791    1932364

# %% [markdown]
# <h3>3 to 4:</h3>

# %%
leave3.TRIPID.value_counts()[7110198]
# Out:
# 57

# %%
leave4.TRIPID.value_counts()[7110198]
# Out:
# 237

# %%
# Grabbing trip 7110198 from leave3
tripMove = leave3 [leave3['TRIPID'] == 7110198]

tripMove.shape
# Out:
# (57, 9)

# %%
leave4
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 56345236  26-JUN-18 00:00:00  7110198           48         2021
# 58916136  27-JUN-18 00:00:00  7110198           14         6059
# 56345138  26-JUN-18 00:00:00  7110198           33         2008
# 58890403  29-JUN-18 00:00:00  7110198            4          810
# 56807793  27-JUN-18 00:00:00  7110198           20          846
# ...                      ...      ...          ...          ...
# 76131694  27-AUG-18 00:00:00  7502493            3          229
# 77843761  31-AUG-18 00:00:00  7502493           11         4432
# 76906162  29-AUG-18 00:00:00  7502493           38         2804
# 77848485  31-AUG-18 00:00:00  7502493           16           46
# 76476803  28-AUG-18 00:00:00  7502493            8         1642
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 56345236            43116            43116           43116           43116
# 58916136            40745            40745           40745           40745
# 56345138            42380            42380           42380           42380
# 58890403            39962            39962           39962           39962
# 56807793            41588            41588           41588           41588
# ...                   ...              ...             ...             ...
# 76131694            54117            54117           54117           54117
# 77843761            54591            54591           54591           54591
# 76906162            57009            57009           57009           57009
# 77848485            54812            54812           54812           54812
# 76476803            54456            54456           54456           54456
#
#           VEHICLEID
# 56345236    1000302
# 58916136    1000582
# 56345138    1000302
# 58890403    1000296
# 56807793    1000582
# ...             ...
# 76131694    1932370
# 77843761    1932370
# 76906162    1932370
# 77848485    1932370
# 76476803    1932370
#
# [19393421 rows x 9 columns]

# %%
# Append trip dataframe to leave4
leave4 = leave4.append(tripMove)
# Out:
# /tmp/ipykernel_1960/2147485394.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leave4 = leave4.append(tripMove)

# %%
leave4.shape
# Out:
# (19393478, 9)

# %%
# Drop rows with tripMove from leave3
leave3.drop(leave3[leave3['TRIPID'] == 7110198].index, inplace = True)

# %%
leave3.shape
# Out:
# (19393499, 9)

# %%
leave3.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 37491553  30-APR-18 00:00:00  6651088            8         2676
# 44644531  04-MAY-18 00:00:00  6651088           30         1989
# 44001571  02-MAY-18 00:00:00  6651088           32         1992
# 38832489  30-APR-18 00:00:00  6651088           79          987
# 43598285  01-MAY-18 00:00:00  6651088           62         1595
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 37491553            27350            27350           27350           27350
# 44644531            28628            28628           28628           28628
# 44001571            28787            28787           28787           28787
# 38832489            32378            32378           32378           32378
# 43598285            31483            31483           31483           31483
#
#           VEHICLEID
# 37491553    2172259
# 44644531    2693290
# 44001571    2868347
# 38832489    2172259
# 43598285    2172300

# %% [markdown]
# <h3>4 to 5:</h3>

# %%
leave4.TRIPID.value_counts()[7502493]
# Out:
# 77

# %%
leave5.TRIPID.value_counts()[7502493]
# Out:
# 112

# %%
# Grabbing trip 7502493 from leave4
tripMove = leave4 [leave4['TRIPID'] == 7502493]

tripMove.shape
# Out:
# (77, 9)

# %%
leave5
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 76491067  28-AUG-18 00:00:00  7502493           14         7603
# 76322295  27-AUG-18 00:00:00  7502493           17           47
# 76510200  28-AUG-18 00:00:00  7502493           25          350
# 76329266  28-AUG-18 00:00:00  7502493            5          230
# 76117608  27-AUG-18 00:00:00  7502493           33          390
# ...                      ...      ...          ...          ...
# 85334676  11-SEP-18 00:00:00  8089321           16         2154
# 85334677  11-SEP-18 00:00:00  8089321           17         6245
# 85334678  11-SEP-18 00:00:00  8089321           18         4671
# 85334679  11-SEP-18 00:00:00  8089321           19         4672
# 85339184  11-SEP-18 00:00:00  8089321           82          105
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 76491067            54710            54710           54710           54710
# 76322295            54891            54891           54891           54891
# 76510200            56029            56029           56029           56029
# 76329266            54257            54257           54257           54257
# 76117608            56703            56703           56703           56703
# ...                   ...              ...             ...             ...
# 85334676            31045            31045           31045           31045
# 85334677            31078            31078           31078           31078
# 85334678            31158            31158           31158           31158
# 85334679            31231            31231           31231           31231
# 85339184            36003            36003           36003           36003
#
#           VEHICLEID
# 76491067    1932370
# 76322295    1932370
# 76510200    1932370
# 76329266    1932370
# 76117608    1932370
# ...             ...
# 85334676    2693187
# 85334677    2693187
# 85334678    2693187
# 85334679    2693187
# 85339184    2693187
#
# [19393421 rows x 9 columns]

# %%
# Append trip dataframe to leave5
leave5 = leave5.append(tripMove)
# Out:
# /tmp/ipykernel_1960/2528897428.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leave5 = leave5.append(tripMove)

# %%
leave5.shape
# Out:
# (19393498, 9)

# %%
# Drop rows with tripMove from leave4
leave4.drop(leave4[leave4['TRIPID'] == 7502493].index, inplace = True)

# %%
leave4.shape
# Out:
# (19393401, 9)

# %%
leave4.tail()
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 56599825  27-JUN-18 00:00:00  7110198           30          762
# 56623323  27-JUN-18 00:00:00  7110198            5          811
# 57404784  29-JUN-18 00:00:00  7110198           36          435
# 58879315  28-JUN-18 00:00:00  7110198           53         2031
# 57629768  29-JUN-18 00:00:00  7110198           24          756
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 56599825            42211            42211           42211           42211
# 56623323            40004            40004           40004           40004
# 57404784            42551            42551           42551           42551
# 58879315            43473            43473           43473           43473
# 57629768            41820            41820           41820           41820
#
#           VEHICLEID
# 56599825    1000582
# 56623323    1000582
# 57404784    1000296
# 58879315    1000578
# 57629768    1000296

# %% [markdown]
# <h3>5 to 6:</h3>

# %%
leave5.TRIPID.value_counts()[8089321]
# Out:
# 742

# %%
leave6.TRIPID.value_counts()[8089321]
# Out:
# 128

# %%
# Grabbing trip 8089321 from leave6
tripMove = leave6 [leave6['TRIPID'] == 8089321]

tripMove.shape
# Out:
# (128, 9)

# %%
leave5
# Out:
#                 DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 76491067  28-AUG-18 00:00:00  7502493           14         7603
# 76322295  27-AUG-18 00:00:00  7502493           17           47
# 76510200  28-AUG-18 00:00:00  7502493           25          350
# 76329266  28-AUG-18 00:00:00  7502493            5          230
# 76117608  27-AUG-18 00:00:00  7502493           33          390
# ...                      ...      ...          ...          ...
# 76131694  27-AUG-18 00:00:00  7502493            3          229
# 77843761  31-AUG-18 00:00:00  7502493           11         4432
# 76906162  29-AUG-18 00:00:00  7502493           38         2804
# 77848485  31-AUG-18 00:00:00  7502493           16           46
# 76476803  28-AUG-18 00:00:00  7502493            8         1642
#
#           PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 76491067            54710            54710           54710           54710
# 76322295            54891            54891           54891           54891
# 76510200            56029            56029           56029           56029
# 76329266            54257            54257           54257           54257
# 76117608            56703            56703           56703           56703
# ...                   ...              ...             ...             ...
# 76131694            54117            54117           54117           54117
# 77843761            54591            54591           54591           54591
# 76906162            57009            57009           57009           57009
# 77848485            54812            54812           54812           54812
# 76476803            54456            54456           54456           54456
#
#           VEHICLEID
# 76491067    1932370
# 76322295    1932370
# 76510200    1932370
# 76329266    1932370
# 76117608    1932370
# ...             ...
# 76131694    1932370
# 77843761    1932370
# 76906162    1932370
# 77848485    1932370
# 76476803    1932370
#
# [19393498 rows x 9 columns]

# %%
# Append trip dataframe to leave6
leave5 = leave5.append(tripMove)
# Out:
# /tmp/ipykernel_1960/4151740417.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leave5 = leave5.append(tripMove)

# %%
leave5.shape
# Out:
# (19393626, 9)

# %%
# Drop rows with tripMove from leave5
leave6.drop(leave6[leave6['TRIPID'] == 8089321].index, inplace = True)

# %%
leave6.shape
# Out:
# (19393293, 9)

# %%
leave6.tail()
# Out:
#                  DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 113795534  23-DEC-18 00:00:00  8592207           64         3913
# 114168242  26-DEC-18 00:00:00  8592207           43         3947
# 113781124  23-DEC-18 00:00:00  8592207           13         1450
# 115865288  30-DEC-18 00:00:00  8592207           27         2213
# 113764483  23-DEC-18 00:00:00  8592207            3          494
#
#            PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 113795534            67391            67391           67391           67391
# 114168242            66487            66487           66487           66487
# 113781124            65040            65040           65040           65040
# 115865288            65798            65798           65798           65798
# 113764483            64063            64063           64063           64063
#
#            VEHICLEID
# 113795534    3265681
# 114168242    3265682
# 113781124    3265681
# 115865288    2868369
# 113764483    3265681

# %% [markdown]
# ## Send Parts to CSVs

# %%
# Send leave1 to csv:
leave1.to_csv('v3_leave1_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave1_data_prep.ipynb'

# %%
# Send leave2 to csv:
leave2.to_csv('v3_leave2_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave2_data_prep.ipynb'

# %%
# Send leave3 to csv:
leave3.to_csv('v3_leave3_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave3_data_prep.ipynb'

# %%
# Send leave4 to csv:
leave4.to_csv('v3_leave4_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave4_data_prep.ipynb'

# %%
# Send leave5 to csv:
leave5.to_csv('v3_leave5_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave5_data_prep.ipynb'

# %%
# Send leave6 to csv:
leave6.to_csv('v3_leave6_LT_2018.csv', index=False)

# %% [markdown]
# ## Continued in 'v3a_leave6_data_prep.ipynb'
