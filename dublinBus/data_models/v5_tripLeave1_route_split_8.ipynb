# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave1 route split 8 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_8.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (1005937, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5966742            1         1184            47100
# 1   2018-01-01  5966742            2         7490            47213
# 2   2018-01-01  5966742            3          497            47241
# 3   2018-01-01  5966742            4          515            47334
# 4   2018-01-01  5966742            5          516            47405
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            47100           47100           47100    2693259  2018  ...
# 1            47213           47213           47213    2693259  2018  ...
# 2            47241           47241           47241    2693259  2018  ...
# 3            47334           47334           47334    2693259  2018  ...
# 4            47405           47405           47405    2693259  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5966742            1         1184            47100
# 1   2018-01-01  5966742            2         7490            47213
# 2   2018-01-01  5966742            3          497            47241
# 3   2018-01-01  5966742            4          515            47334
# 4   2018-01-01  5966742            5          516            47405
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            47100           47100           47100    2693259  2018  ...
# 1            47213           47213           47213    2693259  2018  ...
# 2            47241           47241           47241    2693259  2018  ...
# 3            47334           47334           47334    2693259  2018  ...
# 4            47405           47405           47405    2693259  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 43

# %%
lwk = wk[(wk['LINEID'] == '43')]

# %%
lwk.shape
# Out:
# (131547, 22)

# %%
# Drop Route 43 rows from wk
wk.drop(wk[wk['LINEID'] == '43'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 356   2018-01-01  5968763            1         1380            50700
# 357   2018-01-01  5968763            2         1381            50726
# 358   2018-01-01  5968763            3         1406            50773
# 359   2018-01-01  5968763            4         1407            50816
# 360   2018-01-01  5968763            5         1409            50855
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 356            50700           50700           50700    2406881  2018  ...
# 357            50726           50726           50726    2406881  2018  ...
# 358            50773           50773           50773    2406881  2018  ...
# 359            50816           50816           50816    2406881  2018  ...
# 360            50855           50855           50855    2406881  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (874390, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_43_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (182391, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 682   2018-01-01  5969335            1         6030            39000
# 683   2018-01-01  5969335            2         6028            39048
# 684   2018-01-01  5969335            3         6025            39078
# 685   2018-01-01  5969335            4         6024            39105
# 686   2018-01-01  5969335            5         6021            39138
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 682            39000           39000           39000    2693293  2018  ...
# 683            39048           39048           39048    2693293  2018  ...
# 684            39078           39078           39078    2693293  2018  ...
# 685            39105           39105           39105    2693293  2018  ...
# 686            39138           39138           39138    2693293  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (691999, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 79A

# %%
lwk = wk[(wk['LINEID'] == '79A')]

# %%
lwk.shape
# Out:
# (91983, 22)

# %%
# Drop Route 79A rows from wk
wk.drop(wk[wk['LINEID'] == '79A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1081   2018-01-01  5970996            1         4167            37800
# 1082   2018-01-01  5970996            2         4170            37890
# 1083   2018-01-01  5970996            3         4153            37950
# 1084   2018-01-01  5970996            4         4154            38005
# 1085   2018-01-01  5970996            5         4416            38051
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1081            37800           37800           37800    2693273  2018  ...
# 1082            37890           37890           37890    2693273  2018  ...
# 1083            37950           37950           37950    2693273  2018  ...
# 1084            38005           38005           38005    2693273  2018  ...
# 1085            38051           38051           38051    2693273  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (600016, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_79A_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 185

# %%
lwk = wk[(wk['LINEID'] == '185')]

# %%
lwk.shape
# Out:
# (38597, 22)

# %%
# Drop Route 185 rows from wk
wk.drop(wk[wk['LINEID'] == '185'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3309   2018-01-02  5955374            1         3890            29400
# 3310   2018-01-02  5955374            2         3891            29494
# 3311   2018-01-02  5955374            3         3949            29844
# 3312   2018-01-02  5955374            4         3950            30062
# 3313   2018-01-02  5955374            5         3372            30153
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3309            29400           29400           29400    1001113  2018  ...
# 3310            29494           29494           29494    1001113  2018  ...
# 3311            29844           29844           29844    1001113  2018  ...
# 3312            30062           30062           30062    1001113  2018  ...
# 3313            30153           30153           30153    1001113  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (561419, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_185_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 25X

# %%
lwk = wk[(wk['LINEID'] == '25X')]

# %%
lwk.shape
# Out:
# (7980, 22)

# %%
# Drop Route 25X rows from wk
wk.drop(wk[wk['LINEID'] == '25X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3807   2018-01-02  5955468            1         7391            21300
# 3808   2018-01-02  5955468            2          493            21395
# 3809   2018-01-02  5955468            3          494            21468
# 3810   2018-01-02  5955468            4          495            21556
# 3811   2018-01-02  5955468            5          400            21627
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3807            21300           21300           21300    2868374  2018  ...
# 3808            21395           21395           21395    2868374  2018  ...
# 3809            21468           21468           21468    2868374  2018  ...
# 3810            21556           21556           21556    2868374  2018  ...
# 3811            21627           21627           21627    2868374  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (553439, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25X_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 66B

# %%
lwk = wk[(wk['LINEID'] == '66B')]

# %%
lwk.shape
# Out:
# (74617, 22)

# %%
# Drop Route 66B rows from wk
wk.drop(wk[wk['LINEID'] == '66B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3904   2018-01-02  5955685            1         3921            26400
# 3905   2018-01-02  5955685            2         3922            26472
# 3906   2018-01-02  5955685            3         3923            26541
# 3907   2018-01-02  5955685            4         3112            26596
# 3908   2018-01-02  5955685            5         3924            26710
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3904            26400           26400           26400    1001220  2018  ...
# 3905            26472           26472           26472    1001220  2018  ...
# 3906            26541           26541           26541    1001220  2018  ...
# 3907            26596           26596           26596    1001220  2018  ...
# 3908            26710           26710           26710    1001220  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (478822, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66B_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 67X

# %%
lwk = wk[(wk['LINEID'] == '67X')]

# %%
lwk.shape
# Out:
# (34386, 22)

# %%
# Drop Route 67X rows from wk
wk.drop(wk[wk['LINEID'] == '67X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3959   2018-01-02  5955823            7         4277            38397
# 3960   2018-01-02  5955823            8         7462            38598
# 3961   2018-01-02  5955823            9         7461            38629
# 3962   2018-01-02  5955823           10         4281            38744
# 3963   2018-01-02  5955823           11         4282            38764
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3959            38397           38397           38397    1000724  2018  ...
# 3960            38598           38598           38598    1000724  2018  ...
# 3961            38629           38629           38629    1000724  2018  ...
# 3962            38744           38744           38744    1000724  2018  ...
# 3963            38764           38764           38764    1000724  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (444436, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67X_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 84X

# %%
lwk = wk[(wk['LINEID'] == '84X')]

# %%
lwk.shape
# Out:
# (26027, 22)

# %%
# Drop Route 84X rows from wk
wk.drop(wk[wk['LINEID'] == '84X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4069   2018-01-02  5956039            1          395            60180
# 4070   2018-01-02  5956039            2          396            60272
# 4071   2018-01-02  5956039            3          397            60323
# 4072   2018-01-02  5956039            4          398            60397
# 4073   2018-01-02  5956039            5          399            60458
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4069            60180           60180           60180    1932330  2018  ...
# 4070            60272           60272           60272    1932330  2018  ...
# 4071            60323           60323           60323    1932330  2018  ...
# 4072            60397           60397           60397    1932330  2018  ...
# 4073            60458           60458           60458    1932330  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (418409, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84X_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 15D

# %%
lwk = wk[(wk['LINEID'] == '15D')]

# %%
lwk.shape
# Out:
# (4393, 22)

# %%
# Drop Route 15D rows from wk
wk.drop(wk[wk['LINEID'] == '15D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4186   2018-01-02  5956232            1         7654            27900
# 4187   2018-01-02  5956232            2         4843            28185
# 4188   2018-01-02  5956232            3         4905            28241
# 4189   2018-01-02  5956232            5         4906            28295
# 4190   2018-01-02  5956232            6         4907            28334
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4186            27900           27900           27900    1001194  2018  ...
# 4187            28185           28185           28185    1001194  2018  ...
# 4188            28241           28241           28241    1001194  2018  ...
# 4189            28295           28295           28295    1001194  2018  ...
# 4190            28334           28334           28334    1001194  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (414016, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15D_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 41X

# %%
lwk = wk[(wk['LINEID'] == '41X')]

# %%
lwk.shape
# Out:
# (13709, 22)

# %%
# Drop Route 41X rows from wk
wk.drop(wk[wk['LINEID'] == '41X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4224   2018-01-02  5956236            1         6200            63000
# 4225   2018-01-02  5956236            2         6201            63018
# 4226   2018-01-02  5956236            3         6196            63124
# 4227   2018-01-02  5956236            4         3532            63177
# 4228   2018-01-02  5956236            5         3533            63235
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4224            63000           63000           63000    1000960  2018  ...
# 4225            63018           63018           63018    1000960  2018  ...
# 4226            63124           63124           63124    1000960  2018  ...
# 4227            63177           63177           63177    1000960  2018  ...
# 4228            63235           63235           63235    1000960  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (400307, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_41X_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 114

# %%
lwk = wk[(wk['LINEID'] == '114')]

# %%
lwk.shape
# Out:
# (40264, 22)

# %%
# Drop Route 114 rows from wk
wk.drop(wk[wk['LINEID'] == '114'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4873   2018-01-02  5956705            3         2960            24221
# 4874   2018-01-02  5956705            4         1840            24383
# 4875   2018-01-02  5956705            5         1841            24423
# 4876   2018-01-02  5956705            6         1842            24469
# 4877   2018-01-02  5956705            7         7374            24523
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4873            24221           24221           24221    2172258  2018  ...
# 4874            24383           24383           24383    2172258  2018  ...
# 4875            24423           24423           24423    2172258  2018  ...
# 4876            24469           24469           24469    2172258  2018  ...
# 4877            24523           24523           24523    2172258  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (360043, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_114_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 76A

# %%
lwk = wk[(wk['LINEID'] == '76A')]

# %%
lwk.shape
# Out:
# (8833, 22)

# %%
# Drop Route 76A rows from wk
wk.drop(wk[wk['LINEID'] == '76A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4914   2018-01-02  5956741            1         6041            82800
# 4915   2018-01-02  5956741            2         2826            82869
# 4916   2018-01-02  5956741            3         2842            82901
# 4917   2018-01-02  5956741            4         2843            82941
# 4918   2018-01-02  5956741            5         2844            82959
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4914            82800           82800           82800    2868392  2018  ...
# 4915            82869           82869           82869    2868392  2018  ...
# 4916            82901           82901           82901    2868392  2018  ...
# 4917            82941           82941           82941    2868392  2018  ...
# 4918            82959           82959           82959    2868392  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (351210, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_76A_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 14C

# %%
lwk = wk[(wk['LINEID'] == '14C')]

# %%
lwk.shape
# Out:
# (4133, 22)

# %%
# Drop Route 14C rows from wk
wk.drop(wk[wk['LINEID'] == '14C'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5058   2018-01-02  5956816            1         4952            63000
# 5059   2018-01-02  5956816            2          768            63119
# 5060   2018-01-02  5956816            3          769            63174
# 5061   2018-01-02  5956816            4          770            63252
# 5062   2018-01-02  5956816            5          771            63284
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5058            63000           63000           63000    2406914  2018  ...
# 5059            63119           63119           63119    2406914  2018  ...
# 5060            63174           63174           63174    2406914  2018  ...
# 5061            63252           63252           63252    2406914  2018  ...
# 5062            63284           63284           63284    2406914  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (347077, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_14C_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (26639, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5119   2018-01-02  5956823            1         4745            21600
# 5120   2018-01-02  5956823            4         4991            21815
# 5121   2018-01-02  5956823            5         4992            21857
# 5122   2018-01-02  5956823            6         1719            21931
# 5123   2018-01-02  5956823            7         1828            22032
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5119            21600           21600           21600    1001211  2018  ...
# 5120            21815           21815           21815    1001211  2018  ...
# 5121            21857           21857           21857    1001211  2018  ...
# 5122            21931           21931           21931    1001211  2018  ...
# 5123            22032           22032           22032    1001211  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (320438, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Route 38B

# %%
lwk = wk[(wk['LINEID'] == '38B')]

# %%
lwk.shape
# Out:
# (22753, 22)

# %%
# Drop Route 38B rows from wk
wk.drop(wk[wk['LINEID'] == '38B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5158   2018-01-02  5956888            2         7120            28154
# 5159   2018-01-02  5956888            3         7119            28264
# 5160   2018-01-02  5956888            4         7127            28354
# 5161   2018-01-02  5956888            5         7143            28506
# 5162   2018-01-02  5956888            6         7168            28789
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5158            28154           28154           28154    1000937  2018  ...
# 5159            28264           28264           28264    1000937  2018  ...
# 5160            28354           28354           28354    1000937  2018  ...
# 5161            28506           28506           28506    1000937  2018  ...
# 5162            28789           28789           28789    1000937  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (297685, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38B_tripLeave1_sp8.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave1_route_split_9

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave1_route_split_9.csv', index=False)
