# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave1 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave1_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (3012255, 22)

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5959946            1         1730            33000
# 1   2018-01-01  5959946            2         1731            33018
# 2   2018-01-01  5959946            3         1732            33049
# 3   2018-01-01  5959946            4         1733            33080
# 4   2018-01-01  5959946            5         1650            33118
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            33000           33000           33000    2868354  2018  ...
# 1            33018           33018           33018    2868354  2018  ...
# 2            33049           33049           33049    2868354  2018  ...
# 3            33080           33080           33080    2868354  2018  ...
# 4            33118           33118           33118    2868354  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int64
# DIRECTION           int64
# actual_duration     int64
# dayOfWeek           int64
# weekend             int64
# rushHour            int64
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5959946            1         1730            33000
# 1   2018-01-01  5959946            2         1731            33018
# 2   2018-01-01  5959946            3         1732            33049
# 3   2018-01-01  5959946            4         1733            33080
# 4   2018-01-01  5959946            5         1650            33118
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            33000           33000           33000    2868354  2018  ...
# 1            33018           33018           33018    2868354  2018  ...
# 2            33049           33049           33049    2868354  2018  ...
# 3            33080           33080           33080    2868354  2018  ...
# 4            33118           33118           33118    2868354  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes
# Out:
# DAYOFSERVICE       object
# TRIPID              int64
# PROGRNUMBER         int64
# STOPPOINTID         int64
# PLANNEDTIME_ARR     int64
# PLANNEDTIME_DEP     int64
# ACTUALTIME_ARR      int64
# ACTUALTIME_DEP      int64
# VEHICLEID           int64
# year                int64
# month               int64
# day                 int64
# id                  int64
# trip_leave_id       int64
# LINEID             object
# num_lineID          int16
# DIRECTION           int16
# actual_duration     int64
# dayOfWeek           int16
# weekend             int16
# rushHour            int16
# actualARR_hour      int64
# dtype: object

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (42502, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 68   2018-01-01  5959991            1         2039            33300
# 69   2018-01-01  5959991            2         2040            33345
# 70   2018-01-01  5959991            3         2041            33401
# 71   2018-01-01  5959991            4         2042            33471
# 72   2018-01-01  5959991            5         2043            33482
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 68            33300           33300           33300    1001078  2018  ...
# 69            33345           33345           33345    1001078  2018  ...
# 70            33401           33401           33401    1001078  2018  ...
# 71            33471           33471           33471    1001078  2018  ...
# 72            33482           33482           33482    1001078  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2969753, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 63

# %%
lwk = wk[(wk['LINEID'] == '63')]

# %%
lwk.shape
# Out:
# (122544, 22)

# %%
# Drop Route 63 rows from wk
wk.drop(wk[wk['LINEID'] == '63'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 929   2018-01-01  5960165            1         5161            32400
# 930   2018-01-01  5960165            2         5162            32473
# 931   2018-01-01  5960165            3         2571            32592
# 932   2018-01-01  5960165            4         2359            32636
# 933   2018-01-01  5960165            5         2360            32696
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 929            32400           32400           32400    1001178  2018  ...
# 930            32473           32473           32473    1001178  2018  ...
# 931            32592           32592           32592    1001178  2018  ...
# 932            32636           32636           32636    1001178  2018  ...
# 933            32696           32696           32696    1001178  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2847209, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_63_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 54A

# %%
lwk = wk[(wk['LINEID'] == '54A')]

# %%
lwk.shape
# Out:
# (123364, 22)

# %%
# Drop Route 54A rows from wk
wk.drop(wk[wk['LINEID'] == '54A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1539   2018-01-01  5960302            1         6285            31500
# 1540   2018-01-01  5960302            2         6286            31526
# 1541   2018-01-01  5960302            3         6287            31581
# 1542   2018-01-01  5960302            4         6288            31613
# 1543   2018-01-01  5960302            5         6342            31650
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1539            31500           31500           31500    2868349  2018  ...
# 1540            31526           31526           31526    2868349  2018  ...
# 1541            31581           31581           31581    2868349  2018  ...
# 1542            31613           31613           31613    2868349  2018  ...
# 1543            31650           31650           31650    2868349  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2723845, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_54A_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 15B

# %%
lwk = wk[(wk['LINEID'] == '15B')]

# %%
lwk.shape
# Out:
# (250757, 22)

# %%
# Drop Route 15B rows from wk
wk.drop(wk[wk['LINEID'] == '15B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2151   2018-01-01  5960507            1         2037            36000
# 2152   2018-01-01  5960507            2         3046            36054
# 2153   2018-01-01  5960507            3         3047            36125
# 2154   2018-01-01  5960507            4         3048            36194
# 2155   2018-01-01  5960507            5         3049            36230
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2151            36000           36000           36000    2172286  2018  ...
# 2152            36054           36054           36054    2172286  2018  ...
# 2153            36125           36125           36125    2172286  2018  ...
# 2154            36194           36194           36194    2172286  2018  ...
# 2155            36230           36230           36230    2172286  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2473088, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15B_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 59

# %%
lwk = wk[(wk['LINEID'] == '59')]

# %%
lwk.shape
# Out:
# (44472, 22)

# %%
# Drop Route 59 rows from wk
wk.drop(wk[wk['LINEID'] == '59'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3970   2018-01-01  5960970            1         7333            61200
# 3971   2018-01-01  5960970            2          783            61324
# 3972   2018-01-01  5960970            3          784            61358
# 3973   2018-01-01  5960970            4          785            61416
# 3974   2018-01-01  5960970            5          786            61499
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3970            61200           61200           61200    1000170  2018  ...
# 3971            61324           61324           61324    1000170  2018  ...
# 3972            61358           61358           61358    1000170  2018  ...
# 3973            61416           61416           61416    1000170  2018  ...
# 3974            61499           61499           61499    1000170  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2428616, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_59_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (102023, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4159   2018-01-01  5961482            2          289            69555
# 4160   2018-01-01  5961482            3          496            69768
# 4161   2018-01-01  5961482            4         7490            69808
# 4162   2018-01-01  5961482            5          515            69895
# 4163   2018-01-01  5961482            6          516            69946
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4159            69555           69555           69555    2693204  2018  ...
# 4160            69768           69768           69768    2693204  2018  ...
# 4161            69808           69808           69808    2693204  2018  ...
# 4162            69895           69895           69895    2693204  2018  ...
# 4163            69946           69946           69946    2693204  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2326593, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 31A

# %%
lwk = wk[(wk['LINEID'] == '31A')]

# %%
lwk.shape
# Out:
# (68574, 22)

# %%
# Drop Route 31A rows from wk
wk.drop(wk[wk['LINEID'] == '31A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4983   2018-01-01  5961967            2         3891            67218
# 4984   2018-01-01  5961967            3         3949            67284
# 4985   2018-01-01  5961967            4         3950            67324
# 4986   2018-01-01  5961967            5         2229            67426
# 4987   2018-01-01  5961967            6         2230            67458
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4983            67218           67218           67218    2693293  2018  ...
# 4984            67284           67284           67284    2693293  2018  ...
# 4985            67324           67324           67324    2693293  2018  ...
# 4986            67426           67426           67426    2693293  2018  ...
# 4987            67458           67458           67458    2693293  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2258019, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_31A_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 25

# %%
lwk = wk[(wk['LINEID'] == '25')]

# %%
lwk.shape
# Out:
# (65378, 22)

# %%
# Drop Route 25 rows from wk
wk.drop(wk[wk['LINEID'] == '25'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5186   2018-01-01  5962073            1          395            32400
# 5187   2018-01-01  5962073            2          396            32438
# 5188   2018-01-01  5962073            3          397            32459
# 5189   2018-01-01  5962073            4          398            32490
# 5190   2018-01-01  5962073            5          399            32515
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5186            32400           32400           32400    2868403  2018  ...
# 5187            32438           32438           32438    2868403  2018  ...
# 5188            32459           32459           32459    2868403  2018  ...
# 5189            32490           32490           32490    2868403  2018  ...
# 5190            32515           32515           32515    2868403  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2192641, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 15A

# %%
lwk = wk[(wk['LINEID'] == '15A')]

# %%
lwk.shape
# Out:
# (201160, 22)

# %%
# Drop Route 15A rows from wk
wk.drop(wk[wk['LINEID'] == '15A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5784   2018-01-01  5962134            1         7073            64500
# 5785   2018-01-01  5962134            2         7097            64564
# 5786   2018-01-01  5962134            3         7098            64599
# 5787   2018-01-01  5962134            4         7099            64630
# 5788   2018-01-01  5962134            5         7100            64676
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5784            64500           64500           64500    2406911  2018  ...
# 5785            64564           64564           64564    2406911  2018  ...
# 5786            64599           64599           64599    2406911  2018  ...
# 5787            64630           64630           64630    2406911  2018  ...
# 5788            64676           64676           64676    2406911  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1991481, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15A_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 238

# %%
lwk = wk[(wk['LINEID'] == '238')]

# %%
lwk.shape
# Out:
# (34433, 22)

# %%
# Drop Route 238 rows from wk
wk.drop(wk[wk['LINEID'] == '238'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5923   2018-01-01  5962377            1         4525            39000
# 5924   2018-01-01  5962377            2         4526            39070
# 5925   2018-01-01  5962377            3         1700            39176
# 5926   2018-01-01  5962377            4         1701            39217
# 5927   2018-01-01  5962377            5         1702            39245
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5923            39000           39000           39000    1000903  2018  ...
# 5924            39070           39070           39070    1000903  2018  ...
# 5925            39176           39176           39176    1000903  2018  ...
# 5926            39217           39217           39217    1000903  2018  ...
# 5927            39245           39245           39245    1000903  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1957048, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_238_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 122

# %%
lwk = wk[(wk['LINEID'] == '122')]

# %%
lwk.shape
# Out:
# (298993, 22)

# %%
# Drop Route 122 rows from wk
wk.drop(wk[wk['LINEID'] == '122'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6534   2018-01-01  5962421            1         4495            30600
# 6535   2018-01-01  5962421            2         1279            30691
# 6536   2018-01-01  5962421            3         1934            30744
# 6537   2018-01-01  5962421            4         2310            30834
# 6538   2018-01-01  5962421            5         2311            30920
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6534            30600           30600           30600    1932371  2018  ...
# 6535            30691           30691           30691    1932371  2018  ...
# 6536            30744           30744           30744    1932371  2018  ...
# 6537            30834           30834           30834    1932371  2018  ...
# 6538            30920           30920           30920    1932371  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1658055, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_122_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 150

# %%
lwk = wk[(wk['LINEID'] == '150')]

# %%
lwk.shape
# Out:
# (178165, 22)

# %%
# Drop Route 150 rows from wk
wk.drop(wk[wk['LINEID'] == '150'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8230   2018-01-01  5962729            1          395            33000
# 8231   2018-01-01  5962729            2          396            33055
# 8232   2018-01-01  5962729            3          397            33085
# 8233   2018-01-01  5962729            4          398            33116
# 8234   2018-01-01  5962729            5          399            33141
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8230            33000           33000           33000    2172249  2018  ...
# 8231            33055           33055           33055    2172249  2018  ...
# 8232            33085           33085           33085    2172249  2018  ...
# 8233            33116           33116           33116    2172249  2018  ...
# 8234            33141           33141           33141    2172249  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1479890, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_150_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 77A

# %%
lwk = wk[(wk['LINEID'] == '77A')]

# %%
lwk.shape
# Out:
# (364329, 22)

# %%
# Drop Route 77A rows from wk
wk.drop(wk[wk['LINEID'] == '77A'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 11251   2018-01-01  5964868            2         4714            30639
# 11252   2018-01-01  5964868            3         4960            30684
# 11253   2018-01-01  5964868            4         4932            30754
# 11254   2018-01-01  5964868            5         4933            30769
# 11255   2018-01-01  5964868            6         2590            30810
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 11251            30639           30639           30639    2534838  2018  ...
# 11252            30684           30684           30684    2534838  2018  ...
# 11253            30754           30754           30754    2534838  2018  ...
# 11254            30769           30769           30769    2534838  2018  ...
# 11255            30810           30810           30810    2534838  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1115561, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77A_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (109624, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 14785   2018-01-01  5966742            1         1184            47100
# 14786   2018-01-01  5966742            2         7490            47213
# 14787   2018-01-01  5966742            3          497            47241
# 14788   2018-01-01  5966742            4          515            47334
# 14789   2018-01-01  5966742            5          516            47405
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 14785            47100           47100           47100    2693259  2018  ...
# 14786            47213           47213           47213    2693259  2018  ...
# 14787            47241           47241           47241    2693259  2018  ...
# 14788            47334           47334           47334    2693259  2018  ...
# 14789            47405           47405           47405    2693259  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1005937, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave1_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave1_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave1_route_split_8.csv', index=False)
