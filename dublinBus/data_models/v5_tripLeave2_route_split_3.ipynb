# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave2 route split 3 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave2_route_split_3.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Out:
# /tmp/ipykernel_21481/3305469356.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk = pd.read_csv('v5_tripLeave2_route_split_3.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (14903352, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-02-26  6288712            1         7158            25200
# 1   2018-02-26  6288712            2         7048            25245
# 2   2018-02-26  6288712            3         7159            25320
# 3   2018-02-26  6288712            4         7017            25447
# 4   2018-02-26  6288712            5         7018            25500
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            25200           25200           25200    1000268  2018  ...
# 1            25245           25245           25245    1000268  2018  ...
# 2            25320           25320           25320    1000268  2018  ...
# 3            25447           25447           25447    1000268  2018  ...
# 4            25500           25500           25500    1000268  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 39X

# %%
lwk = wk[(wk['LINEID'] == '39X')]

# %%
lwk.shape
# Out:
# (6335, 22)

# %%
# Drop Route 39X rows from wk
wk.drop(wk[wk['LINEID'] == '39X'].index, inplace = True)

# %%
wk.head()
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 53   2018-02-26  6288718            1         6290            26760
# 54   2018-02-26  6288718            2         7120            26879
# 55   2018-02-26  6288718            3         7119            26947
# 56   2018-02-26  6288718            4         7127            27003
# 57   2018-02-26  6288718            5         7143            27097
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 53            26760           26760           26760    1000259  2018  ...
# 54            26879           26879           26879    1000259  2018  ...
# 55            26947           26947           26947    1000259  2018  ...
# 56            27003           27003           27003    1000259  2018  ...
# 57            27097           27097           27097    1000259  2018  ...
#
#                    id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14897017, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_39X_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 25D

# %%
lwk = wk[(wk['LINEID'] == '25D')]

# %%
lwk.shape
# Out:
# (8488, 22)

# %%
# Drop Route 25D rows from wk
wk.drop(wk[wk['LINEID'] == '25D'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 113   2018-02-26  6288785            1         7340            63900
# 114   2018-02-26  6288785            3          784            63946
# 115   2018-02-26  6288785            4          785            64015
# 116   2018-02-26  6288785            5          786            64193
# 117   2018-02-26  6288785            6          793            64457
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 113            63900           63900           63900    3088377  2018  ...
# 114            63946           63946           63946    3088377  2018  ...
# 115            64015           64015           64015    3088377  2018  ...
# 116            64193           64193           64193    3088377  2018  ...
# 117            64457           64457           64457    3088377  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14888529, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25D_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 37

# %%
lwk = wk[(wk['LINEID'] == '37')]

# %%
lwk.shape
# Out:
# (294697, 22)

# %%
# Drop Route 37 rows from wk
wk.drop(wk[wk['LINEID'] == '37'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 171   2018-02-26  6288802            1         5161            27600
# 172   2018-02-26  6288802            2         5162            27682
# 173   2018-02-26  6288802            3         2571            27817
# 174   2018-02-26  6288802            4         2359            27930
# 175   2018-02-26  6288802            5         2360            28011
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 171            27600           27600           27600    1001242  2018  ...
# 172            27682           27682           27682    1001242  2018  ...
# 173            27817           27817           27817    1001242  2018  ...
# 174            27930           27930           27930    1001242  2018  ...
# 175            28011           28011           28011    1001242  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14593832, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_37_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 54A

# %%
lwk = wk[(wk['LINEID'] == '54A')]

# %%
lwk.shape
# Out:
# (123146, 22)

# %%
# Drop Route 54A rows from wk
wk.drop(wk[wk['LINEID'] == '54A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 661   2018-02-26  6288814            1         6282            26640
# 662   2018-02-26  6288814            2         6335            26734
# 663   2018-02-26  6288814            3         6326            26795
# 664   2018-02-26  6288814            4         4886            26848
# 665   2018-02-26  6288814            5         4887            26980
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 661            26640           26640           26640    2868312  2018  ...
# 662            26734           26734           26734    2868312  2018  ...
# 663            26795           26795           26795    2868312  2018  ...
# 664            26848           26848           26848    2868312  2018  ...
# 665            26980           26980           26980    2868312  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14470686, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_54A_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 15

# %%
lwk = wk[(wk['LINEID'] == '15')]

# %%
lwk.shape
# Out:
# (616109, 22)

# %%
# Drop Route 15 rows from wk
wk.drop(wk[wk['LINEID'] == '15'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 732   2018-02-26  6288828            1          324            21600
# 733   2018-02-26  6288828            2          327            21704
# 734   2018-02-26  6288828            3         7113            21846
# 735   2018-02-26  6288828            4          127            21941
# 736   2018-02-26  6288828            5          112            22023
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 732            21600           21600           21600    2534827  2018  ...
# 733            21704           21704           21704    2534827  2018  ...
# 734            21846           21846           21846    2534827  2018  ...
# 735            21941           21941           21941    2534827  2018  ...
# 736            22023           22023           22023    2534827  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13854577, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 4

# %%
lwk = wk[(wk['LINEID'] == '4')]

# %%
lwk.shape
# Out:
# (327265, 22)

# %%
# Drop Route 4 rows from wk
wk.drop(wk[wk['LINEID'] == '4'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 968   2018-02-26  6288833            1         7149            62400
# 969   2018-02-26  6288833            3         6363            62530
# 970   2018-02-26  6288833            4         6361            62582
# 971   2018-02-26  6288833            5         6367            62614
# 972   2018-02-26  6288833            6         4985            62638
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 968            62400           62400           62400    2693191  2018  ...
# 969            62530           62530           62530    2693191  2018  ...
# 970            62582           62582           62582    2693191  2018  ...
# 971            62614           62614           62614    2693191  2018  ...
# 972            62638           62638           62638    2693191  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13527312, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_4_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 140

# %%
lwk = wk[(wk['LINEID'] == '140')]

# %%
lwk.shape
# Out:
# (301113, 22)

# %%
# Drop Route 140 rows from wk
wk.drop(wk[wk['LINEID'] == '140'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1211   2018-02-26  6288839            1         7132            37440
# 1212   2018-02-26  6288839            2         1558            37537
# 1213   2018-02-26  6288839            3         2957            37599
# 1214   2018-02-26  6288839            4         2958            37631
# 1215   2018-02-26  6288839            5         4938            37693
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1211            37440           37440           37440    2534822  2018  ...
# 1212            37537           37537           37537    2534822  2018  ...
# 1213            37599           37599           37599    2534822  2018  ...
# 1214            37631           37631           37631    2534822  2018  ...
# 1215            37693           37693           37693    2534822  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13226199, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_140_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 40

# %%
lwk = wk[(wk['LINEID'] == '40')]

# %%
lwk.shape
# Out:
# (674819, 22)

# %%
# Drop Route 40 rows from wk
wk.drop(wk[wk['LINEID'] == '40'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1704   2018-02-26  6288845            2         7120            26600
# 1705   2018-02-26  6288845            3         7119            26679
# 1706   2018-02-26  6288845            4         7127            26744
# 1707   2018-02-26  6288845            5         7143            26854
# 1708   2018-02-26  6288845            6         3368            27087
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1704            26600           26600           26600    1001208  2018  ...
# 1705            26679           26679           26679    1001208  2018  ...
# 1706            26744           26744           26744    1001208  2018  ...
# 1707            26854           26854           26854    1001208  2018  ...
# 1708            27087           27087           27087    1001208  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (12551380, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 25B

# %%
lwk = wk[(wk['LINEID'] == '25B')]

# %%
lwk.shape
# Out:
# (166098, 22)

# %%
# Drop Route 25B rows from wk
wk.drop(wk[wk['LINEID'] == '25B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1781   2018-02-26  6288847            1         4606            22500
# 1782   2018-02-26  6288847            2         7142            22562
# 1783   2018-02-26  6288847            3         7015            22652
# 1784   2018-02-26  6288847            4         4617            22735
# 1785   2018-02-26  6288847            5         4555            22752
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1781            22500           22500           22500    2534785  2018  ...
# 1782            22562           22562           22562    2534785  2018  ...
# 1783            22652           22652           22652    2534785  2018  ...
# 1784            22735           22735           22735    2534785  2018  ...
# 1785            22752           22752           22752    2534785  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (12385282, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25B_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Route 151

# %%
lwk = wk[(wk['LINEID'] == '151')]

# %%
lwk.shape
# Out:
# (248246, 22)

# %%
# Drop Route 151 rows from wk
wk.drop(wk[wk['LINEID'] == '151'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2235   2018-02-26  6288856            2         2183            39637
# 2236   2018-02-26  6288856            3         2184            39726
# 2237   2018-02-26  6288856            4         2185            39821
# 2238   2018-02-26  6288856            5         1423            39932
# 2239   2018-02-26  6288856            6         1424            39973
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2235            39637           39637           39637    2534801  2018  ...
# 2236            39726           39726           39726    2534801  2018  ...
# 2237            39821           39821           39821    2534801  2018  ...
# 2238            39932           39932           39932    2534801  2018  ...
# 2239            39973           39973           39973    2534801  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (12137036, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_151_tripLeave2_sp3.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave2_route_split_4

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave2_route_split_4.csv', index=False)
