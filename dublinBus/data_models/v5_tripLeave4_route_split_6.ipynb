# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave4 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave4_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (3149561, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-06-24  7115697            1         2037            36000
# 1   2018-06-24  7115697            2         3046            36056
# 2   2018-06-24  7115697            3         3047            36130
# 3   2018-06-24  7115697            4         3048            36202
# 4   2018-06-24  7115697            5         3049            36242
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            36000           36000           36000    2172282  2018  ...
# 1            36056           36056           36056    2172282  2018  ...
# 2            36130           36130           36130    2172282  2018  ...
# 3            36202           36202           36202    2172282  2018  ...
# 4            36242           36242           36242    2172282  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 59

# %%
lwk = wk[(wk['LINEID'] == '59')]

# %%
lwk.shape
# Out:
# (47006, 22)

# %%
# Drop Route 59 rows from wk
wk.drop(wk[wk['LINEID'] == '59'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 637   2018-06-24  7115758            1         1730            33000
# 638   2018-06-24  7115758            2         1731            33024
# 639   2018-06-24  7115758            3         1732            33053
# 640   2018-06-24  7115758            4         1733            33082
# 641   2018-06-24  7115758            5         1650            33117
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 637            33000           33000           33000    2534859  2018  ...
# 638            33024           33024           33024    2534859  2018  ...
# 639            33053           33053           33053    2534859  2018  ...
# 640            33082           33082           33082    2534859  2018  ...
# 641            33117           33117           33117    2534859  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3102555, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_59_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (47145, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 812   2018-06-24  7115821            1          950            33300
# 813   2018-06-24  7115821            2          915            33340
# 814   2018-06-24  7115821            3          916            33369
# 815   2018-06-24  7115821            4          917            33395
# 816   2018-06-24  7115821            5          918            33431
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 812            33300           33300           33300    2406900  2018  ...
# 813            33340           33340           33340    2406900  2018  ...
# 814            33369           33369           33369    2406900  2018  ...
# 815            33395           33395           33395    2406900  2018  ...
# 816            33431           33431           33431    2406900  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3055410, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 29A

# %%
lwk = wk[(wk['LINEID'] == '29A')]

# %%
lwk.shape
# Out:
# (226730, 22)

# %%
# Drop Route 29A rows from wk
wk.drop(wk[wk['LINEID'] == '29A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1264   2018-06-24  7115905            1         4167            37800
# 1265   2018-06-24  7115905            2         4170            37892
# 1266   2018-06-24  7115905            3         4153            37954
# 1267   2018-06-24  7115905            4         4154            38011
# 1268   2018-06-24  7115905            5         4416            38058
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1264            37800           37800           37800    2868383  2018  ...
# 1265            37892           37892           37892    2868383  2018  ...
# 1266            37954           37954           37954    2868383  2018  ...
# 1267            38011           38011           38011    2868383  2018  ...
# 1268            38058           38058           38058    2868383  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2828680, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_29A_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 185

# %%
lwk = wk[(wk['LINEID'] == '185')]

# %%
lwk.shape
# Out:
# (44210, 22)

# %%
# Drop Route 185 rows from wk
wk.drop(wk[wk['LINEID'] == '185'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1709   2018-06-25  7110226            1         1380            28800
# 1710   2018-06-25  7110226            2         1381            28842
# 1711   2018-06-25  7110226            3         1406            28916
# 1712   2018-06-25  7110226            4         1407            28985
# 1713   2018-06-25  7110226            5         1409            29047
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1709            28800           28800           28800    1000243  2018  ...
# 1710            28842           28842           28842    1000243  2018  ...
# 1711            28916           28916           28916    1000243  2018  ...
# 1712            28985           28985           28985    1000243  2018  ...
# 1713            29047           29047           29047    1000243  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2784470, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_185_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (198953, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2181   2018-06-25  7110270            1         4342            29700
# 2182   2018-06-25  7110270            2         4348            29784
# 2183   2018-06-25  7110270            3         7122            29907
# 2184   2018-06-25  7110270            4         7121            29978
# 2185   2018-06-25  7110270            5         7183            30011
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2181            29700           29700           29700    1000223  2018  ...
# 2182            29784           29784           29784    1000223  2018  ...
# 2183            29907           29907           29907    1000223  2018  ...
# 2184            29978           29978           29978    1000223  2018  ...
# 2185            30011           30011           30011    1000223  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2585517, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (143439, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2636   2018-06-25  7110281            2         3922            25881
# 2637   2018-06-25  7110281            3         3923            25937
# 2638   2018-06-25  7110281            4         7079            26011
# 2639   2018-06-25  7110281            5         7080            26077
# 2640   2018-06-25  7110281            6         7081            26121
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2636            25881           25881           25881    1000596  2018  ...
# 2637            25937           25937           25937    1000596  2018  ...
# 2638            26011           26011           26011    1000596  2018  ...
# 2639            26077           26077           26077    1000596  2018  ...
# 2640            26121           26121           26121    1000596  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2442078, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 67X

# %%
lwk = wk[(wk['LINEID'] == '67X')]

# %%
lwk.shape
# Out:
# (34642, 22)

# %%
# Drop Route 67X rows from wk
wk.drop(wk[wk['LINEID'] == '67X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2690   2018-06-25  7110309            1         3544            27000
# 2691   2018-06-25  7110309            2         3552            27049
# 2692   2018-06-25  7110309            3         3553            27075
# 2693   2018-06-25  7110309            4         3554            27133
# 2694   2018-06-25  7110309            5         3555            27174
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2690            27000           27000           27000    2406872  2018  ...
# 2691            27049           27049           27049    2406872  2018  ...
# 2692            27075           27075           27075    2406872  2018  ...
# 2693            27133           27133           27133    2406872  2018  ...
# 2694            27174           27174           27174    2406872  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2407436, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_67X_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 7B

# %%
lwk = wk[(wk['LINEID'] == '7B')]

# %%
lwk.shape
# Out:
# (20264, 22)

# %%
# Drop Route 7B rows from wk
wk.drop(wk[wk['LINEID'] == '7B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2748   2018-06-25  7110352            1         7067            29100
# 2749   2018-06-25  7110352            2         2956            29121
# 2750   2018-06-25  7110352            3         2965            29164
# 2751   2018-06-25  7110352            4         2983            29226
# 2752   2018-06-25  7110352            5         2984            29297
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2748            29100           29100           29100    1000190  2018  ...
# 2749            29121           29121           29121    1000190  2018  ...
# 2750            29164           29164           29164    1000190  2018  ...
# 2751            29226           29226           29226    1000190  2018  ...
# 2752            29297           29297           29297    1000190  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2387172, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7B_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 15D

# %%
lwk = wk[(wk['LINEID'] == '15D')]

# %%
lwk.shape
# Out:
# (3864, 22)

# %%
# Drop Route 15D rows from wk
wk.drop(wk[wk['LINEID'] == '15D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2840   2018-06-25  7110441            2         3082            27982
# 2841   2018-06-25  7110441            3         3165            28026
# 2842   2018-06-25  7110441            4         3166            28093
# 2843   2018-06-25  7110441            5         3167            28114
# 2844   2018-06-25  7110441            6         3168            28150
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2840            27982           27982           27982    1932299  2018  ...
# 2841            28026           28026           28026    1932299  2018  ...
# 2842            28093           28093           28093    1932299  2018  ...
# 2843            28114           28114           28114    1932299  2018  ...
# 2844            28150           28150           28150    1932299  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2383308, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15D_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 114

# %%
lwk = wk[(wk['LINEID'] == '114')]

# %%
lwk.shape
# Out:
# (50252, 22)

# %%
# Drop Route 114 rows from wk
wk.drop(wk[wk['LINEID'] == '114'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3274   2018-06-25  7110474           11         2954            39545
# 3275   2018-06-25  7110474           12         7067            39600
# 3276   2018-06-25  7110474           13         2956            39720
# 3277   2018-06-25  7110474           14         2965            39840
# 3278   2018-06-25  7110474           15         7448            39872
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3274            39545           39545           39545    2406918  2018  ...
# 3275            39600           39600           39600    2406918  2018  ...
# 3276            39720           39720           39720    2406918  2018  ...
# 3277            39840           39840           39840    2406918  2018  ...
# 3278            39872           39872           39872    2406918  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2333056, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_114_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 161

# %%
lwk = wk[(wk['LINEID'] == '161')]

# %%
lwk.shape
# Out:
# (3613, 22)

# %%
# Drop Route 161 rows from wk
wk.drop(wk[wk['LINEID'] == '161'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3295   2018-06-25  7110500            1         4260            26100
# 3296   2018-06-25  7110500            2         7296            26281
# 3297   2018-06-25  7110500            3         4266            26352
# 3298   2018-06-25  7110500            4         4253            26378
# 3299   2018-06-25  7110500            5         4268            26408
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3295            26100           26100           26100    2693217  2018  ...
# 3296            26281           26281           26281    2693217  2018  ...
# 3297            26352           26352           26352    2693217  2018  ...
# 3298            26378           26378           26378    2693217  2018  ...
# 3299            26408           26408           26408    2693217  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2329443, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_161_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 84X

# %%
lwk = wk[(wk['LINEID'] == '84X')]

# %%
lwk.shape
# Out:
# (21273, 22)

# %%
# Drop Route 84X rows from wk
wk.drop(wk[wk['LINEID'] == '84X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3425   2018-06-25  7110559            1         7333            59400
# 3426   2018-06-25  7110559            2          783            59527
# 3427   2018-06-25  7110559            3          784            59563
# 3428   2018-06-25  7110559            4          785            59623
# 3429   2018-06-25  7110559            5          786            59763
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3425            59400           59400           59400    1001206  2018  ...
# 3426            59527           59527           59527    1001206  2018  ...
# 3427            59563           59563           59563    1001206  2018  ...
# 3428            59623           59623           59623    1001206  2018  ...
# 3429            59763           59763           59763    1001206  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2308170, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_84X_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (107213, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3472   2018-06-25  7110627           13          780            62358
# 3473   2018-06-25  7110627           14          781            62409
# 3474   2018-06-25  7110627           15          782            62454
# 3475   2018-06-25  7110627           16          783            62522
# 3476   2018-06-25  7110627           17          784            62567
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3472            62358           62358           62358    1000283  2018  ...
# 3473            62409           62409           62409    1000283  2018  ...
# 3474            62454           62454           62454    1000283  2018  ...
# 3475            62522           62522           62522    1000283  2018  ...
# 3476            62567           62567           62567    1000283  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2200957, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (25942, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3521   2018-06-25  7110653            1         4747            25200
# 3522   2018-06-25  7110653            2         2960            25232
# 3523   2018-06-25  7110653            3         1545            25270
# 3524   2018-06-25  7110653            4         1816            25326
# 3525   2018-06-25  7110653            5         6171            25368
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3521            25200           25200           25200    1001166  2018  ...
# 3522            25232           25232           25232    1001166  2018  ...
# 3523            25270           25270           25270    1001166  2018  ...
# 3524            25326           25326           25326    1001166  2018  ...
# 3525            25368           25368           25368    1001166  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2175015, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 236

# %%
lwk = wk[(wk['LINEID'] == '236')]

# %%
lwk.shape
# Out:
# (6181, 22)

# %%
# Drop Route 236 rows from wk
wk.drop(wk[wk['LINEID'] == '236'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3706   2018-06-25  7110730            1         3640            26100
# 3707   2018-06-25  7110730            2         3574            26157
# 3708   2018-06-25  7110730            3         3641            26223
# 3709   2018-06-25  7110730            4         3642            26252
# 3710   2018-06-25  7110730            5         3643            26352
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3706            26100           26100           26100    2534813  2018  ...
# 3707            26157           26157           26157    2534813  2018  ...
# 3708            26223           26223           26223    2534813  2018  ...
# 3709            26252           26252           26252    2534813  2018  ...
# 3710            26352           26352           26352    2534813  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2168834, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_236_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 32X

# %%
lwk = wk[(wk['LINEID'] == '32X')]

# %%
lwk.shape
# Out:
# (6230, 22)

# %%
# Drop Route 32X rows from wk
wk.drop(wk[wk['LINEID'] == '32X'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3803   2018-06-25  7110745            1          324            74700
# 3804   2018-06-25  7110745            2          327            74823
# 3805   2018-06-25  7110745            3         7113            74958
# 3806   2018-06-25  7110745            4          127            75030
# 3807   2018-06-25  7110745            5          112            75092
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3803            74700           74700           74700    2868313  2018  ...
# 3804            74823           74823           74823    2868313  2018  ...
# 3805            74958           74958           74958    2868313  2018  ...
# 3806            75030           75030           75030    2868313  2018  ...
# 3807            75092           75092           75092    2868313  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2162604, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_32X_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Route 4

# %%
lwk = wk[(wk['LINEID'] == '4')]

# %%
lwk.shape
# Out:
# (346605, 22)

# %%
# Drop Route 4 rows from wk
wk.drop(wk[wk['LINEID'] == '4'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4081   2018-06-25  7110895            1         4745            29760
# 4082   2018-06-25  7110895            2         4989            29783
# 4083   2018-06-25  7110895            3         4990            29891
# 4084   2018-06-25  7110895            4         4991            29911
# 4085   2018-06-25  7110895            5         4992            29941
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4081            29760           29760           29760    1001213  2018  ...
# 4082            29783           29783           29783    1001213  2018  ...
# 4083            29891           29891           29891    1001213  2018  ...
# 4084            29911           29911           29911    1001213  2018  ...
# 4085            29941           29941           29941    1001213  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1815999, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_4_tripLeave4_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave4_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave4_route_split_7.csv', index=False)
