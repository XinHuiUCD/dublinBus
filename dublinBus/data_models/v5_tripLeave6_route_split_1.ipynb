# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave6_route_split_1.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (15784271, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-09-09  8089827            2         4725            49420
# 1   2018-09-09  8089827            3          273            49606
# 2   2018-09-09  8089827            4          405            49870
# 3   2018-09-09  8089827            5          408            50006
# 4   2018-09-09  8089827            6          409            50031
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            49420           49420           49420    2693216  2018  ...
# 1            49606           49606           49606    2693216  2018  ...
# 2            49870           49870           49870    2693216  2018  ...
# 3            50006           50006           50006    2693216  2018  ...
# 4            50031           50031           50031    2693216  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 7A

# %%
lwk = wk[(wk['LINEID'] == '7A')]

# %%
lwk.shape
# Out:
# (233685, 22)

# %%
# Drop Route 7A rows from wk
wk.drop(wk[wk['LINEID'] == '7A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 120   2018-09-09  8089830            1          395            25800
# 121   2018-09-09  8089830            2          396            25847
# 122   2018-09-09  8089830            3          397            25873
# 123   2018-09-09  8089830            4          398            25901
# 124   2018-09-09  8089830            5          399            25924
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 120            25800           25800           25800    2868349  2018  ...
# 121            25847           25847           25847    2868349  2018  ...
# 122            25873           25873           25873    2868349  2018  ...
# 123            25901           25901           25901    2868349  2018  ...
# 124            25924           25924           25924    2868349  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15550586, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_7A_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 77A

# %%
lwk = wk[(wk['LINEID'] == '77A')]

# %%
lwk.shape
# Out:
# (401575, 22)

# %%
# Drop Route 77A rows from wk
wk.drop(wk[wk['LINEID'] == '77A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 903   2018-09-09  8089842            1         6318            34800
# 904   2018-09-09  8089842            2         6319            34837
# 905   2018-09-09  8089842            3         7246            34877
# 906   2018-09-09  8089842            4         6320            34960
# 907   2018-09-09  8089842            5         4594            35032
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 903            34800           34800           34800    3265677  2018  ...
# 904            34837           34837           34837    3265677  2018  ...
# 905            34877           34877           34877    3265677  2018  ...
# 906            34960           34960           34960    3265677  2018  ...
# 907            35032           35032           35032    3265677  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (15149011, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77A_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 15

# %%
lwk = wk[(wk['LINEID'] == '15')]

# %%
lwk.shape
# Out:
# (682358, 22)

# %%
# Drop Route 15 rows from wk
wk.drop(wk[wk['LINEID'] == '15'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1317   2018-09-09  8089875            1         4342            34200
# 1318   2018-09-09  8089875            2         4348            34285
# 1319   2018-09-09  8089875            3         7122            34410
# 1320   2018-09-09  8089875            4         7121            34469
# 1321   2018-09-09  8089875            5         7183            34497
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1317            34200           34200           34200    2868402  2018  ...
# 1318            34285           34285           34285    2868402  2018  ...
# 1319            34410           34410           34410    2868402  2018  ...
# 1320            34469           34469           34469    2868402  2018  ...
# 1321            34497           34497           34497    2868402  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14466653, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (146918, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1953   2018-09-09  8089903            1         4316            54900
# 1954   2018-09-09  8089903            2         4317            54928
# 1955   2018-09-09  8089903            3         7013            55115
# 1956   2018-09-09  8089903            4         6162            55226
# 1957   2018-09-09  8089903            5         7022            55254
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1953            54900           54900           54900    2406932  2018  ...
# 1954            54928           54928           54928    2406932  2018  ...
# 1955            55115           55115           55115    2406932  2018  ...
# 1956            55226           55226           55226    2406932  2018  ...
# 1957            55254           55254           55254    2406932  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14319735, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 40B

# %%
lwk = wk[(wk['LINEID'] == '40B')]

# %%
lwk.shape
# Out:
# (25702, 22)

# %%
# Drop Route 40B rows from wk
wk.drop(wk[wk['LINEID'] == '40B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1993   2018-09-09  8089904            1         6004            59100
# 1994   2018-09-09  8089904            2            7            59207
# 1995   2018-09-09  8089904            3           11            59400
# 1996   2018-09-09  8089904            4           14            59447
# 1997   2018-09-09  8089904            5           15            59501
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1993            59100           59100           59100    2406932  2018  ...
# 1994            59207           59207           59207    2406932  2018  ...
# 1995            59400           59400           59400    2406932  2018  ...
# 1996            59447           59447           59447    2406932  2018  ...
# 1997            59501           59501           59501    2406932  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14294033, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40B_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 40D

# %%
lwk = wk[(wk['LINEID'] == '40D')]

# %%
lwk.shape
# Out:
# (202285, 22)

# %%
# Drop Route 40D rows from wk
wk.drop(wk[wk['LINEID'] == '40D'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2122   2018-09-09  8089967            4         7127            33350
# 2123   2018-09-09  8089967            5         7143            33416
# 2124   2018-09-09  8089967            6         3368            33555
# 2125   2018-09-09  8089967            7         7137            33647
# 2126   2018-09-09  8089967            8         7139            33716
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2122            33350           33350           33350    1001227  2018  ...
# 2123            33416           33416           33416    1001227  2018  ...
# 2124            33555           33555           33555    1001227  2018  ...
# 2125            33647           33647           33647    1001227  2018  ...
# 2126            33716           33716           33716    1001227  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (14091748, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_40D_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 25B

# %%
lwk = wk[(wk['LINEID'] == '25B')]

# %%
lwk.shape
# Out:
# (171095, 22)

# %%
# Drop Route 25B rows from wk
wk.drop(wk[wk['LINEID'] == '25B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2237   2018-09-09  8089971            1         4620            52920
# 2238   2018-09-09  8089971            2         7563            52967
# 2239   2018-09-09  8089971            3         3368            53017
# 2240   2018-09-09  8089971            4         4626            53097
# 2241   2018-09-09  8089971            5         4627            53145
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2237            52920           52920           52920    1001187  2018  ...
# 2238            52967           52967           52967    1001187  2018  ...
# 2239            53017           53017           53017    1001187  2018  ...
# 2240            53097           53097           53097    1001187  2018  ...
# 2241            53145           53145           53145    1001187  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13920653, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25B_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 25A

# %%
lwk = wk[(wk['LINEID'] == '25A')]

# %%
lwk.shape
# Out:
# (189714, 22)

# %%
# Drop Route 25A rows from wk
wk.drop(wk[wk['LINEID'] == '25A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2607   2018-09-09  8089997            1         4096            36000
# 2608   2018-09-09  8089997            2         4114            36023
# 2609   2018-09-09  8089997            3         4115            36038
# 2610   2018-09-09  8089997            4         4116            36107
# 2611   2018-09-09  8089997            5         4117            36137
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2607            36000           36000           36000    2534807  2018  ...
# 2608            36023           36023           36023    2534807  2018  ...
# 2609            36038           36038           36038    2534807  2018  ...
# 2610            36107           36107           36107    2534807  2018  ...
# 2611            36137           36137           36137    2534807  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13730939, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25A_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Route 44

# %%
lwk = wk[(wk['LINEID'] == '44')]

# %%
lwk.shape
# Out:
# (151637, 22)

# %%
# Drop Route 44 rows from wk
wk.drop(wk[wk['LINEID'] == '44'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3483   2018-09-09  8090030            1          248            45000
# 3484   2018-09-09  8090030            2          249            45041
# 3485   2018-09-09  8090030            3          250            45114
# 3486   2018-09-09  8090030            4          251            45157
# 3487   2018-09-09  8090030            5          252            45230
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3483            45000           45000           45000    2868380  2018  ...
# 3484            45041           45041           45041    2868380  2018  ...
# 3485            45114           45114           45114    2868380  2018  ...
# 3486            45157           45157           45157    2868380  2018  ...
# 3487            45230           45230           45230    2868380  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (13579302, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_44_tripLeave6_sp1.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave6_route_split_2

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave6_route_split_2.csv', index=False)
