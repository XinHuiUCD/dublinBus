# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
rt = pd.read_csv('v8c_route_33.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
rt.shape
# Out:
# (1314517, 26)

# %%
rt.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  VEHICLEID  \
# 0   2018-01-01  5955452            1         6048            43200    2534846
# 1   2018-01-01  5955452            2         5064            43212    2534846
# 2   2018-01-01  5955452            3         7173            43237    2534846
# 3   2018-01-01  5955452            4         3811            43260    2534846
# 4   2018-01-01  5955452            5         3812            43266    2534846
#
#    year  month  day                 id  ...  weekend  rushHour  \
# 0  2018      1    1  20180101595545201  ...        0         0
# 1  2018      1    1  20180101595545202  ...        0         0
# 2  2018      1    1  20180101595545203  ...        0         0
# 3  2018      1    1  20180101595545204  ...        0         0
# 4  2018      1    1  20180101595545205  ...        0         0
#
#    stop_actARR_hour  wthr_tr_lt_id  temp  humidity  wind_speed  weather_id  \
# ...

# %%
rt.isnull().sum()
# Out:
# DAYOFSERVICE                 0
# TRIPID                       0
# PROGRNUMBER                  0
# STOPPOINTID                  0
# PLANNEDTIME_ARR              0
# VEHICLEID                    0
# year                         0
# month                        0
# day                          0
# id                           0
# trip_leave_id                0
# LINEID                       0
# num_lineID                   0
# DIRECTION                    0
# act_trip_dur                 0
# dayOfWeek                    0
# weekend                      0
# rushHour                     0
# stop_actARR_hour             0
# wthr_tr_lt_id                0
# temp                      3076
# humidity                  3076
# wind_speed                3076
# weather_id                3076
# weather_description       3076
# dos_trpID_stpID_prgNum       0
# dtype: int64

# %% [markdown]
# ## Drop Rows with NaNs

# %%
rt = rt.dropna()

# %%
rt.shape
# Out:
# (1311441, 26)

# %%
rt.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  VEHICLEID  \
# 0   2018-01-01  5955452            1         6048            43200    2534846
# 1   2018-01-01  5955452            2         5064            43212    2534846
# 2   2018-01-01  5955452            3         7173            43237    2534846
# 3   2018-01-01  5955452            4         3811            43260    2534846
# 4   2018-01-01  5955452            5         3812            43266    2534846
#
#    year  month  day                 id  ...  weekend  rushHour  \
# 0  2018      1    1  20180101595545201  ...        0         0
# 1  2018      1    1  20180101595545202  ...        0         0
# 2  2018      1    1  20180101595545203  ...        0         0
# 3  2018      1    1  20180101595545204  ...        0         0
# 4  2018      1    1  20180101595545205  ...        0         0
#
#    stop_actARR_hour  wthr_tr_lt_id  temp  humidity  wind_speed  weather_id  \
# ...

# %%
rt.isnull().sum()
# Out:
# DAYOFSERVICE              0
# TRIPID                    0
# PROGRNUMBER               0
# STOPPOINTID               0
# PLANNEDTIME_ARR           0
# VEHICLEID                 0
# year                      0
# month                     0
# day                       0
# id                        0
# trip_leave_id             0
# LINEID                    0
# num_lineID                0
# DIRECTION                 0
# act_trip_dur              0
# dayOfWeek                 0
# weekend                   0
# rushHour                  0
# stop_actARR_hour          0
# wthr_tr_lt_id             0
# temp                      0
# humidity                  0
# wind_speed                0
# weather_id                0
# weather_description       0
# dos_trpID_stpID_prgNum    0
# dtype: int64

# %% [markdown]
# ## Send to CSV

# %%
# Send route to csv:
rt.to_csv('v8c_route_33.csv', index=False)
