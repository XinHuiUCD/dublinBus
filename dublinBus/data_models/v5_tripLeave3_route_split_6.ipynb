# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave3 route split 6 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave3_route_split_6.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (5656706, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6654629            1         4745            30600
# 1   2018-04-29  6654629            2         4989            30618
# 2   2018-04-29  6654629            3         4990            30703
# 3   2018-04-29  6654629            4         4991            30719
# 4   2018-04-29  6654629            5         4992            30742
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            30600           30600           30600    1000909  2018  ...
# 1            30618           30618           30618    1000909  2018  ...
# 2            30703           30703           30703    1000909  2018  ...
# 3            30719           30719           30719    1000909  2018  ...
# 4            30742           30742           30742    1000909  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 38

# %%
lwk = wk[(wk['LINEID'] == '38')]

# %%
lwk.shape
# Out:
# (171109, 22)

# %%
# Drop Route 38 rows from wk
wk.drop(wk[wk['LINEID'] == '38'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 223   2018-04-29  6654633            1         4745            46500
# 224   2018-04-29  6654633            2         4989            46522
# 225   2018-04-29  6654633            3         4990            46626
# 226   2018-04-29  6654633            4         4991            46645
# 227   2018-04-29  6654633            5         4992            46674
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 223            46500           46500           46500    1000909  2018  ...
# 224            46522           46522           46522    1000909  2018  ...
# 225            46626           46626           46626    1000909  2018  ...
# 226            46645           46645           46645    1000909  2018  ...
# 227            46674           46674           46674    1000909  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5485597, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 38A

# %%
lwk = wk[(wk['LINEID'] == '38A')]

# %%
lwk.shape
# Out:
# (123955, 22)

# %%
# Drop Route 38A rows from wk
wk.drop(wk[wk['LINEID'] == '38A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 697   2018-04-29  6654698            1         3333            38400
# 698   2018-04-29  6654698            2         3334            38448
# 699   2018-04-29  6654698            3         3352            38493
# 700   2018-04-29  6654698            4         3335            38535
# 701   2018-04-29  6654698            5         3336            38572
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 697            38400           38400           38400    1000764  2018  ...
# 698            38448           38448           38448    1000764  2018  ...
# 699            38493           38493           38493    1000764  2018  ...
# 700            38535           38535           38535    1000764  2018  ...
# 701            38572           38572           38572    1000764  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5361642, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_38A_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 270

# %%
lwk = wk[(wk['LINEID'] == '270')]

# %%
lwk.shape
# Out:
# (33786, 22)

# %%
# Drop Route 270 rows from wk
wk.drop(wk[wk['LINEID'] == '270'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1043   2018-04-29  6654980            2          327            37910
# 1044   2018-04-29  6654980            3         7113            38014
# 1045   2018-04-29  6654980            4          127            38110
# 1046   2018-04-29  6654980            5          112            38194
# 1047   2018-04-29  6654980            6          113            38262
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1043            37910           37910           37910    2693192  2018  ...
# 1044            38014           38014           38014    2693192  2018  ...
# 1045            38110           38110           38110    2693192  2018  ...
# 1046            38194           38194           38194    2693192  2018  ...
# 1047            38262           38262           38262    2693192  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (5327856, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_270_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 4

# %%
lwk = wk[(wk['LINEID'] == '4')]

# %%
lwk.shape
# Out:
# (333285, 22)

# %%
# Drop Route 4 rows from wk
wk.drop(wk[wk['LINEID'] == '4'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1632   2018-04-29  6654993            1         4342            41400
# 1633   2018-04-29  6654993            2         4348            41481
# 1634   2018-04-29  6654993            3         4646            41551
# 1635   2018-04-29  6654993            4         4647            41584
# 1636   2018-04-29  6654993            5         4435            41706
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 1632            41400           41400           41400    1000963  2018  ...
# 1633            41481           41481           41481    1000963  2018  ...
# 1634            41551           41551           41551    1000963  2018  ...
# 1635            41584           41584           41584    1000963  2018  ...
# 1636            41706           41706           41706    1000963  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4994571, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_4_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 75

# %%
lwk = wk[(wk['LINEID'] == '75')]

# %%
lwk.shape
# Out:
# (297300, 22)

# %%
# Drop Route 75 rows from wk
wk.drop(wk[wk['LINEID'] == '75'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2119   2018-04-29  6655033            1         7571            51000
# 2120   2018-04-29  6655033            2         1644            51097
# 2121   2018-04-29  6655033            3         1605            51168
# 2122   2018-04-29  6655033            4          228            51330
# 2123   2018-04-29  6655033            5          229            51372
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2119            51000           51000           51000    1932325  2018  ...
# 2120            51097           51097           51097    1932325  2018  ...
# 2121            51168           51168           51168    1932325  2018  ...
# 2122            51330           51330           51330    1932325  2018  ...
# 2123            51372           51372           51372    1932325  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4697271, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_75_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 104

# %%
lwk = wk[(wk['LINEID'] == '104')]

# %%
lwk.shape
# Out:
# (46892, 22)

# %%
# Drop Route 104 rows from wk
wk.drop(wk[wk['LINEID'] == '104'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2560   2018-04-29  6655310            1         1423            28800
# 2561   2018-04-29  6655310            2         1424            28834
# 2562   2018-04-29  6655310            3         1425            28876
# 2563   2018-04-29  6655310            4         1426            28939
# 2564   2018-04-29  6655310            5         1427            28980
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2560            28800           28800           28800    2868325  2018  ...
# 2561            28834           28834           28834    2868325  2018  ...
# 2562            28876           28876           28876    2868325  2018  ...
# 2563            28939           28939           28939    2868325  2018  ...
# 2564            28980           28980           28980    2868325  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4650379, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_104_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 122

# %%
lwk = wk[(wk['LINEID'] == '122')]

# %%
lwk.shape
# Out:
# (284602, 22)

# %%
# Drop Route 122 rows from wk
wk.drop(wk[wk['LINEID'] == '122'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3302   2018-04-29  6655653            1         7564            46800
# 3303   2018-04-29  6655653            2         4521            46993
# 3304   2018-04-29  6655653            3         1283            47131
# 3305   2018-04-29  6655653            4         4456            47180
# 3306   2018-04-29  6655653            5         1284            47226
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3302            46800           46800           46800    2534842  2018  ...
# 3303            46993           46993           46993    2534842  2018  ...
# 3304            47131           47131           47131    2534842  2018  ...
# 3305            47180           47180           47180    2534842  2018  ...
# 3306            47226           47226           47226    2534842  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4365777, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_122_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 65B

# %%
lwk = wk[(wk['LINEID'] == '65B')]

# %%
lwk.shape
# Out:
# (114544, 22)

# %%
# Drop Route 65B rows from wk
wk.drop(wk[wk['LINEID'] == '65B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3593   2018-04-29  6655846            2         3891            67214
# 3594   2018-04-29  6655846            3         3949            67265
# 3595   2018-04-29  6655846            4         3950            67297
# 3596   2018-04-29  6655846            5         2229            67424
# 3597   2018-04-29  6655846            6         2230            67465
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3593            67214           67214           67214    2534785  2018  ...
# 3594            67265           67265           67265    2534785  2018  ...
# 3595            67297           67297           67297    2534785  2018  ...
# 3596            67424           67424           67424    2534785  2018  ...
# 3597            67465           67465           67465    2534785  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4251233, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_65B_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 25

# %%
lwk = wk[(wk['LINEID'] == '25')]

# %%
lwk.shape
# Out:
# (65591, 22)

# %%
# Drop Route 25 rows from wk
wk.drop(wk[wk['LINEID'] == '25'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 3835   2018-04-29  6655940            1         6285            29700
# 3836   2018-04-29  6655940            2         6286            29724
# 3837   2018-04-29  6655940            3         6287            29775
# 3838   2018-04-29  6655940            4         6288            29805
# 3839   2018-04-29  6655940            5         6342            29839
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 3835            29700           29700           29700    2693283  2018  ...
# 3836            29724           29724           29724    2693283  2018  ...
# 3837            29775           29775           29775    2693283  2018  ...
# 3838            29805           29805           29805    2693283  2018  ...
# 3839            29839           29839           29839    2693283  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (4185642, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_25_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 15B

# %%
lwk = wk[(wk['LINEID'] == '15B')]

# %%
lwk.shape
# Out:
# (253977, 22)

# %%
# Drop Route 15B rows from wk
wk.drop(wk[wk['LINEID'] == '15B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4625   2018-04-29  6655960            2         7142            43278
# 4626   2018-04-29  6655960            3         7015            43359
# 4627   2018-04-29  6655960            4         4617            43433
# 4628   2018-04-29  6655960            5         4555            43449
# 4629   2018-04-29  6655960            6         4576            43511
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4625            43278           43278           43278    1000927  2018  ...
# 4626            43359           43359           43359    1000927  2018  ...
# 4627            43433           43433           43433    1000927  2018  ...
# 4628            43449           43449           43449    1000927  2018  ...
# 4629            43511           43511           43511    1000927  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3931665, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_15B_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 151

# %%
lwk = wk[(wk['LINEID'] == '151')]

# %%
lwk.shape
# Out:
# (267001, 22)

# %%
# Drop Route 151 rows from wk
wk.drop(wk[wk['LINEID'] == '151'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4978   2018-04-29  6656102            1         2039            33300
# 4979   2018-04-29  6656102            2         2040            33351
# 4980   2018-04-29  6656102            3         2041            33415
# 4981   2018-04-29  6656102            4         2042            33495
# 4982   2018-04-29  6656102            5         2043            33504
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4978            33300           33300           33300    1001229  2018  ...
# 4979            33351           33351           33351    1001229  2018  ...
# 4980            33415           33415           33415    1001229  2018  ...
# 4981            33495           33495           33495    1001229  2018  ...
# 4982            33504           33504           33504    1001229  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3664664, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_151_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 63

# %%
lwk = wk[(wk['LINEID'] == '63')]

# %%
lwk.shape
# Out:
# (123755, 22)

# %%
# Drop Route 63 rows from wk
wk.drop(wk[wk['LINEID'] == '63'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 5695   2018-04-29  6656203            1         6004            52200
# 5696   2018-04-29  6656203            2            3            52269
# 5697   2018-04-29  6656203            3          192            52436
# 5698   2018-04-29  6656203            4          795            52462
# 5699   2018-04-29  6656203            5          796            52496
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 5695            52200           52200           52200    2868324  2018  ...
# 5696            52269           52269           52269    2868324  2018  ...
# 5697            52436           52436           52436    2868324  2018  ...
# 5698            52462           52462           52462    2868324  2018  ...
# 5699            52496           52496           52496    2868324  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3540909, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_63_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 120

# %%
lwk = wk[(wk['LINEID'] == '120')]

# %%
lwk.shape
# Out:
# (140296, 22)

# %%
# Drop Route 120 rows from wk
wk.drop(wk[wk['LINEID'] == '120'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6071   2018-04-29  6656361            1         7333            61200
# 6072   2018-04-29  6656361            2          783            61295
# 6073   2018-04-29  6656361            3          784            61319
# 6074   2018-04-29  6656361            4          785            61360
# 6075   2018-04-29  6656361            5          786            61445
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6071            61200           61200           61200    2868375  2018  ...
# 6072            61295           61295           61295    2868375  2018  ...
# 6073            61319           61319           61319    2868375  2018  ...
# 6074            61360           61360           61360    2868375  2018  ...
# 6075            61445           61445           61445    2868375  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3400613, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_120_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 70

# %%
lwk = wk[(wk['LINEID'] == '70')]

# %%
lwk.shape
# Out:
# (102283, 22)

# %%
# Drop Route 70 rows from wk
wk.drop(wk[wk['LINEID'] == '70'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6409   2018-04-29  6656481            1          395            35100
# 6410   2018-04-29  6656481            2          396            35203
# 6411   2018-04-29  6656481            3          397            35260
# 6412   2018-04-29  6656481            4          398            35292
# 6413   2018-04-29  6656481            5          399            35318
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 6409            35100           35100           35100    1000168  2018  ...
# 6410            35203           35203           35203    1000168  2018  ...
# 6411            35260           35260           35260    1000168  2018  ...
# 6412            35292           35292           35292    1000168  2018  ...
# 6413            35318           35318           35318    1000168  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3298330, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_70_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Route 56A

# %%
lwk = wk[(wk['LINEID'] == '56A')]

# %%
lwk.shape
# Out:
# (84995, 22)

# %%
# Drop Route 56A rows from wk
wk.drop(wk[wk['LINEID'] == '56A'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8395   2018-04-29  6656624            1         4863            29700
# 8396   2018-04-29  6656624            2         4864            29733
# 8397   2018-04-29  6656624            3         4865            29757
# 8398   2018-04-29  6656624            4         4577            29782
# 8399   2018-04-29  6656624            5         4578            29825
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8395            29700           29700           29700    1000329  2018  ...
# 8396            29733           29733           29733    1000329  2018  ...
# 8397            29757           29757           29757    1000329  2018  ...
# 8398            29782           29782           29782    1000329  2018  ...
# 8399            29825           29825           29825    1000329  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3213335, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_56A_tripLeave3_sp6.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave3_route_split_7

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave3_route_split_7.csv', index=False)
