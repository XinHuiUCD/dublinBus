# %%
# Library Imports.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Allows plots to appear directly in the notebook.
# %matplotlib inline

from patsy import dmatrices
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

# %%
# Read CSV files into Data Frames:
weather = pd.read_csv('cleaned_2018_OpenWeather.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
trips = pd.read_csv('trips_2018.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
weather.shape
# Out:
# (26280, 29)

# %%
weather.dtypes
# Out:
# dt                       int64
# dt_iso                  object
# timezonetext            object
# timezone                 int64
# city_name               object
# lat                    float64
# lon                    float64
# temp                   float64
# visibility             float64
# dew_point              float64
# feels_like             float64
# temp_min               float64
# temp_max               float64
# pressure                 int64
# sea_level              float64
# grnd_level             float64
# humidity                 int64
# wind_speed             float64
# wind_deg                 int64
# wind_gust              float64
# rain_1h                float64
# rain_3h                float64
# snow_1h                float64
# snow_3h                float64
# clouds_all               int64
# weather_id               int64
# weather_main            object
# weather_description     object
# weather_icon            object
# dtype: object

# %%
trips.shape
# Out:
# (1048575, 16)

# %%
trips.dtypes
# Out:
# DATASOURCE          object
# DAYOFSERVICE        object
# TRIPID               int64
# LINEID              object
# ROUTEID             object
# DIRECTION            int64
# PLANNEDTIME_ARR      int64
# PLANNEDTIME_DEP      int64
# ACTUALTIME_ARR     float64
# ACTUALTIME_DEP     float64
# BASIN               object
# TENDERLOT          float64
# SUPPRESSED         float64
# JUSTIFICATIONID    float64
# LASTUPDATE          object
# NOTE                object
# dtype: object

# %%
weather.head()
# Out:
#            dt         dt_iso timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  wind_gust  rain_1h  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     2.30
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     1.51
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     0.64
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...        NaN     0.17
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...        NaN      NaN
#
#    rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN      NaN          75         501          Rain
# 1      NaN      NaN      NaN          75         501          Rain
# 2      NaN      NaN      NaN          75         500          Rain
# 3      NaN      NaN      NaN          75         500          Rain
# 4      NaN      NaN      NaN          75         803        Clouds
#
#    weather_description  weather_icon
# 0        moderate rain           10n
# 1        moderate rain           10n
# 2           light rain           10n
# 3           light rain           10n
# 4        broken clouds           04n
#
# [5 rows x 29 columns]

# %%
weather2 = weather.rename(columns={'dt_iso': 'DAYOFSERVICE'})

# %%
weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  wind_gust  rain_1h  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     2.30
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     1.51
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...        NaN     0.64
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...        NaN     0.17
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...        NaN      NaN
#
#    rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN      NaN          75         501          Rain
# 1      NaN      NaN      NaN          75         501          Rain
# 2      NaN      NaN      NaN          75         500          Rain
# 3      NaN      NaN      NaN          75         500          Rain
# 4      NaN      NaN      NaN          75         803        Clouds
#
#    weather_description  weather_icon
# 0        moderate rain           10n
# 1        moderate rain           10n
# 2           light rain           10n
# 3           light rain           10n
# 4        broken clouds           04n
#
# [5 rows x 29 columns]

# %%
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            87245            84600         87524.0         84600.0  BasDef
# 1            30517            26460         32752.0             NaN  BasDef
# 2            35512            32100         36329.0         32082.0  BasDef
# 3            57261            54420         58463.0         54443.0  BasDef
# 4            85383            81600         84682.0         81608.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE
# 0        NaN         NaN              NaN  2/28/2018 12:05  ,2967409,
# 1        NaN         NaN              NaN  2/28/2018 12:05  ,2580260,
# 2        NaN         NaN              NaN  2/28/2018 12:05  ,2448968,
# 3        NaN         NaN              NaN  2/28/2018 12:05  ,3094242,
# 4        NaN         NaN              NaN  2/28/2018 12:05  ,2526331,

# %%
trips['planDep_time'] = (trips['PLANNEDTIME_DEP'] / 3600).round()

# %%
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            87245            84600         87524.0         84600.0  BasDef
# 1            30517            26460         32752.0             NaN  BasDef
# 2            35512            32100         36329.0         32082.0  BasDef
# 3            57261            54420         58463.0         54443.0  BasDef
# 4            85383            81600         84682.0         81608.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE  \
# 0        NaN         NaN              NaN  2/28/2018 12:05  ,2967409,
# 1        NaN         NaN              NaN  2/28/2018 12:05  ,2580260,
# 2        NaN         NaN              NaN  2/28/2018 12:05  ,2448968,
# 3        NaN         NaN              NaN  2/28/2018 12:05  ,3094242,
# 4        NaN         NaN              NaN  2/28/2018 12:05  ,2526331,
#
#    planDep_time
# 0          24.0
# 1           7.0
# 2           9.0
# 3          15.0
# 4          23.0

# %%
trips[['xDOS', 'hour']] = trips.DAYOFSERVICE.str.split(' ', expand=True)
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            87245            84600         87524.0         84600.0  BasDef
# 1            30517            26460         32752.0             NaN  BasDef
# 2            35512            32100         36329.0         32082.0  BasDef
# 3            57261            54420         58463.0         54443.0  BasDef
# 4            85383            81600         84682.0         81608.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE  \
# 0        NaN         NaN              NaN  2/28/2018 12:05  ,2967409,
# 1        NaN         NaN              NaN  2/28/2018 12:05  ,2580260,
# 2        NaN         NaN              NaN  2/28/2018 12:05  ,2448968,
# 3        NaN         NaN              NaN  2/28/2018 12:05  ,3094242,
# 4        NaN         NaN              NaN  2/28/2018 12:05  ,2526331,
#
#    planDep_time      xDOS  hour
# 0          24.0  2/7/2018  0:00
# 1           7.0  2/7/2018  0:00
# 2           9.0  2/7/2018  0:00
# 3          15.0  2/7/2018  0:00
# 4          23.0  2/7/2018  0:00

# %%
trips[['xMonth', 'xDay', 'xYear']] = trips.xDOS.str.split('/', expand=True)
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  ...  \
# 0            87245            84600         87524.0         84600.0  ...
# 1            30517            26460         32752.0             NaN  ...
# 2            35512            32100         36329.0         32082.0  ...
# 3            57261            54420         58463.0         54443.0  ...
# 4            85383            81600         84682.0         81608.0  ...
#
#   SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE planDep_time  \
# 0        NaN              NaN  2/28/2018 12:05  ,2967409,         24.0
# 1        NaN              NaN  2/28/2018 12:05  ,2580260,          7.0
# 2        NaN              NaN  2/28/2018 12:05  ,2448968,          9.0
# 3        NaN              NaN  2/28/2018 12:05  ,3094242,         15.0
# 4        NaN              NaN  2/28/2018 12:05  ,2526331,         23.0
#
#        xDOS  hour xMonth xDay xYear
# 0  2/7/2018  0:00      2    7  2018
# 1  2/7/2018  0:00      2    7  2018
# 2  2/7/2018  0:00      2    7  2018
# 3  2/7/2018  0:00      2    7  2018
# 4  2/7/2018  0:00      2    7  2018
#
# [5 rows x 22 columns]

# %%
trips['planDep_time'] = np.where(trips['planDep_time'] == 24, 0, trips['planDep_time'])

# %%
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  ...  \
# 0            87245            84600         87524.0         84600.0  ...
# 1            30517            26460         32752.0             NaN  ...
# 2            35512            32100         36329.0         32082.0  ...
# 3            57261            54420         58463.0         54443.0  ...
# 4            85383            81600         84682.0         81608.0  ...
#
#   SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE planDep_time  \
# 0        NaN              NaN  2/28/2018 12:05  ,2967409,          0.0
# 1        NaN              NaN  2/28/2018 12:05  ,2580260,          7.0
# 2        NaN              NaN  2/28/2018 12:05  ,2448968,          9.0
# 3        NaN              NaN  2/28/2018 12:05  ,3094242,         15.0
# 4        NaN              NaN  2/28/2018 12:05  ,2526331,         23.0
#
#        xDOS  hour xMonth xDay xYear
# 0  2/7/2018  0:00      2    7  2018
# 1  2/7/2018  0:00      2    7  2018
# 2  2/7/2018  0:00      2    7  2018
# 3  2/7/2018  0:00      2    7  2018
# 4  2/7/2018  0:00      2    7  2018
#
# [5 rows x 22 columns]

# %%
trips['planDep_time'] = trips['planDep_time'].astype('int')

# %%
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  ...  \
# 0            87245            84600         87524.0         84600.0  ...
# 1            30517            26460         32752.0             NaN  ...
# 2            35512            32100         36329.0         32082.0  ...
# 3            57261            54420         58463.0         54443.0  ...
# 4            85383            81600         84682.0         81608.0  ...
#
#   SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE planDep_time  \
# 0        NaN              NaN  2/28/2018 12:05  ,2967409,            0
# 1        NaN              NaN  2/28/2018 12:05  ,2580260,            7
# 2        NaN              NaN  2/28/2018 12:05  ,2448968,            9
# 3        NaN              NaN  2/28/2018 12:05  ,3094242,           15
# 4        NaN              NaN  2/28/2018 12:05  ,2526331,           23
#
#        xDOS  hour xMonth xDay xYear
# 0  2/7/2018  0:00      2    7  2018
# 1  2/7/2018  0:00      2    7  2018
# 2  2/7/2018  0:00      2    7  2018
# 3  2/7/2018  0:00      2    7  2018
# 4  2/7/2018  0:00      2    7  2018
#
# [5 rows x 22 columns]

# %%
trips['planDep_time'] = trips['planDep_time'].astype('string')

# %%
trips['DOS_ID'] = trips.xMonth + trips.xDay + trips.xYear + trips.planDep_time
trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  ...  \
# 0            87245            84600         87524.0         84600.0  ...
# 1            30517            26460         32752.0             NaN  ...
# 2            35512            32100         36329.0         32082.0  ...
# 3            57261            54420         58463.0         54443.0  ...
# 4            85383            81600         84682.0         81608.0  ...
#
#   JUSTIFICATIONID       LASTUPDATE       NOTE  planDep_time      xDOS  hour  \
# 0             NaN  2/28/2018 12:05  ,2967409,             0  2/7/2018  0:00
# 1             NaN  2/28/2018 12:05  ,2580260,             7  2/7/2018  0:00
# 2             NaN  2/28/2018 12:05  ,2448968,             9  2/7/2018  0:00
# 3             NaN  2/28/2018 12:05  ,3094242,            15  2/7/2018  0:00
# 4             NaN  2/28/2018 12:05  ,2526331,            23  2/7/2018  0:00
#
#   xMonth xDay xYear    DOS_ID
# 0      2    7  2018   2720180
# 1      2    7  2018   2720187
# 2      2    7  2018   2720189
# 3      2    7  2018  27201815
# 4      2    7  2018  27201823
#
# [5 rows x 23 columns]

# %%
trips.drop('xDOS', axis=1, inplace=True)
trips.drop('hour', axis=1, inplace=True)
trips.drop('xMonth', axis=1, inplace=True)
trips.drop('xDay', axis=1, inplace=True)
trips.drop('xYear', axis=1, inplace=True)

trips.head()
# Out:
#   DATASOURCE   DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            87245            84600         87524.0         84600.0  BasDef
# 1            30517            26460         32752.0             NaN  BasDef
# 2            35512            32100         36329.0         32082.0  BasDef
# 3            57261            54420         58463.0         54443.0  BasDef
# 4            85383            81600         84682.0         81608.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID       LASTUPDATE       NOTE  \
# 0        NaN         NaN              NaN  2/28/2018 12:05  ,2967409,
# 1        NaN         NaN              NaN  2/28/2018 12:05  ,2580260,
# 2        NaN         NaN              NaN  2/28/2018 12:05  ,2448968,
# 3        NaN         NaN              NaN  2/28/2018 12:05  ,3094242,
# 4        NaN         NaN              NaN  2/28/2018 12:05  ,2526331,
#
#   planDep_time    DOS_ID
# 0            0   2720180
# 1            7   2720187
# 2            9   2720189
# 3           15  27201815
# 4           23  27201823

# %%
weather2[['xDOS', 'hour']] = weather2.DAYOFSERVICE.str.split(' ', expand=True)
weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  rain_3h  snow_1h  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...      NaN      NaN
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...      NaN      NaN
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...      NaN      NaN
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...      NaN      NaN
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...      NaN      NaN
#
#    snow_3h  clouds_all  weather_id  weather_main  weather_description  \
# 0      NaN          75         501          Rain        moderate rain
# 1      NaN          75         501          Rain        moderate rain
# 2      NaN          75         500          Rain           light rain
# 3      NaN          75         500          Rain           light rain
# 4      NaN          75         803        Clouds        broken clouds
#
#    weather_icon      xDOS  hour
# 0           10n  1/1/2017  0:00
# 1           10n  1/1/2017  1:00
# 2           10n  1/1/2017  2:00
# 3           10n  1/1/2017  3:00
# 4           04n  1/1/2017  4:00
#
# [5 rows x 31 columns]

# %%
weather2[['xMonth', 'xDay', 'xYear']] = weather2.xDOS.str.split('/', expand=True)
weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  clouds_all  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...          75
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...          75
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...          75
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...          75
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...          75
#
#    weather_id  weather_main  weather_description  weather_icon      xDOS  \
# 0         501          Rain        moderate rain           10n  1/1/2017
# 1         501          Rain        moderate rain           10n  1/1/2017
# 2         500          Rain           light rain           10n  1/1/2017
# 3         500          Rain           light rain           10n  1/1/2017
# 4         803        Clouds        broken clouds           04n  1/1/2017
#
#    hour  xMonth  xDay  xYear
# 0  0:00       1     1   2017
# 1  1:00       1     1   2017
# 2  2:00       1     1   2017
# 3  3:00       1     1   2017
# 4  4:00       1     1   2017
#
# [5 rows x 34 columns]

# %%
weather2[['xHour', 'xMin']] = weather2.hour.str.split(':', expand=True)
weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  weather_main  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...          Rain
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...          Rain
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...          Rain
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...          Rain
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...        Clouds
#
#    weather_description  weather_icon      xDOS  hour  xMonth  xDay  xYear  \
# 0        moderate rain           10n  1/1/2017  0:00       1     1   2017
# 1        moderate rain           10n  1/1/2017  1:00       1     1   2017
# 2           light rain           10n  1/1/2017  2:00       1     1   2017
# 3           light rain           10n  1/1/2017  3:00       1     1   2017
# 4        broken clouds           04n  1/1/2017  4:00       1     1   2017
#
#    xHour  xMin
# 0      0    00
# 1      1    00
# 2      2    00
# 3      3    00
# 4      4    00
#
# [5 rows x 36 columns]

# %%
weather2['DOS_ID'] = weather2.xMonth + weather2.xDay + weather2.xYear + weather2.xHour
weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  weather_description  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...        moderate rain
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...        moderate rain
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...           light rain
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...           light rain
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...        broken clouds
#
#    weather_icon      xDOS  hour  xMonth  xDay  xYear  xHour  xMin   DOS_ID
# 0           10n  1/1/2017  0:00       1     1   2017      0    00  1120170
# 1           10n  1/1/2017  1:00       1     1   2017      1    00  1120171
# 2           10n  1/1/2017  2:00       1     1   2017      2    00  1120172
# 3           10n  1/1/2017  3:00       1     1   2017      3    00  1120173
# 4           04n  1/1/2017  4:00       1     1   2017      4    00  1120174
#
# [5 rows x 37 columns]

# %%
weather2.drop('xDOS', axis=1, inplace=True)
weather2.drop('hour', axis=1, inplace=True)
weather2.drop('xMonth', axis=1, inplace=True)
weather2.drop('xDay', axis=1, inplace=True)
weather2.drop('xYear', axis=1, inplace=True)
weather2.drop('xHour', axis=1, inplace=True)
weather2.drop('xMin', axis=1, inplace=True)

weather2.head()
# Out:
#            dt   DAYOFSERVICE timezonetext  timezone        city_name  \
# 0  1483228800  1/1/2017 0:00     0000 UTC         0  Custom location
# 1  1483232400  1/1/2017 1:00     0000 UTC         0  Custom location
# 2  1483236000  1/1/2017 2:00     0000 UTC         0  Custom location
# 3  1483239600  1/1/2017 3:00     0000 UTC         0  Custom location
# 4  1483243200  1/1/2017 4:00     0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  ...  rain_1h  rain_3h  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35  ...     2.30      NaN
# 1  53.345035 -6.267261  5.39      9999.0       4.35  ...     1.51      NaN
# 2  53.345035 -6.267261  5.39      9999.0       4.35  ...     0.64      NaN
# 3  53.345035 -6.267261  4.39      9999.0       3.36  ...     0.17      NaN
# 4  53.345035 -6.267261  4.39      9999.0       2.42  ...      NaN      NaN
#
#    snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN          75         501          Rain
# 1      NaN      NaN          75         501          Rain
# 2      NaN      NaN          75         500          Rain
# 3      NaN      NaN          75         500          Rain
# 4      NaN      NaN          75         803        Clouds
#
#    weather_description  weather_icon   DOS_ID
# 0        moderate rain           10n  1120170
# 1        moderate rain           10n  1120171
# 2           light rain           10n  1120172
# 3           light rain           10n  1120173
# 4        broken clouds           04n  1120174
#
# [5 rows x 30 columns]

# %%
tripWeather = pd.merge(trips, weather2, how="left", on=["DOS_ID"])

# %%
tripWeather.head()
# Out:
#   DATASOURCE DAYOFSERVICE_x   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  2/7/2018 0:00  6253783     68    68_80          1
# 1         DB  2/7/2018 0:00  6262138    25B  25B_271          2
# 2         DB  2/7/2018 0:00  6254942    45A   45A_70          2
# 3         DB  2/7/2018 0:00  6259460    25A  25A_273          1
# 4         DB  2/7/2018 0:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  ...  \
# 0            87245            84600         87524.0         84600.0  ...
# 1            30517            26460         32752.0             NaN  ...
# 2            35512            32100         36329.0         32082.0  ...
# 3            57261            54420         58463.0         54443.0  ...
# 4            85383            81600         84682.0         81608.0  ...
#
#   wind_gust  rain_1h  rain_3h  snow_1h snow_3h clouds_all weather_id  \
# 0       NaN      NaN      NaN      NaN     NaN         20        801
# 1       NaN      NaN      NaN      NaN     NaN         20        801
# 2       NaN      NaN      NaN      NaN     NaN         75        803
# 3       NaN      0.2      NaN      NaN     NaN         90        300
# 4       NaN      NaN      NaN      NaN     NaN         75        300
#
#   weather_main      weather_description weather_icon
# 0       Clouds               few clouds          02n
# 1       Clouds               few clouds          02n
# 2       Clouds            broken clouds          04d
# 3      Drizzle  light intensity drizzle          09d
# 4      Drizzle  light intensity drizzle          09n
#
# [5 rows x 47 columns]

# %%
# Send merged df to csv:
tripWeather.to_csv('tripWeather.csv', index=False)
