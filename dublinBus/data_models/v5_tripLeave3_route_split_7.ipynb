# %%
# Library Imports.
import pandas as pd

import numpy as np

# %%
# Read tripleave3 route split 7 CSV file into Data Frame:
wk = pd.read_csv('v5_tripLeave3_route_split_7.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
wk.shape
# Out:
# (3213335, 22)

# %%
wk.head()

# %%
wk.dtypes

# %% [markdown]
# ## Datatype Changes

# %%
wk['num_lineID'] = wk['num_lineID'].astype('int16')
wk['DIRECTION'] = wk['DIRECTION'].astype('int16')

# %%
wk['actual_duration'] = wk['actual_duration'].astype('int64')
wk['dayOfWeek'] = wk['dayOfWeek'].astype('int16')

# %%
wk['weekend'] = wk['weekend'].astype('int16')
wk['rushHour'] = wk['rushHour'].astype('int16')

# %%
wk.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-04-29  6656624            1         4863            29700
# 1   2018-04-29  6656624            2         4864            29733
# 2   2018-04-29  6656624            3         4865            29757
# 3   2018-04-29  6656624            4         4577            29782
# 4   2018-04-29  6656624            5         4578            29825
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 0            29700           29700           29700    1000329  2018  ...
# 1            29733           29733           29733    1000329  2018  ...
# 2            29757           29757           29757    1000329  2018  ...
# 3            29782           29782           29782    1000329  2018  ...
# 4            29825           29825           29825    1000329  2018  ...
#
#                   id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.dtypes

# %% [markdown]
# ## Route 150

# %%
lwk = wk[(wk['LINEID'] == '150')]

# %%
lwk.shape
# Out:
# (182582, 22)

# %%
# Drop Route 150 rows from wk
wk.drop(wk[wk['LINEID'] == '150'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 219   2018-04-29  6656686            1          395            31200
# 220   2018-04-29  6656686            2          396            31253
# 221   2018-04-29  6656686            3          397            31282
# 222   2018-04-29  6656686            4          398            31314
# 223   2018-04-29  6656686            5          399            31340
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 219            31200           31200           31200    2172293  2018  ...
# 220            31253           31253           31253    2172293  2018  ...
# 221            31282           31282           31282    2172293  2018  ...
# 222            31314           31314           31314    2172293  2018  ...
# 223            31340           31340           31340    2172293  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (3030753, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_150_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 77A

# %%
lwk = wk[(wk['LINEID'] == '77A')]

# %%
lwk.shape
# Out:
# (367877, 22)

# %%
# Drop Route 77A rows from wk
wk.drop(wk[wk['LINEID'] == '77A'].index, inplace = True)

# %%
wk.head()
# Out:
#     DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 782   2018-04-29  6656993            2         2806            34270
# 783   2018-04-29  6656993            3         2807            34297
# 784   2018-04-29  6656993            4         2808            34337
# 785   2018-04-29  6656993            5          486            34407
# 786   2018-04-29  6656993            6          487            34461
#
#      PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 782            34270           34270           34270    1000154  2018  ...
# 783            34297           34297           34297    1000154  2018  ...
# 784            34337           34337           34337    1000154  2018  ...
# 785            34407           34407           34407    1000154  2018  ...
# 786            34461           34461           34461    1000154  2018  ...
#
#                     id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2662876, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_77A_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 18

# %%
lwk = wk[(wk['LINEID'] == '18')]

# %%
lwk.shape
# Out:
# (205883, 22)

# %%
# Drop Route 18 rows from wk
wk.drop(wk[wk['LINEID'] == '18'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2126   2018-04-29  6657454            1         2210            61800
# 2127   2018-04-29  6657454            2         2211            61887
# 2128   2018-04-29  6657454            3         2241            61966
# 2129   2018-04-29  6657454            4         2242            62006
# 2130   2018-04-29  6657454            5         2243            62107
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2126            61800           61800           61800    2868315  2018  ...
# 2127            61887           61887           61887    2868315  2018  ...
# 2128            61966           61966           61966    2868315  2018  ...
# 2129            62006           62006           62006    2868315  2018  ...
# 2130            62107           62107           62107    2868315  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2456993, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_18_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 26

# %%
lwk = wk[(wk['LINEID'] == '26')]

# %%
lwk.shape
# Out:
# (58386, 22)

# %%
# Drop Route 26 rows from wk
wk.drop(wk[wk['LINEID'] == '26'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2205   2018-04-29  6657806            1         7348            38400
# 2206   2018-04-29  6657806            3         3671            38568
# 2207   2018-04-29  6657806            4         3672            38591
# 2208   2018-04-29  6657806            5         3078            38743
# 2209   2018-04-29  6657806            6         3087            38827
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2205            38400           38400           38400    2868306  2018  ...
# 2206            38568           38568           38568    2868306  2018  ...
# 2207            38591           38591           38591    2868306  2018  ...
# 2208            38743           38743           38743    2868306  2018  ...
# 2209            38827           38827           38827    2868306  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2398607, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_26_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 102

# %%
lwk = wk[(wk['LINEID'] == '102')]

# %%
lwk.shape
# Out:
# (168502, 22)

# %%
# Drop Route 102 rows from wk
wk.drop(wk[wk['LINEID'] == '102'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2686   2018-04-29  6658073            4         6016            41726
# 2687   2018-04-29  6658073            5         6017            41803
# 2688   2018-04-29  6658073            6         7192            41832
# 2689   2018-04-29  6658073            7         4683            41889
# 2690   2018-04-29  6658073            8          107            41963
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2686            41726           41726           41726    2693189  2018  ...
# 2687            41803           41803           41803    2693189  2018  ...
# 2688            41832           41832           41832    2693189  2018  ...
# 2689            41889           41889           41889    2693189  2018  ...
# 2690            41963           41963           41963    2693189  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (2230105, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_102_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 13

# %%
lwk = wk[(wk['LINEID'] == '13')]

# %%
lwk.shape
# Out:
# (470753, 22)

# %%
# Drop Route 13 rows from wk
wk.drop(wk[wk['LINEID'] == '13'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2996   2018-04-29  6658204            1          324            56100
# 2997   2018-04-29  6658204            7         1634            56368
# 2998   2018-04-29  6658204            8         1635            56379
# 2999   2018-04-29  6658204            9         1636            56434
# 3000   2018-04-29  6658204           10         1637            56516
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 2996            56100           56100           56100    1000205  2018  ...
# 2997            56368           56368           56368    1000205  2018  ...
# 2998            56379           56379           56379    1000205  2018  ...
# 2999            56434           56434           56434    1000205  2018  ...
# 3000            56516           56516           56516    1000205  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1759352, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_13_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 27B

# %%
lwk = wk[(wk['LINEID'] == '27B')]

# %%
lwk.shape
# Out:
# (238751, 22)

# %%
# Drop Route 27B rows from wk
wk.drop(wk[wk['LINEID'] == '27B'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 4091   2018-04-29  6658822            1         7662            34200
# 4092   2018-04-29  6658822            2         7564            34314
# 4093   2018-04-29  6658822            3          340            34428
# 4094   2018-04-29  6658822            4          350            34542
# 4095   2018-04-29  6658822            5          351            34615
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 4091            34200           34200           34200    2534804  2018  ...
# 4092            34314           34314           34314    2534804  2018  ...
# 4093            34428           34428           34428    2534804  2018  ...
# 4094            34542           34542           34542    2534804  2018  ...
# 4095            34615           34615           34615    2534804  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1520601, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_27B_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 47

# %%
lwk = wk[(wk['LINEID'] == '47')]

# %%
lwk.shape
# Out:
# (84316, 22)

# %%
# Drop Route 47 rows from wk
wk.drop(wk[wk['LINEID'] == '47'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 8668   2018-04-29  6660466            1         4342            34200
# 8669   2018-04-29  6660466            2         4348            34286
# 8670   2018-04-29  6660466            3         7122            34411
# 8671   2018-04-29  6660466            4         7121            34470
# 8672   2018-04-29  6660466            5         7183            34498
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 8668            34200           34200           34200    1000696  2018  ...
# 8669            34286           34286           34286    1000696  2018  ...
# 8670            34411           34411           34411    1000696  2018  ...
# 8671            34470           34470           34470    1000696  2018  ...
# 8672            34498           34498           34498    1000696  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1436285, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_47_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 49

# %%
lwk = wk[(wk['LINEID'] == '49')]

# %%
lwk.shape
# Out:
# (138754, 22)

# %%
# Drop Route 49 rows from wk
wk.drop(wk[wk['LINEID'] == '49'].index, inplace = True)

# %%
wk.head()
# Out:
#      DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 9302   2018-04-29  6660605            1         7591            37200
# 9303   2018-04-29  6660605            3          496            37288
# 9304   2018-04-29  6660605            4         7490            37303
# 9305   2018-04-29  6660605            5          515            37370
# 9306   2018-04-29  6660605            6          516            37409
#
#       PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 9302            37200           37200           37200    1932324  2018  ...
# 9303            37288           37288           37288    1932324  2018  ...
# 9304            37303           37303           37303    1932324  2018  ...
# 9305            37370           37370           37370    1932324  2018  ...
# 9306            37409           37409           37409    1932324  2018  ...
#
#                      id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (1297531, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_49_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 130

# %%
lwk = wk[(wk['LINEID'] == '130')]

# %%
lwk.shape
# Out:
# (308145, 22)

# %%
# Drop Route 130 rows from wk
wk.drop(wk[wk['LINEID'] == '130'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 12004   2018-04-29  6661948            1         1380            50700
# 12005   2018-04-29  6661948            2         1381            50732
# 12006   2018-04-29  6661948            3         1406            50788
# 12007   2018-04-29  6661948            4         1407            50840
# 12008   2018-04-29  6661948            5         1409            50886
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 12004            50700           50700           50700    2868330  2018  ...
# 12005            50732           50732           50732    2868330  2018  ...
# 12006            50788           50788           50788    2868330  2018  ...
# 12007            50840           50840           50840    2868330  2018  ...
# 12008            50886           50886           50886    2868330  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (989386, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_130_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 17

# %%
lwk = wk[(wk['LINEID'] == '17')]

# %%
lwk.shape
# Out:
# (184134, 22)

# %%
# Drop Route 17 rows from wk
wk.drop(wk[wk['LINEID'] == '17'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 14843   2018-04-29  6663414            1         4167            37800
# 14844   2018-04-29  6663414            2         4170            37817
# 14845   2018-04-29  6663414            3         4153            37828
# 14846   2018-04-29  6663414            4         4154            37838
# 14847   2018-04-29  6663414            5         4416            37847
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 14843            37800           37800           37800    1932339  2018  ...
# 14844            37817           37817           37817    1932339  2018  ...
# 14845            37828           37828           37828    1932339  2018  ...
# 14846            37838           37838           37838    1932339  2018  ...
# 14847            37847           37847           37847    1932339  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (805252, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_17_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 185

# %%
lwk = wk[(wk['LINEID'] == '185')]

# %%
lwk.shape
# Out:
# (39125, 22)

# %%
# Drop Route 185 rows from wk
wk.drop(wk[wk['LINEID'] == '185'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 17802   2018-04-29  6664485            1         2270            37800
# 17803   2018-04-29  6664485            2         2274            37974
# 17804   2018-04-29  6664485            3         7601            38100
# 17805   2018-04-29  6664485            4         2508            38243
# 17806   2018-04-29  6664485            5         2278            38304
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 17802            37800           37800           37800    2693258  2018  ...
# 17803            37974           37974           37974    2693258  2018  ...
# 17804            38100           38100           38100    2693258  2018  ...
# 17805            38243           38243           38243    2693258  2018  ...
# 17806            38304           38304           38304    2693258  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (766127, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_185_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 53

# %%
lwk = wk[(wk['LINEID'] == '53')]

# %%
lwk.shape
# Out:
# (25333, 22)

# %%
# Drop Route 53 rows from wk
wk.drop(wk[wk['LINEID'] == '53'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 18213   2018-04-29  6665287            1         4657            32400
# 18214   2018-04-29  6665287            2         7279            32448
# 18215   2018-04-29  6665287            3         4658            32487
# 18216   2018-04-29  6665287            4         4659            32514
# 18217   2018-04-29  6665287            5         4660            32561
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 18213            32400           32400           32400    2172279  2018  ...
# 18214            32448           32448           32448    2172279  2018  ...
# 18215            32487           32487           32487    2172279  2018  ...
# 18216            32514           32514           32514    2172279  2018  ...
# 18217            32561           32561           32561    2172279  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (740794, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_53_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 184

# %%
lwk = wk[(wk['LINEID'] == '184')]

# %%
lwk.shape
# Out:
# (132418, 22)

# %%
# Drop Route 184 rows from wk
wk.drop(wk[wk['LINEID'] == '184'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 18880   2018-04-30  6651132            1         3605            26700
# 18881   2018-04-30  6651132            2         3606            26745
# 18882   2018-04-30  6651132            3         3607            26798
# 18883   2018-04-30  6651132            4         6051            26811
# 18884   2018-04-30  6651132            5         6053            26853
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 18880            26700           26700           26700    1001162  2018  ...
# 18881            26745           26745           26745    1001162  2018  ...
# 18882            26798           26798           26798    1001162  2018  ...
# 18883            26811           26811           26811    1001162  2018  ...
# 18884            26853           26853           26853    1001162  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (608376, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_184_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 142

# %%
lwk = wk[(wk['LINEID'] == '142')]

# %%
lwk.shape
# Out:
# (22635, 22)

# %%
# Drop Route 142 rows from wk
wk.drop(wk[wk['LINEID'] == '142'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 19547   2018-04-30  6651361            1         3980            28500
# 19548   2018-04-30  6651361            2         6089            28594
# 19549   2018-04-30  6651361            3         3981            28735
# 19550   2018-04-30  6651361            4         3982            28804
# 19551   2018-04-30  6651361            5         3983            28947
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 19547            28500           28500           28500    2693214  2018  ...
# 19548            28594           28594           28594    2693214  2018  ...
# 19549            28735           28735           28735    2693214  2018  ...
# 19550            28804           28804           28804    2693214  2018  ...
# 19551            28947           28947           28947    2693214  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (585741, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_142_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 66X

# %%
lwk = wk[(wk['LINEID'] == '66X')]

# %%
lwk.shape
# Out:
# (25916, 22)

# %%
# Drop Route 66X rows from wk
wk.drop(wk[wk['LINEID'] == '66X'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 19651   2018-04-30  6651366            1         7391            66600
# 19652   2018-04-30  6651366            2          493            66766
# 19653   2018-04-30  6651366            3          494            66894
# 19654   2018-04-30  6651366            4          495            67048
# 19655   2018-04-30  6651366            5          400            67172
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 19651            66600           66600           66600    2406866  2018  ...
# 19652            66766           66766           66766    2406866  2018  ...
# 19653            66894           66894           66894    2406866  2018  ...
# 19654            67048           67048           67048    2406866  2018  ...
# 19655            67172           67172           67172    2406866  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (559825, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66X_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Route 66A

# %%
lwk = wk[(wk['LINEID'] == '66A')]

# %%
lwk.shape
# Out:
# (67466, 22)

# %%
# Drop Route 66A rows from wk
wk.drop(wk[wk['LINEID'] == '66A'].index, inplace = True)

# %%
wk.head()
# Out:
#       DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 19744   2018-04-30  6651402            1         6290            27360
# 19745   2018-04-30  6651402            2         7120            27480
# 19746   2018-04-30  6651402            3         7119            27548
# 19747   2018-04-30  6651402            4         7127            27604
# 19748   2018-04-30  6651402            5         7143            27698
#
#        PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  VEHICLEID  year  ...  \
# 19744            27360           27360           27360    1000951  2018  ...
# 19745            27480           27480           27480    1000951  2018  ...
# 19746            27548           27548           27548    1000951  2018  ...
# 19747            27604           27604           27604    1000951  2018  ...
# 19748            27698           27698           27698    1000951  2018  ...
#
#                       id    trip_leave_id  LINEID  num_lineID DIRECTION  \
# ...

# %%
wk.shape
# Out:
# (492359, 22)

# %% [markdown]
# <h3>Send to CSV</h3>

# %%
# Send df to csv:
lwk.to_csv('v5_66A_tripLeave3_sp7.csv', index=False)

# %% [markdown]
# ## Continue v5_tripLeave3_route_split_8

# %%
# Send df to csv:
wk.to_csv('v5_tripLeave3_route_split_8.csv', index=False)
